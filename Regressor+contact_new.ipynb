# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
from torch_geometric.data import Data
print(os.getpid())
import sequenceHandler  
import importlib
importlib.reload(sequenceHandler)
from sequenceHandler import distance_map_PDB
import torch.nn as nn
from torch_geometric.nn import MessagePassing, LayerNorm
import torch.nn.functional as F
from sklearn.metrics import auc, precision_score, recall_score, f1_score, average_precision_score, roc_curve, precision_recall_curve
from torch_geometric.utils import softmax
# Out:
# 2044884

# %%
def sinusoidal_positional_encoding(N, d_model):
    pe = torch.zeros(N, d_model)
    position = torch.arange(0, N, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # shape [N, d_model]

# %%
# Build graph data for a single sequence
def build_graph(filename, sequence, score_map, distance_map=None, sep_min=0):
    
    N = len(sequence)

    # score map to tensor
    score_map = torch.tensor(score_map, dtype=torch.float)
    #score_map = torch.log(score_map + 1.0)  #renormalization to see again when we have more data
    #score_map = (score_map - score_map.mean()) / (score_map.std() + 1e-6)
    idx = torch.arange(N)
    i, j = torch.meshgrid(idx, idx, indexing='ij')  # shape [N, N]

    sep = torch.abs(i - j).float()
    sep_bucket = torch.clamp(sep, max=32).long()


    # masks
    not_self = i != j
    pair_mask = i < j
    long_range_ok = (torch.abs(i - j) >= sep_min)

    if distance_map is not None:
        distance_map = torch.tensor(distance_map, dtype=torch.float)
        distance_map=torch.log((distance_map)/8) #renormalization to see again when we have more data
        known = torch.isfinite(distance_map)
        labels = distance_map
    else:
        known = torch.ones((N, N), dtype=torch.bool)
        labels = torch.zeros((N, N), dtype=torch.float)

    edge_mask = known & long_range_ok

    # remove i == j
    valid = not_self

    src = i[valid]
    dst = j[valid]

    # after you create src, dst for all i != j
    edge_to_idx = {(int(s), int(d)): k for k, (s, d) in enumerate(zip(src.tolist(), dst.tolist()))}
    rev_edge_idx = torch.tensor([edge_to_idx[(int(d), int(s))] for s, d in zip(src.tolist(), dst.tolist())],dtype=torch.long)

    edge_index = torch.stack([src, dst], dim=0)

    #edge_attr = score_map[valid].unsqueeze(-1)
    y = labels[valid].unsqueeze(-1)

    mask = edge_mask[valid]
    pair_mask = pair_mask[valid]

    x = sinusoidal_positional_encoding(N, d_model=16)

    return Data(
        x=x,
        edge_index=edge_index,
        #edge_attr=edge_attr,
        edge_attr = torch.stack([score_map[valid],sep_bucket[valid].float()], dim=-1),
        y=y,
        edge_mask=mask,
        pair_mask=pair_mask,
        rev_edge_idx=rev_edge_idx,
        filename=filename,
        L=N
    )

# %%
folder_path = "Data_C_alpha"

all_data = []
for file in os.listdir(folder_path):
    if file.endswith(".pkl"):
        full_path = os.path.join(folder_path, file)
        
        with open(full_path, "rb") as f:
            loaded = pickle.load(f)

        filename=str(file)
        sequence=loaded['sequence']
        distance_map=loaded['distance_map']
        contact_map_DCA=loaded['dca']
        data = build_graph(filename,sequence, contact_map_DCA, distance_map)
        all_data.append(data)


from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

# train_loader=DataLoader(all_data, batch_size=1, shuffle=True) 
# test_loader=DataLoader(all_data, batch_size=1, shuffle=True) 

train_data, test_data = train_test_split(all_data, test_size=0.2, random_state=0)


train_loader = DataLoader(train_data, batch_size=1, shuffle=True) 
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# %%
print(train_loader)

with torch.no_grad():
    for batch in train_loader:
        print(batch)
# Out:
# <torch_geometric.loader.dataloader.DataLoader object at 0x737a86192cf0>
# DataBatch(x=[176, 16], edge_index=[2, 30800], edge_attr=[30800, 2], y=[30800, 1], edge_mask=[30800], pair_mask=[30800], rev_edge_idx=[30800], filename=[1], L=[1], batch=[176], ptr=[2])
# DataBatch(x=[213, 16], edge_index=[2, 45156], edge_attr=[45156, 2], y=[45156, 1], edge_mask=[45156], pair_mask=[45156], rev_edge_idx=[45156], filename=[1], L=[1], batch=[213], ptr=[2])
# DataBatch(x=[70, 16], edge_index=[2, 4830], edge_attr=[4830, 2], y=[4830, 1], edge_mask=[4830], pair_mask=[4830], rev_edge_idx=[4830], filename=[1], L=[1], batch=[70], ptr=[2])
# DataBatch(x=[287, 16], edge_index=[2, 82082], edge_attr=[82082, 2], y=[82082, 1], edge_mask=[82082], pair_mask=[82082], rev_edge_idx=[82082], filename=[1], L=[1], batch=[287], ptr=[2])
# DataBatch(x=[108, 16], edge_index=[2, 11556], edge_attr=[11556, 2], y=[11556, 1], edge_mask=[11556], pair_mask=[11556], rev_edge_idx=[11556], filename=[1], L=[1], batch=[108], ptr=[2])
# DataBatch(x=[278, 16], edge_index=[2, 77006], edge_attr=[77006, 2], y=[77006, 1], edge_mask=[77006], pair_mask=[77006], rev_edge_idx=[77006], filename=[1], L=[1], batch=[278], ptr=[2])
# DataBatch(x=[120, 16], edge_index=[2, 14280], edge_attr=[14280, 2], y=[14280, 1], edge_mask=[14280], pair_mask=[14280], rev_edge_idx=[14280], filename=[1], L=[1], batch=[120], ptr=[2])
# DataBatch(x=[256, 16], edge_index=[2, 65280], edge_attr=[65280, 2], y=[65280, 1], edge_mask=[65280], pair_mask=[65280], rev_edge_idx=[65280], filename=[1], L=[1], batch=[256], ptr=[2])
# DataBatch(x=[159, 16], edge_index=[2, 25122], edge_attr=[25122, 2], y=[25122, 1], edge_mask=[25122], pair_mask=[25122], rev_edge_idx=[25122], filename=[1], L=[1], batch=[159], ptr=[2])
# DataBatch(x=[274, 16], edge_index=[2, 74802], edge_attr=[74802, 2], y=[74802, 1], edge_mask=[74802], pair_mask=[74802], rev_edge_idx=[74802], filename=[1], L=[1], batch=[274], ptr=[2])
# DataBatch(x=[101, 16], edge_index=[2, 10100], edge_attr=[10100, 2], y=[10100, 1], edge_mask=[10100], pair_mask=[10100], rev_edge_idx=[10100], filename=[1], L=[1], batch=[101], ptr=[2])
# DataBatch(x=[191, 16], edge_index=[2, 36290], edge_attr=[36290, 2], y=[36290, 1], edge_mask=[36290], pair_mask=[36290], rev_edge_idx=[36290], filename=[1], L=[1], batch=[191], ptr=[2])
# DataBatch(x=[176, 16], edge_index=[2, 30800], edge_attr=[30800, 2], y=[30800, 1], edge_mask=[30800], pair_mask=[30800], rev_edge_idx=[30800], filename=[1], L=[1], batch=[176], ptr=[2])
# DataBatch(x=[182, 16], edge_index=[2, 32942], edge_attr=[32942, 2], y=[32942, 1], edge_mask=[32942], pair_mask=[32942], rev_edge_idx=[32942], filename=[1], L=[1], batch=[182], ptr=[2])
# DataBatch(x=[436, 16], edge_index=[2, 189660], edge_attr=[189660, 2], y=[189660, 1], edge_mask=[189660], pair_mask=[189660], rev_edge_idx=[189660], filename=[1], L=[1], batch=[436], ptr=[2])
# DataBatch(x=[184, 16], edge_index=[2, 33672], edge_attr=[33672, 2], y=[33672, 1], edge_mask=[33672], pair_mask=[33672], rev_edge_idx=[33672], filename=[1], L=[1], batch=[184], ptr=[2])
# DataBatch(x=[408, 16], edge_index=[2, 166056], edge_attr=[166056, 2], y=[166056, 1], edge_mask=[166056], pair_mask=[166056], rev_edge_idx=[166056], filename=[1], L=[1], batch=[408], ptr=[2])
# DataBatch(x=[151, 16], edge_index=[2, 22650], edge_attr=[22650, 2], y=[22650, 1], edge_mask=[22650], pair_mask=[22650], rev_edge_idx=[22650], filename=[1], L=[1], batch=[151], ptr=[2])
# DataBatch(x=[217, 16], edge_index=[2, 46872], edge_attr=[46872, 2], y=[46872, 1], edge_mask=[46872], pair_mask=[46872], rev_edge_idx=[46872], filename=[1], L=[1], batch=[217], ptr=[2])
# DataBatch(x=[356, 16], edge_index=[2, 126380], edge_attr=[126380, 2], y=[126380, 1], edge_mask=[126380], pair_mask=[126380], rev_edge_idx=[126380], filename=[1], L=[1], batch=[356], ptr=[2])
# DataBatch(x=[194, 16], edge_index=[2, 37442], edge_attr=[37442, 2], y=[37442, 1], edge_mask=[37442], pair_mask=[37442], rev_edge_idx=[37442], filename=[1], L=[1], batch=[194], ptr=[2])
# DataBatch(x=[464, 16], edge_index=[2, 214832], edge_attr=[214832, 2], y=[214832, 1], edge_mask=[214832], pair_mask=[214832], rev_edge_idx=[214832], filename=[1], L=[1], batch=[464], ptr=[2])
# DataBatch(x=[278, 16], edge_index=[2, 77006], edge_attr=[77006, 2], y=[77006, 1], edge_mask=[77006], pair_mask=[77006], rev_edge_idx=[77006], filename=[1], L=[1], batch=[278], ptr=[2])
# DataBatch(x=[194, 16], edge_index=[2, 37442], edge_attr=[37442, 2], y=[37442, 1], edge_mask=[37442], pair_mask=[37442], rev_edge_idx=[37442], filename=[1], L=[1], batch=[194], ptr=[2])
# DataBatch(x=[252, 16], edge_index=[2, 63252], edge_attr=[63252, 2], y=[63252, 1], edge_mask=[63252], pair_mask=[63252], rev_edge_idx=[63252], filename=[1], L=[1], batch=[252], ptr=[2])
# DataBatch(x=[124, 16], edge_index=[2, 15252], edge_attr=[15252, 2], y=[15252, 1], edge_mask=[15252], pair_mask=[15252], rev_edge_idx=[15252], filename=[1], L=[1], batch=[124], ptr=[2])
# DataBatch(x=[70, 16], edge_index=[2, 4830], edge_attr=[4830, 2], y=[4830, 1], edge_mask=[4830], pair_mask=[4830], rev_edge_idx=[4830], filename=[1], L=[1], batch=[70], ptr=[2])
# DataBatch(x=[112, 16], edge_index=[2, 12432], edge_attr=[12432, 2], y=[12432, 1], edge_mask=[12432], pair_mask=[12432], rev_edge_idx=[12432], filename=[1], L=[1], batch=[112], ptr=[2])
# DataBatch(x=[48, 16], edge_index=[2, 2256], edge_attr=[2256, 2], y=[2256, 1], edge_mask=[2256], pair_mask=[2256], rev_edge_idx=[2256], filename=[1], L=[1], batch=[48], ptr=[2])
# DataBatch(x=[263, 16], edge_index=[2, 68906], edge_attr=[68906, 2], y=[68906, 1], edge_mask=[68906], pair_mask=[68906], rev_edge_idx=[68906], filename=[1], L=[1], batch=[263], ptr=[2])
# DataBatch(x=[36, 16], edge_index=[2, 1260], edge_attr=[1260, 2], y=[1260, 1], edge_mask=[1260], pair_mask=[1260], rev_edge_idx=[1260], filename=[1], L=[1], batch=[36], ptr=[2])
# DataBatch(x=[117, 16], edge_index=[2, 13572], edge_attr=[13572, 2], y=[13572, 1], edge_mask=[13572], pair_mask=[13572], rev_edge_idx=[13572], filename=[1], L=[1], batch=[117], ptr=[2])
# DataBatch(x=[414, 16], edge_index=[2, 170982], edge_attr=[170982, 2], y=[170982, 1], edge_mask=[170982], pair_mask=[170982], rev_edge_idx=[170982], filename=[1], L=[1], batch=[414], ptr=[2])
# DataBatch(x=[135, 16], edge_index=[2, 18090], edge_attr=[18090, 2], y=[18090, 1], edge_mask=[18090], pair_mask=[18090], rev_edge_idx=[18090], filename=[1], L=[1], batch=[135], ptr=[2])
# DataBatch(x=[93, 16], edge_index=[2, 8556], edge_attr=[8556, 2], y=[8556, 1], edge_mask=[8556], pair_mask=[8556], rev_edge_idx=[8556], filename=[1], L=[1], batch=[93], ptr=[2])
# DataBatch(x=[82, 16], edge_index=[2, 6642], edge_attr=[6642, 2], y=[6642, 1], edge_mask=[6642], pair_mask=[6642], rev_edge_idx=[6642], filename=[1], L=[1], batch=[82], ptr=[2])
# DataBatch(x=[489, 16], edge_index=[2, 238632], edge_attr=[238632, 2], y=[238632, 1], edge_mask=[238632], pair_mask=[238632], rev_edge_idx=[238632], filename=[1], L=[1], batch=[489], ptr=[2])
# DataBatch(x=[174, 16], edge_index=[2, 30102], edge_attr=[30102, 2], y=[30102, 1], edge_mask=[30102], pair_mask=[30102], rev_edge_idx=[30102], filename=[1], L=[1], batch=[174], ptr=[2])
# DataBatch(x=[109, 16], edge_index=[2, 11772], edge_attr=[11772, 2], y=[11772, 1], edge_mask=[11772], pair_mask=[11772], rev_edge_idx=[11772], filename=[1], L=[1], batch=[109], ptr=[2])
# DataBatch(x=[36, 16], edge_index=[2, 1260], edge_attr=[1260, 2], y=[1260, 1], edge_mask=[1260], pair_mask=[1260], rev_edge_idx=[1260], filename=[1], L=[1], batch=[36], ptr=[2])
# DataBatch(x=[133, 16], edge_index=[2, 17556], edge_attr=[17556, 2], y=[17556, 1], edge_mask=[17556], pair_mask=[17556], rev_edge_idx=[17556], filename=[1], L=[1], batch=[133], ptr=[2])
# DataBatch(x=[71, 16], edge_index=[2, 4970], edge_attr=[4970, 2], y=[4970, 1], edge_mask=[4970], pair_mask=[4970], rev_edge_idx=[4970], filename=[1], L=[1], batch=[71], ptr=[2])
# DataBatch(x=[130, 16], edge_index=[2, 16770], edge_attr=[16770, 2], y=[16770, 1], edge_mask=[16770], pair_mask=[16770], rev_edge_idx=[16770], filename=[1], L=[1], batch=[130], ptr=[2])
# DataBatch(x=[137, 16], edge_index=[2, 18632], edge_attr=[18632, 2], y=[18632, 1], edge_mask=[18632], pair_mask=[18632], rev_edge_idx=[18632], filename=[1], L=[1], batch=[137], ptr=[2])
# DataBatch(x=[68, 16], edge_index=[2, 4556], edge_attr=[4556, 2], y=[4556, 1], edge_mask=[4556], pair_mask=[4556], rev_edge_idx=[4556], filename=[1], L=[1], batch=[68], ptr=[2])
# DataBatch(x=[103, 16], edge_index=[2, 10506], edge_attr=[10506, 2], y=[10506, 1], edge_mask=[10506], pair_mask=[10506], rev_edge_idx=[10506], filename=[1], L=[1], batch=[103], ptr=[2])
# DataBatch(x=[199, 16], edge_index=[2, 39402], edge_attr=[39402, 2], y=[39402, 1], edge_mask=[39402], pair_mask=[39402], rev_edge_idx=[39402], filename=[1], L=[1], batch=[199], ptr=[2])
# DataBatch(x=[114, 16], edge_index=[2, 12882], edge_attr=[12882, 2], y=[12882, 1], edge_mask=[12882], pair_mask=[12882], rev_edge_idx=[12882], filename=[1], L=[1], batch=[114], ptr=[2])
# DataBatch(x=[242, 16], edge_index=[2, 58322], edge_attr=[58322, 2], y=[58322, 1], edge_mask=[58322], pair_mask=[58322], rev_edge_idx=[58322], filename=[1], L=[1], batch=[242], ptr=[2])
# DataBatch(x=[183, 16], edge_index=[2, 33306], edge_attr=[33306, 2], y=[33306, 1], edge_mask=[33306], pair_mask=[33306], rev_edge_idx=[33306], filename=[1], L=[1], batch=[183], ptr=[2])
# DataBatch(x=[381, 16], edge_index=[2, 144780], edge_attr=[144780, 2], y=[144780, 1], edge_mask=[144780], pair_mask=[144780], rev_edge_idx=[144780], filename=[1], L=[1], batch=[381], ptr=[2])
# DataBatch(x=[292, 16], edge_index=[2, 84972], edge_attr=[84972, 2], y=[84972, 1], edge_mask=[84972], pair_mask=[84972], rev_edge_idx=[84972], filename=[1], L=[1], batch=[292], ptr=[2])
# DataBatch(x=[128, 16], edge_index=[2, 16256], edge_attr=[16256, 2], y=[16256, 1], edge_mask=[16256], pair_mask=[16256], rev_edge_idx=[16256], filename=[1], L=[1], batch=[128], ptr=[2])
# DataBatch(x=[63, 16], edge_index=[2, 3906], edge_attr=[3906, 2], y=[3906, 1], edge_mask=[3906], pair_mask=[3906], rev_edge_idx=[3906], filename=[1], L=[1], batch=[63], ptr=[2])
# DataBatch(x=[113, 16], edge_index=[2, 12656], edge_attr=[12656, 2], y=[12656, 1], edge_mask=[12656], pair_mask=[12656], rev_edge_idx=[12656], filename=[1], L=[1], batch=[113], ptr=[2])
# DataBatch(x=[127, 16], edge_index=[2, 16002], edge_attr=[16002, 2], y=[16002, 1], edge_mask=[16002], pair_mask=[16002], rev_edge_idx=[16002], filename=[1], L=[1], batch=[127], ptr=[2])
# DataBatch(x=[191, 16], edge_index=[2, 36290], edge_attr=[36290, 2], y=[36290, 1], edge_mask=[36290], pair_mask=[36290], rev_edge_idx=[36290], filename=[1], L=[1], batch=[191], ptr=[2])
# DataBatch(x=[191, 16], edge_index=[2, 36290], edge_attr=[36290, 2], y=[36290, 1], edge_mask=[36290], pair_mask=[36290], rev_edge_idx=[36290], filename=[1], L=[1], batch=[191], ptr=[2])
# DataBatch(x=[157, 16], edge_index=[2, 24492], edge_attr=[24492, 2], y=[24492, 1], edge_mask=[24492], pair_mask=[24492], rev_edge_idx=[24492], filename=[1], L=[1], batch=[157], ptr=[2])
# DataBatch(x=[383, 16], edge_index=[2, 146306], edge_attr=[146306, 2], y=[146306, 1], edge_mask=[146306], pair_mask=[146306], rev_edge_idx=[146306], filename=[1], L=[1], batch=[383], ptr=[2])
# DataBatch(x=[129, 16], edge_index=[2, 16512], edge_attr=[16512, 2], y=[16512, 1], edge_mask=[16512], pair_mask=[16512], rev_edge_idx=[16512], filename=[1], L=[1], batch=[129], ptr=[2])
# DataBatch(x=[203, 16], edge_index=[2, 41006], edge_attr=[41006, 2], y=[41006, 1], edge_mask=[41006], pair_mask=[41006], rev_edge_idx=[41006], filename=[1], L=[1], batch=[203], ptr=[2])
# DataBatch(x=[152, 16], edge_index=[2, 22952], edge_attr=[22952, 2], y=[22952, 1], edge_mask=[22952], pair_mask=[22952], rev_edge_idx=[22952], filename=[1], L=[1], batch=[152], ptr=[2])
# DataBatch(x=[123, 16], edge_index=[2, 15006], edge_attr=[15006, 2], y=[15006, 1], edge_mask=[15006], pair_mask=[15006], rev_edge_idx=[15006], filename=[1], L=[1], batch=[123], ptr=[2])
# DataBatch(x=[84, 16], edge_index=[2, 6972], edge_attr=[6972, 2], y=[6972, 1], edge_mask=[6972], pair_mask=[6972], rev_edge_idx=[6972], filename=[1], L=[1], batch=[84], ptr=[2])
# DataBatch(x=[187, 16], edge_index=[2, 34782], edge_attr=[34782, 2], y=[34782, 1], edge_mask=[34782], pair_mask=[34782], rev_edge_idx=[34782], filename=[1], L=[1], batch=[187], ptr=[2])
# DataBatch(x=[110, 16], edge_index=[2, 11990], edge_attr=[11990, 2], y=[11990, 1], edge_mask=[11990], pair_mask=[11990], rev_edge_idx=[11990], filename=[1], L=[1], batch=[110], ptr=[2])
# DataBatch(x=[69, 16], edge_index=[2, 4692], edge_attr=[4692, 2], y=[4692, 1], edge_mask=[4692], pair_mask=[4692], rev_edge_idx=[4692], filename=[1], L=[1], batch=[69], ptr=[2])
# DataBatch(x=[107, 16], edge_index=[2, 11342], edge_attr=[11342, 2], y=[11342, 1], edge_mask=[11342], pair_mask=[11342], rev_edge_idx=[11342], filename=[1], L=[1], batch=[107], ptr=[2])
# DataBatch(x=[95, 16], edge_index=[2, 8930], edge_attr=[8930, 2], y=[8930, 1], edge_mask=[8930], pair_mask=[8930], rev_edge_idx=[8930], filename=[1], L=[1], batch=[95], ptr=[2])
# DataBatch(x=[70, 16], edge_index=[2, 4830], edge_attr=[4830, 2], y=[4830, 1], edge_mask=[4830], pair_mask=[4830], rev_edge_idx=[4830], filename=[1], L=[1], batch=[70], ptr=[2])
# DataBatch(x=[131, 16], edge_index=[2, 17030], edge_attr=[17030, 2], y=[17030, 1], edge_mask=[17030], pair_mask=[17030], rev_edge_idx=[17030], filename=[1], L=[1], batch=[131], ptr=[2])
# DataBatch(x=[108, 16], edge_index=[2, 11556], edge_attr=[11556, 2], y=[11556, 1], edge_mask=[11556], pair_mask=[11556], rev_edge_idx=[11556], filename=[1], L=[1], batch=[108], ptr=[2])
# DataBatch(x=[81, 16], edge_index=[2, 6480], edge_attr=[6480, 2], y=[6480, 1], edge_mask=[6480], pair_mask=[6480], rev_edge_idx=[6480], filename=[1], L=[1], batch=[81], ptr=[2])
# DataBatch(x=[148, 16], edge_index=[2, 21756], edge_attr=[21756, 2], y=[21756, 1], edge_mask=[21756], pair_mask=[21756], rev_edge_idx=[21756], filename=[1], L=[1], batch=[148], ptr=[2])
# DataBatch(x=[237, 16], edge_index=[2, 55932], edge_attr=[55932, 2], y=[55932, 1], edge_mask=[55932], pair_mask=[55932], rev_edge_idx=[55932], filename=[1], L=[1], batch=[237], ptr=[2])
# DataBatch(x=[149, 16], edge_index=[2, 22052], edge_attr=[22052, 2], y=[22052, 1], edge_mask=[22052], pair_mask=[22052], rev_edge_idx=[22052], filename=[1], L=[1], batch=[149], ptr=[2])
# DataBatch(x=[244, 16], edge_index=[2, 59292], edge_attr=[59292, 2], y=[59292, 1], edge_mask=[59292], pair_mask=[59292], rev_edge_idx=[59292], filename=[1], L=[1], batch=[244], ptr=[2])
# DataBatch(x=[438, 16], edge_index=[2, 191406], edge_attr=[191406, 2], y=[191406, 1], edge_mask=[191406], pair_mask=[191406], rev_edge_idx=[191406], filename=[1], L=[1], batch=[438], ptr=[2])
# DataBatch(x=[108, 16], edge_index=[2, 11556], edge_attr=[11556, 2], y=[11556, 1], edge_mask=[11556], pair_mask=[11556], rev_edge_idx=[11556], filename=[1], L=[1], batch=[108], ptr=[2])
# DataBatch(x=[420, 16], edge_index=[2, 175980], edge_attr=[175980, 2], y=[175980, 1], edge_mask=[175980], pair_mask=[175980], rev_edge_idx=[175980], filename=[1], L=[1], batch=[420], ptr=[2])
# DataBatch(x=[76, 16], edge_index=[2, 5700], edge_attr=[5700, 2], y=[5700, 1], edge_mask=[5700], pair_mask=[5700], rev_edge_idx=[5700], filename=[1], L=[1], batch=[76], ptr=[2])
# DataBatch(x=[142, 16], edge_index=[2, 20022], edge_attr=[20022, 2], y=[20022, 1], edge_mask=[20022], pair_mask=[20022], rev_edge_idx=[20022], filename=[1], L=[1], batch=[142], ptr=[2])
# DataBatch(x=[281, 16], edge_index=[2, 78680], edge_attr=[78680, 2], y=[78680, 1], edge_mask=[78680], pair_mask=[78680], rev_edge_idx=[78680], filename=[1], L=[1], batch=[281], ptr=[2])
# DataBatch(x=[182, 16], edge_index=[2, 32942], edge_attr=[32942, 2], y=[32942, 1], edge_mask=[32942], pair_mask=[32942], rev_edge_idx=[32942], filename=[1], L=[1], batch=[182], ptr=[2])
# DataBatch(x=[232, 16], edge_index=[2, 53592], edge_attr=[53592, 2], y=[53592, 1], edge_mask=[53592], pair_mask=[53592], rev_edge_idx=[53592], filename=[1], L=[1], batch=[232], ptr=[2])
# DataBatch(x=[154, 16], edge_index=[2, 23562], edge_attr=[23562, 2], y=[23562, 1], edge_mask=[23562], pair_mask=[23562], rev_edge_idx=[23562], filename=[1], L=[1], batch=[154], ptr=[2])
# DataBatch(x=[161, 16], edge_index=[2, 25760], edge_attr=[25760, 2], y=[25760, 1], edge_mask=[25760], pair_mask=[25760], rev_edge_idx=[25760], filename=[1], L=[1], batch=[161], ptr=[2])
# DataBatch(x=[175, 16], edge_index=[2, 30450], edge_attr=[30450, 2], y=[30450, 1], edge_mask=[30450], pair_mask=[30450], rev_edge_idx=[30450], filename=[1], L=[1], batch=[175], ptr=[2])
# DataBatch(x=[32, 16], edge_index=[2, 992], edge_attr=[992, 2], y=[992, 1], edge_mask=[992], pair_mask=[992], rev_edge_idx=[992], filename=[1], L=[1], batch=[32], ptr=[2])
# DataBatch(x=[102, 16], edge_index=[2, 10302], edge_attr=[10302, 2], y=[10302, 1], edge_mask=[10302], pair_mask=[10302], rev_edge_idx=[10302], filename=[1], L=[1], batch=[102], ptr=[2])
# DataBatch(x=[79, 16], edge_index=[2, 6162], edge_attr=[6162, 2], y=[6162, 1], edge_mask=[6162], pair_mask=[6162], rev_edge_idx=[6162], filename=[1], L=[1], batch=[79], ptr=[2])
# DataBatch(x=[104, 16], edge_index=[2, 10712], edge_attr=[10712, 2], y=[10712, 1], edge_mask=[10712], pair_mask=[10712], rev_edge_idx=[10712], filename=[1], L=[1], batch=[104], ptr=[2])
# DataBatch(x=[68, 16], edge_index=[2, 4556], edge_attr=[4556, 2], y=[4556, 1], edge_mask=[4556], pair_mask=[4556], rev_edge_idx=[4556], filename=[1], L=[1], batch=[68], ptr=[2])
# DataBatch(x=[86, 16], edge_index=[2, 7310], edge_attr=[7310, 2], y=[7310, 1], edge_mask=[7310], pair_mask=[7310], rev_edge_idx=[7310], filename=[1], L=[1], batch=[86], ptr=[2])
# DataBatch(x=[136, 16], edge_index=[2, 18360], edge_attr=[18360, 2], y=[18360, 1], edge_mask=[18360], pair_mask=[18360], rev_edge_idx=[18360], filename=[1], L=[1], batch=[136], ptr=[2])
# DataBatch(x=[231, 16], edge_index=[2, 53130], edge_attr=[53130, 2], y=[53130, 1], edge_mask=[53130], pair_mask=[53130], rev_edge_idx=[53130], filename=[1], L=[1], batch=[231], ptr=[2])
# DataBatch(x=[368, 16], edge_index=[2, 135056], edge_attr=[135056, 2], y=[135056, 1], edge_mask=[135056], pair_mask=[135056], rev_edge_idx=[135056], filename=[1], L=[1], batch=[368], ptr=[2])
# DataBatch(x=[133, 16], edge_index=[2, 17556], edge_attr=[17556, 2], y=[17556, 1], edge_mask=[17556], pair_mask=[17556], rev_edge_idx=[17556], filename=[1], L=[1], batch=[133], ptr=[2])
# DataBatch(x=[71, 16], edge_index=[2, 4970], edge_attr=[4970, 2], y=[4970, 1], edge_mask=[4970], pair_mask=[4970], rev_edge_idx=[4970], filename=[1], L=[1], batch=[71], ptr=[2])
# DataBatch(x=[186, 16], edge_index=[2, 34410], edge_attr=[34410, 2], y=[34410, 1], edge_mask=[34410], pair_mask=[34410], rev_edge_idx=[34410], filename=[1], L=[1], batch=[186], ptr=[2])
# DataBatch(x=[191, 16], edge_index=[2, 36290], edge_attr=[36290, 2], y=[36290, 1], edge_mask=[36290], pair_mask=[36290], rev_edge_idx=[36290], filename=[1], L=[1], batch=[191], ptr=[2])
# DataBatch(x=[174, 16], edge_index=[2, 30102], edge_attr=[30102, 2], y=[30102, 1], edge_mask=[30102], pair_mask=[30102], rev_edge_idx=[30102], filename=[1], L=[1], batch=[174], ptr=[2])
# DataBatch(x=[174, 16], edge_index=[2, 30102], edge_attr=[30102, 2], y=[30102, 1], edge_mask=[30102], pair_mask=[30102], rev_edge_idx=[30102], filename=[1], L=[1], batch=[174], ptr=[2])
# DataBatch(x=[204, 16], edge_index=[2, 41412], edge_attr=[41412, 2], y=[41412, 1], edge_mask=[41412], pair_mask=[41412], rev_edge_idx=[41412], filename=[1], L=[1], batch=[204], ptr=[2])
# DataBatch(x=[449, 16], edge_index=[2, 201152], edge_attr=[201152, 2], y=[201152, 1], edge_mask=[201152], pair_mask=[201152], rev_edge_idx=[201152], filename=[1], L=[1], batch=[449], ptr=[2])
# DataBatch(x=[72, 16], edge_index=[2, 5112], edge_attr=[5112, 2], y=[5112, 1], edge_mask=[5112], pair_mask=[5112], rev_edge_idx=[5112], filename=[1], L=[1], batch=[72], ptr=[2])
# DataBatch(x=[438, 16], edge_index=[2, 191406], edge_attr=[191406, 2], y=[191406, 1], edge_mask=[191406], pair_mask=[191406], rev_edge_idx=[191406], filename=[1], L=[1], batch=[438], ptr=[2])
# DataBatch(x=[99, 16], edge_index=[2, 9702], edge_attr=[9702, 2], y=[9702, 1], edge_mask=[9702], pair_mask=[9702], rev_edge_idx=[9702], filename=[1], L=[1], batch=[99], ptr=[2])
# DataBatch(x=[77, 16], edge_index=[2, 5852], edge_attr=[5852, 2], y=[5852, 1], edge_mask=[5852], pair_mask=[5852], rev_edge_idx=[5852], filename=[1], L=[1], batch=[77], ptr=[2])
# DataBatch(x=[125, 16], edge_index=[2, 15500], edge_attr=[15500, 2], y=[15500, 1], edge_mask=[15500], pair_mask=[15500], rev_edge_idx=[15500], filename=[1], L=[1], batch=[125], ptr=[2])
# DataBatch(x=[101, 16], edge_index=[2, 10100], edge_attr=[10100, 2], y=[10100, 1], edge_mask=[10100], pair_mask=[10100], rev_edge_idx=[10100], filename=[1], L=[1], batch=[101], ptr=[2])
# DataBatch(x=[97, 16], edge_index=[2, 9312], edge_attr=[9312, 2], y=[9312, 1], edge_mask=[9312], pair_mask=[9312], rev_edge_idx=[9312], filename=[1], L=[1], batch=[97], ptr=[2])
# DataBatch(x=[107, 16], edge_index=[2, 11342], edge_attr=[11342, 2], y=[11342, 1], edge_mask=[11342], pair_mask=[11342], rev_edge_idx=[11342], filename=[1], L=[1], batch=[107], ptr=[2])
# DataBatch(x=[354, 16], edge_index=[2, 124962], edge_attr=[124962, 2], y=[124962, 1], edge_mask=[124962], pair_mask=[124962], rev_edge_idx=[124962], filename=[1], L=[1], batch=[354], ptr=[2])
# DataBatch(x=[36, 16], edge_index=[2, 1260], edge_attr=[1260, 2], y=[1260, 1], edge_mask=[1260], pair_mask=[1260], rev_edge_idx=[1260], filename=[1], L=[1], batch=[36], ptr=[2])
# DataBatch(x=[102, 16], edge_index=[2, 10302], edge_attr=[10302, 2], y=[10302, 1], edge_mask=[10302], pair_mask=[10302], rev_edge_idx=[10302], filename=[1], L=[1], batch=[102], ptr=[2])
# DataBatch(x=[97, 16], edge_index=[2, 9312], edge_attr=[9312, 2], y=[9312, 1], edge_mask=[9312], pair_mask=[9312], rev_edge_idx=[9312], filename=[1], L=[1], batch=[97], ptr=[2])
# DataBatch(x=[128, 16], edge_index=[2, 16256], edge_attr=[16256, 2], y=[16256, 1], edge_mask=[16256], pair_mask=[16256], rev_edge_idx=[16256], filename=[1], L=[1], batch=[128], ptr=[2])
# DataBatch(x=[305, 16], edge_index=[2, 92720], edge_attr=[92720, 2], y=[92720, 1], edge_mask=[92720], pair_mask=[92720], rev_edge_idx=[92720], filename=[1], L=[1], batch=[305], ptr=[2])
# DataBatch(x=[39, 16], edge_index=[2, 1482], edge_attr=[1482, 2], y=[1482, 1], edge_mask=[1482], pair_mask=[1482], rev_edge_idx=[1482], filename=[1], L=[1], batch=[39], ptr=[2])
# DataBatch(x=[256, 16], edge_index=[2, 65280], edge_attr=[65280, 2], y=[65280, 1], edge_mask=[65280], pair_mask=[65280], rev_edge_idx=[65280], filename=[1], L=[1], batch=[256], ptr=[2])
# DataBatch(x=[173, 16], edge_index=[2, 29756], edge_attr=[29756, 2], y=[29756, 1], edge_mask=[29756], pair_mask=[29756], rev_edge_idx=[29756], filename=[1], L=[1], batch=[173], ptr=[2])
# DataBatch(x=[418, 16], edge_index=[2, 174306], edge_attr=[174306, 2], y=[174306, 1], edge_mask=[174306], pair_mask=[174306], rev_edge_idx=[174306], filename=[1], L=[1], batch=[418], ptr=[2])
# DataBatch(x=[64, 16], edge_index=[2, 4032], edge_attr=[4032, 2], y=[4032, 1], edge_mask=[4032], pair_mask=[4032], rev_edge_idx=[4032], filename=[1], L=[1], batch=[64], ptr=[2])
# DataBatch(x=[75, 16], edge_index=[2, 5550], edge_attr=[5550, 2], y=[5550, 1], edge_mask=[5550], pair_mask=[5550], rev_edge_idx=[5550], filename=[1], L=[1], batch=[75], ptr=[2])
# DataBatch(x=[167, 16], edge_index=[2, 27722], edge_attr=[27722, 2], y=[27722, 1], edge_mask=[27722], pair_mask=[27722], rev_edge_idx=[27722], filename=[1], L=[1], batch=[167], ptr=[2])
# DataBatch(x=[62, 16], edge_index=[2, 3782], edge_attr=[3782, 2], y=[3782, 1], edge_mask=[3782], pair_mask=[3782], rev_edge_idx=[3782], filename=[1], L=[1], batch=[62], ptr=[2])
# DataBatch(x=[139, 16], edge_index=[2, 19182], edge_attr=[19182, 2], y=[19182, 1], edge_mask=[19182], pair_mask=[19182], rev_edge_idx=[19182], filename=[1], L=[1], batch=[139], ptr=[2])
# DataBatch(x=[64, 16], edge_index=[2, 4032], edge_attr=[4032, 2], y=[4032, 1], edge_mask=[4032], pair_mask=[4032], rev_edge_idx=[4032], filename=[1], L=[1], batch=[64], ptr=[2])
# DataBatch(x=[151, 16], edge_index=[2, 22650], edge_attr=[22650, 2], y=[22650, 1], edge_mask=[22650], pair_mask=[22650], rev_edge_idx=[22650], filename=[1], L=[1], batch=[151], ptr=[2])
# DataBatch(x=[123, 16], edge_index=[2, 15006], edge_attr=[15006, 2], y=[15006, 1], edge_mask=[15006], pair_mask=[15006], rev_edge_idx=[15006], filename=[1], L=[1], batch=[123], ptr=[2])
# DataBatch(x=[78, 16], edge_index=[2, 6006], edge_attr=[6006, 2], y=[6006, 1], edge_mask=[6006], pair_mask=[6006], rev_edge_idx=[6006], filename=[1], L=[1], batch=[78], ptr=[2])
# DataBatch(x=[298, 16], edge_index=[2, 88506], edge_attr=[88506, 2], y=[88506, 1], edge_mask=[88506], pair_mask=[88506], rev_edge_idx=[88506], filename=[1], L=[1], batch=[298], ptr=[2])
# DataBatch(x=[244, 16], edge_index=[2, 59292], edge_attr=[59292, 2], y=[59292, 1], edge_mask=[59292], pair_mask=[59292], rev_edge_idx=[59292], filename=[1], L=[1], batch=[244], ptr=[2])
# DataBatch(x=[207, 16], edge_index=[2, 42642], edge_attr=[42642, 2], y=[42642, 1], edge_mask=[42642], pair_mask=[42642], rev_edge_idx=[42642], filename=[1], L=[1], batch=[207], ptr=[2])
# DataBatch(x=[68, 16], edge_index=[2, 4556], edge_attr=[4556, 2], y=[4556, 1], edge_mask=[4556], pair_mask=[4556], rev_edge_idx=[4556], filename=[1], L=[1], batch=[68], ptr=[2])
# DataBatch(x=[268, 16], edge_index=[2, 71556], edge_attr=[71556, 2], y=[71556, 1], edge_mask=[71556], pair_mask=[71556], rev_edge_idx=[71556], filename=[1], L=[1], batch=[268], ptr=[2])
# DataBatch(x=[193, 16], edge_index=[2, 37056], edge_attr=[37056, 2], y=[37056, 1], edge_mask=[37056], pair_mask=[37056], rev_edge_idx=[37056], filename=[1], L=[1], batch=[193], ptr=[2])
# DataBatch(x=[154, 16], edge_index=[2, 23562], edge_attr=[23562, 2], y=[23562, 1], edge_mask=[23562], pair_mask=[23562], rev_edge_idx=[23562], filename=[1], L=[1], batch=[154], ptr=[2])
# DataBatch(x=[135, 16], edge_index=[2, 18090], edge_attr=[18090, 2], y=[18090, 1], edge_mask=[18090], pair_mask=[18090], rev_edge_idx=[18090], filename=[1], L=[1], batch=[135], ptr=[2])
# DataBatch(x=[93, 16], edge_index=[2, 8556], edge_attr=[8556, 2], y=[8556, 1], edge_mask=[8556], pair_mask=[8556], rev_edge_idx=[8556], filename=[1], L=[1], batch=[93], ptr=[2])
# DataBatch(x=[82, 16], edge_index=[2, 6642], edge_attr=[6642, 2], y=[6642, 1], edge_mask=[6642], pair_mask=[6642], rev_edge_idx=[6642], filename=[1], L=[1], batch=[82], ptr=[2])
# DataBatch(x=[254, 16], edge_index=[2, 64262], edge_attr=[64262, 2], y=[64262, 1], edge_mask=[64262], pair_mask=[64262], rev_edge_idx=[64262], filename=[1], L=[1], batch=[254], ptr=[2])
# DataBatch(x=[221, 16], edge_index=[2, 48620], edge_attr=[48620, 2], y=[48620, 1], edge_mask=[48620], pair_mask=[48620], rev_edge_idx=[48620], filename=[1], L=[1], batch=[221], ptr=[2])
# DataBatch(x=[325, 16], edge_index=[2, 105300], edge_attr=[105300, 2], y=[105300, 1], edge_mask=[105300], pair_mask=[105300], rev_edge_idx=[105300], filename=[1], L=[1], batch=[325], ptr=[2])
# DataBatch(x=[96, 16], edge_index=[2, 9120], edge_attr=[9120, 2], y=[9120, 1], edge_mask=[9120], pair_mask=[9120], rev_edge_idx=[9120], filename=[1], L=[1], batch=[96], ptr=[2])
# DataBatch(x=[55, 16], edge_index=[2, 2970], edge_attr=[2970, 2], y=[2970, 1], edge_mask=[2970], pair_mask=[2970], rev_edge_idx=[2970], filename=[1], L=[1], batch=[55], ptr=[2])
# DataBatch(x=[206, 16], edge_index=[2, 42230], edge_attr=[42230, 2], y=[42230, 1], edge_mask=[42230], pair_mask=[42230], rev_edge_idx=[42230], filename=[1], L=[1], batch=[206], ptr=[2])
# DataBatch(x=[81, 16], edge_index=[2, 6480], edge_attr=[6480, 2], y=[6480, 1], edge_mask=[6480], pair_mask=[6480], rev_edge_idx=[6480], filename=[1], L=[1], batch=[81], ptr=[2])
# DataBatch(x=[106, 16], edge_index=[2, 11130], edge_attr=[11130, 2], y=[11130, 1], edge_mask=[11130], pair_mask=[11130], rev_edge_idx=[11130], filename=[1], L=[1], batch=[106], ptr=[2])
# DataBatch(x=[67, 16], edge_index=[2, 4422], edge_attr=[4422, 2], y=[4422, 1], edge_mask=[4422], pair_mask=[4422], rev_edge_idx=[4422], filename=[1], L=[1], batch=[67], ptr=[2])
# DataBatch(x=[247, 16], edge_index=[2, 60762], edge_attr=[60762, 2], y=[60762, 1], edge_mask=[60762], pair_mask=[60762], rev_edge_idx=[60762], filename=[1], L=[1], batch=[247], ptr=[2])
# DataBatch(x=[140, 16], edge_index=[2, 19460], edge_attr=[19460, 2], y=[19460, 1], edge_mask=[19460], pair_mask=[19460], rev_edge_idx=[19460], filename=[1], L=[1], batch=[140], ptr=[2])
# DataBatch(x=[88, 16], edge_index=[2, 7656], edge_attr=[7656, 2], y=[7656, 1], edge_mask=[7656], pair_mask=[7656], rev_edge_idx=[7656], filename=[1], L=[1], batch=[88], ptr=[2])
# DataBatch(x=[168, 16], edge_index=[2, 28056], edge_attr=[28056, 2], y=[28056, 1], edge_mask=[28056], pair_mask=[28056], rev_edge_idx=[28056], filename=[1], L=[1], batch=[168], ptr=[2])
# DataBatch(x=[113, 16], edge_index=[2, 12656], edge_attr=[12656, 2], y=[12656, 1], edge_mask=[12656], pair_mask=[12656], rev_edge_idx=[12656], filename=[1], L=[1], batch=[113], ptr=[2])
# DataBatch(x=[63, 16], edge_index=[2, 3906], edge_attr=[3906, 2], y=[3906, 1], edge_mask=[3906], pair_mask=[3906], rev_edge_idx=[3906], filename=[1], L=[1], batch=[63], ptr=[2])
# DataBatch(x=[103, 16], edge_index=[2, 10506], edge_attr=[10506, 2], y=[10506, 1], edge_mask=[10506], pair_mask=[10506], rev_edge_idx=[10506], filename=[1], L=[1], batch=[103], ptr=[2])
# DataBatch(x=[82, 16], edge_index=[2, 6642], edge_attr=[6642, 2], y=[6642, 1], edge_mask=[6642], pair_mask=[6642], rev_edge_idx=[6642], filename=[1], L=[1], batch=[82], ptr=[2])
# DataBatch(x=[245, 16], edge_index=[2, 59780], edge_attr=[59780, 2], y=[59780, 1], edge_mask=[59780], pair_mask=[59780], rev_edge_idx=[59780], filename=[1], L=[1], batch=[245], ptr=[2])
# DataBatch(x=[60, 16], edge_index=[2, 3540], edge_attr=[3540, 2], y=[3540, 1], edge_mask=[3540], pair_mask=[3540], rev_edge_idx=[3540], filename=[1], L=[1], batch=[60], ptr=[2])
# DataBatch(x=[47, 16], edge_index=[2, 2162], edge_attr=[2162, 2], y=[2162, 1], edge_mask=[2162], pair_mask=[2162], rev_edge_idx=[2162], filename=[1], L=[1], batch=[47], ptr=[2])
# DataBatch(x=[281, 16], edge_index=[2, 78680], edge_attr=[78680, 2], y=[78680, 1], edge_mask=[78680], pair_mask=[78680], rev_edge_idx=[78680], filename=[1], L=[1], batch=[281], ptr=[2])
# DataBatch(x=[180, 16], edge_index=[2, 32220], edge_attr=[32220, 2], y=[32220, 1], edge_mask=[32220], pair_mask=[32220], rev_edge_idx=[32220], filename=[1], L=[1], batch=[180], ptr=[2])
# DataBatch(x=[208, 16], edge_index=[2, 43056], edge_attr=[43056, 2], y=[43056, 1], edge_mask=[43056], pair_mask=[43056], rev_edge_idx=[43056], filename=[1], L=[1], batch=[208], ptr=[2])
# DataBatch(x=[277, 16], edge_index=[2, 76452], edge_attr=[76452, 2], y=[76452, 1], edge_mask=[76452], pair_mask=[76452], rev_edge_idx=[76452], filename=[1], L=[1], batch=[277], ptr=[2])
# DataBatch(x=[113, 16], edge_index=[2, 12656], edge_attr=[12656, 2], y=[12656, 1], edge_mask=[12656], pair_mask=[12656], rev_edge_idx=[12656], filename=[1], L=[1], batch=[113], ptr=[2])
# DataBatch(x=[57, 16], edge_index=[2, 3192], edge_attr=[3192, 2], y=[3192, 1], edge_mask=[3192], pair_mask=[3192], rev_edge_idx=[3192], filename=[1], L=[1], batch=[57], ptr=[2])
# DataBatch(x=[297, 16], edge_index=[2, 87912], edge_attr=[87912, 2], y=[87912, 1], edge_mask=[87912], pair_mask=[87912], rev_edge_idx=[87912], filename=[1], L=[1], batch=[297], ptr=[2])
# DataBatch(x=[54, 16], edge_index=[2, 2862], edge_attr=[2862, 2], y=[2862, 1], edge_mask=[2862], pair_mask=[2862], rev_edge_idx=[2862], filename=[1], L=[1], batch=[54], ptr=[2])
# DataBatch(x=[138, 16], edge_index=[2, 18906], edge_attr=[18906, 2], y=[18906, 1], edge_mask=[18906], pair_mask=[18906], rev_edge_idx=[18906], filename=[1], L=[1], batch=[138], ptr=[2])
# DataBatch(x=[38, 16], edge_index=[2, 1406], edge_attr=[1406, 2], y=[1406, 1], edge_mask=[1406], pair_mask=[1406], rev_edge_idx=[1406], filename=[1], L=[1], batch=[38], ptr=[2])
# DataBatch(x=[229, 16], edge_index=[2, 52212], edge_attr=[52212, 2], y=[52212, 1], edge_mask=[52212], pair_mask=[52212], rev_edge_idx=[52212], filename=[1], L=[1], batch=[229], ptr=[2])
# DataBatch(x=[121, 16], edge_index=[2, 14520], edge_attr=[14520, 2], y=[14520, 1], edge_mask=[14520], pair_mask=[14520], rev_edge_idx=[14520], filename=[1], L=[1], batch=[121], ptr=[2])
# DataBatch(x=[111, 16], edge_index=[2, 12210], edge_attr=[12210, 2], y=[12210, 1], edge_mask=[12210], pair_mask=[12210], rev_edge_idx=[12210], filename=[1], L=[1], batch=[111], ptr=[2])
# DataBatch(x=[230, 16], edge_index=[2, 52670], edge_attr=[52670, 2], y=[52670, 1], edge_mask=[52670], pair_mask=[52670], rev_edge_idx=[52670], filename=[1], L=[1], batch=[230], ptr=[2])
# DataBatch(x=[88, 16], edge_index=[2, 7656], edge_attr=[7656, 2], y=[7656, 1], edge_mask=[7656], pair_mask=[7656], rev_edge_idx=[7656], filename=[1], L=[1], batch=[88], ptr=[2])
# DataBatch(x=[150, 16], edge_index=[2, 22350], edge_attr=[22350, 2], y=[22350, 1], edge_mask=[22350], pair_mask=[22350], rev_edge_idx=[22350], filename=[1], L=[1], batch=[150], ptr=[2])
# DataBatch(x=[288, 16], edge_index=[2, 82656], edge_attr=[82656, 2], y=[82656, 1], edge_mask=[82656], pair_mask=[82656], rev_edge_idx=[82656], filename=[1], L=[1], batch=[288], ptr=[2])
# DataBatch(x=[319, 16], edge_index=[2, 101442], edge_attr=[101442, 2], y=[101442, 1], edge_mask=[101442], pair_mask=[101442], rev_edge_idx=[101442], filename=[1], L=[1], batch=[319], ptr=[2])
# DataBatch(x=[78, 16], edge_index=[2, 6006], edge_attr=[6006, 2], y=[6006, 1], edge_mask=[6006], pair_mask=[6006], rev_edge_idx=[6006], filename=[1], L=[1], batch=[78], ptr=[2])
# DataBatch(x=[110, 16], edge_index=[2, 11990], edge_attr=[11990, 2], y=[11990, 1], edge_mask=[11990], pair_mask=[11990], rev_edge_idx=[11990], filename=[1], L=[1], batch=[110], ptr=[2])
# DataBatch(x=[599, 16], edge_index=[2, 358202], edge_attr=[358202, 2], y=[358202, 1], edge_mask=[358202], pair_mask=[358202], rev_edge_idx=[358202], filename=[1], L=[1], batch=[599], ptr=[2])
# DataBatch(x=[102, 16], edge_index=[2, 10302], edge_attr=[10302, 2], y=[10302, 1], edge_mask=[10302], pair_mask=[10302], rev_edge_idx=[10302], filename=[1], L=[1], batch=[102], ptr=[2])
# DataBatch(x=[148, 16], edge_index=[2, 21756], edge_attr=[21756, 2], y=[21756, 1], edge_mask=[21756], pair_mask=[21756], rev_edge_idx=[21756], filename=[1], L=[1], batch=[148], ptr=[2])
# DataBatch(x=[298, 16], edge_index=[2, 88506], edge_attr=[88506, 2], y=[88506, 1], edge_mask=[88506], pair_mask=[88506], rev_edge_idx=[88506], filename=[1], L=[1], batch=[298], ptr=[2])
# DataBatch(x=[80, 16], edge_index=[2, 6320], edge_attr=[6320, 2], y=[6320, 1], edge_mask=[6320], pair_mask=[6320], rev_edge_idx=[6320], filename=[1], L=[1], batch=[80], ptr=[2])
# DataBatch(x=[138, 16], edge_index=[2, 18906], edge_attr=[18906, 2], y=[18906, 1], edge_mask=[18906], pair_mask=[18906], rev_edge_idx=[18906], filename=[1], L=[1], batch=[138], ptr=[2])
# DataBatch(x=[103, 16], edge_index=[2, 10506], edge_attr=[10506, 2], y=[10506, 1], edge_mask=[10506], pair_mask=[10506], rev_edge_idx=[10506], filename=[1], L=[1], batch=[103], ptr=[2])
# DataBatch(x=[199, 16], edge_index=[2, 39402], edge_attr=[39402, 2], y=[39402, 1], edge_mask=[39402], pair_mask=[39402], rev_edge_idx=[39402], filename=[1], L=[1], batch=[199], ptr=[2])
# DataBatch(x=[149, 16], edge_index=[2, 22052], edge_attr=[22052, 2], y=[22052, 1], edge_mask=[22052], pair_mask=[22052], rev_edge_idx=[22052], filename=[1], L=[1], batch=[149], ptr=[2])
# DataBatch(x=[101, 16], edge_index=[2, 10100], edge_attr=[10100, 2], y=[10100, 1], edge_mask=[10100], pair_mask=[10100], rev_edge_idx=[10100], filename=[1], L=[1], batch=[101], ptr=[2])
# DataBatch(x=[28, 16], edge_index=[2, 756], edge_attr=[756, 2], y=[756, 1], edge_mask=[756], pair_mask=[756], rev_edge_idx=[756], filename=[1], L=[1], batch=[28], ptr=[2])
# DataBatch(x=[83, 16], edge_index=[2, 6806], edge_attr=[6806, 2], y=[6806, 1], edge_mask=[6806], pair_mask=[6806], rev_edge_idx=[6806], filename=[1], L=[1], batch=[83], ptr=[2])
# DataBatch(x=[76, 16], edge_index=[2, 5700], edge_attr=[5700, 2], y=[5700, 1], edge_mask=[5700], pair_mask=[5700], rev_edge_idx=[5700], filename=[1], L=[1], batch=[76], ptr=[2])
# DataBatch(x=[106, 16], edge_index=[2, 11130], edge_attr=[11130, 2], y=[11130, 1], edge_mask=[11130], pair_mask=[11130], rev_edge_idx=[11130], filename=[1], L=[1], batch=[106], ptr=[2])
# DataBatch(x=[90, 16], edge_index=[2, 8010], edge_attr=[8010, 2], y=[8010, 1], edge_mask=[8010], pair_mask=[8010], rev_edge_idx=[8010], filename=[1], L=[1], batch=[90], ptr=[2])
# DataBatch(x=[93, 16], edge_index=[2, 8556], edge_attr=[8556, 2], y=[8556, 1], edge_mask=[8556], pair_mask=[8556], rev_edge_idx=[8556], filename=[1], L=[1], batch=[93], ptr=[2])
# DataBatch(x=[153, 16], edge_index=[2, 23256], edge_attr=[23256, 2], y=[23256, 1], edge_mask=[23256], pair_mask=[23256], rev_edge_idx=[23256], filename=[1], L=[1], batch=[153], ptr=[2])
# DataBatch(x=[110, 16], edge_index=[2, 11990], edge_attr=[11990, 2], y=[11990, 1], edge_mask=[11990], pair_mask=[11990], rev_edge_idx=[11990], filename=[1], L=[1], batch=[110], ptr=[2])
# DataBatch(x=[153, 16], edge_index=[2, 23256], edge_attr=[23256, 2], y=[23256, 1], edge_mask=[23256], pair_mask=[23256], rev_edge_idx=[23256], filename=[1], L=[1], batch=[153], ptr=[2])
# DataBatch(x=[173, 16], edge_index=[2, 29756], edge_attr=[29756, 2], y=[29756, 1], edge_mask=[29756], pair_mask=[29756], rev_edge_idx=[29756], filename=[1], L=[1], batch=[173], ptr=[2])
# DataBatch(x=[194, 16], edge_index=[2, 37442], edge_attr=[37442, 2], y=[37442, 1], edge_mask=[37442], pair_mask=[37442], rev_edge_idx=[37442], filename=[1], L=[1], batch=[194], ptr=[2])
# DataBatch(x=[423, 16], edge_index=[2, 178506], edge_attr=[178506, 2], y=[178506, 1], edge_mask=[178506], pair_mask=[178506], rev_edge_idx=[178506], filename=[1], L=[1], batch=[423], ptr=[2])
# DataBatch(x=[156, 16], edge_index=[2, 24180], edge_attr=[24180, 2], y=[24180, 1], edge_mask=[24180], pair_mask=[24180], rev_edge_idx=[24180], filename=[1], L=[1], batch=[156], ptr=[2])
# DataBatch(x=[110, 16], edge_index=[2, 11990], edge_attr=[11990, 2], y=[11990, 1], edge_mask=[11990], pair_mask=[11990], rev_edge_idx=[11990], filename=[1], L=[1], batch=[110], ptr=[2])
# DataBatch(x=[174, 16], edge_index=[2, 30102], edge_attr=[30102, 2], y=[30102, 1], edge_mask=[30102], pair_mask=[30102], rev_edge_idx=[30102], filename=[1], L=[1], batch=[174], ptr=[2])
# DataBatch(x=[198, 16], edge_index=[2, 39006], edge_attr=[39006, 2], y=[39006, 1], edge_mask=[39006], pair_mask=[39006], rev_edge_idx=[39006], filename=[1], L=[1], batch=[198], ptr=[2])
# DataBatch(x=[158, 16], edge_index=[2, 24806], edge_attr=[24806, 2], y=[24806, 1], edge_mask=[24806], pair_mask=[24806], rev_edge_idx=[24806], filename=[1], L=[1], batch=[158], ptr=[2])
# DataBatch(x=[95, 16], edge_index=[2, 8930], edge_attr=[8930, 2], y=[8930, 1], edge_mask=[8930], pair_mask=[8930], rev_edge_idx=[8930], filename=[1], L=[1], batch=[95], ptr=[2])
# DataBatch(x=[430, 16], edge_index=[2, 184470], edge_attr=[184470, 2], y=[184470, 1], edge_mask=[184470], pair_mask=[184470], rev_edge_idx=[184470], filename=[1], L=[1], batch=[430], ptr=[2])
# DataBatch(x=[180, 16], edge_index=[2, 32220], edge_attr=[32220, 2], y=[32220, 1], edge_mask=[32220], pair_mask=[32220], rev_edge_idx=[32220], filename=[1], L=[1], batch=[180], ptr=[2])
# DataBatch(x=[47, 16], edge_index=[2, 2162], edge_attr=[2162, 2], y=[2162, 1], edge_mask=[2162], pair_mask=[2162], rev_edge_idx=[2162], filename=[1], L=[1], batch=[47], ptr=[2])
# DataBatch(x=[43, 16], edge_index=[2, 1806], edge_attr=[1806, 2], y=[1806, 1], edge_mask=[1806], pair_mask=[1806], rev_edge_idx=[1806], filename=[1], L=[1], batch=[43], ptr=[2])
# DataBatch(x=[142, 16], edge_index=[2, 20022], edge_attr=[20022, 2], y=[20022, 1], edge_mask=[20022], pair_mask=[20022], rev_edge_idx=[20022], filename=[1], L=[1], batch=[142], ptr=[2])
# DataBatch(x=[139, 16], edge_index=[2, 19182], edge_attr=[19182, 2], y=[19182, 1], edge_mask=[19182], pair_mask=[19182], rev_edge_idx=[19182], filename=[1], L=[1], batch=[139], ptr=[2])
# DataBatch(x=[362, 16], edge_index=[2, 130682], edge_attr=[130682, 2], y=[130682, 1], edge_mask=[130682], pair_mask=[130682], rev_edge_idx=[130682], filename=[1], L=[1], batch=[362], ptr=[2])
# DataBatch(x=[69, 16], edge_index=[2, 4692], edge_attr=[4692, 2], y=[4692, 1], edge_mask=[4692], pair_mask=[4692], rev_edge_idx=[4692], filename=[1], L=[1], batch=[69], ptr=[2])
# DataBatch(x=[74, 16], edge_index=[2, 5402], edge_attr=[5402, 2], y=[5402, 1], edge_mask=[5402], pair_mask=[5402], rev_edge_idx=[5402], filename=[1], L=[1], batch=[74], ptr=[2])
# DataBatch(x=[134, 16], edge_index=[2, 17822], edge_attr=[17822, 2], y=[17822, 1], edge_mask=[17822], pair_mask=[17822], rev_edge_idx=[17822], filename=[1], L=[1], batch=[134], ptr=[2])
# DataBatch(x=[58, 16], edge_index=[2, 3306], edge_attr=[3306, 2], y=[3306, 1], edge_mask=[3306], pair_mask=[3306], rev_edge_idx=[3306], filename=[1], L=[1], batch=[58], ptr=[2])
# DataBatch(x=[120, 16], edge_index=[2, 14280], edge_attr=[14280, 2], y=[14280, 1], edge_mask=[14280], pair_mask=[14280], rev_edge_idx=[14280], filename=[1], L=[1], batch=[120], ptr=[2])
# DataBatch(x=[151, 16], edge_index=[2, 22650], edge_attr=[22650, 2], y=[22650, 1], edge_mask=[22650], pair_mask=[22650], rev_edge_idx=[22650], filename=[1], L=[1], batch=[151], ptr=[2])
# DataBatch(x=[77, 16], edge_index=[2, 5852], edge_attr=[5852, 2], y=[5852, 1], edge_mask=[5852], pair_mask=[5852], rev_edge_idx=[5852], filename=[1], L=[1], batch=[77], ptr=[2])
# DataBatch(x=[238, 16], edge_index=[2, 56406], edge_attr=[56406, 2], y=[56406, 1], edge_mask=[56406], pair_mask=[56406], rev_edge_idx=[56406], filename=[1], L=[1], batch=[238], ptr=[2])
# DataBatch(x=[292, 16], edge_index=[2, 84972], edge_attr=[84972, 2], y=[84972, 1], edge_mask=[84972], pair_mask=[84972], rev_edge_idx=[84972], filename=[1], L=[1], batch=[292], ptr=[2])
# DataBatch(x=[284, 16], edge_index=[2, 80372], edge_attr=[80372, 2], y=[80372, 1], edge_mask=[80372], pair_mask=[80372], rev_edge_idx=[80372], filename=[1], L=[1], batch=[284], ptr=[2])
# DataBatch(x=[48, 16], edge_index=[2, 2256], edge_attr=[2256, 2], y=[2256, 1], edge_mask=[2256], pair_mask=[2256], rev_edge_idx=[2256], filename=[1], L=[1], batch=[48], ptr=[2])
# DataBatch(x=[76, 16], edge_index=[2, 5700], edge_attr=[5700, 2], y=[5700, 1], edge_mask=[5700], pair_mask=[5700], rev_edge_idx=[5700], filename=[1], L=[1], batch=[76], ptr=[2])
# DataBatch(x=[204, 16], edge_index=[2, 41412], edge_attr=[41412, 2], y=[41412, 1], edge_mask=[41412], pair_mask=[41412], rev_edge_idx=[41412], filename=[1], L=[1], batch=[204], ptr=[2])
# DataBatch(x=[220, 16], edge_index=[2, 48180], edge_attr=[48180, 2], y=[48180, 1], edge_mask=[48180], pair_mask=[48180], rev_edge_idx=[48180], filename=[1], L=[1], batch=[220], ptr=[2])
# DataBatch(x=[366, 16], edge_index=[2, 133590], edge_attr=[133590, 2], y=[133590, 1], edge_mask=[133590], pair_mask=[133590], rev_edge_idx=[133590], filename=[1], L=[1], batch=[366], ptr=[2])
# DataBatch(x=[30, 16], edge_index=[2, 870], edge_attr=[870, 2], y=[870, 1], edge_mask=[870], pair_mask=[870], rev_edge_idx=[870], filename=[1], L=[1], batch=[30], ptr=[2])
# DataBatch(x=[82, 16], edge_index=[2, 6642], edge_attr=[6642, 2], y=[6642, 1], edge_mask=[6642], pair_mask=[6642], rev_edge_idx=[6642], filename=[1], L=[1], batch=[82], ptr=[2])
# DataBatch(x=[291, 16], edge_index=[2, 84390], edge_attr=[84390, 2], y=[84390, 1], edge_mask=[84390], pair_mask=[84390], rev_edge_idx=[84390], filename=[1], L=[1], batch=[291], ptr=[2])
# DataBatch(x=[218, 16], edge_index=[2, 47306], edge_attr=[47306, 2], y=[47306, 1], edge_mask=[47306], pair_mask=[47306], rev_edge_idx=[47306], filename=[1], L=[1], batch=[218], ptr=[2])
# DataBatch(x=[196, 16], edge_index=[2, 38220], edge_attr=[38220, 2], y=[38220, 1], edge_mask=[38220], pair_mask=[38220], rev_edge_idx=[38220], filename=[1], L=[1], batch=[196], ptr=[2])
# DataBatch(x=[96, 16], edge_index=[2, 9120], edge_attr=[9120, 2], y=[9120, 1], edge_mask=[9120], pair_mask=[9120], rev_edge_idx=[9120], filename=[1], L=[1], batch=[96], ptr=[2])
# DataBatch(x=[87, 16], edge_index=[2, 7482], edge_attr=[7482, 2], y=[7482, 1], edge_mask=[7482], pair_mask=[7482], rev_edge_idx=[7482], filename=[1], L=[1], batch=[87], ptr=[2])
# DataBatch(x=[283, 16], edge_index=[2, 79806], edge_attr=[79806, 2], y=[79806, 1], edge_mask=[79806], pair_mask=[79806], rev_edge_idx=[79806], filename=[1], L=[1], batch=[283], ptr=[2])
# DataBatch(x=[238, 16], edge_index=[2, 56406], edge_attr=[56406, 2], y=[56406, 1], edge_mask=[56406], pair_mask=[56406], rev_edge_idx=[56406], filename=[1], L=[1], batch=[238], ptr=[2])
# DataBatch(x=[79, 16], edge_index=[2, 6162], edge_attr=[6162, 2], y=[6162, 1], edge_mask=[6162], pair_mask=[6162], rev_edge_idx=[6162], filename=[1], L=[1], batch=[79], ptr=[2])
# DataBatch(x=[116, 16], edge_index=[2, 13340], edge_attr=[13340, 2], y=[13340, 1], edge_mask=[13340], pair_mask=[13340], rev_edge_idx=[13340], filename=[1], L=[1], batch=[116], ptr=[2])
# DataBatch(x=[36, 16], edge_index=[2, 1260], edge_attr=[1260, 2], y=[1260, 1], edge_mask=[1260], pair_mask=[1260], rev_edge_idx=[1260], filename=[1], L=[1], batch=[36], ptr=[2])
# DataBatch(x=[124, 16], edge_index=[2, 15252], edge_attr=[15252, 2], y=[15252, 1], edge_mask=[15252], pair_mask=[15252], rev_edge_idx=[15252], filename=[1], L=[1], batch=[124], ptr=[2])
# DataBatch(x=[166, 16], edge_index=[2, 27390], edge_attr=[27390, 2], y=[27390, 1], edge_mask=[27390], pair_mask=[27390], rev_edge_idx=[27390], filename=[1], L=[1], batch=[166], ptr=[2])
# DataBatch(x=[128, 16], edge_index=[2, 16256], edge_attr=[16256, 2], y=[16256, 1], edge_mask=[16256], pair_mask=[16256], rev_edge_idx=[16256], filename=[1], L=[1], batch=[128], ptr=[2])
# DataBatch(x=[96, 16], edge_index=[2, 9120], edge_attr=[9120, 2], y=[9120, 1], edge_mask=[9120], pair_mask=[9120], rev_edge_idx=[9120], filename=[1], L=[1], batch=[96], ptr=[2])
# DataBatch(x=[141, 16], edge_index=[2, 19740], edge_attr=[19740, 2], y=[19740, 1], edge_mask=[19740], pair_mask=[19740], rev_edge_idx=[19740], filename=[1], L=[1], batch=[141], ptr=[2])
# DataBatch(x=[134, 16], edge_index=[2, 17822], edge_attr=[17822, 2], y=[17822, 1], edge_mask=[17822], pair_mask=[17822], rev_edge_idx=[17822], filename=[1], L=[1], batch=[134], ptr=[2])
# DataBatch(x=[242, 16], edge_index=[2, 58322], edge_attr=[58322, 2], y=[58322, 1], edge_mask=[58322], pair_mask=[58322], rev_edge_idx=[58322], filename=[1], L=[1], batch=[242], ptr=[2])
# DataBatch(x=[120, 16], edge_index=[2, 14280], edge_attr=[14280, 2], y=[14280, 1], edge_mask=[14280], pair_mask=[14280], rev_edge_idx=[14280], filename=[1], L=[1], batch=[120], ptr=[2])
# DataBatch(x=[66, 16], edge_index=[2, 4290], edge_attr=[4290, 2], y=[4290, 1], edge_mask=[4290], pair_mask=[4290], rev_edge_idx=[4290], filename=[1], L=[1], batch=[66], ptr=[2])
# DataBatch(x=[80, 16], edge_index=[2, 6320], edge_attr=[6320, 2], y=[6320, 1], edge_mask=[6320], pair_mask=[6320], rev_edge_idx=[6320], filename=[1], L=[1], batch=[80], ptr=[2])
# DataBatch(x=[36, 16], edge_index=[2, 1260], edge_attr=[1260, 2], y=[1260, 1], edge_mask=[1260], pair_mask=[1260], rev_edge_idx=[1260], filename=[1], L=[1], batch=[36], ptr=[2])
# DataBatch(x=[158, 16], edge_index=[2, 24806], edge_attr=[24806, 2], y=[24806, 1], edge_mask=[24806], pair_mask=[24806], rev_edge_idx=[24806], filename=[1], L=[1], batch=[158], ptr=[2])
# DataBatch(x=[116, 16], edge_index=[2, 13340], edge_attr=[13340, 2], y=[13340, 1], edge_mask=[13340], pair_mask=[13340], rev_edge_idx=[13340], filename=[1], L=[1], batch=[116], ptr=[2])
# DataBatch(x=[102, 16], edge_index=[2, 10302], edge_attr=[10302, 2], y=[10302, 1], edge_mask=[10302], pair_mask=[10302], rev_edge_idx=[10302], filename=[1], L=[1], batch=[102], ptr=[2])
# DataBatch(x=[331, 16], edge_index=[2, 109230], edge_attr=[109230, 2], y=[109230, 1], edge_mask=[109230], pair_mask=[109230], rev_edge_idx=[109230], filename=[1], L=[1], batch=[331], ptr=[2])
# DataBatch(x=[81, 16], edge_index=[2, 6480], edge_attr=[6480, 2], y=[6480, 1], edge_mask=[6480], pair_mask=[6480], rev_edge_idx=[6480], filename=[1], L=[1], batch=[81], ptr=[2])
# ...
# DataBatch(x=[78, 16], edge_index=[2, 6006], edge_attr=[6006, 2], y=[6006, 1], edge_mask=[6006], pair_mask=[6006], rev_edge_idx=[6006], filename=[1], L=[1], batch=[78], ptr=[2])
# DataBatch(x=[113, 16], edge_index=[2, 12656], edge_attr=[12656, 2], y=[12656, 1], edge_mask=[12656], pair_mask=[12656], rev_edge_idx=[12656], filename=[1], L=[1], batch=[113], ptr=[2])
# DataBatch(x=[217, 16], edge_index=[2, 46872], edge_attr=[46872, 2], y=[46872, 1], edge_mask=[46872], pair_mask=[46872], rev_edge_idx=[46872], filename=[1], L=[1], batch=[217], ptr=[2])
# DataBatch(x=[72, 16], edge_index=[2, 5112], edge_attr=[5112, 2], y=[5112, 1], edge_mask=[5112], pair_mask=[5112], rev_edge_idx=[5112], filename=[1], L=[1], batch=[72], ptr=[2])
# DataBatch(x=[102, 16], edge_index=[2, 10302], edge_attr=[10302, 2], y=[10302, 1], edge_mask=[10302], pair_mask=[10302], rev_edge_idx=[10302], filename=[1], L=[1], batch=[102], ptr=[2])
# DataBatch(x=[346, 16], edge_index=[2, 119370], edge_attr=[119370, 2], y=[119370, 1], edge_mask=[119370], pair_mask=[119370], rev_edge_idx=[119370], filename=[1], L=[1], batch=[346], ptr=[2])
# DataBatch(x=[253, 16], edge_index=[2, 63756], edge_attr=[63756, 2], y=[63756, 1], edge_mask=[63756], pair_mask=[63756], rev_edge_idx=[63756], filename=[1], L=[1], batch=[253], ptr=[2])
# DataBatch(x=[191, 16], edge_index=[2, 36290], edge_attr=[36290, 2], y=[36290, 1], edge_mask=[36290], pair_mask=[36290], rev_edge_idx=[36290], filename=[1], L=[1], batch=[191], ptr=[2])
# DataBatch(x=[364, 16], edge_index=[2, 132132], edge_attr=[132132, 2], y=[132132, 1], edge_mask=[132132], pair_mask=[132132], rev_edge_idx=[132132], filename=[1], L=[1], batch=[364], ptr=[2])
# DataBatch(x=[116, 16], edge_index=[2, 13340], edge_attr=[13340, 2], y=[13340, 1], edge_mask=[13340], pair_mask=[13340], rev_edge_idx=[13340], filename=[1], L=[1], batch=[116], ptr=[2])
# DataBatch(x=[211, 16], edge_index=[2, 44310], edge_attr=[44310, 2], y=[44310, 1], edge_mask=[44310], pair_mask=[44310], rev_edge_idx=[44310], filename=[1], L=[1], batch=[211], ptr=[2])
# DataBatch(x=[143, 16], edge_index=[2, 20306], edge_attr=[20306, 2], y=[20306, 1], edge_mask=[20306], pair_mask=[20306], rev_edge_idx=[20306], filename=[1], L=[1], batch=[143], ptr=[2])
# DataBatch(x=[116, 16], edge_index=[2, 13340], edge_attr=[13340, 2], y=[13340, 1], edge_mask=[13340], pair_mask=[13340], rev_edge_idx=[13340], filename=[1], L=[1], batch=[116], ptr=[2])
# DataBatch(x=[81, 16], edge_index=[2, 6480], edge_attr=[6480, 2], y=[6480, 1], edge_mask=[6480], pair_mask=[6480], rev_edge_idx=[6480], filename=[1], L=[1], batch=[81], ptr=[2])
# DataBatch(x=[417, 16], edge_index=[2, 173472], edge_attr=[173472, 2], y=[173472, 1], edge_mask=[173472], pair_mask=[173472], rev_edge_idx=[173472], filename=[1], L=[1], batch=[417], ptr=[2])
# DataBatch(x=[310, 16], edge_index=[2, 95790], edge_attr=[95790, 2], y=[95790, 1], edge_mask=[95790], pair_mask=[95790], rev_edge_idx=[95790], filename=[1], L=[1], batch=[310], ptr=[2])
# DataBatch(x=[106, 16], edge_index=[2, 11130], edge_attr=[11130, 2], y=[11130, 1], edge_mask=[11130], pair_mask=[11130], rev_edge_idx=[11130], filename=[1], L=[1], batch=[106], ptr=[2])
# DataBatch(x=[66, 16], edge_index=[2, 4290], edge_attr=[4290, 2], y=[4290, 1], edge_mask=[4290], pair_mask=[4290], rev_edge_idx=[4290], filename=[1], L=[1], batch=[66], ptr=[2])
# DataBatch(x=[279, 16], edge_index=[2, 77562], edge_attr=[77562, 2], y=[77562, 1], edge_mask=[77562], pair_mask=[77562], rev_edge_idx=[77562], filename=[1], L=[1], batch=[279], ptr=[2])
# DataBatch(x=[155, 16], edge_index=[2, 23870], edge_attr=[23870, 2], y=[23870, 1], edge_mask=[23870], pair_mask=[23870], rev_edge_idx=[23870], filename=[1], L=[1], batch=[155], ptr=[2])
# DataBatch(x=[166, 16], edge_index=[2, 27390], edge_attr=[27390, 2], y=[27390, 1], edge_mask=[27390], pair_mask=[27390], rev_edge_idx=[27390], filename=[1], L=[1], batch=[166], ptr=[2])
# DataBatch(x=[115, 16], edge_index=[2, 13110], edge_attr=[13110, 2], y=[13110, 1], edge_mask=[13110], pair_mask=[13110], rev_edge_idx=[13110], filename=[1], L=[1], batch=[115], ptr=[2])
# DataBatch(x=[119, 16], edge_index=[2, 14042], edge_attr=[14042, 2], y=[14042, 1], edge_mask=[14042], pair_mask=[14042], rev_edge_idx=[14042], filename=[1], L=[1], batch=[119], ptr=[2])
# DataBatch(x=[47, 16], edge_index=[2, 2162], edge_attr=[2162, 2], y=[2162, 1], edge_mask=[2162], pair_mask=[2162], rev_edge_idx=[2162], filename=[1], L=[1], batch=[47], ptr=[2])
# DataBatch(x=[143, 16], edge_index=[2, 20306], edge_attr=[20306, 2], y=[20306, 1], edge_mask=[20306], pair_mask=[20306], rev_edge_idx=[20306], filename=[1], L=[1], batch=[143], ptr=[2])
# DataBatch(x=[133, 16], edge_index=[2, 17556], edge_attr=[17556, 2], y=[17556, 1], edge_mask=[17556], pair_mask=[17556], rev_edge_idx=[17556], filename=[1], L=[1], batch=[133], ptr=[2])
# DataBatch(x=[104, 16], edge_index=[2, 10712], edge_attr=[10712, 2], y=[10712, 1], edge_mask=[10712], pair_mask=[10712], rev_edge_idx=[10712], filename=[1], L=[1], batch=[104], ptr=[2])
# DataBatch(x=[345, 16], edge_index=[2, 118680], edge_attr=[118680, 2], y=[118680, 1], edge_mask=[118680], pair_mask=[118680], rev_edge_idx=[118680], filename=[1], L=[1], batch=[345], ptr=[2])
# DataBatch(x=[31, 16], edge_index=[2, 930], edge_attr=[930, 2], y=[930, 1], edge_mask=[930], pair_mask=[930], rev_edge_idx=[930], filename=[1], L=[1], batch=[31], ptr=[2])
# DataBatch(x=[280, 16], edge_index=[2, 78120], edge_attr=[78120, 2], y=[78120, 1], edge_mask=[78120], pair_mask=[78120], rev_edge_idx=[78120], filename=[1], L=[1], batch=[280], ptr=[2])
# DataBatch(x=[34, 16], edge_index=[2, 1122], edge_attr=[1122, 2], y=[1122, 1], edge_mask=[1122], pair_mask=[1122], rev_edge_idx=[1122], filename=[1], L=[1], batch=[34], ptr=[2])
# DataBatch(x=[217, 16], edge_index=[2, 46872], edge_attr=[46872, 2], y=[46872, 1], edge_mask=[46872], pair_mask=[46872], rev_edge_idx=[46872], filename=[1], L=[1], batch=[217], ptr=[2])
# DataBatch(x=[196, 16], edge_index=[2, 38220], edge_attr=[38220, 2], y=[38220, 1], edge_mask=[38220], pair_mask=[38220], rev_edge_idx=[38220], filename=[1], L=[1], batch=[196], ptr=[2])
# DataBatch(x=[163, 16], edge_index=[2, 26406], edge_attr=[26406, 2], y=[26406, 1], edge_mask=[26406], pair_mask=[26406], rev_edge_idx=[26406], filename=[1], L=[1], batch=[163], ptr=[2])
# DataBatch(x=[171, 16], edge_index=[2, 29070], edge_attr=[29070, 2], y=[29070, 1], edge_mask=[29070], pair_mask=[29070], rev_edge_idx=[29070], filename=[1], L=[1], batch=[171], ptr=[2])
# DataBatch(x=[238, 16], edge_index=[2, 56406], edge_attr=[56406, 2], y=[56406, 1], edge_mask=[56406], pair_mask=[56406], rev_edge_idx=[56406], filename=[1], L=[1], batch=[238], ptr=[2])
# DataBatch(x=[70, 16], edge_index=[2, 4830], edge_attr=[4830, 2], y=[4830, 1], edge_mask=[4830], pair_mask=[4830], rev_edge_idx=[4830], filename=[1], L=[1], batch=[70], ptr=[2])
# DataBatch(x=[123, 16], edge_index=[2, 15006], edge_attr=[15006, 2], y=[15006, 1], edge_mask=[15006], pair_mask=[15006], rev_edge_idx=[15006], filename=[1], L=[1], batch=[123], ptr=[2])
# DataBatch(x=[353, 16], edge_index=[2, 124256], edge_attr=[124256, 2], y=[124256, 1], edge_mask=[124256], pair_mask=[124256], rev_edge_idx=[124256], filename=[1], L=[1], batch=[353], ptr=[2])
# DataBatch(x=[74, 16], edge_index=[2, 5402], edge_attr=[5402, 2], y=[5402, 1], edge_mask=[5402], pair_mask=[5402], rev_edge_idx=[5402], filename=[1], L=[1], batch=[74], ptr=[2])
# DataBatch(x=[109, 16], edge_index=[2, 11772], edge_attr=[11772, 2], y=[11772, 1], edge_mask=[11772], pair_mask=[11772], rev_edge_idx=[11772], filename=[1], L=[1], batch=[109], ptr=[2])
# DataBatch(x=[65, 16], edge_index=[2, 4160], edge_attr=[4160, 2], y=[4160, 1], edge_mask=[4160], pair_mask=[4160], rev_edge_idx=[4160], filename=[1], L=[1], batch=[65], ptr=[2])
# DataBatch(x=[38, 16], edge_index=[2, 1406], edge_attr=[1406, 2], y=[1406, 1], edge_mask=[1406], pair_mask=[1406], rev_edge_idx=[1406], filename=[1], L=[1], batch=[38], ptr=[2])
# DataBatch(x=[151, 16], edge_index=[2, 22650], edge_attr=[22650, 2], y=[22650, 1], edge_mask=[22650], pair_mask=[22650], rev_edge_idx=[22650], filename=[1], L=[1], batch=[151], ptr=[2])
# DataBatch(x=[110, 16], edge_index=[2, 11990], edge_attr=[11990, 2], y=[11990, 1], edge_mask=[11990], pair_mask=[11990], rev_edge_idx=[11990], filename=[1], L=[1], batch=[110], ptr=[2])
# DataBatch(x=[70, 16], edge_index=[2, 4830], edge_attr=[4830, 2], y=[4830, 1], edge_mask=[4830], pair_mask=[4830], rev_edge_idx=[4830], filename=[1], L=[1], batch=[70], ptr=[2])
# DataBatch(x=[175, 16], edge_index=[2, 30450], edge_attr=[30450, 2], y=[30450, 1], edge_mask=[30450], pair_mask=[30450], rev_edge_idx=[30450], filename=[1], L=[1], batch=[175], ptr=[2])
# DataBatch(x=[109, 16], edge_index=[2, 11772], edge_attr=[11772, 2], y=[11772, 1], edge_mask=[11772], pair_mask=[11772], rev_edge_idx=[11772], filename=[1], L=[1], batch=[109], ptr=[2])
# DataBatch(x=[133, 16], edge_index=[2, 17556], edge_attr=[17556, 2], y=[17556, 1], edge_mask=[17556], pair_mask=[17556], rev_edge_idx=[17556], filename=[1], L=[1], batch=[133], ptr=[2])
# DataBatch(x=[43, 16], edge_index=[2, 1806], edge_attr=[1806, 2], y=[1806, 1], edge_mask=[1806], pair_mask=[1806], rev_edge_idx=[1806], filename=[1], L=[1], batch=[43], ptr=[2])
# DataBatch(x=[268, 16], edge_index=[2, 71556], edge_attr=[71556, 2], y=[71556, 1], edge_mask=[71556], pair_mask=[71556], rev_edge_idx=[71556], filename=[1], L=[1], batch=[268], ptr=[2])
# DataBatch(x=[103, 16], edge_index=[2, 10506], edge_attr=[10506, 2], y=[10506, 1], edge_mask=[10506], pair_mask=[10506], rev_edge_idx=[10506], filename=[1], L=[1], batch=[103], ptr=[2])
# DataBatch(x=[72, 16], edge_index=[2, 5112], edge_attr=[5112, 2], y=[5112, 1], edge_mask=[5112], pair_mask=[5112], rev_edge_idx=[5112], filename=[1], L=[1], batch=[72], ptr=[2])
# DataBatch(x=[123, 16], edge_index=[2, 15006], edge_attr=[15006, 2], y=[15006, 1], edge_mask=[15006], pair_mask=[15006], rev_edge_idx=[15006], filename=[1], L=[1], batch=[123], ptr=[2])
# DataBatch(x=[93, 16], edge_index=[2, 8556], edge_attr=[8556, 2], y=[8556, 1], edge_mask=[8556], pair_mask=[8556], rev_edge_idx=[8556], filename=[1], L=[1], batch=[93], ptr=[2])
# DataBatch(x=[184, 16], edge_index=[2, 33672], edge_attr=[33672, 2], y=[33672, 1], edge_mask=[33672], pair_mask=[33672], rev_edge_idx=[33672], filename=[1], L=[1], batch=[184], ptr=[2])
# DataBatch(x=[160, 16], edge_index=[2, 25440], edge_attr=[25440, 2], y=[25440, 1], edge_mask=[25440], pair_mask=[25440], rev_edge_idx=[25440], filename=[1], L=[1], batch=[160], ptr=[2])
# DataBatch(x=[125, 16], edge_index=[2, 15500], edge_attr=[15500, 2], y=[15500, 1], edge_mask=[15500], pair_mask=[15500], rev_edge_idx=[15500], filename=[1], L=[1], batch=[125], ptr=[2])
# DataBatch(x=[218, 16], edge_index=[2, 47306], edge_attr=[47306, 2], y=[47306, 1], edge_mask=[47306], pair_mask=[47306], rev_edge_idx=[47306], filename=[1], L=[1], batch=[218], ptr=[2])
# DataBatch(x=[94, 16], edge_index=[2, 8742], edge_attr=[8742, 2], y=[8742, 1], edge_mask=[8742], pair_mask=[8742], rev_edge_idx=[8742], filename=[1], L=[1], batch=[94], ptr=[2])
# DataBatch(x=[47, 16], edge_index=[2, 2162], edge_attr=[2162, 2], y=[2162, 1], edge_mask=[2162], pair_mask=[2162], rev_edge_idx=[2162], filename=[1], L=[1], batch=[47], ptr=[2])
# DataBatch(x=[65, 16], edge_index=[2, 4160], edge_attr=[4160, 2], y=[4160, 1], edge_mask=[4160], pair_mask=[4160], rev_edge_idx=[4160], filename=[1], L=[1], batch=[65], ptr=[2])
# DataBatch(x=[143, 16], edge_index=[2, 20306], edge_attr=[20306, 2], y=[20306, 1], edge_mask=[20306], pair_mask=[20306], rev_edge_idx=[20306], filename=[1], L=[1], batch=[143], ptr=[2])
# DataBatch(x=[118, 16], edge_index=[2, 13806], edge_attr=[13806, 2], y=[13806, 1], edge_mask=[13806], pair_mask=[13806], rev_edge_idx=[13806], filename=[1], L=[1], batch=[118], ptr=[2])
# DataBatch(x=[86, 16], edge_index=[2, 7310], edge_attr=[7310, 2], y=[7310, 1], edge_mask=[7310], pair_mask=[7310], rev_edge_idx=[7310], filename=[1], L=[1], batch=[86], ptr=[2])
# DataBatch(x=[115, 16], edge_index=[2, 13110], edge_attr=[13110, 2], y=[13110, 1], edge_mask=[13110], pair_mask=[13110], rev_edge_idx=[13110], filename=[1], L=[1], batch=[115], ptr=[2])
# DataBatch(x=[106, 16], edge_index=[2, 11130], edge_attr=[11130, 2], y=[11130, 1], edge_mask=[11130], pair_mask=[11130], rev_edge_idx=[11130], filename=[1], L=[1], batch=[106], ptr=[2])
# DataBatch(x=[129, 16], edge_index=[2, 16512], edge_attr=[16512, 2], y=[16512, 1], edge_mask=[16512], pair_mask=[16512], rev_edge_idx=[16512], filename=[1], L=[1], batch=[129], ptr=[2])
# DataBatch(x=[263, 16], edge_index=[2, 68906], edge_attr=[68906, 2], y=[68906, 1], edge_mask=[68906], pair_mask=[68906], rev_edge_idx=[68906], filename=[1], L=[1], batch=[263], ptr=[2])
# DataBatch(x=[56, 16], edge_index=[2, 3080], edge_attr=[3080, 2], y=[3080, 1], edge_mask=[3080], pair_mask=[3080], rev_edge_idx=[3080], filename=[1], L=[1], batch=[56], ptr=[2])
# DataBatch(x=[210, 16], edge_index=[2, 43890], edge_attr=[43890, 2], y=[43890, 1], edge_mask=[43890], pair_mask=[43890], rev_edge_idx=[43890], filename=[1], L=[1], batch=[210], ptr=[2])
# DataBatch(x=[493, 16], edge_index=[2, 242556], edge_attr=[242556, 2], y=[242556, 1], edge_mask=[242556], pair_mask=[242556], rev_edge_idx=[242556], filename=[1], L=[1], batch=[493], ptr=[2])
# DataBatch(x=[239, 16], edge_index=[2, 56882], edge_attr=[56882, 2], y=[56882, 1], edge_mask=[56882], pair_mask=[56882], rev_edge_idx=[56882], filename=[1], L=[1], batch=[239], ptr=[2])
# DataBatch(x=[48, 16], edge_index=[2, 2256], edge_attr=[2256, 2], y=[2256, 1], edge_mask=[2256], pair_mask=[2256], rev_edge_idx=[2256], filename=[1], L=[1], batch=[48], ptr=[2])
# DataBatch(x=[270, 16], edge_index=[2, 72630], edge_attr=[72630, 2], y=[72630, 1], edge_mask=[72630], pair_mask=[72630], rev_edge_idx=[72630], filename=[1], L=[1], batch=[270], ptr=[2])
# DataBatch(x=[133, 16], edge_index=[2, 17556], edge_attr=[17556, 2], y=[17556, 1], edge_mask=[17556], pair_mask=[17556], rev_edge_idx=[17556], filename=[1], L=[1], batch=[133], ptr=[2])
# DataBatch(x=[68, 16], edge_index=[2, 4556], edge_attr=[4556, 2], y=[4556, 1], edge_mask=[4556], pair_mask=[4556], rev_edge_idx=[4556], filename=[1], L=[1], batch=[68], ptr=[2])
# DataBatch(x=[254, 16], edge_index=[2, 64262], edge_attr=[64262, 2], y=[64262, 1], edge_mask=[64262], pair_mask=[64262], rev_edge_idx=[64262], filename=[1], L=[1], batch=[254], ptr=[2])
# DataBatch(x=[92, 16], edge_index=[2, 8372], edge_attr=[8372, 2], y=[8372, 1], edge_mask=[8372], pair_mask=[8372], rev_edge_idx=[8372], filename=[1], L=[1], batch=[92], ptr=[2])
# DataBatch(x=[62, 16], edge_index=[2, 3782], edge_attr=[3782, 2], y=[3782, 1], edge_mask=[3782], pair_mask=[3782], rev_edge_idx=[3782], filename=[1], L=[1], batch=[62], ptr=[2])
# DataBatch(x=[67, 16], edge_index=[2, 4422], edge_attr=[4422, 2], y=[4422, 1], edge_mask=[4422], pair_mask=[4422], rev_edge_idx=[4422], filename=[1], L=[1], batch=[67], ptr=[2])
# DataBatch(x=[154, 16], edge_index=[2, 23562], edge_attr=[23562, 2], y=[23562, 1], edge_mask=[23562], pair_mask=[23562], rev_edge_idx=[23562], filename=[1], L=[1], batch=[154], ptr=[2])
# DataBatch(x=[68, 16], edge_index=[2, 4556], edge_attr=[4556, 2], y=[4556, 1], edge_mask=[4556], pair_mask=[4556], rev_edge_idx=[4556], filename=[1], L=[1], batch=[68], ptr=[2])
# DataBatch(x=[257, 16], edge_index=[2, 65792], edge_attr=[65792, 2], y=[65792, 1], edge_mask=[65792], pair_mask=[65792], rev_edge_idx=[65792], filename=[1], L=[1], batch=[257], ptr=[2])
# DataBatch(x=[299, 16], edge_index=[2, 89102], edge_attr=[89102, 2], y=[89102, 1], edge_mask=[89102], pair_mask=[89102], rev_edge_idx=[89102], filename=[1], L=[1], batch=[299], ptr=[2])
# DataBatch(x=[58, 16], edge_index=[2, 3306], edge_attr=[3306, 2], y=[3306, 1], edge_mask=[3306], pair_mask=[3306], rev_edge_idx=[3306], filename=[1], L=[1], batch=[58], ptr=[2])
# DataBatch(x=[179, 16], edge_index=[2, 31862], edge_attr=[31862, 2], y=[31862, 1], edge_mask=[31862], pair_mask=[31862], rev_edge_idx=[31862], filename=[1], L=[1], batch=[179], ptr=[2])

# %%
class AttentionMPLayer(MessagePassing):
    """Single attention-based message-passing layer (node + edge updates)."""

    def __init__(self, hidden_dim, heads=4, dropout=0.0):
        super().__init__(node_dim=0, aggr='add', flow='source_to_target')

        self.hidden_dim = hidden_dim
        self.heads = heads
        self.head_dim = hidden_dim // heads
        self.dropout = dropout

        assert hidden_dim % heads == 0, "hidden_dim must be divisible by heads"

        # Edge update MLP: [x_i, x_j, e_ij] -> e'_ij
        self.edge_mlp = nn.Sequential(
            nn.Linear(3 * hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, hidden_dim)
        )

        # Attention projections (Q, K spaces)
        self.att_lin_i = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_lin_j = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_lin_e = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_vec = nn.Parameter(torch.Tensor(1, heads, self.head_dim))

        # Message projections (V space)
        self.pay_lin_j = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.pay_lin_e = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)

        # Node update MLP: [x_i, aggregated_messages] -> x'_i
        self.node_mlp = nn.Sequential(
            nn.Linear(2 * hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.att_lin_i.weight)
        nn.init.xavier_uniform_(self.att_lin_j.weight)
        nn.init.xavier_uniform_(self.att_lin_e.weight)
        nn.init.xavier_uniform_(self.pay_lin_j.weight)
        nn.init.xavier_uniform_(self.pay_lin_e.weight)
        nn.init.xavier_uniform_(self.att_vec)

    def forward(self, x, edge_index, edge_attr):
        edge_attr_new = self.edge_updater(edge_index, x=x, edge_attr=edge_attr)
        message = self.propagate(edge_index, x=x, edge_attr=edge_attr_new)
        x_new = self.node_mlp(torch.cat([x, message], dim=-1))
        return x_new, edge_attr_new

    def edge_update(self, x_i, x_j, edge_attr):
        return self.edge_mlp(torch.cat([x_i, x_j, edge_attr], dim=-1))

    def message(self, x_i, x_j, edge_attr, index, ptr, size_i):
        q_i = self.att_lin_i(x_i).view(-1, self.heads, self.head_dim)
        k_j = self.att_lin_j(x_j).view(-1, self.heads, self.head_dim)
        k_e = self.att_lin_e(edge_attr).view(-1, self.heads, self.head_dim)

        score = F.leaky_relu(q_i + k_j + k_e, 0.2)
        alpha = (score * self.att_vec).sum(dim=-1)
        alpha = softmax(alpha, index, ptr, size_i)
        alpha = F.dropout(alpha, p=self.dropout, training=self.training)

        v_j = self.pay_lin_j(x_j).view(-1, self.heads, self.head_dim)
        v_e = self.pay_lin_e(edge_attr).view(-1, self.heads, self.head_dim)
        msg = (v_j + v_e) * alpha.unsqueeze(-1)
        return msg.view(-1, self.hidden_dim)

    def update(self, inputs, x):
        return inputs


class MP_GNN(nn.Module):
    """
    Attention MPNN for edge classification + SAGE contrastive learning.

    Returns (x_sage, out_reg, out_cls):
      x_sage   — L2-normalized node embeddings at layer num_layers_sage (for SAGE loss)
      out_reg  — per-edge regression logits [E]
      out_cls  — per-edge classification logits [E]
    """

    def __init__(self, num_layers=6, num_heads=2,
                 node_in_dim=16, edge_in_dim=16, latent_dim=32):
        super().__init__()

        assert latent_dim % num_heads == 0, "latent_dim must be divisible by num_heads"

        
        self.node_in_dim = node_in_dim
        self.edge_in_dim = edge_in_dim

        self.in_x_proj = nn.Linear(node_in_dim, latent_dim)
        self.sep_embedding = nn.Embedding(33, 8)

        self.edge_embed = nn.Sequential(
            nn.Linear(1 + 8, latent_dim),
            nn.ReLU(),
            nn.Linear(latent_dim, latent_dim),
        )

        self.convs = nn.ModuleList()
        self.node_norms = nn.ModuleList()
        self.edge_norms = nn.ModuleList()
        for _ in range(num_layers):
            self.node_norms.append(LayerNorm(latent_dim))
            self.edge_norms.append(LayerNorm(latent_dim))
            self.convs.append(AttentionMPLayer(hidden_dim=latent_dim, heads=num_heads, dropout=0.1))

        self.out_cls = nn.Sequential(
            nn.Linear(latent_dim, latent_dim),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Linear(latent_dim, 1)
        )


        self.out_reg = nn.Sequential(
            nn.Linear(latent_dim, latent_dim),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Linear(latent_dim, 1)
        )


    def forward(self, graph):
        x, edge_index, edge_attr = graph.x, graph.edge_index, graph.edge_attr

        x = self.in_x_proj(x)
        score = edge_attr[:, 0:1]
        sep_bucket = edge_attr[:, 1].long()

        sep_emb = self.sep_embedding(sep_bucket)

        edge_attr = torch.cat([score, sep_emb], dim=-1)

        edge_attr = self.edge_embed(edge_attr)

        for i, (conv, node_norm, edge_norm) in enumerate(zip(self.convs, self.node_norms, self.edge_norms)):
            x = node_norm(x)
            edge_attr = edge_norm(edge_attr)
            x_new, edge_attr_new = conv(x, edge_index, edge_attr)
            x = x + x_new
            edge_attr = edge_attr + edge_attr_new

            x = F.dropout(x, p=0.2, training=self.training)
            edge_attr = F.dropout(edge_attr, p=0.2, training=self.training)

        out_cls = self.out_cls(edge_attr).squeeze(-1)
        out_reg = self.out_reg(edge_attr).squeeze(-1)
        return x, out_reg, out_cls

# %%
def triangle_inequality_loss_sampled(pred_dist_matrix, mask_matrix, num_samples=10000):
    B, N, _ = pred_dist_matrix.shape
    device = pred_dist_matrix.device
    # Randomly pick i, j, k indices
    i = torch.randint(0, N, (num_samples,), device=pred_dist_matrix.device)
    j = torch.randint(0, N, (num_samples,), device=pred_dist_matrix.device)
    k = torch.randint(0, N, (num_samples,), device=pred_dist_matrix.device)
    
    d_ij = torch.exp(pred_dist_matrix[:, i, j])
    d_ik = torch.exp(pred_dist_matrix[:, i, k])
    d_kj = torch.exp(pred_dist_matrix[:, k, j])

    valid = (
        mask_matrix[:, i, j] &
        mask_matrix[:, i, k] &
        mask_matrix[:, k, j])
    
    violations = torch.relu(d_ij - (d_ik + d_kj))
    violations = violations[valid]
    if violations.numel() == 0:
        return torch.tensor(0.0, device=device)

    return torch.mean(violations**2)

# %%
from torch_geometric.utils import to_dense_adj
def compute_loss(batch, pred_dist, true_dist, epoch=0):
    valid = batch.edge_mask #& batch.pair_mask

    # separation bucket is already in edge_attr[:, 1]
    sep = batch.edge_attr[:, 1].long()

    #ignore very local pairs, upweight long-range ones
    weights = torch.ones_like(true_dist)

    weights[sep < 6] = 2.0
    weights[(sep >= 6) & (sep < 12)] = 3.0
    weights[sep >= 12] = 5.0        # long-range

    per_edge = F.smooth_l1_loss(
        pred_dist[valid],
        true_dist[valid],
        beta=0.1,
        reduction='none'
    )

    #main_loss
    main_loss = (weights[valid] * per_edge).sum() / (weights[valid].sum()+1e-8)

    #symmetry loss
    sym_loss = F.mse_loss(
        pred_dist[valid],
        pred_dist[batch.rev_edge_idx][valid]
    )

    #triangular loss
    dense_pred = to_dense_adj(batch.edge_index, batch.batch, edge_attr=pred_dist)
    dense_mask = to_dense_adj(batch.edge_index, batch.batch, edge_attr=batch.edge_mask.float()).bool()
    tri_loss = triangle_inequality_loss_sampled(dense_pred, dense_mask)

    λ_sym = min(0.1, epoch / 50 * 0.1)

    if epoch < 50:
        λ_tri = 0.0
    else:
        λ_tri = min(0.01, (epoch - 50) / 100 * 0.01)

    loss = main_loss + λ_sym * sym_loss + λ_tri * tri_loss
    
    return loss

# %%
def compute_pos_weight(loader, device):
    total_pos = 0
    total_neg = 0

    for batch in loader:
        batch = batch.to(device)

        y = batch.y.squeeze(-1)
        mask = batch.edge_mask #& batch.pair_mask  

        y = y[mask]

        total_pos += (y < 0).sum().item()
        total_neg += (y >= 0).sum().item()

    pos_weight = total_neg / max(total_pos, 1)
    return torch.tensor(pos_weight, dtype=torch.float, device=device)

# %%
# device= torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
# model = EdgeGNN(node_in_ch=16, sep_emb_dim=8, hidden_ch=64, mlp_hidden_ch=32, GNN_layers=3).to(device)

# save_path = "best_model_regressor+contact.pt"
# #to load an old model
# state_dict = torch.load(save_path)
# model.load_state_dict(state_dict)

# %%
def model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(
        p.numel() for p in model.parameters()
        if p.requires_grad
    )

    print(f"Total parameters:      {total_params:,}")
    print(f"Trainable parameters:  {trainable_params:,}")
    print(f"Non-trainable params:  {total_params - trainable_params:,}")

# %%
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
model = MP_GNN(
    num_layers=4,
    num_heads=4,
    node_in_dim=16,
    latent_dim=100
).to(device)

model_size(model)
save_path = "best_model_regressor+contact_C_alpha_drop_clip_new.pt"
#to load an old model
# state_dict = torch.load(save_path)
# model.load_state_dict(state_dict)


optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,mode='min',factor=0.5, patience=7,min_lr=1e-6)

pos_weight = compute_pos_weight(train_loader, device)
pos_weight = torch.tensor(8.0, device=device)  ###cambiato il pos weight, per vedere se è meglio clipparlo o no
print("pos_weight:", pos_weight.item())
loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight,reduction='mean')

tr=np.log(11/8)
# Out:
# Total parameters:      518,666
# Trainable parameters:  518,666
# Non-trainable params:  0
# pos_weight: 8.0

# %%
train_losses = []
val_losses = []

best_val_loss = float('inf')
patience = 50
epochs_no_improve = 0


for epoch in range(10000): 

    model.train()
    total_loss = 0.0
    total_edges = 0

    for batch in train_loader:
        batch = batch.to(device) 

        optimizer.zero_grad(set_to_none=True) 
        _, pred_dist, pred_logits = model(batch)

        mask = batch.edge_mask
        true_dist = batch.y.squeeze(-1)
        true_contacts = (true_dist < tr).float()   #contact at tr!
        pred_dist = pred_dist.squeeze(-1)
        pred_logits = pred_logits.squeeze(-1)

        loss_contact= loss_fn(pred_logits[mask], true_contacts[mask])

        loss_regression=compute_loss(batch,pred_dist,true_dist,epoch)

        loss = 3* loss_regression + loss_contact  #messo 3 per clipping

        #print(f"contact loss: {loss_contact.item()}, regression loss: {loss_regression.item()}")

        n_edges = mask.sum().item()
        total_loss += loss.item() * n_edges
        total_edges += n_edges

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)  #gradient clipping
        optimizer.step()
    
    train_loss = total_loss / max(total_edges, 1)
    
    model.eval()
    total_loss_val = 0.0
    total_edges_val = 0

    with torch.no_grad():

        loss_contact_tot=[]
        loss_regression_tot=[]
        for batch in test_loader:
            batch = batch.to(device)

            _, pred_dist,pred_logits = model(batch)

            mask = batch.edge_mask
            true_dist = batch.y.squeeze(-1)
            true_contacts = (true_dist < tr).float()
            pred_dist = pred_dist.squeeze(-1)
            pred_logits = pred_logits.squeeze(-1)

            loss_contact= loss_fn(pred_logits[mask], true_contacts[mask])

            loss_regression=compute_loss(batch,pred_dist,true_dist,epoch)

            loss_contact_tot.append(loss_contact.item())
            loss_regression_tot.append(loss_regression.item())

            loss = 3* loss_regression + loss_contact  #messo 3 per clipping
            
            n_edges = mask.sum().item()
            total_loss_val += loss.item() * n_edges
            total_edges_val += n_edges
    

    val_loss= total_loss_val / max(total_edges_val, 1)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]['lr']

    print(f"contact loss: {np.mean(loss_contact_tot):.4f}, regression loss: {np.mean(loss_regression_tot):.4f}")
    print(f"Epoch {epoch}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0

        torch.save(model.state_dict(), save_path)

    else:
        epochs_no_improve += 1

    if epochs_no_improve >= patience:
        print(f"Early stopping triggered after {epoch+1} epochs")
        break
# Out:
# contact loss: 1.0444, regression loss: 0.2762
# Epoch 0: Train Loss=1.7632, Val Loss=1.6864
# contact loss: 1.0287, regression loss: 0.2776
# Epoch 1: Train Loss=1.6282, Val Loss=1.6291
# contact loss: 1.0175, regression loss: 0.2681
# Epoch 2: Train Loss=1.6075, Val Loss=1.6058
# contact loss: 1.0146, regression loss: 0.2670
# Epoch 3: Train Loss=1.5970, Val Loss=1.5858
# contact loss: 1.0110, regression loss: 0.2587
# Epoch 4: Train Loss=1.5844, Val Loss=1.5687
# contact loss: 0.9941, regression loss: 0.2639
# Epoch 5: Train Loss=1.5744, Val Loss=1.5558
# contact loss: 0.9906, regression loss: 0.2545
# Epoch 6: Train Loss=1.5576, Val Loss=1.5498
# contact loss: 0.9763, regression loss: 0.2538
# Epoch 7: Train Loss=1.5344, Val Loss=1.5441
# contact loss: 0.9635, regression loss: 0.2491
# Epoch 8: Train Loss=1.5227, Val Loss=1.5108
# contact loss: 0.9797, regression loss: 0.2488
# Epoch 9: Train Loss=1.5142, Val Loss=1.5363
# contact loss: 0.9595, regression loss: 0.2564
# Epoch 10: Train Loss=1.5058, Val Loss=1.5347
# contact loss: 0.9537, regression loss: 0.2537
# Epoch 11: Train Loss=1.5014, Val Loss=1.5147
# contact loss: 0.9744, regression loss: 0.2412
# Epoch 12: Train Loss=1.4973, Val Loss=1.4981
# contact loss: 0.9522, regression loss: 0.2564
# Epoch 13: Train Loss=1.4936, Val Loss=1.5175
# contact loss: 0.9554, regression loss: 0.2510
# Epoch 14: Train Loss=1.4906, Val Loss=1.5125
# contact loss: 0.9562, regression loss: 0.2502
# Epoch 15: Train Loss=1.4835, Val Loss=1.4894
# contact loss: 0.9431, regression loss: 0.2443
# Epoch 16: Train Loss=1.4776, Val Loss=1.4764
# contact loss: 0.9432, regression loss: 0.2411
# Epoch 17: Train Loss=1.4685, Val Loss=1.4676
# contact loss: 0.9269, regression loss: 0.2375
# Epoch 18: Train Loss=1.4573, Val Loss=1.4380
# contact loss: 0.9272, regression loss: 0.2391
# Epoch 19: Train Loss=1.4443, Val Loss=1.4377
# contact loss: 0.9218, regression loss: 0.2370
# Epoch 20: Train Loss=1.4298, Val Loss=1.4337
# contact loss: 0.9036, regression loss: 0.2538
# Epoch 21: Train Loss=1.4144, Val Loss=1.4783
# contact loss: 0.8967, regression loss: 0.2402
# Epoch 22: Train Loss=1.4059, Val Loss=1.4329
# contact loss: 0.9008, regression loss: 0.2339
# Epoch 23: Train Loss=1.3948, Val Loss=1.4049
# contact loss: 0.8958, regression loss: 0.2299
# Epoch 24: Train Loss=1.3899, Val Loss=1.3757
# contact loss: 0.8823, regression loss: 0.2313
# Epoch 25: Train Loss=1.3739, Val Loss=1.3588
# contact loss: 0.8922, regression loss: 0.2462
# Epoch 26: Train Loss=1.3665, Val Loss=1.4112
# contact loss: 0.8813, regression loss: 0.2319
# Epoch 27: Train Loss=1.3594, Val Loss=1.3483
# contact loss: 0.8662, regression loss: 0.2360
# Epoch 28: Train Loss=1.3491, Val Loss=1.3619
# contact loss: 0.8671, regression loss: 0.2254
# Epoch 29: Train Loss=1.3412, Val Loss=1.3126
# contact loss: 0.8657, regression loss: 0.2414
# Epoch 30: Train Loss=1.3344, Val Loss=1.3647
# contact loss: 0.8584, regression loss: 0.2277
# Epoch 31: Train Loss=1.3273, Val Loss=1.3236
# contact loss: 0.8766, regression loss: 0.2289
# Epoch 32: Train Loss=1.3192, Val Loss=1.3433
# contact loss: 0.8683, regression loss: 0.2343
# Epoch 33: Train Loss=1.3153, Val Loss=1.3095
# contact loss: 0.8493, regression loss: 0.2162
# Epoch 34: Train Loss=1.3106, Val Loss=1.2816
# contact loss: 0.8538, regression loss: 0.2481
# Epoch 35: Train Loss=1.3029, Val Loss=1.3961
# contact loss: 0.8541, regression loss: 0.2233
# Epoch 36: Train Loss=1.2997, Val Loss=1.2889
# contact loss: 0.8670, regression loss: 0.2146
# Epoch 37: Train Loss=1.3002, Val Loss=1.2811
# contact loss: 0.8571, regression loss: 0.2276
# Epoch 38: Train Loss=1.2979, Val Loss=1.3293
# contact loss: 0.8510, regression loss: 0.2158
# Epoch 39: Train Loss=1.2960, Val Loss=1.2711
# contact loss: 0.8492, regression loss: 0.2166
# Epoch 40: Train Loss=1.2872, Val Loss=1.2781
# contact loss: 0.8471, regression loss: 0.2226
# Epoch 41: Train Loss=1.2868, Val Loss=1.2704
# contact loss: 0.8543, regression loss: 0.2184
# Epoch 42: Train Loss=1.2834, Val Loss=1.2807
# contact loss: 0.8446, regression loss: 0.2398
# Epoch 43: Train Loss=1.2802, Val Loss=1.3825
# contact loss: 0.8408, regression loss: 0.2317
# Epoch 44: Train Loss=1.2818, Val Loss=1.3258
# contact loss: 0.8457, regression loss: 0.2353
# Epoch 45: Train Loss=1.2767, Val Loss=1.3272
# contact loss: 0.8412, regression loss: 0.2334
# Epoch 46: Train Loss=1.2715, Val Loss=1.3007
# contact loss: 0.8390, regression loss: 0.2205
# Epoch 47: Train Loss=1.2716, Val Loss=1.2934
# contact loss: 0.8484, regression loss: 0.2176
# Epoch 48: Train Loss=1.2704, Val Loss=1.2800
# contact loss: 0.8439, regression loss: 0.2116
# Epoch 49: Train Loss=1.2679, Val Loss=1.2615
# contact loss: 0.8359, regression loss: 0.2319
# Epoch 50: Train Loss=1.2637, Val Loss=1.3114
# contact loss: 0.8533, regression loss: 0.2183
# Epoch 51: Train Loss=1.2625, Val Loss=1.2775
# contact loss: 0.8437, regression loss: 0.2103
# Epoch 52: Train Loss=1.2594, Val Loss=1.2397
# contact loss: 0.8390, regression loss: 0.2140
# Epoch 53: Train Loss=1.2582, Val Loss=1.2470
# contact loss: 0.8262, regression loss: 0.2224
# Epoch 54: Train Loss=1.2568, Val Loss=1.2747
# contact loss: 0.8321, regression loss: 0.2247
# Epoch 55: Train Loss=1.2560, Val Loss=1.3108
# contact loss: 0.8431, regression loss: 0.2141
# Epoch 56: Train Loss=1.2493, Val Loss=1.2722
# contact loss: 0.8437, regression loss: 0.2173
# Epoch 57: Train Loss=1.2521, Val Loss=1.2840
# contact loss: 0.8263, regression loss: 0.2166
# Epoch 58: Train Loss=1.2498, Val Loss=1.2766
# contact loss: 0.8294, regression loss: 0.2213
# Epoch 59: Train Loss=1.2489, Val Loss=1.2854
# contact loss: 0.8387, regression loss: 0.2233
# Epoch 60: Train Loss=1.2447, Val Loss=1.2575
# contact loss: 0.8215, regression loss: 0.2180
# Epoch 61: Train Loss=1.2264, Val Loss=1.2703
# contact loss: 0.8212, regression loss: 0.2104
# Epoch 62: Train Loss=1.2246, Val Loss=1.2395
# contact loss: 0.8231, regression loss: 0.2221
# Epoch 63: Train Loss=1.2253, Val Loss=1.2807
# contact loss: 0.8274, regression loss: 0.2122
# Epoch 64: Train Loss=1.2200, Val Loss=1.2401
# contact loss: 0.8170, regression loss: 0.2169
# Epoch 65: Train Loss=1.2226, Val Loss=1.2504
# contact loss: 0.8200, regression loss: 0.2149
# Epoch 66: Train Loss=1.2201, Val Loss=1.2436
# contact loss: 0.8306, regression loss: 0.2124
# Epoch 67: Train Loss=1.2193, Val Loss=1.2415
# contact loss: 0.8201, regression loss: 0.2091
# Epoch 68: Train Loss=1.2172, Val Loss=1.2340
# contact loss: 0.8241, regression loss: 0.2163
# Epoch 69: Train Loss=1.2157, Val Loss=1.2437
# contact loss: 0.8207, regression loss: 0.2132
# Epoch 70: Train Loss=1.2141, Val Loss=1.2388
# contact loss: 0.8174, regression loss: 0.2136
# Epoch 71: Train Loss=1.2123, Val Loss=1.2618
# contact loss: 0.8156, regression loss: 0.2164
# Epoch 72: Train Loss=1.2120, Val Loss=1.2493
# contact loss: 0.8229, regression loss: 0.2205
# Epoch 73: Train Loss=1.2125, Val Loss=1.2839
# contact loss: 0.8375, regression loss: 0.2075
# Epoch 74: Train Loss=1.2089, Val Loss=1.2362
# contact loss: 0.8124, regression loss: 0.2113
# Epoch 75: Train Loss=1.2077, Val Loss=1.2406
# contact loss: 0.8180, regression loss: 0.2132
# Epoch 76: Train Loss=1.2084, Val Loss=1.2528
# contact loss: 0.8218, regression loss: 0.2084
# Epoch 77: Train Loss=1.1994, Val Loss=1.2358
# contact loss: 0.8212, regression loss: 0.2136
# Epoch 78: Train Loss=1.1982, Val Loss=1.2460
# contact loss: 0.8170, regression loss: 0.2115
# Epoch 79: Train Loss=1.1974, Val Loss=1.2393
# contact loss: 0.8199, regression loss: 0.2149
# Epoch 80: Train Loss=1.1954, Val Loss=1.2596
# contact loss: 0.8126, regression loss: 0.2132
# Epoch 81: Train Loss=1.1963, Val Loss=1.2523
# contact loss: 0.8210, regression loss: 0.2112
# Epoch 82: Train Loss=1.1959, Val Loss=1.2481
# contact loss: 0.8240, regression loss: 0.2134
# Epoch 83: Train Loss=1.1963, Val Loss=1.2500
# contact loss: 0.8186, regression loss: 0.2190
# Epoch 84: Train Loss=1.1937, Val Loss=1.2779
# contact loss: 0.8167, regression loss: 0.2094
# Epoch 85: Train Loss=1.1903, Val Loss=1.2294
# contact loss: 0.8206, regression loss: 0.2108
# Epoch 86: Train Loss=1.1870, Val Loss=1.2446
# contact loss: 0.8184, regression loss: 0.2125
# Epoch 87: Train Loss=1.1882, Val Loss=1.2449
# contact loss: 0.8191, regression loss: 0.2137
# Epoch 88: Train Loss=1.1881, Val Loss=1.2376
# contact loss: 0.8155, regression loss: 0.2130
# Epoch 89: Train Loss=1.1869, Val Loss=1.2415
# contact loss: 0.8188, regression loss: 0.2131
# Epoch 90: Train Loss=1.1879, Val Loss=1.2438
# contact loss: 0.8182, regression loss: 0.2145
# Epoch 91: Train Loss=1.1861, Val Loss=1.2499
# contact loss: 0.8207, regression loss: 0.2133
# Epoch 92: Train Loss=1.1882, Val Loss=1.2529
# contact loss: 0.8231, regression loss: 0.2141
# Epoch 93: Train Loss=1.1854, Val Loss=1.2465
# contact loss: 0.8208, regression loss: 0.2113
# Epoch 94: Train Loss=1.1845, Val Loss=1.2407
# contact loss: 0.8191, regression loss: 0.2129
# Epoch 95: Train Loss=1.1842, Val Loss=1.2439
# contact loss: 0.8210, regression loss: 0.2104
# Epoch 96: Train Loss=1.1823, Val Loss=1.2392
# contact loss: 0.8194, regression loss: 0.2118
# Epoch 97: Train Loss=1.1826, Val Loss=1.2427
# contact loss: 0.8195, regression loss: 0.2107
# Epoch 98: Train Loss=1.1830, Val Loss=1.2368
# contact loss: 0.8194, regression loss: 0.2151
# Epoch 99: Train Loss=1.1821, Val Loss=1.2581
# contact loss: 0.8188, regression loss: 0.2144
# Epoch 100: Train Loss=1.1816, Val Loss=1.2516
# contact loss: 0.8175, regression loss: 0.2118
# Epoch 101: Train Loss=1.1823, Val Loss=1.2383
# contact loss: 0.8183, regression loss: 0.2122
# Epoch 102: Train Loss=1.1807, Val Loss=1.2410
# contact loss: 0.8216, regression loss: 0.2119
# Epoch 103: Train Loss=1.1814, Val Loss=1.2437
# contact loss: 0.8175, regression loss: 0.2133
# Epoch 104: Train Loss=1.1805, Val Loss=1.2465
# contact loss: 0.8196, regression loss: 0.2120
# Epoch 105: Train Loss=1.1806, Val Loss=1.2411
# contact loss: 0.8168, regression loss: 0.2120
# Epoch 106: Train Loss=1.1799, Val Loss=1.2419
# contact loss: 0.8186, regression loss: 0.2128
# Epoch 107: Train Loss=1.1807, Val Loss=1.2452
# contact loss: 0.8194, regression loss: 0.2117
# Epoch 108: Train Loss=1.1808, Val Loss=1.2417
# contact loss: 0.8185, regression loss: 0.2119
# Epoch 109: Train Loss=1.1807, Val Loss=1.2421
# contact loss: 0.8182, regression loss: 0.2132
# Epoch 110: Train Loss=1.1803, Val Loss=1.2464
# contact loss: 0.8191, regression loss: 0.2131
# Epoch 111: Train Loss=1.1791, Val Loss=1.2461
# contact loss: 0.8210, regression loss: 0.2120
# Epoch 112: Train Loss=1.1788, Val Loss=1.2440
# contact loss: 0.8197, regression loss: 0.2137
# Epoch 113: Train Loss=1.1800, Val Loss=1.2504
# contact loss: 0.8188, regression loss: 0.2123
# Epoch 114: Train Loss=1.1792, Val Loss=1.2447
# contact loss: 0.8195, regression loss: 0.2125
# Epoch 115: Train Loss=1.1793, Val Loss=1.2450
# contact loss: 0.8180, regression loss: 0.2127
# Epoch 116: Train Loss=1.1807, Val Loss=1.2445
# contact loss: 0.8183, regression loss: 0.2116
# Epoch 117: Train Loss=1.1796, Val Loss=1.2396
# contact loss: 0.8193, regression loss: 0.2116
# Epoch 118: Train Loss=1.1783, Val Loss=1.2414
# contact loss: 0.8193, regression loss: 0.2123
# Epoch 119: Train Loss=1.1785, Val Loss=1.2437
# contact loss: 0.8187, regression loss: 0.2132
# Epoch 120: Train Loss=1.1789, Val Loss=1.2459
# contact loss: 0.8203, regression loss: 0.2110
# Epoch 121: Train Loss=1.1786, Val Loss=1.2376
# contact loss: 0.8200, regression loss: 0.2131
# Epoch 122: Train Loss=1.1781, Val Loss=1.2474
# contact loss: 0.8197, regression loss: 0.2123
# Epoch 123: Train Loss=1.1790, Val Loss=1.2437
# contact loss: 0.8197, regression loss: 0.2122
# Epoch 124: Train Loss=1.1785, Val Loss=1.2424
# contact loss: 0.8187, regression loss: 0.2126
# Epoch 125: Train Loss=1.1783, Val Loss=1.2446
# contact loss: 0.8192, regression loss: 0.2122
# Epoch 126: Train Loss=1.1784, Val Loss=1.2427
# contact loss: 0.8185, regression loss: 0.2129
# Epoch 127: Train Loss=1.1782, Val Loss=1.2461
# contact loss: 0.8199, regression loss: 0.2120
# Epoch 128: Train Loss=1.1793, Val Loss=1.2430
# contact loss: 0.8189, regression loss: 0.2121
# Epoch 129: Train Loss=1.1781, Val Loss=1.2418
# contact loss: 0.8192, regression loss: 0.2121
# Epoch 130: Train Loss=1.1779, Val Loss=1.2430
# contact loss: 0.8179, regression loss: 0.2135
# Epoch 131: Train Loss=1.1786, Val Loss=1.2489
# contact loss: 0.8203, regression loss: 0.2121
# Epoch 132: Train Loss=1.1793, Val Loss=1.2439
# contact loss: 0.8194, regression loss: 0.2124
# Epoch 133: Train Loss=1.1791, Val Loss=1.2446
# contact loss: 0.8190, regression loss: 0.2127
# Epoch 134: Train Loss=1.1782, Val Loss=1.2456
# contact loss: 0.8192, regression loss: 0.2121
# Epoch 135: Train Loss=1.1779, Val Loss=1.2444
# Early stopping triggered after 136 epochs

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

model = MP_GNN(
    num_layers=4,
    num_heads=4,
    node_in_dim=16,
    latent_dim=100
).to(device)


save_path = "best_model_regressor+contact_C_alpha_drop_clip_new.pt"
tr=np.log(11/8)


state_dict = torch.load(save_path)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
def graph_to_matrix(data, values, mask=None):
    num_nodes = data.x.shape[0]
    mat = torch.zeros((num_nodes, num_nodes))

    edge_index = data.edge_index

    if mask is not None:
        edge_index = edge_index[:, mask]
        values = values[mask]
    mat[edge_index[0], edge_index[1]] = values.squeeze()

    return mat

# %% [markdown]
# Let's evaluate the contact prediction

# %%
#roc and precision recall curve

from sklearn.metrics import auc, precision_score, recall_score, f1_score, average_precision_score, roc_curve

model.eval()

all_probs = []
all_true = []

for batch in test_loader:
    batch = batch.to(device)

    with torch.no_grad():
        _, _, pred_logits = model(batch)
        probs = torch.sigmoid(pred_logits.squeeze(-1))

    true_dist = batch.y.squeeze(-1)
    true_contacts = (true_dist < tr).float()
    mask = batch.edge_mask & batch.pair_mask
  


    all_probs.append(probs[mask].cpu())
    all_true.append(true_contacts[mask].cpu())

all_probs = torch.cat(all_probs)
all_true = torch.cat(all_true)



# compute ROC
fpr, tpr, _ = roc_curve(all_true, all_probs)
roc_auc = auc(fpr, tpr)

print("Validation ROC AUC GNN:", roc_auc)


plt.figure()

plt.plot(fpr, tpr, label=f"GNN (AUC={roc_auc:.3f})")

plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()

#compute PR
from sklearn.metrics import precision_recall_curve, auc

precision, recall, _ = precision_recall_curve(all_true, all_probs)
pr_auc = auc(recall, precision)


print("PR AUC GNN:", pr_auc)


plt.figure()
plt.plot(recall, precision, label=f"PR AUC GNN = {pr_auc:.3f}")
plt.plot([1, 0], [0, 1], linestyle='--')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()

plt.show()
# Out:
# Validation ROC AUC GNN: 0.9259989021728312
# PR AUC GNN: 0.7313657362837518

# %%
def topk_L_precision(model, loader, device, ratio=1.0):
    model.eval()
    per_graph_precisions = []

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            _, _,logits = model(batch)

            probs = torch.sigmoid(logits.squeeze(-1))
            true_dist = batch.y.squeeze(-1)
            true_contacts = (true_dist < tr).float()

            valid_mask = batch.edge_mask & batch.pair_mask

            # graph id for each edge
            edge_graph_id = batch.batch[batch.edge_index[0]]

            num_graphs = batch.num_graphs

            for g in range(num_graphs):
                graph_mask = valid_mask & (edge_graph_id == g)

                probs_g = probs[graph_mask]
                true_g = true_contacts[graph_mask]

                if probs_g.numel() == 0:
                    continue

                # length of the protein
                L = int(batch.L[g]) if torch.is_tensor(batch.L) else int(batch.L)

                k = max(1, int(L * ratio))
                k = min(k, probs_g.numel())

                top_idx = torch.topk(probs_g, k=k).indices
                #knumber of true contacts in top-k​/k
                precision_g = (true_g[top_idx] > 0.5).float().mean().item()

                per_graph_precisions.append(precision_g)

    return float(np.mean(per_graph_precisions)), per_graph_precisions

print("Top-k*L precision:", topk_L_precision(model, test_loader, device, ratio=5)[0])
# Out:
# Top-k*L precision: 0.870568960522994

# %%
#loader = DataLoader([train_loader.dataset[10]], batch_size=1)
# loader = DataLoader([test_data[2]], batch_size=1)
# batch = next(iter(loader)).to(device)
k=2

prec=[]
prec_dca=[]
for batch in test_loader:
    batch = batch.to(device)

    #accuracy for a single batch
    with torch.no_grad():
        _, _,pred_logits = model(batch)
        scores = torch.sigmoid(pred_logits.squeeze(-1))
        scores_dca = batch.edge_attr[:, 0].squeeze(-1)  # DCA scores

    mask = batch.edge_mask & batch.pair_mask
    scores = scores[mask]
    scores_dca = scores_dca[mask]
    true_dist = batch.y.squeeze(-1)[mask]
    true_contacts = (true_dist < tr).float()
    
    L = batch.L
    topk = int(k * L)

    topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices
    topk_idx_dca = torch.topk(scores_dca, k=min(topk, scores_dca.numel())).indices

    topk_true = true_contacts[topk_idx]
    topk_true_dca = true_contacts[topk_idx_dca]

    num_correct = topk_true.sum()
    precision = (num_correct / len(topk_true)).item()
    prec.append(precision)

    num_correct_dca = topk_true_dca.sum()
    precision_dca = (num_correct_dca / len(topk_true_dca)).item()
    prec_dca.append(precision_dca)


print(f"Precision of the GNN: {np.mean(prec)}")
print(f"Precision of the DCA: {np.mean(prec_dca)}")
# Out:
# Precision of the GNN: 0.9948311478663714
# Precision of the DCA: 0.7438383265279043

# %%
k_values = [1,2,5]
results = {k: [] for k in k_values}
for k in k_values:
    vals= topk_L_precision(model, test_loader, device, ratio=k)[1]
    results[k].extend(vals)

for k in k_values:
    plt.hist(results[k], bins=40, histtype='step',linewidth=2, label=f"GNN k={k}")


plt.legend()
plt.title("Precision@kL distributions")
plt.show()

# %%
#precision in function of the number of contact to predict
total_k=np.linspace(0.1,10,20)
p_GNN=[]
p_DCA=[]
for k in total_k:

    prec=[]
    prec_dca=[]
    for batch in test_loader:
        batch = batch.to(device)

        #accuracy for a single batch
        with torch.no_grad():
            _, _,pred_logits = model(batch)
            scores = torch.sigmoid(pred_logits.squeeze(-1))
            scores_dca = batch.edge_attr[:, 0].squeeze(-1)  # DCA scores

        mask = batch.edge_mask & batch.pair_mask
        scores = scores[mask]
        scores_dca = scores_dca[mask]
        true_dist = batch.y.squeeze(-1)[mask]
        true_contacts = (true_dist < tr).float()
        
        L = batch.L
        topk = int(k * L)

        topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices
        topk_idx_dca = torch.topk(scores_dca, k=min(topk, scores_dca.numel())).indices

        topk_true = true_contacts[topk_idx]
        topk_true_dca = true_contacts[topk_idx_dca]

        num_correct = topk_true.sum()
        precision = (num_correct / len(topk_true)).item()
        prec.append(precision)

        num_correct_dca = topk_true_dca.sum()
        precision_dca = (num_correct_dca / len(topk_true_dca)).item()
        prec_dca.append(precision_dca)

    p_GNN.append(np.mean(prec))
    p_DCA.append(np.mean(prec_dca))

    

plt.figure()

plt.plot(total_k, p_GNN, label=f"Precision GNN")
plt.plot(total_k, p_DCA, label=f"Precision DCA")


plt.xlabel("k")
plt.ylabel("Precision")
plt.title("Precision of the top k*L contacts")
plt.legend()

plt.show()

# %% [markdown]
# Let's evaluate the regressor

# %%
def loss_per_graph(batch, pred_dist):
    scores = pred_dist.squeeze(-1)
    y_true = batch.y.squeeze(-1)

    mask = batch.edge_mask

    scores = scores[mask]
    y_true = y_true[mask]

    edge_batch = batch.batch[batch.edge_index[0]][mask]

    loss_tot = []

    for g in edge_batch.unique():
        g_mask = edge_batch == g

        g_scores = scores[g_mask]
        g_true = y_true[g_mask]

        if g_scores.numel() == 0:
            continue

        loss = torch.mean(torch.abs(g_scores - g_true))  # MAE per graph
        loss_tot.append(loss.item())

    return loss_tot

# %%
all_losses = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        _, pred_dist,_ = model(batch)

        loss_tot= loss_per_graph(batch,pred_dist)
        all_losses.extend(loss_tot)

print(np.mean(all_losses))

plt.hist(all_losses, bins=40, histtype='step',linewidth=2, label=f"GNN MEA")

plt.legend()
plt.title("Loss distributions")
plt.show()
# Out:
# 0.2485163090750575

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

all_pred = []
all_true = []

model.eval()

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)

        _, pred_dist, _ = model(batch)

        pred = pred_dist.squeeze(-1)
        true = batch.y.squeeze(-1)

        mask = batch.edge_mask

        pred = pred[mask]
        true = true[mask]

        all_pred.append(pred.cpu())
        all_true.append(true.cpu())

# concatenate everything
all_pred = torch.cat(all_pred).numpy()
all_true = torch.cat(all_true).numpy()

# scatter plot
plt.figure(figsize=(6,6))

plt.scatter(all_true, all_pred, s=10, alpha=0.5)

# ideal diagonal
min_val = min(all_true.min(), all_pred.min())
max_val = max(all_true.max(), all_pred.max())

plt.plot([min_val, max_val],
         [min_val, max_val],
         '--')

plt.xlabel("Real distance")
plt.ylabel("Predicted distance")
plt.title("Predicted vs Real Distances")
plt.grid(True)

plt.show()

# %%
all_original = []
all_true = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)

        original = batch.edge_attr[:, 0].squeeze(-1)  # DCA scores
        true = batch.y.squeeze(-1)

        mask = batch.edge_mask

        original = original[mask]
        true = true[mask]

        all_original.append(original.cpu())
        all_true.append(true.cpu())

all_original = torch.cat(all_original).numpy()
all_true = torch.cat(all_true).numpy()

plt.figure(figsize=(6,6))

plt.scatter(all_true, all_original, s=10, alpha=0.5)

min_val = min(all_true.min(), all_original.min())
max_val = max(all_true.max(), all_original.max())

plt.plot([min_val, max_val],
         [min_val, max_val],
         '--')

plt.xlabel("Real distance")
plt.ylabel("Original DCA score")
plt.title("DCA vs Real Distances")
plt.grid(True)

plt.show()

# %%
sorted_losses = sorted(enumerate(all_losses), key=lambda x: x[1])

# First 3 minimum values and their indices
# First 3 minimum values and their indices
for idx, val in sorted_losses[:10]:
    print(val, idx)

for idx, val in sorted_losses[len(sorted_losses)-3:len(sorted_losses)]:
    print(val, idx)
# Out:
# 0.10304669290781021 289
# 0.1383923441171646 300
# 0.14383769035339355 165
# 0.1451600044965744 39
# 0.14706622064113617 212
# 0.14720526337623596 269
# 0.14902327954769135 222
# 0.1521887332201004 48
# 0.15429435670375824 103
# 0.1549297422170639 176
# 0.47839608788490295 60
# 0.4791002571582794 64
# 0.49096283316612244 292

# %%
pos=39
i=0
with torch.no_grad():
    for batch in test_loader:
        if i==pos:
            batch = batch.to(device)
            _, pred_dist,_ = model(batch)
            break
        i+=1

#batch=train_data[pos]
print(batch)
print(batch.filename)

mask = batch.edge_mask #& batch.pair_mask

pred_dist_map = graph_to_matrix(batch, pred_dist.squeeze(-1).cpu(), mask.cpu())
true_dist_map = graph_to_matrix(batch, batch.y.cpu(),mask.cpu())
original_dca_map = graph_to_matrix(batch, batch.edge_attr[:,0].cpu())


fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns

# --- Predicted Distance Map ---
im0 = axes[0].imshow(pred_dist_map, cmap='coolwarm_r', origin='lower')
axes[0].set_title("Predicted Distance Map")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# --- True Distance Map ---


im1 = axes[1].imshow(true_dist_map, cmap='coolwarm_r', origin='lower')
axes[1].set_title("True Distance Map")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# --- Original DCA Map ---
im2 = axes[2].imshow(original_dca_map, cmap='coolwarm', origin='lower')
axes[2].set_title("Original DCA Map")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# DataBatch(x=[111, 16], edge_index=[2, 12210], edge_attr=[12210, 2], y=[12210, 1], edge_mask=[12210], pair_mask=[12210], rev_edge_idx=[12210], filename=[1], L=[1], batch=[111], ptr=[2])
# ['data_PF00072.pkl']

# %% [markdown]
# Let's try 3d reconstruct

# %%
#non guardare -> option 1

import numpy as np
from Bio.PDB import PDBParser, Polypeptide
from scipy.spatial.distance import pdist, squareform
from scipy.optimize import minimize


# ---------------------------------------------------------------------
# 1) Reproduce the same filtered residue order as mapPDBToHMM
# ---------------------------------------------------------------------
def get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds):
    """
    Rebuilds the residue list in the same spirit/order as mapPDBToHMM.
    Assumes chainIds is a string like 'A' or 'AB'.
    """
    chainIds = list(chainIds)
    structure = PDBParser(QUIET=True).get_structure('void', pdbFile)

    chains = structure[0].get_chains()
    residues = [chain.get_list() for chain in chains if chain.id in chainIds]
    residues = [res for resList in residues for res in resList]

    filtered_residues = []
    filtered_seq = []

    for res in residues:
        if Polypeptide.is_aa(res, standard=True):
            try:
                aa = Polypeptide.protein_letters_3to1[res.get_resname()]
            except Exception:
                continue
            filtered_residues.append(res)
            filtered_seq.append(aa)

    if len(filtered_residues) == 0:
        raise ValueError(f"No standard amino-acid residues found on chains {chainIds}")

    return filtered_residues, ''.join(filtered_seq)


# ---------------------------------------------------------------------
# 2) Representative coordinate per residue
# ---------------------------------------------------------------------
def residue_rep_coord(res, distType='all'):
    """
    distType:
      - 'all'   -> centroid of all atoms in the residue
      - 'alpha' -> CA
      - 'beta'  -> CB, or CA for GLY
    """
    if distType == 'alpha':
        if "CA" in res:
            return res["CA"].get_coord()
        # fallback
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    if distType == 'beta':
        if res.get_resname() == 'GLY':
            if "CA" in res:
                return res["CA"].get_coord()
        else:
            if "CB" in res:
                return res["CB"].get_coord()
        # fallback
        if "CA" in res:
            return res["CA"].get_coord()
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    # distType == 'all'
    atoms = [a.get_coord() for a in res.get_atoms()]
    return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])


def extract_reference_coords_from_mi(pdbFile, chainIds, mi, distType='all'):
    """
    Builds an array of shape (len(mi), 3), with NaN for gaps/unmapped positions.
    Your code suggests:
      - mi == -1 => gap
      - positive values are 1-based residue indices in the filtered residue list
    """
    residues, seq = get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds)
    rep_coords = np.asarray([residue_rep_coord(res, distType=distType) for res in residues], dtype=float)

    mi = np.asarray(mi, dtype=int)
    coords_full = np.full((len(mi), 3), np.nan, dtype=float)

    valid = mi >= 1   # matches your current convention
    idx = mi[valid] - 1
    if np.any(idx < 0) or np.any(idx >= len(rep_coords)):
        raise ValueError("mi contains indices outside the filtered residue list.")

    coords_full[valid] = rep_coords[idx]
    return coords_full, residues, seq


# ---------------------------------------------------------------------
# 3) Classical MDS initialization
# ---------------------------------------------------------------------
def classical_mds(D, n_components=3):
    """
    Classical MDS for a complete distance matrix.
    """
    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    D2 = D ** 2
    J = np.eye(n) - np.ones((n, n)) / n
    B = -0.5 * J @ D2 @ J

    evals, evecs = np.linalg.eigh(B)
    idx = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:, idx]

    vals = np.maximum(evals[:n_components], 0.0)
    X = evecs[:, :n_components] * np.sqrt(vals)
    return X


def initial_fill_for_mds(D):
    """
    Fill missing distances for a good initial guess.
    """
    D = np.asarray(D, dtype=float)
    out = D.copy()

    finite = np.isfinite(out)
    finite_vals = out[finite & ~np.eye(out.shape[0], dtype=bool)]
    if finite_vals.size == 0:
        raise ValueError("No finite distances available for reconstruction.")

    fill_value = np.median(finite_vals) * 1.5
    out[~np.isfinite(out)] = fill_value
    out = 0.5 * (out + out.T)
    np.fill_diagonal(out, 0.0)
    return out


# ---------------------------------------------------------------------
# 4) Reconstruction by stress minimization over observed pairs
# ---------------------------------------------------------------------
def reconstruct_3d_from_partial_distance_matrix(D, random_state=0, maxiter=800):
    """
    Reconstruct coordinates from a distance matrix that may contain inf entries.
    We minimize stress only over finite pairs.

    Returns:
        X: (N,3) coordinates
        stress: final MSE over observed pairs
        success: optimizer success flag
    """
    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    D0 = initial_fill_for_mds(D)
    X0 = classical_mds(D0, n_components=3)

    iu = np.triu_indices(n, k=1)
    obs = np.isfinite(D[iu])
    i_idx = iu[0][obs]
    j_idx = iu[1][obs]
    target = D[i_idx, j_idx]

    def objective(x_flat):
        X = x_flat.reshape(n, 3)
        d = np.linalg.norm(X[i_idx] - X[j_idx], axis=1)
        return np.mean((d - target) ** 2)

    res = minimize(
        objective,
        X0.ravel(),
        method='L-BFGS-B',
        options={'maxiter': maxiter, 'ftol': 1e-10}
    )

    X = res.x.reshape(n, 3)
    return X, float(res.fun), bool(res.success)


# ---------------------------------------------------------------------
# 5) Alignment and comparison to PDB coordinates
# ---------------------------------------------------------------------

def kabsch_align(P, Q):
    """
    Align P onto Q with optimal rotation after centering.
    Returns aligned P, centered Q, RMSD.
    """
    P = np.asarray(P, dtype=float)
    Q = np.asarray(Q, dtype=float)

    Pc = P - P.mean(axis=0)
    Qc = Q - Q.mean(axis=0)

    C = Pc.T @ Qc
    V, S, Wt = np.linalg.svd(C)
    d = np.sign(np.linalg.det(V @ Wt))
    R = V @ np.diag([1.0, 1.0, d]) @ Wt

    P_aligned = Pc @ R
    rmsd_val = np.sqrt(np.mean(np.sum((P_aligned - Qc) ** 2, axis=1)))
    return P_aligned, Qc, rmsd_val

def best_alignment_with_mirror(P, Q):
    """
    Distance maps cannot distinguish mirror images.
    Try both orientations and keep the better one.
    """
    P1, Qc1, r1 = kabsch_align(P, Q)

    Pm = P.copy()
    Pm[:, 0] *= -1
    P2, Qc2, r2 = kabsch_align(Pm, Q)

    if r2 < r1:
        return P2, Qc2, r2, "mirrored"
    return P1, Qc1, r1, "normal"

#if i want scaling
def optimal_scaling(P, Q):
    """
    Find scalar s minimizing ||sP - Q||^2
    """
    num = np.sum(P * Q)
    den = np.sum(P * P)
    return num / den

def align_with_scaling(P, Q):
    """
    Align P onto Q with rotation + scaling
    """
    # center
    Pc = P - P.mean(axis=0)
    Qc = Q - Q.mean(axis=0)

    # rotation (Kabsch)
    C = Pc.T @ Qc
    V, S, Wt = np.linalg.svd(C)
    d = np.sign(np.linalg.det(V @ Wt))
    R = V @ np.diag([1, 1, d]) @ Wt

    P_rot = Pc @ R

    # scaling
    s = optimal_scaling(P_rot, Qc)
    P_scaled = s * P_rot

    rmsd = np.sqrt(np.mean(np.sum((P_scaled - Qc)**2, axis=1)))

    return P_scaled, Qc, rmsd, s


def best_alignment_with_scaling_and_mirror(P, Q):
    # normal
    P1, Qc1, r1, s1 = align_with_scaling(P, Q)

    # mirrored
    Pm = P.copy()
    Pm[:, 0] *= -1
    P2, Qc2, r2, s2 = align_with_scaling(Pm, Q)

    if r2 < r1:
        return P2, Qc2, r2, s2, "mirrored"
    else:
        return P1, Qc1, r1, s1, "normal"



def distance_metrics(D_true, D_pred):
    """
    Compare two complete distance matrices on the upper triangle.
    """
    iu = np.triu_indices_from(D_true, k=1)
    a = D_true[iu]
    b = D_pred[iu]

    mask = np.isfinite(a) & np.isfinite(b)
    a = a[mask]
    b = b[mask]

    pearson = np.corrcoef(a, b)[0, 1] if len(a) > 1 else np.nan
    mae = np.mean(np.abs(a - b)) if len(a) else np.nan
    rmse = np.sqrt(np.mean((a - b) ** 2)) if len(a) else np.nan

    return {"pearson": pearson, "mae": mae, "rmse": rmse}


# ---------------------------------------------------------------------
# 6) End-to-end pipeline
# ---------------------------------------------------------------------
def reconstruct_and_compare_with_mapPDBToHMM(dm, mi, pdbFile, chainIds, distType='all'):
    """
    dm: output distance map from mapPDBToHMM
    mi: mapping indexes from mapPDBToHMM
    distType: must match the way the map was constructed
    """
    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # Use only residues that are mapped and have enough finite constraints
    valid = (mi >= 1) & (np.isfinite(dm).sum(axis=1) > 1)

    if valid.sum() < 4:
        raise ValueError("Too few mapped residues with finite distances to reconstruct 3D.")

    D_obs = dm[np.ix_(valid, valid)]

    # Reconstruct 3D from the observed map
    X_rec, stress, success = reconstruct_3d_from_partial_distance_matrix(D_obs)

    # Build PDB reference coordinates in the same order
    # For distType='all', centroid is the most reasonable comparison point.
    ref_coords_full, residues, seq = extract_reference_coords_from_mi(
        pdbFile, chainIds, mi, distType=distType
    )
    X_ref = ref_coords_full[valid]

    # Align reconstruction to the PDB reference
    X_aligned, X_ref_centered, coord_rmsd, scale, orientation = best_alignment_with_scaling_and_mirror(X_rec, X_ref)

    print("Scale factor:", scale)

    # Distance consistency of reconstructed 3D against observed dm
    D_rec = squareform(pdist(X_rec))
    dm_stats = distance_metrics(D_obs, D_rec)

    return {
        "X_rec": X_rec,
        "X_aligned": X_aligned,
        "X_ref_centered": X_ref_centered,
        "valid_mask": valid,
        "stress": stress,
        "optimizer_success": success,
        "coord_rmsd": coord_rmsd,
        "orientation": orientation,
        "distance_metrics": dm_stats,
        "D_obs": D_obs,
        "D_rec": D_rec,
    }

#plot

def plot_3d_overlay(X_ref, X_rec_aligned, title="3D comparison"):
    """
    X_ref: reference coordinates (from PDB, centered)
    X_rec_aligned: reconstructed coordinates aligned to reference
    """

    fig = plt.figure(figsize=(8, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot PDB reference
    ax.plot(
        X_ref[:, 0], X_ref[:, 1], X_ref[:, 2],
        label="PDB",
        linewidth=2
    )

    # Plot reconstructed
    ax.plot(
        X_rec_aligned[:, 0], X_rec_aligned[:, 1], X_rec_aligned[:, 2],
        linestyle='--',
        label="Reconstruction",
        linewidth=2
    )

    # Optionally connect corresponding residues (helps visually)
    for i in range(len(X_ref)):
        ax.plot(
            [X_ref[i, 0], X_rec_aligned[i, 0]],
            [X_ref[i, 1], X_rec_aligned[i, 1]],
            [X_ref[i, 2], X_rec_aligned[i, 2]],
            alpha=0.2
        )

    ax.set_title(title)
    ax.legend()
    plt.tight_layout()
    plt.show()


def plot_error_per_residue(X_ref, X_rec):
    errors = np.linalg.norm(X_ref - X_rec, axis=1)

    plt.figure(figsize=(7, 3))
    plt.plot(errors)
    plt.xlabel("Residue index")
    plt.ylabel("Distance error")
    plt.title("Per-residue reconstruction error")
    plt.tight_layout()
    plt.show()


def save_coords_as_pdb(coords, filename="reconstructed.pdb", chain_id="A"):
    """
    Save coordinates as a fake CA-only PDB for visualization.
    """
    with open(filename, "w") as f:
        for i, (x, y, z) in enumerate(coords, start=1):
            f.write(
                f"ATOM  {i:5d}  CA  ALA {chain_id}{i:4d}    "
                f"{x:8.3f}{y:8.3f}{z:8.3f}  1.00  0.00           C\n"
            )

                # Write CONECT records (chain connectivity)
        for i in range(1, len(coords)):
            f.write(f"CONECT{i:5d}{i+1:5d}\n")
            f.write(f"CONECT{i+1:5d}{i:5d}\n")
            
        f.write("END\n")

# %%
#option 2 (MDS + stess minimization)

import numpy as np
from Bio.PDB import PDBParser, Polypeptide
from scipy.spatial.distance import pdist, squareform
from scipy.optimize import minimize


# ---------------------------------------------------------------------
# 1) Reproduce the same filtered residue order as mapPDBToHMM
# ---------------------------------------------------------------------
def get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds):
    """
    Rebuilds the residue list in the same spirit/order as mapPDBToHMM.
    Assumes chainIds is a string like 'A' or 'AB'.
    """
    chainIds = list(chainIds)
    structure = PDBParser(QUIET=True).get_structure('void', pdbFile)

    chains = structure[0].get_chains()
    residues = [chain.get_list() for chain in chains if chain.id in chainIds]
    residues = [res for resList in residues for res in resList]

    filtered_residues = []
    filtered_seq = []

    for res in residues:
        if Polypeptide.is_aa(res, standard=True):
            try:
                aa = Polypeptide.protein_letters_3to1[res.get_resname()]
            except Exception:
                continue
            filtered_residues.append(res)
            filtered_seq.append(aa)

    if len(filtered_residues) == 0:
        raise ValueError(f"No standard amino-acid residues found on chains {chainIds}")

    return filtered_residues, ''.join(filtered_seq)


# ---------------------------------------------------------------------
# 2) Representative coordinate per residue
# ---------------------------------------------------------------------
def residue_rep_coord(res, distType='all'):
    """
    distType:
      - 'all'   -> centroid of all atoms in the residue
      - 'alpha' -> CA
      - 'beta'  -> CB, or CA for GLY
    """
    if distType == 'alpha':
        if "CA" in res:
            return res["CA"].get_coord()
        # fallback
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    if distType == 'beta':
        if res.get_resname() == 'GLY':
            if "CA" in res:
                return res["CA"].get_coord()
        else:
            if "CB" in res:
                return res["CB"].get_coord()
        # fallback
        if "CA" in res:
            return res["CA"].get_coord()
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    # distType == 'all'
    atoms = [a.get_coord() for a in res.get_atoms()]
    return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])


def extract_reference_coords_from_mi(pdbFile, chainIds, mi, distType='all'):
    """
    Builds an array of shape (len(mi), 3), with NaN for gaps/unmapped positions.
    Your code suggests:
      - mi == -1 => gap
      - positive values are 1-based residue indices in the filtered residue list
    """
    residues, seq = get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds)
    rep_coords = np.asarray([residue_rep_coord(res, distType=distType) for res in residues], dtype=float)

    mi = np.asarray(mi, dtype=int)
    coords_full = np.full((len(mi), 3), np.nan, dtype=float)

    valid = mi >= 1   # matches your current convention
    idx = mi[valid] - 1
    if np.any(idx < 0) or np.any(idx >= len(rep_coords)):
        raise ValueError("mi contains indices outside the filtered residue list.")

    coords_full[valid] = rep_coords[idx]
    return coords_full, residues, seq


#preprocess distance matrix 

def get_valid_mask(dm, mi, min_finite_per_row=1):
    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # residue exists in the mapped structure
    mapped = mi >= 1

    # residue has enough finite distances to be useful
    enough_contacts = np.isfinite(dm).sum(axis=1) >= min_finite_per_row

    return mapped & enough_contacts



# def preprocess_distance_matrix(D, q=0.98):
#     """
#     Symmetrize, remove infinities, and clip extreme values.
#     """
#     D = np.asarray(D, dtype=float)
#     D = 0.5 * (D + D.T)
#     np.fill_diagonal(D, 0.0)

#     finite = np.isfinite(D) & (D > 0)
#     vals = D[finite]

#     if vals.size == 0:
#         raise ValueError("No finite distances in matrix.")

#     fill_value = np.median(vals)
#     upper = np.quantile(vals, q)

#     D2 = D.copy()
#     D2[~np.isfinite(D2)] = fill_value  #########invece che il gap mette un valore medio, non sono sicuro vada molto bene
#     D2 = np.clip(D2, 0.0, upper)

#     return D2



# ---------------------------------------------------------------------
# 3) Classical MDS initialization
# ---------------------------------------------------------------------
def classical_mds(D, n_components=3):
    """
    Classical MDS for a complete distance matrix.
    """
    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    D2 = D ** 2
    J = np.eye(n) - np.ones((n, n)) / n
    B = -0.5 * J @ D2 @ J

    evals, evecs = np.linalg.eigh(B)
    idx = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:, idx]

    vals = np.maximum(evals[:n_components], 0.0)
    X = evecs[:, :n_components] * np.sqrt(vals)
    return X



# ---------------------------------------------------------------------
# 4) Reconstruction by stress minimization over observed pairs
# ---------------------------------------------------------------------
def huber_loss(r, delta=1.0):
    """
    Robust loss for residuals.
    """
    a = np.abs(r)
    return np.where(a <= delta, 0.5 * r * r, delta * (a - 0.5 * delta))


def robust_reconstruct_3d(
    D,
    ignore_band=2,
    chain_lambda=0.1,
    smooth_lambda=0.02,
    n_restarts=10,
    maxiter=1000,
    random_state=0,
):
    """
    Reconstruct 3D coordinates from a noisy distance matrix.

    ignore_band:
        ignore pairs with |i-j| <= ignore_band in the distance fit
        and let the smoothness prior handle local geometry.

    chain_lambda:
        soft penalty on consecutive residues staying too far apart.

    smooth_lambda:
        soft penalty on curvature of the chain.

    Returns:
        best_X, best_stress
    """
    rng = np.random.default_rng(random_state)
    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    if np.isinf(D).any() or np.isnan(D).any():
        raise ValueError("D must be gap-free and finite before reconstruction.")

    # enforce symmetry
    D = 0.5 * (D + D.T)
    np.fill_diagonal(D, 0.0)

    # initial guess
    X0 = classical_mds(D, n_components=3)

    iu = np.triu_indices(n, k=1)
    ii = iu[0]
    jj = iu[1]
    targets = D[ii, jj]

    # use only nonlocal pairs in the fit if requested
    keep = np.abs(ii - jj) > ignore_band
    ii = ii[keep]
    jj = jj[keep]
    targets = targets[keep]

    if len(targets) < 3:
        raise ValueError("Too few distance constraints for reconstruction.")

    #chain_target = np.median(np.diag(D, k=1)) if n > 1 else 0.0
    chain_target = 3.80

    def objective(x_flat):
        X = x_flat.reshape(n, 3)

        # fit observed nonlocal distances
        d_obs = np.linalg.norm(X[ii] - X[jj], axis=1)
        resid = d_obs - targets
        stress_data = np.mean(huber_loss(resid, delta=1.0))

        # weak chain continuity prior
        if n > 1:
            d_chain = np.linalg.norm(X[1:] - X[:-1], axis=1)
            stress_chain = np.mean(huber_loss(d_chain - chain_target, delta=1.0))
        else:
            stress_chain = 0.0

        # smoothness prior: avoid jagged backbone
        if n > 2:
            second_diff = X[2:] - 2 * X[1:-1] + X[:-2]
            stress_smooth = np.mean(np.sum(second_diff ** 2, axis=1))
        else:
            stress_smooth = 0.0

        return stress_data + chain_lambda * stress_chain + smooth_lambda * stress_smooth

    best_X = None
    best_fun = np.inf
    best_success = False
    
    for _ in range(n_restarts):
        x_init = X0 + 0.05 * rng.standard_normal(X0.shape)
        res = minimize(
            objective,
            x_init.ravel(),
            method="L-BFGS-B",
            options={"maxiter": maxiter, "ftol": 1e-10},
        )

        if res.fun < best_fun:
            best_fun = res.fun
            best_X = res.x.reshape(n, 3)
            best_success = res.success

    return best_X, best_fun, best_success


# ---------------------------------------------------------------------
# 5) Alignment and comparison to PDB coordinates
# ---------------------------------------------------------------------
#taking the pdb as the target, no gap
def extract_reference_coords_from_mi(pdbFile, chainIds, mi, distType='all'):
    residues, seq = get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds)
    rep_coords = np.asarray([residue_rep_coord(res, distType=distType) for res in residues], dtype=float)

    mi = np.asarray(mi, dtype=int)
    coords_full = np.full((len(mi), 3), np.nan, dtype=float)

    valid = mi >= 1
    idx = mi[valid] - 1

    if np.any(idx < 0) or np.any(idx >= len(rep_coords)):
        raise ValueError("mi contains indices outside the filtered residue list.")

    coords_full[valid] = rep_coords[idx]
    return coords_full, residues, seq



def kabsch_align(P, Q):
    """
    Align P onto Q with optimal rotation after centering.
    Returns aligned P, centered Q, RMSD.
    """
    P = np.asarray(P, dtype=float)
    Q = np.asarray(Q, dtype=float)

    Pc = P - P.mean(axis=0)
    Qc = Q - Q.mean(axis=0)

    C = Pc.T @ Qc
    V, S, Wt = np.linalg.svd(C)
    d = np.sign(np.linalg.det(V @ Wt))
    R = V @ np.diag([1.0, 1.0, d]) @ Wt

    P_aligned = Pc @ R
    rmsd_val = np.sqrt(np.mean(np.sum((P_aligned - Qc) ** 2, axis=1)))
    return P_aligned, Qc, rmsd_val

def best_alignment_with_mirror(P, Q):
    """
    Distance maps cannot distinguish mirror images.
    Try both orientations and keep the better one.
    """
    P1, Qc1, r1 = kabsch_align(P, Q)

    Pm = P.copy()
    Pm[:, 0] *= -1
    P2, Qc2, r2 = kabsch_align(Pm, Q)

    if r2 < r1:
        return P2, Qc2, r2, "mirrored"
    return P1, Qc1, r1, "normal"




#if i want scaling
def optimal_scaling(P, Q):
    """
    Find scalar s minimizing ||sP - Q||^2
    """
    num = np.sum(P * Q)
    den = np.sum(P * P)
    return num / den

def align_with_scaling(P, Q):
    """
    Align P onto Q with rotation + scaling
    """
    # center
    Pc = P - P.mean(axis=0)
    Qc = Q - Q.mean(axis=0)

    # rotation (Kabsch)
    C = Pc.T @ Qc
    V, S, Wt = np.linalg.svd(C)
    d = np.sign(np.linalg.det(V @ Wt))
    R = V @ np.diag([1, 1, d]) @ Wt

    P_rot = Pc @ R

    # scaling
    s = optimal_scaling(P_rot, Qc)
    P_scaled = s * P_rot

    rmsd = np.sqrt(np.mean(np.sum((P_scaled - Qc)**2, axis=1)))

    return P_scaled, Qc, rmsd, s


def best_alignment_with_scaling_and_mirror(P, Q):
    # normal
    P1, Qc1, r1, s1 = align_with_scaling(P, Q)

    # mirrored
    Pm = P.copy()
    Pm[:, 0] *= -1
    P2, Qc2, r2, s2 = align_with_scaling(Pm, Q)

    if r2 < r1:
        return P2, Qc2, r2, s2, "mirrored"
    else:
        return P1, Qc1, r1, s1, "normal"



def distance_metrics(D_true, D_pred):
    """
    Compare two complete distance matrices on the upper triangle.
    """
    iu = np.triu_indices_from(D_true, k=1)
    a = D_true[iu]
    b = D_pred[iu]

    mask = np.isfinite(a) & np.isfinite(b)
    a = a[mask]
    b = b[mask]

    pearson = np.corrcoef(a, b)[0, 1] if len(a) > 1 else np.nan
    mae = np.mean(np.abs(a - b)) if len(a) else np.nan
    rmse = np.sqrt(np.mean((a - b) ** 2)) if len(a) else np.nan

    return {"pearson": pearson, "mae": mae, "rmse": rmse}


# ---------------------------------------------------------------------
# 6) End-to-end pipeline
# ---------------------------------------------------------------------
def reconstruct_and_compare_with_mapPDBToHMM(dm, mi, pdbFile, chainIds, distType='all'):
    """
    dm: output distance map from mapPDBToHMM
    mi: mapping indexes from mapPDBToHMM
    distType: must match the way the map was constructed
    """
    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # residues that actually exist in the mapped structure
    valid = get_valid_mask(dm, mi, min_finite_per_row=1)

    if valid.sum() < 4:
        raise ValueError("Too few mapped residues with finite distances to reconstruct 3D.")

    D_obs = dm[np.ix_(valid, valid)]

    if np.isinf(D_obs).any() or np.isnan(D_obs).any():
        raise ValueError("Gap handling failed: D_obs must be fully finite after filtering.")


    # Reconstruct 3D from the observed map
    X_rec, stress, success = robust_reconstruct_3d(
    D_obs,
    ignore_band=2,
    chain_lambda=0.1, 
    smooth_lambda=0.02,
    n_restarts=20,
    maxiter=1500,
)
    # Build PDB reference coordinates in the same order
    # For distType='all', centroid is the most reasonable comparison point.
    ref_coords_full, residues, seq = extract_reference_coords_from_mi(
        pdbFile, chainIds, mi, distType=distType
    )
    X_ref = ref_coords_full[valid]

    # Align reconstruction to the PDB reference
    X_aligned, X_ref_centered, coord_rmsd, scale, orientation = best_alignment_with_scaling_and_mirror(X_rec, X_ref)
    
    print("Scale factor:", scale)

    # Distance consistency of reconstructed 3D against observed dm
    D_rec = squareform(pdist(X_rec))  ###here is the distance matrix of the reconstructed pdb
    dm_stats = distance_metrics(D_obs, D_rec)

    return {
        "X_rec": X_rec,
        "X_aligned": X_aligned,
        "X_ref_centered": X_ref_centered,
        "valid_mask": valid,
        "stress": stress,
        "coord_rmsd": coord_rmsd,
        "orientation": orientation,
        "distance_metrics": dm_stats,
        "D_obs": D_obs,
        "D_rec": D_rec,
    }


#plot

def plot_3d_overlay(X_ref, X_rec_aligned, title="3D comparison"):
    """
    X_ref: reference coordinates (from PDB, centered)
    X_rec_aligned: reconstructed coordinates aligned to reference
    """

    fig = plt.figure(figsize=(8, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot PDB reference
    ax.plot(
        X_ref[:, 0], X_ref[:, 1], X_ref[:, 2],
        label="PDB",
        linewidth=2
    )

    # Plot reconstructed
    ax.plot(
        X_rec_aligned[:, 0], X_rec_aligned[:, 1], X_rec_aligned[:, 2],
        linestyle='--',
        label="Reconstruction",
        linewidth=2
    )

    # Optionally connect corresponding residues (helps visually)
    for i in range(len(X_ref)):
        ax.plot(
            [X_ref[i, 0], X_rec_aligned[i, 0]],
            [X_ref[i, 1], X_rec_aligned[i, 1]],
            [X_ref[i, 2], X_rec_aligned[i, 2]],
            alpha=0.2
        )

    ax.set_title(title)
    ax.legend()
    plt.tight_layout()
    plt.show()


def plot_3d_overlay_masked(X_ref_full, X_rec_full, valid_mask,
                           title="3D comparison", show_connections=True):
    """
    Plot only residues that exist in the reconstructed subset.

    Parameters:
    - X_ref_full: (N,3) reference coordinates (with gaps as NaN or unused)
    - X_rec_full: (M,3) reconstructed coordinates (already filtered OR same size)
    - valid_mask: (N,) boolean mask of valid residues
    """

    valid_mask = np.asarray(valid_mask, dtype=bool)

    # Extract only valid residues from reference
    X_ref = X_ref_full[valid_mask]

    # Handle two cases:
    # 1) X_rec already filtered (same size as X_ref)
    # 2) X_rec is full-size → filter it
    if X_rec_full.shape[0] == valid_mask.shape[0]:
        X_rec = X_rec_full[valid_mask]
    else:
        X_rec = X_rec_full

    if X_ref.shape != X_rec.shape:
        raise ValueError(f"Shape mismatch: ref {X_ref.shape}, rec {X_rec.shape}")

    fig = plt.figure(figsize=(8, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot reference
    ax.plot(
        X_ref[:, 0], X_ref[:, 1], X_ref[:, 2],
        label="PDB (valid residues)",
        linewidth=2
    )

    # Plot reconstruction
    ax.plot(
        X_rec[:, 0], X_rec[:, 1], X_rec[:, 2],
        linestyle='--',
        label="Reconstruction",
        linewidth=2
    )

    # Optional: connect corresponding residues
    if show_connections:
        for i in range(len(X_ref)):
            ax.plot(
                [X_ref[i, 0], X_rec[i, 0]],
                [X_ref[i, 1], X_rec[i, 1]],
                [X_ref[i, 2], X_rec[i, 2]],
                alpha=0.2
            )

    ax.set_title(title)
    ax.legend()
    plt.tight_layout()
    plt.show()

def plot_error_per_residue(X_ref, X_rec):
    errors = np.linalg.norm(X_ref - X_rec, axis=1)

    plt.figure(figsize=(7, 3))
    plt.plot(errors)
    plt.xlabel("Residue index")
    plt.ylabel("Distance error")
    plt.title("Per-residue reconstruction error")
    plt.tight_layout()
    plt.show()


def save_coords_as_pdb(coords, filename="reconstructed.pdb", chain_id="A"):
    """
    Save coordinates as a fake CA-only PDB for visualization.
    """
    with open(filename, "w") as f:
        for i, (x, y, z) in enumerate(coords, start=1):
            f.write(
                f"ATOM  {i:5d}  CA  ALA {chain_id}{i:4d}    "
                f"{x:8.3f}{y:8.3f}{z:8.3f}  1.00  0.00           C\n"
            )

                # Write CONECT records (chain connectivity)
        for i in range(1, len(coords)):
            f.write(f"CONECT{i:5d}{i+1:5d}\n")
            f.write(f"CONECT{i+1:5d}{i:5d}\n")
            
        f.write("END\n")

# %%
#non guardare ->option3


import numpy as np
from Bio.PDB import PDBParser, Polypeptide
from scipy.spatial.distance import pdist, squareform
from scipy.optimize import minimize


# ---------------------------------------------------------------------
# 1) Reproduce the same filtered residue order as mapPDBToHMM
# ---------------------------------------------------------------------
def get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds):
    """
    Rebuilds the residue list in the same spirit/order as mapPDBToHMM.
    Assumes chainIds is a string like 'A' or 'AB'.
    """
    chainIds = list(chainIds)
    structure = PDBParser(QUIET=True).get_structure('void', pdbFile)

    chains = structure[0].get_chains()
    residues = [chain.get_list() for chain in chains if chain.id in chainIds]
    residues = [res for resList in residues for res in resList]

    filtered_residues = []
    filtered_seq = []

    for res in residues:
        if Polypeptide.is_aa(res, standard=True):
            try:
                aa = Polypeptide.protein_letters_3to1[res.get_resname()]
            except Exception:
                continue
            filtered_residues.append(res)
            filtered_seq.append(aa)

    if len(filtered_residues) == 0:
        raise ValueError(f"No standard amino-acid residues found on chains {chainIds}")

    return filtered_residues, ''.join(filtered_seq)


# ---------------------------------------------------------------------
# 2) Representative coordinate per residue
# ---------------------------------------------------------------------
def residue_rep_coord(res, distType='all'):
    """
    distType:
      - 'all'   -> centroid of all atoms in the residue
      - 'alpha' -> CA
      - 'beta'  -> CB, or CA for GLY
    """
    if distType == 'alpha':
        if "CA" in res:
            return res["CA"].get_coord()
        # fallback
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    if distType == 'beta':
        if res.get_resname() == 'GLY':
            if "CA" in res:
                return res["CA"].get_coord()
        else:
            if "CB" in res:
                return res["CB"].get_coord()
        # fallback
        if "CA" in res:
            return res["CA"].get_coord()
        atoms = [a.get_coord() for a in res.get_atoms()]
        return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])

    # distType == 'all'
    atoms = [a.get_coord() for a in res.get_atoms()]
    return np.mean(atoms, axis=0) if atoms else np.array([np.nan, np.nan, np.nan])


def extract_reference_coords_from_mi(pdbFile, chainIds, mi, distType='all'):
    """
    Builds an array of shape (len(mi), 3), with NaN for gaps/unmapped positions.
    Your code suggests:
      - mi == -1 => gap
      - positive values are 1-based residue indices in the filtered residue list
    """
    residues, seq = get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds)
    rep_coords = np.asarray([residue_rep_coord(res, distType=distType) for res in residues], dtype=float)

    mi = np.asarray(mi, dtype=int)
    coords_full = np.full((len(mi), 3), np.nan, dtype=float)

    valid = mi >= 1   # matches your current convention
    idx = mi[valid] - 1
    if np.any(idx < 0) or np.any(idx >= len(rep_coords)):
        raise ValueError("mi contains indices outside the filtered residue list.")

    coords_full[valid] = rep_coords[idx]
    return coords_full, residues, seq


#preprocess distance matrix 

def get_valid_mask(dm, mi, min_finite_per_row=1):
    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # residue exists in the mapped structure
    mapped = mi >= 1

    # residue has enough finite distances to be useful
    enough_contacts = np.isfinite(dm).sum(axis=1) >= min_finite_per_row

    return mapped & enough_contacts



# def preprocess_distance_matrix(D, q=0.98):
#     """
#     Symmetrize, remove infinities, and clip extreme values.
#     """
#     D = np.asarray(D, dtype=float)
#     D = 0.5 * (D + D.T)
#     np.fill_diagonal(D, 0.0)

#     finite = np.isfinite(D) & (D > 0)
#     vals = D[finite]

#     if vals.size == 0:
#         raise ValueError("No finite distances in matrix.")

#     fill_value = np.median(vals)
#     upper = np.quantile(vals, q)

#     D2 = D.copy()
#     D2[~np.isfinite(D2)] = fill_value  #########invece che il gap mette un valore medio, non sono sicuro vada molto bene
#     D2 = np.clip(D2, 0.0, upper)

#     return D2



# ---------------------------------------------------------------------
# 3) Classical MDS initialization
# ---------------------------------------------------------------------
def classical_mds(D, n_components=3):
    """
    Classical MDS for a complete distance matrix.
    """
    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    D2 = D ** 2
    J = np.eye(n) - np.ones((n, n)) / n
    B = -0.5 * J @ D2 @ J

    evals, evecs = np.linalg.eigh(B)
    idx = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:, idx]

    vals = np.maximum(evals[:n_components], 0.0)
    X = evecs[:, :n_components] * np.sqrt(vals)
    return X



# ---------------------------------------------------------------------
# 4) Reconstruction by stress minimization over observed pairs
# ---------------------------------------------------------------------


def robust_reconstruct_3d_exact_bonds(
    D,
    valid_mask,
    bond_len=3.8,
    ignore_band=2,
    smooth_lambda=0.02,
    n_restarts=10,
    maxiter=1000,
    random_state=0,
):
    """
    Reconstruct 3D coordinates from a distance matrix while enforcing
    exact backbone bond length between consecutive REAL residues.

    Parameters
    ----------
    D : (N, N) array
        Full distance matrix. Gaps may be NaN/inf anywhere.
    valid_mask : (N,) boolean array
        True for real residues, False for gaps.
    bond_len : float
        Exact distance between consecutive residues in the compact chain.
    ignore_band : int
        Ignore pairs with |i-j| <= ignore_band in the distance fit.
        This is applied after removing gaps.
    smooth_lambda : float
        Weight of curvature regularization.
    n_restarts : int
        Number of random restarts.
    maxiter : int
        Max optimizer iterations.
    random_state : int
        RNG seed.

    Returns
    -------
    X_full : (N, 3) array
        Reconstructed coordinates with NaN at gaps.
    X_compact : (M, 3) array
        Coordinates for only the real residues.
    best_fun : float
        Final objective value.
    best_success : bool
        Optimizer success flag.
    valid_idx : (M,) array
        Indices of real residues in the original full array.
    """
    rng = np.random.default_rng(random_state)

    D = np.asarray(D, dtype=float)
    valid_mask = np.asarray(valid_mask, dtype=bool)

    if D.ndim != 2 or D.shape[0] != D.shape[1]:
        raise ValueError("D must be a square matrix.")
    if len(valid_mask) != D.shape[0]:
        raise ValueError("valid_mask must have the same length as D.shape[0].")

    # Keep only real residues
    valid_idx = np.flatnonzero(valid_mask)
    m = len(valid_idx)

    if m < 2:
        raise ValueError("Need at least 2 real residues to reconstruct a chain.")

    # Compact observed matrix
    D_obs = D[np.ix_(valid_idx, valid_idx)].copy()
    D_obs = 0.5 * (D_obs + D_obs.T)
    np.fill_diagonal(D_obs, 0.0)

    # Use only finite nonlocal pairs in the fit
    iu = np.triu_indices(m, k=1)
    ii, jj = iu
    targets = D_obs[ii, jj]

    keep = np.isfinite(targets) & (np.abs(ii - jj) > ignore_band)
    ii = ii[keep]
    jj = jj[keep]
    targets = targets[keep]

    if len(targets) < 3:
        raise ValueError("Too few usable distance constraints after filtering.")

    def huber_loss(r, delta=1.0):
        a = np.abs(r)
        return np.where(a <= delta, 0.5 * r * r, delta * (a - 0.5 * delta))

    def classical_mds(Dmat, n_components=3):
        Dmat = np.asarray(Dmat, dtype=float)
        n = Dmat.shape[0]
        D2 = Dmat ** 2
        J = np.eye(n) - np.ones((n, n)) / n
        B = -0.5 * J @ D2 @ J
        evals, evecs = np.linalg.eigh(B)
        idx = np.argsort(evals)[::-1]
        evals = evals[idx]
        evecs = evecs[:, idx]
        vals = np.maximum(evals[:n_components], 0.0)
        return evecs[:, :n_components] * np.sqrt(vals)

    def build_coords(params):
        """
        Params:
          - first 3 values: x0
          - remaining values: raw direction vectors for each bond
        Bond length is enforced exactly by normalization.
        """
        x0 = params[:3]

        if m == 1:
            return x0[None, :]

        U = params[3:].reshape(m - 1, 3)
        norms = np.linalg.norm(U, axis=1, keepdims=True)
        dirs = U / np.maximum(norms, 1e-12)   # unit directions
        steps = bond_len * dirs

        X = np.empty((m, 3), dtype=float)
        X[0] = x0
        X[1:] = x0 + np.cumsum(steps, axis=0)
        return X

    def objective(params):
        X = build_coords(params)

        # Fit observed distances
        d_obs = np.linalg.norm(X[ii] - X[jj], axis=1)
        resid = d_obs - targets
        stress_data = np.mean(huber_loss(resid, delta=1.0))

        # Optional smoothness prior
        if m > 2:
            second_diff = X[2:] - 2 * X[1:-1] + X[:-2]
            stress_smooth = np.mean(np.sum(second_diff ** 2, axis=1))
        else:
            stress_smooth = 0.0

        return stress_data + smooth_lambda * stress_smooth

    # Initial guess from MDS
    X0 = classical_mds(D_obs, n_components=3)
    if not np.all(np.isfinite(X0)) or np.allclose(X0, 0):
        X0 = rng.normal(size=(m, 3))

    if m == 1:
        base_params = X0[0].copy()
    else:
        diffs = np.diff(X0, axis=0)
        norms = np.linalg.norm(diffs, axis=1, keepdims=True)
        dirs0 = diffs / np.maximum(norms, 1e-12)
        U0 = dirs0 + 0.05 * rng.standard_normal(dirs0.shape)
        base_params = np.concatenate([X0[0], U0.ravel()])

    best_fun = np.inf
    best_X = None
    best_success = False

    for _ in range(n_restarts):
        p0 = base_params.copy()
        if m >= 1:
            p0[:3] += 0.2 * rng.standard_normal(3)
        if m > 1:
            p0[3:] += 0.2 * rng.standard_normal(p0[3:].shape)

        res = minimize(
            objective,
            p0,
            method="L-BFGS-B",
            options={"maxiter": maxiter, "ftol": 1e-10},
        )

        if res.fun < best_fun:
            best_fun = res.fun
            best_X = build_coords(res.x)
            best_success = res.success

    # Expand back to full length, with NaN at gaps
    X_full = np.full((D.shape[0], 3), np.nan, dtype=float)
    X_full[valid_idx] = best_X

    return X_full, best_X, best_fun, best_success, valid_idx


# ---------------------------------------------------------------------
# 5) Alignment and comparison to PDB coordinates
# ---------------------------------------------------------------------
#taking the pdb as the target, no gap
def extract_reference_coords_from_mi(pdbFile, chainIds, mi, distType='all'):
    residues, seq = get_filtered_residues_like_mapPDBToHMM(pdbFile, chainIds)
    rep_coords = np.asarray([residue_rep_coord(res, distType=distType) for res in residues], dtype=float)

    mi = np.asarray(mi, dtype=int)
    coords_full = np.full((len(mi), 3), np.nan, dtype=float)

    valid = mi >= 1
    idx = mi[valid] - 1

    if np.any(idx < 0) or np.any(idx >= len(rep_coords)):
        raise ValueError("mi contains indices outside the filtered residue list.")

    coords_full[valid] = rep_coords[idx]
    return coords_full, residues, seq



def kabsch_align(P, Q):
    """
    Align P onto Q with optimal rotation after centering.
    Returns aligned P, centered Q, RMSD.
    """
    P = np.asarray(P, dtype=float)
    Q = np.asarray(Q, dtype=float)

    Pc = P - P.mean(axis=0)
    Qc = Q - Q.mean(axis=0)

    C = Pc.T @ Qc
    V, S, Wt = np.linalg.svd(C)
    d = np.sign(np.linalg.det(V @ Wt))
    R = V @ np.diag([1.0, 1.0, d]) @ Wt

    P_aligned = Pc @ R
    rmsd_val = np.sqrt(np.mean(np.sum((P_aligned - Qc) ** 2, axis=1)))
    return P_aligned, Qc, rmsd_val

def best_alignment_with_mirror(P, Q):
    """
    Distance maps cannot distinguish mirror images.
    Try both orientations and keep the better one.
    """
    P1, Qc1, r1 = kabsch_align(P, Q)

    Pm = P.copy()
    Pm[:, 0] *= -1
    P2, Qc2, r2 = kabsch_align(Pm, Q)

    if r2 < r1:
        return P2, Qc2, r2, "mirrored"
    return P1, Qc1, r1, "normal"




def distance_metrics(D_true, D_pred):
    """
    Compare two complete distance matrices on the upper triangle.
    """
    iu = np.triu_indices_from(D_true, k=1)
    a = D_true[iu]
    b = D_pred[iu]

    mask = np.isfinite(a) & np.isfinite(b)
    a = a[mask]
    b = b[mask]

    pearson = np.corrcoef(a, b)[0, 1] if len(a) > 1 else np.nan
    mae = np.mean(np.abs(a - b)) if len(a) else np.nan
    rmse = np.sqrt(np.mean((a - b) ** 2)) if len(a) else np.nan

    return {"pearson": pearson, "mae": mae, "rmse": rmse}


# ---------------------------------------------------------------------
# 6) End-to-end pipeline
# ---------------------------------------------------------------------
def reconstruct_and_compare_with_mapPDBToHMM(dm, mi, pdbFile, chainIds, distType='alpha'):
    """
    dm: output distance map from mapPDBToHMM
    mi: mapping indexes from mapPDBToHMM
    distType: must match the way the map was constructed
    """
    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # residues that actually exist in the mapped structure
    valid = get_valid_mask(dm, mi, min_finite_per_row=1)

    if valid.sum() < 4:
        raise ValueError("Too few mapped residues with finite distances to reconstruct 3D.")

    D_obs = dm[np.ix_(valid, valid)]

    if np.isinf(D_obs).any() or np.isnan(D_obs).any():
        raise ValueError("Gap handling failed: D_obs must be fully finite after filtering.")


    X_full, X_rec, stress, success, valid_idx = robust_reconstruct_3d_exact_bonds(
        dm,
        valid_mask=valid,
        bond_len=3.8,
        ignore_band=2,
        smooth_lambda=0.02,
        n_restarts=20,
        maxiter=1500,
    )
    # Build PDB reference coordinates in the same order
    # For distType='all', centroid is the most reasonable comparison point.
    ref_coords_full, residues, seq = extract_reference_coords_from_mi(
        pdbFile, chainIds, mi, distType=distType
    )
    X_ref = ref_coords_full[valid]

    # Align reconstruction to the PDB reference
    X_aligned, X_ref_centered, coord_rmsd, orientation = best_alignment_with_mirror(X_rec, X_ref)
    

    # Distance consistency of reconstructed 3D against observed dm
    D_rec = squareform(pdist(X_rec))
    dm_stats = distance_metrics(D_obs, D_rec)

    return {
        "X_rec": X_rec,
        "X_aligned": X_aligned,
        "X_ref_centered": X_ref_centered,
        "valid_mask": valid,
        "stress": stress,
        "coord_rmsd": coord_rmsd,
        "orientation": orientation,
        "distance_metrics": dm_stats,
        "D_obs": D_obs,
        "D_rec": D_rec,
    }


#plot

def plot_3d_overlay_masked(X_ref_full, X_rec_full, valid_mask,
                           title="3D comparison", show_connections=True):
    """
    Plot only residues that exist in the reconstructed subset.

    Parameters:
    - X_ref_full: (N,3) reference coordinates (with gaps as NaN or unused)
    - X_rec_full: (M,3) reconstructed coordinates (already filtered OR same size)
    - valid_mask: (N,) boolean mask of valid residues
    """

    valid_mask = np.asarray(valid_mask, dtype=bool)

    # Extract only valid residues from reference
    X_ref = X_ref_full[valid_mask]

    # Handle two cases:
    # 1) X_rec already filtered (same size as X_ref)
    # 2) X_rec is full-size → filter it
    if X_rec_full.shape[0] == valid_mask.shape[0]:
        X_rec = X_rec_full[valid_mask]
    else:
        X_rec = X_rec_full

    if X_ref.shape != X_rec.shape:
        raise ValueError(f"Shape mismatch: ref {X_ref.shape}, rec {X_rec.shape}")

    fig = plt.figure(figsize=(8, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot reference
    ax.plot(
        X_ref[:, 0], X_ref[:, 1], X_ref[:, 2],
        label="PDB (valid residues)",
        linewidth=2
    )

    # Plot reconstruction
    ax.plot(
        X_rec[:, 0], X_rec[:, 1], X_rec[:, 2],
        linestyle='--',
        label="Reconstruction",
        linewidth=2
    )

    # Optional: connect corresponding residues
    if show_connections:
        for i in range(len(X_ref)):
            ax.plot(
                [X_ref[i, 0], X_rec[i, 0]],
                [X_ref[i, 1], X_rec[i, 1]],
                [X_ref[i, 2], X_rec[i, 2]],
                alpha=0.2
            )

    ax.set_title(title)
    ax.legend()
    plt.tight_layout()
    plt.show()

def plot_error_per_residue(X_ref, X_rec):
    errors = np.linalg.norm(X_ref - X_rec, axis=1)

    plt.figure(figsize=(7, 3))
    plt.plot(errors)
    plt.xlabel("Residue index")
    plt.ylabel("Distance error")
    plt.title("Per-residue reconstruction error")
    plt.tight_layout()
    plt.show()


def save_coords_as_pdb(coords, filename="reconstructed.pdb", chain_id="A"):
    """
    Save coordinates as a fake CA-only PDB for visualization.
    """
    with open(filename, "w") as f:
        for i, (x, y, z) in enumerate(coords, start=1):
            f.write(
                f"ATOM  {i:5d}  CA  ALA {chain_id}{i:4d}    "
                f"{x:8.3f}{y:8.3f}{z:8.3f}  1.00  0.00           C\n"
            )

                # Write CONECT records (chain connectivity)
        for i in range(1, len(coords)):
            f.write(f"CONECT{i:5d}{i+1:5d}\n")
            f.write(f"CONECT{i+1:5d}{i:5d}\n")
            
        f.write("END\n")

# %%
#non guardare -> option 4


import numpy as np
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform


# ==========================================================
# Low-rank EDM reconstruction
# ==========================================================

def lowrank_edm_reconstruct(
    D,
    rank=3,
    mask=None,
    n_restarts=10,
    maxiter=1500,
    random_state=0,
):
    """
    Low-rank Euclidean Distance Matrix fitting.

    Solves:

        min_X sum_ij w_ij (||x_i-x_j||^2 - D_ij^2)^2

    where:
        X in R^{n x rank}

    Parameters
    ----------
    D : ndarray (n,n)
        Distance matrix.
    rank : int
        Embedding dimension.
    mask : ndarray (n,n) or None
        Binary mask for observed entries.
    n_restarts : int
        Number of random restarts.
    maxiter : int
        L-BFGS iterations.

    Returns
    -------
    X_best : ndarray (n, rank)
    best_loss : float
    """

    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    # Symmetrize
    D = 0.5 * (D + D.T)

    # Squared distances
    D2 = D ** 2

    # Observation mask
    if mask is None:
        W = np.isfinite(D).astype(float)
    else:
        W = mask.astype(float)

    np.fill_diagonal(W, 0.0)

    # Replace NaNs
    D2 = np.nan_to_num(D2, nan=0.0)

    best_loss = np.inf
    X_best = None

    def objective_and_grad(x_flat):
        X = x_flat.reshape(n, rank)

        diff = X[:, None, :] - X[None, :, :]
        dist2 = np.sum(diff**2, axis=2)

        R = W * (dist2 - D2)

        obj = 0.5 * np.sum(R**2)

        grad = np.zeros_like(X)

        for i in range(n):
            grad[i] = 4.0 * np.sum(
                R[i, :, None] * diff[i],
                axis=0
            )

        return obj, grad.ravel()

    rng = np.random.default_rng(random_state)

    for restart in range(n_restarts):

        X0 = 0.01 * rng.normal(size=(n, rank))

        result = minimize(
            fun=lambda x: objective_and_grad(x)[0],
            x0=X0.ravel(),
            jac=lambda x: objective_and_grad(x)[1],
            method="L-BFGS-B",
            options={
                "maxiter": maxiter,
                "ftol": 1e-12,
            },
        )

        if result.fun < best_loss:
            best_loss = result.fun
            X_best = result.x.reshape(n, rank)

    return X_best, best_loss


# ==========================================================
# Your pipeline
# ==========================================================

def reconstruct_and_compare_with_mapPDBToHMM(
    dm,
    mi,
    pdbFile,
    chainIds,
    distType='all'
):
    """
    dm: output distance map from mapPDBToHMM
    mi: mapping indexes from mapPDBToHMM
    distType: must match the way the map was constructed
    """

    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # ======================================================
    # Keep only valid mapped residues
    # ======================================================

    valid = (
        (mi >= 1)
        & (np.isfinite(dm).sum(axis=1) > 1)
    )

    if valid.sum() < 4:
        raise ValueError(
            "Too few mapped residues with finite distances "
            "to reconstruct 3D."
        )

    D_obs = dm[np.ix_(valid, valid)]

    # ======================================================
    # Preprocess distance matrix
    # ======================================================

    if np.isinf(D_obs).any() or np.isnan(D_obs).any():
        raise ValueError("Gap handling failed: D_obs must be fully finite after filtering.")
    D_clean = D_obs

    # ======================================================
    # Build observation mask
    # ======================================================

    mask = np.isfinite(D_clean).astype(float)

    # Replace NaNs/infs
    D_clean = np.nan_to_num(D_clean, nan=0.0)

    # ======================================================
    # LOW-RANK EDM FITTING
    # ======================================================

    X_rec, stress = lowrank_edm_reconstruct(
        D_clean,
        rank=3,
        mask=mask,
        n_restarts=20,
        maxiter=1500,
    )

    # ======================================================
    # Build PDB reference coordinates
    # ======================================================

    ref_coords_full, residues, seq = \
        extract_reference_coords_from_mi(
            pdbFile,
            chainIds,
            mi,
            distType=distType
        )

    X_ref = ref_coords_full[valid]

    # ======================================================
    # Align reconstruction to reference
    # ======================================================

    X_aligned, X_ref_centered, coord_rmsd, scale, orientation = \
        best_alignment_with_scaling_and_mirror(
            X_rec,
            X_ref
        )

    print("Scale factor:", scale)

    # ======================================================
    # Distance consistency
    # ======================================================

    D_rec = squareform(pdist(X_rec))

    dm_stats = distance_metrics(
        D_obs,
        D_rec
    )

    return {
        "X_rec": X_rec,
        "X_aligned": X_aligned,
        "X_ref_centered": X_ref_centered,
        "valid_mask": valid,
        "stress": stress,
        "coord_rmsd": coord_rmsd,
        "orientation": orientation,
        "distance_metrics": dm_stats,
        "D_obs": D_obs,
        "D_rec": D_rec,
    }

# %%
#opzion 5 (edm + stress refinement)



import numpy as np
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform


# ==========================================================
# Low-rank EDM reconstruction
# ==========================================================

def lowrank_edm_reconstruct(
    D,
    rank=3,
    mask=None,
    n_restarts=10,
    maxiter=1500,
    random_state=0,
):
    """
    Low-rank Euclidean Distance Matrix fitting.

    Solves:

        min_X sum_ij w_ij (||x_i-x_j||^2 - D_ij^2)^2

    where:
        X in R^{n x rank}

    Parameters
    ----------
    D : ndarray (n,n)
        Distance matrix.
    rank : int
        Embedding dimension.
    mask : ndarray (n,n) or None
        Binary mask for observed entries.
    n_restarts : int
        Number of random restarts.
    maxiter : int
        L-BFGS iterations.

    Returns
    -------
    X_best : ndarray (n, rank)
    best_loss : float
    """

    D = np.asarray(D, dtype=float)
    n = D.shape[0]

    # Symmetrize
    D = 0.5 * (D + D.T)

    # Squared distances
    D2 = D ** 2

    # Observation mask
    if mask is None:
        W = np.isfinite(D).astype(float)
    else:
        W = mask.astype(float)

    np.fill_diagonal(W, 0.0)

    # Replace NaNs
    D2 = np.nan_to_num(D2, nan=0.0)

    best_loss = np.inf
    X_best = None

    def objective_and_grad(x_flat):
        X = x_flat.reshape(n, rank)

        diff = X[:, None, :] - X[None, :, :]
        dist2 = np.sum(diff**2, axis=2)

        R = W * (dist2 - D2)

        obj = 0.5 * np.sum(R**2)

        grad = np.zeros_like(X)

        for i in range(n):
            grad[i] = 4.0 * np.sum(
                R[i, :, None] * diff[i],
                axis=0
            )

        return obj, grad.ravel()

    rng = np.random.default_rng(random_state)

    for restart in range(n_restarts):

        X0 = 0.01 * rng.normal(size=(n, rank))

        result = minimize(
            fun=lambda x: objective_and_grad(x)[0],
            x0=X0.ravel(),
            jac=lambda x: objective_and_grad(x)[1],
            method="L-BFGS-B",
            options={
                "maxiter": maxiter,
                "ftol": 1e-12,
            },
        )

        if result.fun < best_loss:
            best_loss = result.fun
            X_best = result.x.reshape(n, rank)

    return X_best, best_loss

def stress_refinement(
    X0,
    D,
    mask=None,
    maxiter=1000,
):
    """
    Refine coordinates using classical stress minimization.

    Minimizes:
        sum_ij w_ij (||xi-xj|| - Dij)^2
    """

    D = np.asarray(D, dtype=float)
    n, rank = X0.shape

    if mask is None:
        W = np.isfinite(D).astype(float)
    else:
        W = mask.astype(float)

    np.fill_diagonal(W, 0.0)

    D = np.nan_to_num(D, nan=0.0)

    eps = 1e-12

    def objective_and_grad(x_flat):

        X = x_flat.reshape(n, rank)

        diff = X[:, None, :] - X[None, :, :]

        dist = np.sqrt(
            np.sum(diff**2, axis=2) + eps
        )

        R = W * (dist - D)

        obj = 0.5 * np.sum(R**2)

        grad = np.zeros_like(X)

        for i in range(n):

            tmp = (
                R[i, :, None]
                * diff[i]
                / dist[i, :, None]
            )

            tmp[~np.isfinite(tmp)] = 0.0

            grad[i] = np.sum(tmp, axis=0)

        return obj, grad.ravel()

    result = minimize(
        fun=lambda x: objective_and_grad(x)[0],
        x0=X0.ravel(),
        jac=lambda x: objective_and_grad(x)[1],
        method="L-BFGS-B",
        options={
            "maxiter": maxiter,
            "ftol": 1e-12,
        },
    )

    return result.x.reshape(n, rank), result.fun

# ==========================================================
# Your pipeline
# ==========================================================

def reconstruct_and_compare_with_mapPDBToHMM(
    dm,
    mi,
    pdbFile,
    chainIds,
    distType='all'
):
    """
    dm: output distance map from mapPDBToHMM
    mi: mapping indexes from mapPDBToHMM
    distType: must match the way the map was constructed
    """

    dm = np.asarray(dm, dtype=float)
    mi = np.asarray(mi, dtype=int)

    # ======================================================
    # Keep only valid mapped residues
    # ======================================================

    valid = (
        (mi >= 1)
        & (np.isfinite(dm).sum(axis=1) > 1)
    )

    if valid.sum() < 4:
        raise ValueError(
            "Too few mapped residues with finite distances "
            "to reconstruct 3D."
        )

    D_obs = dm[np.ix_(valid, valid)]

    # ======================================================
    # Preprocess distance matrix
    # ======================================================

    if np.isinf(D_obs).any() or np.isnan(D_obs).any():
        raise ValueError("Gap handling failed: D_obs must be fully finite after filtering.")
    D_clean = D_obs

    # ======================================================
    # Build observation mask
    # ======================================================

    mask = np.isfinite(D_clean).astype(float)

    # Replace NaNs/infs
    D_clean = np.nan_to_num(D_clean, nan=0.0)

    # ======================================================
    # LOW-RANK EDM FITTING
    # ======================================================

    X_rec, edm_loss = lowrank_edm_reconstruct(
        D_clean,
        rank=3,
        mask=mask,
        n_restarts=20,
        maxiter=1500,
    )

    # ======================================================
    # STRESS REFINEMENT
    # ======================================================

    X_rec, stress = stress_refinement(
        X_rec,
        D_clean,
        mask=mask,
        maxiter=1000,
    )


    # ======================================================
    # Build PDB reference coordinates
    # ======================================================

    ref_coords_full, residues, seq = \
        extract_reference_coords_from_mi(
            pdbFile,
            chainIds,
            mi,
            distType=distType
        )

    X_ref = ref_coords_full[valid]

    # ======================================================
    # Align reconstruction to reference
    # ======================================================

    X_aligned, X_ref_centered, coord_rmsd, scale, orientation = \
        best_alignment_with_scaling_and_mirror(
            X_rec,
            X_ref
        )

    print("Scale factor:", scale)

    # ======================================================
    # Distance consistency
    # ======================================================

    D_rec = squareform(pdist(X_rec))

    dm_stats = distance_metrics(
        D_obs,
        D_rec
    )

    return {
        "X_rec": X_rec,
        "X_aligned": X_aligned,
        "X_ref_centered": X_ref_centered,
        "valid_mask": valid,
        "stress": stress,
        "coord_rmsd": coord_rmsd,
        "orientation": orientation,
        "distance_metrics": dm_stats,
        "D_obs": D_obs,
        "D_rec": D_rec,
    }

# %%
#real distance map


from sequenceHandler import mapPDBToHMM
pfam_id= "PF00072"
pdb_file = f"PDB/{pfam_id}.pdb"
chain_id = "A"
hmm_file = f"HMM/{pfam_id}.hmm"
hmm_file_2 = "None"        
output_map_file = "None"  




_, mi, aligned_sequence = mapPDBToHMM(pdb_file, chain_id, hmm_file, hmm_file_2, output_map_file, distType='all')
true_dm = 8 * np.exp(np.asanyarray(true_dist_map))

result = reconstruct_and_compare_with_mapPDBToHMM(true_dm, mi, pdb_file, chain_id, distType='all')
print(result["stress"], result["coord_rmsd"], result["distance_metrics"])
valid = result["valid_mask"]

plot_3d_overlay(
    result["X_ref_centered"],
    result["X_aligned"], 
    title=f"RMSD = {result['coord_rmsd']:.2f}"
)


plot_error_per_residue(
    result["X_ref_centered"],
    result["X_aligned"]
)

# Save reference
save_coords_as_pdb(result["X_ref_centered"], "reference.pdb")
#save reconstructed
save_coords_as_pdb(result["X_aligned"], "reconstructed.pdb")


#predicted distance map
pred_dm = 8 * np.exp(np.asanyarray(pred_dist_map))
result = reconstruct_and_compare_with_mapPDBToHMM(pred_dm, mi, pdb_file, chain_id, distType='all')
print(result["stress"], result["coord_rmsd"], result["distance_metrics"])
valid = result["valid_mask"]

plot_3d_overlay(
    result["X_ref_centered"],
    result["X_aligned"],
    title=f"RMSD = {result['coord_rmsd']:.2f}"
)


plot_error_per_residue(
    result["X_ref_centered"],
    result["X_aligned"]
)


# Save reconstructed (aligned)
save_coords_as_pdb(result["X_aligned"], "reconstructed_GNN.pdb")
# Out:
# Scale factor: 0.9630469794163503
# 0.3167056969582884 3.8421811838359137 {'pearson': np.float64(0.9982351097601545), 'mae': np.float64(0.3020636175951954), 'rmse': np.float64(0.37962605694084645)}
# Scale factor: 1.003860793317025
# 1.1380760441502396 4.694127121448636 {'pearson': np.float64(0.9585397490216773), 'mae': np.float64(1.3185408574829771), 'rmse': np.float64(1.8230747349283716)}
