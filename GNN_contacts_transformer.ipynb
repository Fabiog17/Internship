# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
from torch_geometric.data import Data
print(os.getpid())
# Out:
# 1408242

# %%
def sinusoidal_positional_encoding(N, d_model):
    pe = torch.zeros(N, d_model)
    position = torch.arange(0, N, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # shape [N, d_model]

# %%
import torch
import numpy as np
from torch_geometric.data import Data

def build_graph_contact(sequence, score_map, distance_map=None, contact_cutoff=8.0, sep_min=5):

    N = len(sequence)

    # score map to tensor
    score_map = torch.tensor(score_map, dtype=torch.float)
    score_map = torch.log(score_map + 1.0)  #renormalization to see again when we have more data


    idx = torch.arange(N)
    i, j = torch.meshgrid(idx, idx, indexing='ij')  # shape [N, N]

    # masks
    not_self = i != j
    pair_mask = i < j
    long_range_ok = (torch.abs(i - j) >= sep_min)

    if distance_map is not None:
        distance_map = torch.tensor(distance_map, dtype=torch.float)
        known = torch.isfinite(distance_map)
        contact = distance_map <= contact_cutoff
        labels = (known & contact).float()
    else:
        known = torch.ones((N, N), dtype=torch.bool)
        labels = torch.zeros((N, N), dtype=torch.float)

    edge_mask = known & long_range_ok

    # remove i == j
    valid = not_self

    src = i[valid]
    dst = j[valid]

    edge_index = torch.stack([src, dst], dim=0)

    edge_attr = score_map[valid].unsqueeze(-1)
    y = labels[valid].unsqueeze(-1)

    mask = edge_mask[valid]
    pair_mask = pair_mask[valid]

    x = sinusoidal_positional_encoding(N, d_model=16)

    return Data(
        x=x,
        edge_index=edge_index,
        edge_attr=edge_attr,
        y=y,
        edge_mask=mask,
        pair_mask=pair_mask,
        L=N
    )

# %%
folder_path = "Data"

all_data = []
for file in os.listdir(folder_path):
    if file.endswith(".pkl"):
        full_path = os.path.join(folder_path, file)
        
        with open(full_path, "rb") as f:
            loaded = pickle.load(f)

        sequence=loaded['sequence']
        distance_map=loaded['distance_map']
        contact_map_DCA=loaded['dca']
        data = build_graph_contact(sequence, contact_map_DCA, distance_map)
        all_data.append(data)

from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(all_data, test_size=0.2, random_state=1)


train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
#train_loader = DataLoader([all_data[3]], batch_size=1)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.nn import TransformerConv


class TransformerBlock(nn.Module):
    #One graph-transformer block: multi-head attention on graph edges, residual + LayerNorm, FFN + residual + LayerNorm
    def __init__(self, hidden_dim, heads=4, dropout=0.1):
        super().__init__()
        assert hidden_dim % heads == 0, "hidden_dim must be divisible by heads"

        self.attn = TransformerConv(
            in_channels=hidden_dim,
            out_channels=hidden_dim // heads,
            heads=heads,
            concat=True,          # output dim = heads * out_channels = hidden_dim
            beta=True,            # learnable residual gating
            dropout=dropout,
            edge_dim=hidden_dim   # encoded edge_attr dimension
        )

        self.norm1 = nn.LayerNorm(hidden_dim)
        self.norm2 = nn.LayerNorm(hidden_dim)

        self.ffn = nn.Sequential(
            nn.Linear(hidden_dim, 4 * hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(4 * hidden_dim, hidden_dim),
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, edge_index, edge_attr):
        # Attention block
        h = self.attn(x, edge_index, edge_attr)
        x = self.norm1(x + self.dropout(h))

        # FFN block
        h = self.ffn(x)
        x = self.norm2(x + self.dropout(h))

        return x


class EdgeGraphTransformer(nn.Module):
   
    def __init__(
        self,
        node_in_ch=16,
        edge_in_ch=1,
        hidden_dim=128,
        mlp_hidden_ch=64,
        num_layers=4,
        heads=4,
        dropout=0.1,
    ):
        super().__init__()

        self.node_norm = nn.LayerNorm(node_in_ch)
        self.edge_norm = nn.LayerNorm(edge_in_ch)

        self.node_in = nn.Linear(node_in_ch, hidden_dim)
        self.edge_in = nn.Linear(edge_in_ch, hidden_dim)

        self.layers = nn.ModuleList([
            TransformerBlock(hidden_dim=hidden_dim, heads=heads, dropout=dropout)
            for _ in range(num_layers)
        ])

        # Edge classifier: [h_i, h_j, e_ij] -> logit
        self.edge_head = nn.Sequential(
            nn.Linear(2*hidden_dim, mlp_hidden_ch),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(mlp_hidden_ch, 1)
        )

        self.edge_mlp = nn.Sequential(
            nn.Linear(2 * hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
        )

    def forward(self, graph):
        x, edge_index, edge_attr = graph.x, graph.edge_index, graph.edge_attr

        # Input projection
        x = self.node_in(self.node_norm(x))
        edge_attr = self.edge_in(self.edge_norm(edge_attr))

        # Transformer encoder
        for layer in self.layers:
            x = layer(x, edge_index, edge_attr)

        # Edge-level prediction
        src, dst = edge_index
        edge_msg = torch.cat([x[src], x[dst]], dim=-1)
        edge_attr = edge_attr + self.edge_mlp(edge_msg)
        edge_logits = self.edge_head(edge_msg)  

        return x, edge_logits

# %%
def compute_pos_weight(loader, device):
    total_pos = 0
    total_neg = 0

    for batch in loader:
        batch = batch.to(device)

        y = batch.y.squeeze(-1)
        mask = batch.edge_mask #& batch.pair_mask  

        y = y[mask]

        total_pos += (y == 1).sum().item()
        total_neg += (y == 0).sum().item()

    pos_weight = total_neg / max(total_pos, 1)
    return torch.tensor(pos_weight, dtype=torch.float, device=device)

# %%
def average_loss(model, loader, loss_fn, device):
    model.eval()
    total_loss = 0.0
    total_edges = 0
    total_batches= 0

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)

            _, pred_logits = model(batch)
            pred_logits = pred_logits.squeeze(-1)
            true_contacts = batch.y.squeeze(-1)

            mask = batch.edge_mask #& batch.pair_mask

            loss = loss_fn(pred_logits[mask], true_contacts[mask])

            n_edges = mask.sum().item()
            total_loss += loss.item() * n_edges
            total_edges += n_edges
            total_batches += 1

    return total_loss / max(total_edges, 1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = EdgeGraphTransformer(node_in_ch=16,edge_in_ch=1,hidden_dim=64,mlp_hidden_ch=32,num_layers=2,heads=2,dropout=0.3).to(device)
pos_weight = compute_pos_weight(train_loader, device)
print("pos_weight:", pos_weight.item())
loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight,reduction='mean')

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

train_losses = []
val_losses = []

for epoch in range(2000):

    model.train()

    total_loss = 0.0
    total_edges = 0
    for batch in train_loader:

        batch = batch.to(device)
        optimizer.zero_grad()

        _, pred_logits = model(batch)

        pred_logits = pred_logits.squeeze(-1)
        true_contacts = batch.y.squeeze(-1)

        mask = batch.edge_mask #& batch.pair_mask

        loss = loss_fn(pred_logits[mask], true_contacts[mask])

        n_edges = mask.sum().item()
        total_loss += loss.item() * n_edges
        total_edges += n_edges

        loss.backward()
        optimizer.step()

    train_loss = total_loss / max(total_edges, 1)
    val_loss = average_loss(model, test_loader, loss_fn, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch {epoch}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")
# Out:
# pos_weight: 12.831951141357422
# Epoch 0: Train Loss=1.1873, Val Loss=1.1449
# Epoch 1: Train Loss=1.1523, Val Loss=1.1319
# Epoch 2: Train Loss=1.1457, Val Loss=1.1283
# Epoch 3: Train Loss=1.1414, Val Loss=1.1290
# Epoch 4: Train Loss=1.1391, Val Loss=1.1241
# Epoch 5: Train Loss=1.1367, Val Loss=1.1238
# Epoch 6: Train Loss=1.1362, Val Loss=1.1230
# Epoch 7: Train Loss=1.1342, Val Loss=1.1259
# Epoch 8: Train Loss=1.1343, Val Loss=1.1225
# Epoch 9: Train Loss=1.1326, Val Loss=1.1249
# Epoch 10: Train Loss=1.1325, Val Loss=1.1191
# Epoch 11: Train Loss=1.1317, Val Loss=1.1202
# Epoch 12: Train Loss=1.1312, Val Loss=1.1209
# Epoch 13: Train Loss=1.1312, Val Loss=1.1183
# Epoch 14: Train Loss=1.1299, Val Loss=1.1206
# Epoch 15: Train Loss=1.1299, Val Loss=1.1181
# Epoch 16: Train Loss=1.1297, Val Loss=1.1181
# Epoch 17: Train Loss=1.1303, Val Loss=1.1186
# Epoch 18: Train Loss=1.1282, Val Loss=1.1179
# Epoch 19: Train Loss=1.1294, Val Loss=1.1200
# Epoch 20: Train Loss=1.1284, Val Loss=1.1195
# Epoch 21: Train Loss=1.1291, Val Loss=1.1195
# Epoch 22: Train Loss=1.1279, Val Loss=1.1178
# Epoch 23: Train Loss=1.1279, Val Loss=1.1177
# Epoch 24: Train Loss=1.1274, Val Loss=1.1178
# Epoch 25: Train Loss=1.1274, Val Loss=1.1163
# Epoch 26: Train Loss=1.1271, Val Loss=1.1162
# Epoch 27: Train Loss=1.1268, Val Loss=1.1168
# Epoch 28: Train Loss=1.1264, Val Loss=1.1155
# Epoch 29: Train Loss=1.1264, Val Loss=1.1166
# Epoch 30: Train Loss=1.1262, Val Loss=1.1148
# Epoch 31: Train Loss=1.1263, Val Loss=1.1182
# Epoch 32: Train Loss=1.1266, Val Loss=1.1143
# Epoch 33: Train Loss=1.1260, Val Loss=1.1192
# Epoch 34: Train Loss=1.1258, Val Loss=1.1147
# Epoch 35: Train Loss=1.1252, Val Loss=1.1148
# Epoch 36: Train Loss=1.1253, Val Loss=1.1160
# Epoch 37: Train Loss=1.1250, Val Loss=1.1148
# Epoch 38: Train Loss=1.1247, Val Loss=1.1147
# Epoch 39: Train Loss=1.1251, Val Loss=1.1199
# Epoch 40: Train Loss=1.1256, Val Loss=1.1143
# Epoch 41: Train Loss=1.1241, Val Loss=1.1136
# Epoch 42: Train Loss=1.1245, Val Loss=1.1161
# Epoch 43: Train Loss=1.1245, Val Loss=1.1158
# Epoch 44: Train Loss=1.1238, Val Loss=1.1134
# Epoch 45: Train Loss=1.1238, Val Loss=1.1148
# Epoch 46: Train Loss=1.1244, Val Loss=1.1133
# Epoch 47: Train Loss=1.1233, Val Loss=1.1140
# Epoch 48: Train Loss=1.1235, Val Loss=1.1144
# Epoch 49: Train Loss=1.1237, Val Loss=1.1157
# Epoch 50: Train Loss=1.1233, Val Loss=1.1143
# Epoch 51: Train Loss=1.1234, Val Loss=1.1151
# Epoch 52: Train Loss=1.1235, Val Loss=1.1148
# Epoch 53: Train Loss=1.1234, Val Loss=1.1156
# Epoch 54: Train Loss=1.1227, Val Loss=1.1129
# Epoch 55: Train Loss=1.1227, Val Loss=1.1126
# Epoch 56: Train Loss=1.1221, Val Loss=1.1143
# Epoch 57: Train Loss=1.1233, Val Loss=1.1142
# Epoch 58: Train Loss=1.1228, Val Loss=1.1122
# Epoch 59: Train Loss=1.1218, Val Loss=1.1139
# Epoch 60: Train Loss=1.1218, Val Loss=1.1126
# Epoch 61: Train Loss=1.1216, Val Loss=1.1133
# Epoch 62: Train Loss=1.1222, Val Loss=1.1134
# Epoch 63: Train Loss=1.1219, Val Loss=1.1133
# Epoch 64: Train Loss=1.1219, Val Loss=1.1137
# Epoch 65: Train Loss=1.1215, Val Loss=1.1148
# Epoch 66: Train Loss=1.1213, Val Loss=1.1137
# Epoch 67: Train Loss=1.1214, Val Loss=1.1126
# Epoch 68: Train Loss=1.1207, Val Loss=1.1158
# Epoch 69: Train Loss=1.1212, Val Loss=1.1137
# Epoch 70: Train Loss=1.1225, Val Loss=1.1114
# Epoch 71: Train Loss=1.1206, Val Loss=1.1117
# Epoch 72: Train Loss=1.1220, Val Loss=1.1130
# Epoch 73: Train Loss=1.1209, Val Loss=1.1128
# Epoch 74: Train Loss=1.1206, Val Loss=1.1125
# Epoch 75: Train Loss=1.1203, Val Loss=1.1127
# Epoch 76: Train Loss=1.1201, Val Loss=1.1120
# Epoch 77: Train Loss=1.1202, Val Loss=1.1115
# Epoch 78: Train Loss=1.1202, Val Loss=1.1124
# Epoch 79: Train Loss=1.1210, Val Loss=1.1132
# Epoch 80: Train Loss=1.1203, Val Loss=1.1112
# Epoch 81: Train Loss=1.1197, Val Loss=1.1122
# Epoch 82: Train Loss=1.1197, Val Loss=1.1144
# Epoch 83: Train Loss=1.1198, Val Loss=1.1124
# Epoch 84: Train Loss=1.1194, Val Loss=1.1130
# Epoch 85: Train Loss=1.1190, Val Loss=1.1165
# Epoch 86: Train Loss=1.1193, Val Loss=1.1126
# Epoch 87: Train Loss=1.1200, Val Loss=1.1138
# Epoch 88: Train Loss=1.1196, Val Loss=1.1142
# Epoch 89: Train Loss=1.1196, Val Loss=1.1122
# Epoch 90: Train Loss=1.1190, Val Loss=1.1119
# Epoch 91: Train Loss=1.1197, Val Loss=1.1143
# Epoch 92: Train Loss=1.1191, Val Loss=1.1137
# Epoch 93: Train Loss=1.1190, Val Loss=1.1127
# Epoch 94: Train Loss=1.1194, Val Loss=1.1134
# Epoch 95: Train Loss=1.1188, Val Loss=1.1127
# Epoch 96: Train Loss=1.1188, Val Loss=1.1126
# Epoch 97: Train Loss=1.1195, Val Loss=1.1142
# Epoch 98: Train Loss=1.1185, Val Loss=1.1135
# Epoch 99: Train Loss=1.1184, Val Loss=1.1125
# Epoch 100: Train Loss=1.1179, Val Loss=1.1122
# Epoch 101: Train Loss=1.1181, Val Loss=1.1119
# Epoch 102: Train Loss=1.1187, Val Loss=1.1131
# Epoch 103: Train Loss=1.1180, Val Loss=1.1123
# Epoch 104: Train Loss=1.1183, Val Loss=1.1145
# Epoch 105: Train Loss=1.1181, Val Loss=1.1141
# Epoch 106: Train Loss=1.1176, Val Loss=1.1120
# Epoch 107: Train Loss=1.1179, Val Loss=1.1113
# Epoch 108: Train Loss=1.1180, Val Loss=1.1126
# Epoch 109: Train Loss=1.1176, Val Loss=1.1117
# Epoch 110: Train Loss=1.1181, Val Loss=1.1126
# Epoch 111: Train Loss=1.1174, Val Loss=1.1148
# Epoch 112: Train Loss=1.1181, Val Loss=1.1124
# Epoch 113: Train Loss=1.1180, Val Loss=1.1127
# Epoch 114: Train Loss=1.1178, Val Loss=1.1120
# Epoch 115: Train Loss=1.1166, Val Loss=1.1130
# Epoch 116: Train Loss=1.1183, Val Loss=1.1125
# Epoch 117: Train Loss=1.1179, Val Loss=1.1122
# Epoch 118: Train Loss=1.1174, Val Loss=1.1130
# Epoch 119: Train Loss=1.1175, Val Loss=1.1142
# Epoch 120: Train Loss=1.1175, Val Loss=1.1126
# Epoch 121: Train Loss=1.1172, Val Loss=1.1122
# Epoch 122: Train Loss=1.1164, Val Loss=1.1107
# Epoch 123: Train Loss=1.1164, Val Loss=1.1141
# Epoch 124: Train Loss=1.1169, Val Loss=1.1112
# Epoch 125: Train Loss=1.1168, Val Loss=1.1133
# Epoch 126: Train Loss=1.1175, Val Loss=1.1125
# Epoch 127: Train Loss=1.1167, Val Loss=1.1126
# Epoch 128: Train Loss=1.1171, Val Loss=1.1127
# Epoch 129: Train Loss=1.1164, Val Loss=1.1137
# Epoch 130: Train Loss=1.1158, Val Loss=1.1132
# Epoch 131: Train Loss=1.1165, Val Loss=1.1142
# Epoch 132: Train Loss=1.1170, Val Loss=1.1133
# Epoch 133: Train Loss=1.1162, Val Loss=1.1147
# Epoch 134: Train Loss=1.1163, Val Loss=1.1115
# Epoch 135: Train Loss=1.1157, Val Loss=1.1135
# Epoch 136: Train Loss=1.1154, Val Loss=1.1160
# Epoch 137: Train Loss=1.1159, Val Loss=1.1136
# Epoch 138: Train Loss=1.1163, Val Loss=1.1117
# Epoch 139: Train Loss=1.1162, Val Loss=1.1134
# Epoch 140: Train Loss=1.1158, Val Loss=1.1149
# Epoch 141: Train Loss=1.1170, Val Loss=1.1130
# Epoch 142: Train Loss=1.1160, Val Loss=1.1127
# Epoch 143: Train Loss=1.1151, Val Loss=1.1143
# Epoch 144: Train Loss=1.1150, Val Loss=1.1129
# Epoch 145: Train Loss=1.1155, Val Loss=1.1147
# Epoch 146: Train Loss=1.1152, Val Loss=1.1148
# Epoch 147: Train Loss=1.1154, Val Loss=1.1126
# Epoch 148: Train Loss=1.1152, Val Loss=1.1147
# Epoch 149: Train Loss=1.1147, Val Loss=1.1138
# Epoch 150: Train Loss=1.1145, Val Loss=1.1136
# Epoch 151: Train Loss=1.1149, Val Loss=1.1123
# Epoch 152: Train Loss=1.1151, Val Loss=1.1120
# Epoch 153: Train Loss=1.1150, Val Loss=1.1154
# Epoch 154: Train Loss=1.1152, Val Loss=1.1140
# Epoch 155: Train Loss=1.1143, Val Loss=1.1152
# Epoch 156: Train Loss=1.1148, Val Loss=1.1134
# Epoch 157: Train Loss=1.1147, Val Loss=1.1115
# Epoch 158: Train Loss=1.1143, Val Loss=1.1147
# Epoch 159: Train Loss=1.1139, Val Loss=1.1122
# Epoch 160: Train Loss=1.1152, Val Loss=1.1144
# Epoch 161: Train Loss=1.1142, Val Loss=1.1122
# Epoch 162: Train Loss=1.1146, Val Loss=1.1147
# Epoch 163: Train Loss=1.1141, Val Loss=1.1124
# Epoch 164: Train Loss=1.1138, Val Loss=1.1145
# Epoch 165: Train Loss=1.1140, Val Loss=1.1141
# Epoch 166: Train Loss=1.1139, Val Loss=1.1131
# Epoch 167: Train Loss=1.1137, Val Loss=1.1137
# Epoch 168: Train Loss=1.1139, Val Loss=1.1136
# Epoch 169: Train Loss=1.1136, Val Loss=1.1135
# Epoch 170: Train Loss=1.1141, Val Loss=1.1116
# Epoch 171: Train Loss=1.1137, Val Loss=1.1164
# Epoch 172: Train Loss=1.1133, Val Loss=1.1169
# Epoch 173: Train Loss=1.1135, Val Loss=1.1149
# Epoch 174: Train Loss=1.1141, Val Loss=1.1162
# Epoch 175: Train Loss=1.1135, Val Loss=1.1142
# Epoch 176: Train Loss=1.1134, Val Loss=1.1162
# Epoch 177: Train Loss=1.1138, Val Loss=1.1141
# Epoch 178: Train Loss=1.1129, Val Loss=1.1151
# Epoch 179: Train Loss=1.1126, Val Loss=1.1138
# Epoch 180: Train Loss=1.1126, Val Loss=1.1143
# Epoch 181: Train Loss=1.1125, Val Loss=1.1147
# Epoch 182: Train Loss=1.1127, Val Loss=1.1157
# Epoch 183: Train Loss=1.1119, Val Loss=1.1204
# Epoch 184: Train Loss=1.1127, Val Loss=1.1116
# Epoch 185: Train Loss=1.1132, Val Loss=1.1137
# Epoch 186: Train Loss=1.1125, Val Loss=1.1158
# Epoch 187: Train Loss=1.1127, Val Loss=1.1142
# Epoch 188: Train Loss=1.1122, Val Loss=1.1173
# Epoch 189: Train Loss=1.1121, Val Loss=1.1153
# Epoch 190: Train Loss=1.1124, Val Loss=1.1139
# Epoch 191: Train Loss=1.1123, Val Loss=1.1186
# Epoch 192: Train Loss=1.1124, Val Loss=1.1138
# Epoch 193: Train Loss=1.1120, Val Loss=1.1172
# Epoch 194: Train Loss=1.1115, Val Loss=1.1150
# Epoch 195: Train Loss=1.1123, Val Loss=1.1167
# Epoch 196: Train Loss=1.1121, Val Loss=1.1163
# Epoch 197: Train Loss=1.1114, Val Loss=1.1168
# Epoch 198: Train Loss=1.1120, Val Loss=1.1156
# Epoch 199: Train Loss=1.1118, Val Loss=1.1173
# Epoch 200: Train Loss=1.1123, Val Loss=1.1138
# Epoch 201: Train Loss=1.1122, Val Loss=1.1148
# Epoch 202: Train Loss=1.1113, Val Loss=1.1164
# Epoch 203: Train Loss=1.1113, Val Loss=1.1192
# Epoch 204: Train Loss=1.1116, Val Loss=1.1160
# Epoch 205: Train Loss=1.1106, Val Loss=1.1170
# Epoch 206: Train Loss=1.1117, Val Loss=1.1187
# Epoch 207: Train Loss=1.1113, Val Loss=1.1166
# Epoch 208: Train Loss=1.1113, Val Loss=1.1170
# Epoch 209: Train Loss=1.1104, Val Loss=1.1159
# Epoch 210: Train Loss=1.1108, Val Loss=1.1165
# Epoch 211: Train Loss=1.1114, Val Loss=1.1174
# Epoch 212: Train Loss=1.1101, Val Loss=1.1163
# Epoch 213: Train Loss=1.1113, Val Loss=1.1167
# Epoch 214: Train Loss=1.1104, Val Loss=1.1159
# Epoch 215: Train Loss=1.1101, Val Loss=1.1194
# Epoch 216: Train Loss=1.1108, Val Loss=1.1177
# Epoch 217: Train Loss=1.1097, Val Loss=1.1178
# Epoch 218: Train Loss=1.1109, Val Loss=1.1175
# Epoch 219: Train Loss=1.1105, Val Loss=1.1157
# Epoch 220: Train Loss=1.1100, Val Loss=1.1196
# Epoch 221: Train Loss=1.1096, Val Loss=1.1193
# Epoch 222: Train Loss=1.1106, Val Loss=1.1178
# Epoch 223: Train Loss=1.1097, Val Loss=1.1205
# Epoch 224: Train Loss=1.1100, Val Loss=1.1167
# Epoch 225: Train Loss=1.1091, Val Loss=1.1161
# Epoch 226: Train Loss=1.1097, Val Loss=1.1196
# Epoch 227: Train Loss=1.1098, Val Loss=1.1173
# Epoch 228: Train Loss=1.1097, Val Loss=1.1220
# Epoch 229: Train Loss=1.1095, Val Loss=1.1186
# Epoch 230: Train Loss=1.1096, Val Loss=1.1197
# Epoch 231: Train Loss=1.1098, Val Loss=1.1193
# Epoch 232: Train Loss=1.1095, Val Loss=1.1204
# Epoch 233: Train Loss=1.1087, Val Loss=1.1185
# Epoch 234: Train Loss=1.1089, Val Loss=1.1220
# Epoch 235: Train Loss=1.1086, Val Loss=1.1193
# Epoch 236: Train Loss=1.1094, Val Loss=1.1170
# Epoch 237: Train Loss=1.1081, Val Loss=1.1192
# Epoch 238: Train Loss=1.1087, Val Loss=1.1202
# Epoch 239: Train Loss=1.1083, Val Loss=1.1194
# Epoch 240: Train Loss=1.1083, Val Loss=1.1194
# Epoch 241: Train Loss=1.1081, Val Loss=1.1218
# Epoch 242: Train Loss=1.1084, Val Loss=1.1219
# Epoch 243: Train Loss=1.1082, Val Loss=1.1205
# Epoch 244: Train Loss=1.1079, Val Loss=1.1209
# Epoch 245: Train Loss=1.1072, Val Loss=1.1253
# Epoch 246: Train Loss=1.1075, Val Loss=1.1184
# Epoch 247: Train Loss=1.1078, Val Loss=1.1242
# Epoch 248: Train Loss=1.1082, Val Loss=1.1191
# Epoch 249: Train Loss=1.1071, Val Loss=1.1217
# Epoch 250: Train Loss=1.1072, Val Loss=1.1201
# Epoch 251: Train Loss=1.1082, Val Loss=1.1202
# Epoch 252: Train Loss=1.1080, Val Loss=1.1181
# Epoch 253: Train Loss=1.1074, Val Loss=1.1236
# Epoch 254: Train Loss=1.1072, Val Loss=1.1209
# Epoch 255: Train Loss=1.1081, Val Loss=1.1209
# Epoch 256: Train Loss=1.1070, Val Loss=1.1226
# Epoch 257: Train Loss=1.1071, Val Loss=1.1214
# Epoch 258: Train Loss=1.1068, Val Loss=1.1208
# Epoch 259: Train Loss=1.1068, Val Loss=1.1216
# Epoch 260: Train Loss=1.1066, Val Loss=1.1230
# Epoch 261: Train Loss=1.1068, Val Loss=1.1231
# Epoch 262: Train Loss=1.1063, Val Loss=1.1238
# Epoch 263: Train Loss=1.1054, Val Loss=1.1251
# Epoch 264: Train Loss=1.1067, Val Loss=1.1213
# Epoch 265: Train Loss=1.1065, Val Loss=1.1228
# Epoch 266: Train Loss=1.1055, Val Loss=1.1221
# Epoch 267: Train Loss=1.1057, Val Loss=1.1241
# Epoch 268: Train Loss=1.1061, Val Loss=1.1281
# Epoch 269: Train Loss=1.1046, Val Loss=1.1221
# Epoch 270: Train Loss=1.1065, Val Loss=1.1291
# Epoch 271: Train Loss=1.1057, Val Loss=1.1246
# Epoch 272: Train Loss=1.1059, Val Loss=1.1230
# Epoch 273: Train Loss=1.1052, Val Loss=1.1227
# Epoch 274: Train Loss=1.1053, Val Loss=1.1246
# Epoch 275: Train Loss=1.1057, Val Loss=1.1241
# Epoch 276: Train Loss=1.1047, Val Loss=1.1263
# Epoch 277: Train Loss=1.1049, Val Loss=1.1255
# Epoch 278: Train Loss=1.1054, Val Loss=1.1246
# Epoch 279: Train Loss=1.1057, Val Loss=1.1249
# Epoch 280: Train Loss=1.1047, Val Loss=1.1246
# Epoch 281: Train Loss=1.1050, Val Loss=1.1291
# Epoch 282: Train Loss=1.1045, Val Loss=1.1244
# Epoch 283: Train Loss=1.1042, Val Loss=1.1305
# Epoch 284: Train Loss=1.1038, Val Loss=1.1280
# Epoch 285: Train Loss=1.1036, Val Loss=1.1264
# Epoch 286: Train Loss=1.1048, Val Loss=1.1249
# Epoch 287: Train Loss=1.1040, Val Loss=1.1276
# Epoch 288: Train Loss=1.1043, Val Loss=1.1266
# Epoch 289: Train Loss=1.1036, Val Loss=1.1236
# Epoch 290: Train Loss=1.1041, Val Loss=1.1272
# Epoch 291: Train Loss=1.1034, Val Loss=1.1291
# Epoch 292: Train Loss=1.1036, Val Loss=1.1247
# Epoch 293: Train Loss=1.1037, Val Loss=1.1259
# Epoch 294: Train Loss=1.1035, Val Loss=1.1255
# Epoch 295: Train Loss=1.1028, Val Loss=1.1303
# Epoch 296: Train Loss=1.1037, Val Loss=1.1273
# Epoch 297: Train Loss=1.1037, Val Loss=1.1271
# Epoch 298: Train Loss=1.1037, Val Loss=1.1276
# Epoch 299: Train Loss=1.1033, Val Loss=1.1281
# Epoch 300: Train Loss=1.1031, Val Loss=1.1286
# Epoch 301: Train Loss=1.1033, Val Loss=1.1260
# Epoch 302: Train Loss=1.1017, Val Loss=1.1298
# Epoch 303: Train Loss=1.1031, Val Loss=1.1246
# Epoch 304: Train Loss=1.1027, Val Loss=1.1276
# Epoch 305: Train Loss=1.1024, Val Loss=1.1308
# Epoch 306: Train Loss=1.1028, Val Loss=1.1285
# Epoch 307: Train Loss=1.1024, Val Loss=1.1300
# Epoch 308: Train Loss=1.1024, Val Loss=1.1281
# Epoch 309: Train Loss=1.1020, Val Loss=1.1278
# Epoch 310: Train Loss=1.1006, Val Loss=1.1262
# Epoch 311: Train Loss=1.1015, Val Loss=1.1313
# Epoch 312: Train Loss=1.1018, Val Loss=1.1302
# Epoch 313: Train Loss=1.1015, Val Loss=1.1259
# Epoch 314: Train Loss=1.1024, Val Loss=1.1287
# Epoch 315: Train Loss=1.1015, Val Loss=1.1337
# Epoch 316: Train Loss=1.1010, Val Loss=1.1290
# Epoch 317: Train Loss=1.1009, Val Loss=1.1307
# Epoch 318: Train Loss=1.1002, Val Loss=1.1278
# Epoch 319: Train Loss=1.1023, Val Loss=1.1326
# Epoch 320: Train Loss=1.1017, Val Loss=1.1260
# Epoch 321: Train Loss=1.1013, Val Loss=1.1312
# Epoch 322: Train Loss=1.1001, Val Loss=1.1300
# Epoch 323: Train Loss=1.1018, Val Loss=1.1270
# Epoch 324: Train Loss=1.1008, Val Loss=1.1359
# Epoch 325: Train Loss=1.1007, Val Loss=1.1296
# Epoch 326: Train Loss=1.0993, Val Loss=1.1356
# Epoch 327: Train Loss=1.1011, Val Loss=1.1341
# Epoch 328: Train Loss=1.0991, Val Loss=1.1356
# Epoch 329: Train Loss=1.1006, Val Loss=1.1337
# Epoch 330: Train Loss=1.0993, Val Loss=1.1337
# Epoch 331: Train Loss=1.1003, Val Loss=1.1318
# Epoch 332: Train Loss=1.0996, Val Loss=1.1342
# Epoch 333: Train Loss=1.0993, Val Loss=1.1387
# Epoch 334: Train Loss=1.0999, Val Loss=1.1340
# Epoch 335: Train Loss=1.0995, Val Loss=1.1324
# Epoch 336: Train Loss=1.0986, Val Loss=1.1307
# Epoch 337: Train Loss=1.0999, Val Loss=1.1351
# Epoch 338: Train Loss=1.0989, Val Loss=1.1329
# Epoch 339: Train Loss=1.0982, Val Loss=1.1384
# Epoch 340: Train Loss=1.1003, Val Loss=1.1356
# Epoch 341: Train Loss=1.0997, Val Loss=1.1348
# Epoch 342: Train Loss=1.0982, Val Loss=1.1355
# Epoch 343: Train Loss=1.0994, Val Loss=1.1337
# Epoch 344: Train Loss=1.0979, Val Loss=1.1365
# Epoch 345: Train Loss=1.0980, Val Loss=1.1399
# Epoch 346: Train Loss=1.0980, Val Loss=1.1345
# Epoch 347: Train Loss=1.0978, Val Loss=1.1361
# Epoch 348: Train Loss=1.0979, Val Loss=1.1366
# Epoch 349: Train Loss=1.0980, Val Loss=1.1369
# Epoch 350: Train Loss=1.0983, Val Loss=1.1365
# Epoch 351: Train Loss=1.0974, Val Loss=1.1329
# Epoch 352: Train Loss=1.0980, Val Loss=1.1404
# Epoch 353: Train Loss=1.0981, Val Loss=1.1356
# Epoch 354: Train Loss=1.0975, Val Loss=1.1406
# Epoch 355: Train Loss=1.0979, Val Loss=1.1321
# Epoch 356: Train Loss=1.0971, Val Loss=1.1374
# Epoch 357: Train Loss=1.0965, Val Loss=1.1380
# Epoch 358: Train Loss=1.0970, Val Loss=1.1375
# Epoch 359: Train Loss=1.0969, Val Loss=1.1419
# Epoch 360: Train Loss=1.0966, Val Loss=1.1471
# Epoch 361: Train Loss=1.0973, Val Loss=1.1383
# Epoch 362: Train Loss=1.0964, Val Loss=1.1428
# Epoch 363: Train Loss=1.0968, Val Loss=1.1385
# Epoch 364: Train Loss=1.0968, Val Loss=1.1413
# Epoch 365: Train Loss=1.1059, Val Loss=1.1327
# Epoch 366: Train Loss=1.0999, Val Loss=1.1328
# Epoch 367: Train Loss=1.0978, Val Loss=1.1392
# Epoch 368: Train Loss=1.0969, Val Loss=1.1425
# Epoch 369: Train Loss=1.0953, Val Loss=1.1475
# Epoch 370: Train Loss=1.0960, Val Loss=1.1481
# Epoch 371: Train Loss=1.0958, Val Loss=1.1428
# Epoch 372: Train Loss=1.0955, Val Loss=1.1452
# Epoch 373: Train Loss=1.0951, Val Loss=1.1412
# Epoch 374: Train Loss=1.0955, Val Loss=1.1447
# Epoch 375: Train Loss=1.0950, Val Loss=1.1410
# Epoch 376: Train Loss=1.0959, Val Loss=1.1392
# Epoch 377: Train Loss=1.0961, Val Loss=1.1466
# Epoch 378: Train Loss=1.0957, Val Loss=1.1406
# Epoch 379: Train Loss=1.0969, Val Loss=1.1358
# Epoch 380: Train Loss=1.0957, Val Loss=1.1437
# Epoch 381: Train Loss=1.0947, Val Loss=1.1503
# Epoch 382: Train Loss=1.0947, Val Loss=1.1424
# Epoch 383: Train Loss=1.0943, Val Loss=1.1435
# Epoch 384: Train Loss=1.0936, Val Loss=1.1465
# Epoch 385: Train Loss=1.0935, Val Loss=1.1455
# Epoch 386: Train Loss=1.0936, Val Loss=1.1485
# Epoch 387: Train Loss=1.0943, Val Loss=1.1442
# Epoch 388: Train Loss=1.0950, Val Loss=1.1428
# Epoch 389: Train Loss=1.0944, Val Loss=1.1425
# Epoch 390: Train Loss=1.0939, Val Loss=1.1440
# Epoch 391: Train Loss=1.0944, Val Loss=1.1461
# Epoch 392: Train Loss=1.0934, Val Loss=1.1475
# Epoch 393: Train Loss=1.0936, Val Loss=1.1476
# Epoch 394: Train Loss=1.0939, Val Loss=1.1507
# Epoch 395: Train Loss=1.0945, Val Loss=1.1442
# Epoch 396: Train Loss=1.0930, Val Loss=1.1465
# Epoch 397: Train Loss=1.0925, Val Loss=1.1515
# Epoch 398: Train Loss=1.0936, Val Loss=1.1427
# Epoch 399: Train Loss=1.0938, Val Loss=1.1511
# Epoch 400: Train Loss=1.0934, Val Loss=1.1498
# Epoch 401: Train Loss=1.0930, Val Loss=1.1538
# Epoch 402: Train Loss=1.0920, Val Loss=1.1506
# Epoch 403: Train Loss=1.0947, Val Loss=1.1511
# Epoch 404: Train Loss=1.0943, Val Loss=1.1439
# Epoch 405: Train Loss=1.0932, Val Loss=1.1462
# Epoch 406: Train Loss=1.0926, Val Loss=1.1482
# Epoch 407: Train Loss=1.0924, Val Loss=1.1487
# Epoch 408: Train Loss=1.0926, Val Loss=1.1568
# Epoch 409: Train Loss=1.0924, Val Loss=1.1493
# Epoch 410: Train Loss=1.0938, Val Loss=1.1463
# Epoch 411: Train Loss=1.0924, Val Loss=1.1491
# Epoch 412: Train Loss=1.0927, Val Loss=1.1575
# Epoch 413: Train Loss=1.0921, Val Loss=1.1595
# Epoch 414: Train Loss=1.0915, Val Loss=1.1605
# Epoch 415: Train Loss=1.0921, Val Loss=1.1491
# Epoch 416: Train Loss=1.0920, Val Loss=1.1468
# Epoch 417: Train Loss=1.0920, Val Loss=1.1468
# Epoch 418: Train Loss=1.0918, Val Loss=1.1511
# Epoch 419: Train Loss=1.0918, Val Loss=1.1515
# Epoch 420: Train Loss=1.0911, Val Loss=1.1529
# Epoch 421: Train Loss=1.0914, Val Loss=1.1542
# Epoch 422: Train Loss=1.0921, Val Loss=1.1504
# Epoch 423: Train Loss=1.0903, Val Loss=1.1484
# Epoch 424: Train Loss=1.0905, Val Loss=1.1517
# Epoch 425: Train Loss=1.0912, Val Loss=1.1566
# Epoch 426: Train Loss=1.0926, Val Loss=1.1477
# Epoch 427: Train Loss=1.0908, Val Loss=1.1562
# Epoch 428: Train Loss=1.0906, Val Loss=1.1514
# Epoch 429: Train Loss=1.0908, Val Loss=1.1595
# Epoch 430: Train Loss=1.0897, Val Loss=1.1514
# Epoch 431: Train Loss=1.0921, Val Loss=1.1557
# Epoch 432: Train Loss=1.0921, Val Loss=1.1498
# Epoch 433: Train Loss=1.0903, Val Loss=1.1512
# Epoch 434: Train Loss=1.0895, Val Loss=1.1601
# Epoch 435: Train Loss=1.0900, Val Loss=1.1597
# Epoch 436: Train Loss=1.0898, Val Loss=1.1539
# Epoch 437: Train Loss=1.0899, Val Loss=1.1633
# Epoch 438: Train Loss=1.0900, Val Loss=1.1589
# Epoch 439: Train Loss=1.0898, Val Loss=1.1572
# Epoch 440: Train Loss=1.0892, Val Loss=1.1556
# Epoch 441: Train Loss=1.0894, Val Loss=1.1561
# Epoch 442: Train Loss=1.0899, Val Loss=1.1601
# Epoch 443: Train Loss=1.0893, Val Loss=1.1606
# Epoch 444: Train Loss=1.0895, Val Loss=1.1551
# Epoch 445: Train Loss=1.0898, Val Loss=1.1583
# Epoch 446: Train Loss=1.0887, Val Loss=1.1558
# Epoch 447: Train Loss=1.0901, Val Loss=1.1648
# Epoch 448: Train Loss=1.0891, Val Loss=1.1539
# Epoch 449: Train Loss=1.0884, Val Loss=1.1546
# Epoch 450: Train Loss=1.0885, Val Loss=1.1553
# Epoch 451: Train Loss=1.0890, Val Loss=1.1672
# Epoch 452: Train Loss=1.0880, Val Loss=1.1601
# Epoch 453: Train Loss=1.0884, Val Loss=1.1575
# Epoch 454: Train Loss=1.0898, Val Loss=1.1576
# Epoch 455: Train Loss=1.0917, Val Loss=1.1565
# Epoch 456: Train Loss=1.0895, Val Loss=1.1578
# Epoch 457: Train Loss=1.0874, Val Loss=1.1515
# Epoch 458: Train Loss=1.0881, Val Loss=1.1604
# Epoch 459: Train Loss=1.0875, Val Loss=1.1608
# Epoch 460: Train Loss=1.0875, Val Loss=1.1605
# Epoch 461: Train Loss=1.0882, Val Loss=1.1610
# Epoch 462: Train Loss=1.0875, Val Loss=1.1582
# Epoch 463: Train Loss=1.0877, Val Loss=1.1584
# Epoch 464: Train Loss=1.0884, Val Loss=1.1570
# Epoch 465: Train Loss=1.0877, Val Loss=1.1663
# Epoch 466: Train Loss=1.0876, Val Loss=1.1600
# Epoch 467: Train Loss=1.0868, Val Loss=1.1585
# Epoch 468: Train Loss=1.0892, Val Loss=1.1708
# Epoch 469: Train Loss=1.0859, Val Loss=1.1607
# Epoch 470: Train Loss=1.0866, Val Loss=1.1597
# Epoch 471: Train Loss=1.0873, Val Loss=1.1599
# Epoch 472: Train Loss=1.0869, Val Loss=1.1551
# Epoch 473: Train Loss=1.0858, Val Loss=1.1707
# Epoch 474: Train Loss=1.0855, Val Loss=1.1609
# Epoch 475: Train Loss=1.0858, Val Loss=1.1688
# Epoch 476: Train Loss=1.0855, Val Loss=1.1665
# Epoch 477: Train Loss=1.0862, Val Loss=1.1598
# Epoch 478: Train Loss=1.0869, Val Loss=1.1615
# Epoch 479: Train Loss=1.0869, Val Loss=1.1605
# Epoch 480: Train Loss=1.0860, Val Loss=1.1711
# Epoch 481: Train Loss=1.0869, Val Loss=1.1691
# Epoch 482: Train Loss=1.0870, Val Loss=1.1607
# Epoch 483: Train Loss=1.0858, Val Loss=1.1609
# Epoch 484: Train Loss=1.0860, Val Loss=1.1596
# Epoch 485: Train Loss=1.0863, Val Loss=1.1660
# Epoch 486: Train Loss=1.0858, Val Loss=1.1666
# Epoch 487: Train Loss=1.0864, Val Loss=1.1751
# Epoch 488: Train Loss=1.0851, Val Loss=1.1615
# Epoch 489: Train Loss=1.0845, Val Loss=1.1616
# Epoch 490: Train Loss=1.0857, Val Loss=1.1707
# Epoch 491: Train Loss=1.0866, Val Loss=1.1676
# Epoch 492: Train Loss=1.0869, Val Loss=1.1640
# Epoch 493: Train Loss=1.0850, Val Loss=1.1634
# Epoch 494: Train Loss=1.0853, Val Loss=1.1636
# Epoch 495: Train Loss=1.0853, Val Loss=1.1635
# Epoch 496: Train Loss=1.0848, Val Loss=1.1652
# Epoch 497: Train Loss=1.0851, Val Loss=1.1689
# Epoch 498: Train Loss=1.0837, Val Loss=1.1597
# Epoch 499: Train Loss=1.0842, Val Loss=1.1743
# Epoch 500: Train Loss=1.0833, Val Loss=1.1702
# Epoch 501: Train Loss=1.0838, Val Loss=1.1612
# Epoch 502: Train Loss=1.0842, Val Loss=1.1668
# Epoch 503: Train Loss=1.0831, Val Loss=1.1655
# Epoch 504: Train Loss=1.0858, Val Loss=1.1682
# Epoch 505: Train Loss=1.0848, Val Loss=1.1688
# Epoch 506: Train Loss=1.0843, Val Loss=1.1733
# Epoch 507: Train Loss=1.0828, Val Loss=1.1737
# Epoch 508: Train Loss=1.0839, Val Loss=1.1708
# Epoch 509: Train Loss=1.0828, Val Loss=1.1662
# Epoch 510: Train Loss=1.0837, Val Loss=1.1777
# Epoch 511: Train Loss=1.0833, Val Loss=1.1695
# Epoch 512: Train Loss=1.0840, Val Loss=1.1716
# Epoch 513: Train Loss=1.0837, Val Loss=1.1737
# Epoch 514: Train Loss=1.0826, Val Loss=1.1883
# Epoch 515: Train Loss=1.0831, Val Loss=1.1720
# Epoch 516: Train Loss=1.0842, Val Loss=1.1711
# Epoch 517: Train Loss=1.0842, Val Loss=1.1651
# Epoch 518: Train Loss=1.0824, Val Loss=1.1656
# Epoch 519: Train Loss=1.0835, Val Loss=1.1570
# Epoch 520: Train Loss=1.0837, Val Loss=1.1654
# Epoch 521: Train Loss=1.0828, Val Loss=1.1701
# Epoch 522: Train Loss=1.0821, Val Loss=1.1657
# Epoch 523: Train Loss=1.0835, Val Loss=1.1719
# Epoch 524: Train Loss=1.0838, Val Loss=1.1670
# Epoch 525: Train Loss=1.0818, Val Loss=1.1778
# Epoch 526: Train Loss=1.0829, Val Loss=1.1762
# Epoch 527: Train Loss=1.0822, Val Loss=1.1742
# Epoch 528: Train Loss=1.0816, Val Loss=1.1642
# Epoch 529: Train Loss=1.0818, Val Loss=1.1689
# Epoch 530: Train Loss=1.0838, Val Loss=1.1701
# Epoch 531: Train Loss=1.0826, Val Loss=1.1740
# Epoch 532: Train Loss=1.0815, Val Loss=1.1679
# Epoch 533: Train Loss=1.0812, Val Loss=1.1709
# Epoch 534: Train Loss=1.0817, Val Loss=1.1707
# Epoch 535: Train Loss=1.0838, Val Loss=1.1686
# Epoch 536: Train Loss=1.0848, Val Loss=1.1688
# Epoch 537: Train Loss=1.0817, Val Loss=1.1819
# Epoch 538: Train Loss=1.0820, Val Loss=1.1725
# Epoch 539: Train Loss=1.0803, Val Loss=1.1785
# Epoch 540: Train Loss=1.0812, Val Loss=1.1725
# Epoch 541: Train Loss=1.0813, Val Loss=1.1744
# Epoch 542: Train Loss=1.0821, Val Loss=1.1716
# Epoch 543: Train Loss=1.0806, Val Loss=1.1776
# Epoch 544: Train Loss=1.0803, Val Loss=1.1731
# Epoch 545: Train Loss=1.0816, Val Loss=1.1749
# Epoch 546: Train Loss=1.0818, Val Loss=1.1782
# Epoch 547: Train Loss=1.0798, Val Loss=1.1798
# Epoch 548: Train Loss=1.0803, Val Loss=1.1755
# Epoch 549: Train Loss=1.0802, Val Loss=1.1704
# Epoch 550: Train Loss=1.0807, Val Loss=1.1769
# Epoch 551: Train Loss=1.0807, Val Loss=1.1795
# Epoch 552: Train Loss=1.0802, Val Loss=1.1865
# Epoch 553: Train Loss=1.0804, Val Loss=1.1801
# Epoch 554: Train Loss=1.0839, Val Loss=1.1784
# Epoch 555: Train Loss=1.0829, Val Loss=1.1792
# Epoch 556: Train Loss=1.0801, Val Loss=1.1678
# Epoch 557: Train Loss=1.0799, Val Loss=1.1771
# Epoch 558: Train Loss=1.0802, Val Loss=1.1683
# Epoch 559: Train Loss=1.0805, Val Loss=1.1744
# Epoch 560: Train Loss=1.0802, Val Loss=1.1836
# Epoch 561: Train Loss=1.0825, Val Loss=1.1655
# Epoch 562: Train Loss=1.0801, Val Loss=1.1745
# Epoch 563: Train Loss=1.0804, Val Loss=1.1728
# Epoch 564: Train Loss=1.0812, Val Loss=1.1724
# Epoch 565: Train Loss=1.0798, Val Loss=1.1818
# Epoch 566: Train Loss=1.0790, Val Loss=1.1759
# Epoch 567: Train Loss=1.0789, Val Loss=1.1835
# Epoch 568: Train Loss=1.0795, Val Loss=1.1788
# Epoch 569: Train Loss=1.0792, Val Loss=1.1808
# Epoch 570: Train Loss=1.0792, Val Loss=1.1703
# Epoch 571: Train Loss=1.0787, Val Loss=1.1827
# Epoch 572: Train Loss=1.0786, Val Loss=1.1911
# Epoch 573: Train Loss=1.0825, Val Loss=1.1740
# Epoch 574: Train Loss=1.0787, Val Loss=1.1924
# Epoch 575: Train Loss=1.0800, Val Loss=1.1788
# Epoch 576: Train Loss=1.0801, Val Loss=1.1832
# Epoch 577: Train Loss=1.0781, Val Loss=1.1869
# Epoch 578: Train Loss=1.0790, Val Loss=1.1780
# Epoch 579: Train Loss=1.0800, Val Loss=1.1857
# Epoch 580: Train Loss=1.0792, Val Loss=1.1828
# Epoch 581: Train Loss=1.0794, Val Loss=1.1798
# Epoch 582: Train Loss=1.0796, Val Loss=1.1769
# Epoch 583: Train Loss=1.0777, Val Loss=1.1886
# Epoch 584: Train Loss=1.0777, Val Loss=1.1937
# Epoch 585: Train Loss=1.0784, Val Loss=1.1774
# Epoch 586: Train Loss=1.0781, Val Loss=1.1849
# Epoch 587: Train Loss=1.0788, Val Loss=1.1807
# Epoch 588: Train Loss=1.0783, Val Loss=1.1735
# Epoch 589: Train Loss=1.0767, Val Loss=1.1803
# Epoch 590: Train Loss=1.0778, Val Loss=1.1880
# Epoch 591: Train Loss=1.0779, Val Loss=1.1756
# Epoch 592: Train Loss=1.0800, Val Loss=1.1814
# Epoch 593: Train Loss=1.0771, Val Loss=1.1943
# Epoch 594: Train Loss=1.0778, Val Loss=1.1874
# Epoch 595: Train Loss=1.0771, Val Loss=1.1852
# Epoch 596: Train Loss=1.0767, Val Loss=1.1752
# Epoch 597: Train Loss=1.0766, Val Loss=1.1800
# Epoch 598: Train Loss=1.0790, Val Loss=1.1799
# Epoch 599: Train Loss=1.0783, Val Loss=1.1877
# Epoch 600: Train Loss=1.0769, Val Loss=1.1803
# Epoch 601: Train Loss=1.0781, Val Loss=1.1815
# Epoch 602: Train Loss=1.0784, Val Loss=1.1791
# Epoch 603: Train Loss=1.0762, Val Loss=1.1903
# Epoch 604: Train Loss=1.0772, Val Loss=1.1924
# Epoch 605: Train Loss=1.0756, Val Loss=1.1827
# Epoch 606: Train Loss=1.0771, Val Loss=1.1868
# Epoch 607: Train Loss=1.0769, Val Loss=1.1815
# Epoch 608: Train Loss=1.0767, Val Loss=1.1925
# Epoch 609: Train Loss=1.0767, Val Loss=1.1966
# Epoch 610: Train Loss=1.0776, Val Loss=1.1760
# Epoch 611: Train Loss=1.0782, Val Loss=1.1942
# Epoch 612: Train Loss=1.0758, Val Loss=1.1863
# Epoch 613: Train Loss=1.0762, Val Loss=1.1883
# Epoch 614: Train Loss=1.0749, Val Loss=1.1885
# Epoch 615: Train Loss=1.0766, Val Loss=1.1889
# Epoch 616: Train Loss=1.0753, Val Loss=1.1937
# Epoch 617: Train Loss=1.0764, Val Loss=1.1994
# Epoch 618: Train Loss=1.0756, Val Loss=1.1932
# Epoch 619: Train Loss=1.0772, Val Loss=1.1784
# Epoch 620: Train Loss=1.0778, Val Loss=1.1894
# Epoch 621: Train Loss=1.0776, Val Loss=1.1847
# Epoch 622: Train Loss=1.0767, Val Loss=1.1943
# Epoch 623: Train Loss=1.0758, Val Loss=1.1953
# Epoch 624: Train Loss=1.0740, Val Loss=1.1879
# Epoch 625: Train Loss=1.0751, Val Loss=1.1920
# Epoch 626: Train Loss=1.0748, Val Loss=1.1950
# Epoch 627: Train Loss=1.0757, Val Loss=1.1891
# Epoch 628: Train Loss=1.0759, Val Loss=1.2032
# Epoch 629: Train Loss=1.0756, Val Loss=1.1948
# Epoch 630: Train Loss=1.0784, Val Loss=1.1895
# Epoch 631: Train Loss=1.0744, Val Loss=1.1981
# Epoch 632: Train Loss=1.0738, Val Loss=1.1908
# Epoch 633: Train Loss=1.0756, Val Loss=1.1843
# Epoch 634: Train Loss=1.0732, Val Loss=1.1979
# Epoch 635: Train Loss=1.0743, Val Loss=1.1837
# Epoch 636: Train Loss=1.0757, Val Loss=1.2028
# Epoch 637: Train Loss=1.0769, Val Loss=1.2051
# Epoch 638: Train Loss=1.0749, Val Loss=1.2039
# Epoch 639: Train Loss=1.0750, Val Loss=1.1885
# Epoch 640: Train Loss=1.0744, Val Loss=1.1959
# Epoch 641: Train Loss=1.0741, Val Loss=1.1986
# Epoch 642: Train Loss=1.0739, Val Loss=1.1903
# Epoch 643: Train Loss=1.0747, Val Loss=1.1887
# Epoch 644: Train Loss=1.0751, Val Loss=1.1938
# Epoch 645: Train Loss=1.0748, Val Loss=1.1906
# Epoch 646: Train Loss=1.0747, Val Loss=1.1961
# Epoch 647: Train Loss=1.0741, Val Loss=1.1953
# Epoch 648: Train Loss=1.0733, Val Loss=1.1938
# Epoch 649: Train Loss=1.0732, Val Loss=1.1866
# Epoch 650: Train Loss=1.0738, Val Loss=1.1968
# Epoch 651: Train Loss=1.0760, Val Loss=1.1893
# Epoch 652: Train Loss=1.0744, Val Loss=1.2009
# Epoch 653: Train Loss=1.0733, Val Loss=1.2008
# Epoch 654: Train Loss=1.0719, Val Loss=1.2114
# Epoch 655: Train Loss=1.0721, Val Loss=1.1995
# Epoch 656: Train Loss=1.0748, Val Loss=1.1901
# Epoch 657: Train Loss=1.0746, Val Loss=1.2003
# Epoch 658: Train Loss=1.0760, Val Loss=1.2049
# Epoch 659: Train Loss=1.0727, Val Loss=1.1912
# Epoch 660: Train Loss=1.0736, Val Loss=1.2064
# Epoch 661: Train Loss=1.0741, Val Loss=1.1952
# Epoch 662: Train Loss=1.0735, Val Loss=1.1908
# Epoch 663: Train Loss=1.0722, Val Loss=1.2059
# Epoch 664: Train Loss=1.0727, Val Loss=1.2032
# Epoch 665: Train Loss=1.0722, Val Loss=1.2035
# Epoch 666: Train Loss=1.0711, Val Loss=1.2058
# Epoch 667: Train Loss=1.0744, Val Loss=1.1980
# Epoch 668: Train Loss=1.0722, Val Loss=1.1887
# Epoch 669: Train Loss=1.0729, Val Loss=1.1914
# Epoch 670: Train Loss=1.0729, Val Loss=1.1938
# Epoch 671: Train Loss=1.0721, Val Loss=1.2081
# Epoch 672: Train Loss=1.0731, Val Loss=1.2046
# Epoch 673: Train Loss=1.0727, Val Loss=1.1929
# Epoch 674: Train Loss=1.0715, Val Loss=1.2003
# Epoch 675: Train Loss=1.0764, Val Loss=1.1915
# Epoch 676: Train Loss=1.0744, Val Loss=1.1881
# Epoch 677: Train Loss=1.0722, Val Loss=1.2097
# Epoch 678: Train Loss=1.0721, Val Loss=1.1962
# Epoch 679: Train Loss=1.0721, Val Loss=1.2069
# Epoch 680: Train Loss=1.0727, Val Loss=1.2044
# Epoch 681: Train Loss=1.0720, Val Loss=1.2006
# Epoch 682: Train Loss=1.0716, Val Loss=1.1926
# Epoch 683: Train Loss=1.0723, Val Loss=1.2032
# Epoch 684: Train Loss=1.0715, Val Loss=1.1930
# Epoch 685: Train Loss=1.0720, Val Loss=1.2066
# Epoch 686: Train Loss=1.0725, Val Loss=1.2004
# Epoch 687: Train Loss=1.0739, Val Loss=1.1952
# Epoch 688: Train Loss=1.0723, Val Loss=1.2030
# Epoch 689: Train Loss=1.0709, Val Loss=1.2080
# Epoch 690: Train Loss=1.0703, Val Loss=1.2124
# Epoch 691: Train Loss=1.0762, Val Loss=1.1941
# Epoch 692: Train Loss=1.0720, Val Loss=1.2012
# Epoch 693: Train Loss=1.0704, Val Loss=1.1863
# Epoch 694: Train Loss=1.0704, Val Loss=1.2042
# Epoch 695: Train Loss=1.0692, Val Loss=1.2075
# Epoch 696: Train Loss=1.0703, Val Loss=1.2001
# Epoch 697: Train Loss=1.0708, Val Loss=1.2063
# Epoch 698: Train Loss=1.0709, Val Loss=1.2015
# Epoch 699: Train Loss=1.0703, Val Loss=1.2024
# Epoch 700: Train Loss=1.0732, Val Loss=1.2025
# Epoch 701: Train Loss=1.0734, Val Loss=1.2068
# Epoch 702: Train Loss=1.0704, Val Loss=1.2104
# Epoch 703: Train Loss=1.0706, Val Loss=1.2087
# Epoch 704: Train Loss=1.0707, Val Loss=1.2021
# Epoch 705: Train Loss=1.0708, Val Loss=1.1980
# Epoch 706: Train Loss=1.0699, Val Loss=1.2165
# Epoch 707: Train Loss=1.0705, Val Loss=1.2057
# Epoch 708: Train Loss=1.0712, Val Loss=1.2038
# Epoch 709: Train Loss=1.0705, Val Loss=1.2079
# Epoch 710: Train Loss=1.0696, Val Loss=1.2034
# Epoch 711: Train Loss=1.0700, Val Loss=1.2075
# Epoch 712: Train Loss=1.0701, Val Loss=1.2097
# Epoch 713: Train Loss=1.0711, Val Loss=1.1998
# Epoch 714: Train Loss=1.0716, Val Loss=1.2144
# Epoch 715: Train Loss=1.0688, Val Loss=1.2066
# Epoch 716: Train Loss=1.0704, Val Loss=1.2118
# Epoch 717: Train Loss=1.0712, Val Loss=1.2078
# Epoch 718: Train Loss=1.0703, Val Loss=1.2125
# Epoch 719: Train Loss=1.0713, Val Loss=1.2017
# Epoch 720: Train Loss=1.0695, Val Loss=1.2119
# Epoch 721: Train Loss=1.0698, Val Loss=1.1987
# Epoch 722: Train Loss=1.0684, Val Loss=1.2146
# Epoch 723: Train Loss=1.0708, Val Loss=1.2081
# Epoch 724: Train Loss=1.0695, Val Loss=1.2253
# Epoch 725: Train Loss=1.0697, Val Loss=1.2123
# Epoch 726: Train Loss=1.0701, Val Loss=1.2081
# Epoch 727: Train Loss=1.0689, Val Loss=1.2101
# Epoch 728: Train Loss=1.0695, Val Loss=1.1925
# Epoch 729: Train Loss=1.0687, Val Loss=1.2049
# Epoch 730: Train Loss=1.0708, Val Loss=1.2129
# Epoch 731: Train Loss=1.0731, Val Loss=1.2064
# Epoch 732: Train Loss=1.0690, Val Loss=1.2092
# Epoch 733: Train Loss=1.0694, Val Loss=1.1959
# Epoch 734: Train Loss=1.0701, Val Loss=1.2139
# Epoch 735: Train Loss=1.0690, Val Loss=1.2224
# Epoch 736: Train Loss=1.0679, Val Loss=1.2238
# Epoch 737: Train Loss=1.0677, Val Loss=1.2149
# Epoch 738: Train Loss=1.0707, Val Loss=1.2147
# Epoch 739: Train Loss=1.0691, Val Loss=1.2167
# Epoch 740: Train Loss=1.0697, Val Loss=1.2158
# Epoch 741: Train Loss=1.0692, Val Loss=1.2066
# Epoch 742: Train Loss=1.0683, Val Loss=1.2133
# Epoch 743: Train Loss=1.0680, Val Loss=1.2188
# Epoch 744: Train Loss=1.0693, Val Loss=1.2229
# Epoch 745: Train Loss=1.0696, Val Loss=1.2041
# Epoch 746: Train Loss=1.0688, Val Loss=1.2215
# Epoch 747: Train Loss=1.0679, Val Loss=1.2065
# Epoch 748: Train Loss=1.0680, Val Loss=1.2204
# Epoch 749: Train Loss=1.0699, Val Loss=1.2194
# Epoch 750: Train Loss=1.0675, Val Loss=1.2089
# Epoch 751: Train Loss=1.0669, Val Loss=1.2124
# Epoch 752: Train Loss=1.0681, Val Loss=1.2105
# Epoch 753: Train Loss=1.0674, Val Loss=1.2283
# Epoch 754: Train Loss=1.0665, Val Loss=1.2081
# Epoch 755: Train Loss=1.0676, Val Loss=1.2221
# Epoch 756: Train Loss=1.0684, Val Loss=1.2210
# Epoch 757: Train Loss=1.0673, Val Loss=1.2155
# Epoch 758: Train Loss=1.0700, Val Loss=1.2121
# Epoch 759: Train Loss=1.0737, Val Loss=1.2103
# Epoch 760: Train Loss=1.0692, Val Loss=1.2036
# Epoch 761: Train Loss=1.0683, Val Loss=1.2088
# Epoch 762: Train Loss=1.0682, Val Loss=1.2322
# Epoch 763: Train Loss=1.0683, Val Loss=1.2196
# Epoch 764: Train Loss=1.0671, Val Loss=1.2055
# Epoch 765: Train Loss=1.0671, Val Loss=1.2258
# Epoch 766: Train Loss=1.0660, Val Loss=1.2187
# Epoch 767: Train Loss=1.0655, Val Loss=1.2183
# Epoch 768: Train Loss=1.0677, Val Loss=1.2142
# Epoch 769: Train Loss=1.0673, Val Loss=1.2301
# Epoch 770: Train Loss=1.0669, Val Loss=1.2224
# Epoch 771: Train Loss=1.0689, Val Loss=1.2115
# Epoch 772: Train Loss=1.0675, Val Loss=1.2200
# Epoch 773: Train Loss=1.0666, Val Loss=1.2167
# Epoch 774: Train Loss=1.0657, Val Loss=1.2369
# Epoch 775: Train Loss=1.0667, Val Loss=1.2291
# Epoch 776: Train Loss=1.0674, Val Loss=1.2232
# Epoch 777: Train Loss=1.0690, Val Loss=1.2041
# Epoch 778: Train Loss=1.0670, Val Loss=1.2216
# Epoch 779: Train Loss=1.0664, Val Loss=1.2077
# Epoch 780: Train Loss=1.0657, Val Loss=1.2338
# Epoch 781: Train Loss=1.0676, Val Loss=1.2162
# Epoch 782: Train Loss=1.0696, Val Loss=1.2144
# Epoch 783: Train Loss=1.0661, Val Loss=1.2321
# Epoch 784: Train Loss=1.0670, Val Loss=1.2081
# Epoch 785: Train Loss=1.0666, Val Loss=1.2231
# Epoch 786: Train Loss=1.0659, Val Loss=1.2176
# Epoch 787: Train Loss=1.0663, Val Loss=1.2304
# Epoch 788: Train Loss=1.0692, Val Loss=1.2114
# Epoch 789: Train Loss=1.0673, Val Loss=1.2155
# Epoch 790: Train Loss=1.0649, Val Loss=1.2111
# Epoch 791: Train Loss=1.0652, Val Loss=1.2217
# Epoch 792: Train Loss=1.0649, Val Loss=1.2188
# Epoch 793: Train Loss=1.0651, Val Loss=1.2284
# Epoch 794: Train Loss=1.0674, Val Loss=1.2093
# Epoch 795: Train Loss=1.0652, Val Loss=1.2206
# Epoch 796: Train Loss=1.0666, Val Loss=1.2140
# Epoch 797: Train Loss=1.0670, Val Loss=1.2149
# Epoch 798: Train Loss=1.0671, Val Loss=1.2157
# Epoch 799: Train Loss=1.0663, Val Loss=1.2128
# Epoch 800: Train Loss=1.0671, Val Loss=1.2180
# Epoch 801: Train Loss=1.0692, Val Loss=1.2145
# Epoch 802: Train Loss=1.0659, Val Loss=1.2151
# Epoch 803: Train Loss=1.0651, Val Loss=1.2252
# Epoch 804: Train Loss=1.0664, Val Loss=1.2139
# Epoch 805: Train Loss=1.0649, Val Loss=1.2314
# Epoch 806: Train Loss=1.0647, Val Loss=1.2120
# Epoch 807: Train Loss=1.0669, Val Loss=1.2211
# Epoch 808: Train Loss=1.0662, Val Loss=1.2161
# Epoch 809: Train Loss=1.0666, Val Loss=1.2299
# Epoch 810: Train Loss=1.0647, Val Loss=1.2385
# Epoch 811: Train Loss=1.0648, Val Loss=1.2187
# Epoch 812: Train Loss=1.0634, Val Loss=1.2189
# Epoch 813: Train Loss=1.0637, Val Loss=1.2266
# Epoch 814: Train Loss=1.0649, Val Loss=1.2256
# Epoch 815: Train Loss=1.0645, Val Loss=1.2397
# Epoch 816: Train Loss=1.0660, Val Loss=1.2144
# Epoch 817: Train Loss=1.0656, Val Loss=1.2143
# Epoch 818: Train Loss=1.0645, Val Loss=1.2185
# Epoch 819: Train Loss=1.0648, Val Loss=1.2224
# Epoch 820: Train Loss=1.0652, Val Loss=1.2136
# Epoch 821: Train Loss=1.0647, Val Loss=1.2277
# Epoch 822: Train Loss=1.0650, Val Loss=1.2367
# Epoch 823: Train Loss=1.0656, Val Loss=1.2175
# Epoch 824: Train Loss=1.0647, Val Loss=1.2211
# Epoch 825: Train Loss=1.0640, Val Loss=1.2267
# Epoch 826: Train Loss=1.0649, Val Loss=1.2263
# Epoch 827: Train Loss=1.0657, Val Loss=1.2075
# Epoch 828: Train Loss=1.0678, Val Loss=1.2288
# Epoch 829: Train Loss=1.0644, Val Loss=1.2267
# Epoch 830: Train Loss=1.0648, Val Loss=1.2314
# Epoch 831: Train Loss=1.0640, Val Loss=1.2398
# Epoch 832: Train Loss=1.0641, Val Loss=1.2280
# Epoch 833: Train Loss=1.0637, Val Loss=1.2450
# Epoch 834: Train Loss=1.0656, Val Loss=1.2199
# Epoch 835: Train Loss=1.0640, Val Loss=1.2342
# Epoch 836: Train Loss=1.0634, Val Loss=1.2299
# Epoch 837: Train Loss=1.0648, Val Loss=1.2291
# Epoch 838: Train Loss=1.0668, Val Loss=1.2094
# Epoch 839: Train Loss=1.0653, Val Loss=1.2133
# Epoch 840: Train Loss=1.0631, Val Loss=1.2276
# Epoch 841: Train Loss=1.0626, Val Loss=1.2293
# Epoch 842: Train Loss=1.0642, Val Loss=1.2422
# Epoch 843: Train Loss=1.0648, Val Loss=1.2344
# Epoch 844: Train Loss=1.0648, Val Loss=1.2328
# Epoch 845: Train Loss=1.0642, Val Loss=1.2324
# Epoch 846: Train Loss=1.0620, Val Loss=1.2353
# Epoch 847: Train Loss=1.0628, Val Loss=1.2339
# Epoch 848: Train Loss=1.0647, Val Loss=1.2399
# Epoch 849: Train Loss=1.0641, Val Loss=1.2328
# Epoch 850: Train Loss=1.0641, Val Loss=1.2326
# Epoch 851: Train Loss=1.0634, Val Loss=1.2352
# Epoch 852: Train Loss=1.0633, Val Loss=1.2364
# Epoch 853: Train Loss=1.0667, Val Loss=1.2331
# Epoch 854: Train Loss=1.0639, Val Loss=1.2265
# Epoch 855: Train Loss=1.0649, Val Loss=1.2308
# Epoch 856: Train Loss=1.0617, Val Loss=1.2373
# Epoch 857: Train Loss=1.0616, Val Loss=1.2327
# Epoch 858: Train Loss=1.0635, Val Loss=1.2240
# Epoch 859: Train Loss=1.0635, Val Loss=1.2362
# Epoch 860: Train Loss=1.0636, Val Loss=1.2645
# Epoch 861: Train Loss=1.0621, Val Loss=1.2374
# Epoch 862: Train Loss=1.0625, Val Loss=1.2427
# Epoch 863: Train Loss=1.0627, Val Loss=1.2468
# Epoch 864: Train Loss=1.0638, Val Loss=1.2328
# Epoch 865: Train Loss=1.0649, Val Loss=1.2212
# Epoch 866: Train Loss=1.0635, Val Loss=1.2526
# Epoch 867: Train Loss=1.0630, Val Loss=1.2176
# Epoch 868: Train Loss=1.0666, Val Loss=1.2382
# Epoch 869: Train Loss=1.0633, Val Loss=1.2511
# Epoch 870: Train Loss=1.0624, Val Loss=1.2229
# Epoch 871: Train Loss=1.0613, Val Loss=1.2438
# Epoch 872: Train Loss=1.0621, Val Loss=1.2328
# Epoch 873: Train Loss=1.0630, Val Loss=1.2252
# Epoch 874: Train Loss=1.0644, Val Loss=1.2376
# Epoch 875: Train Loss=1.0665, Val Loss=1.2288
# Epoch 876: Train Loss=1.0622, Val Loss=1.2182
# Epoch 877: Train Loss=1.0638, Val Loss=1.2269
# Epoch 878: Train Loss=1.0610, Val Loss=1.2459
# Epoch 879: Train Loss=1.0637, Val Loss=1.2240
# Epoch 880: Train Loss=1.0640, Val Loss=1.2332
# Epoch 881: Train Loss=1.0616, Val Loss=1.2432
# Epoch 882: Train Loss=1.0609, Val Loss=1.2415
# Epoch 883: Train Loss=1.0620, Val Loss=1.2442
# Epoch 884: Train Loss=1.0619, Val Loss=1.2392
# Epoch 885: Train Loss=1.0617, Val Loss=1.2307
# Epoch 886: Train Loss=1.0615, Val Loss=1.2302
# Epoch 887: Train Loss=1.0614, Val Loss=1.2412
# Epoch 888: Train Loss=1.0614, Val Loss=1.2482
# Epoch 889: Train Loss=1.0639, Val Loss=1.2149
# Epoch 890: Train Loss=1.0638, Val Loss=1.2376
# Epoch 891: Train Loss=1.0626, Val Loss=1.2446
# Epoch 892: Train Loss=1.0617, Val Loss=1.2480
# Epoch 893: Train Loss=1.0614, Val Loss=1.2433
# Epoch 894: Train Loss=1.0626, Val Loss=1.2363
# Epoch 895: Train Loss=1.0621, Val Loss=1.2502
# Epoch 896: Train Loss=1.0619, Val Loss=1.2356
# Epoch 897: Train Loss=1.0621, Val Loss=1.2457
# Epoch 898: Train Loss=1.0620, Val Loss=1.2418
# Epoch 899: Train Loss=1.0629, Val Loss=1.2424
# Epoch 900: Train Loss=1.0623, Val Loss=1.2401
# Epoch 901: Train Loss=1.0639, Val Loss=1.2296
# Epoch 902: Train Loss=1.0612, Val Loss=1.2303
# Epoch 903: Train Loss=1.0611, Val Loss=1.2380
# Epoch 904: Train Loss=1.0626, Val Loss=1.2288
# Epoch 905: Train Loss=1.0614, Val Loss=1.2316
# Epoch 906: Train Loss=1.0619, Val Loss=1.2402
# Epoch 907: Train Loss=1.0639, Val Loss=1.2411
# Epoch 908: Train Loss=1.0624, Val Loss=1.2432
# Epoch 909: Train Loss=1.0621, Val Loss=1.2195
# Epoch 910: Train Loss=1.0611, Val Loss=1.2526
# Epoch 911: Train Loss=1.0622, Val Loss=1.2545
# Epoch 912: Train Loss=1.0604, Val Loss=1.2313
# Epoch 913: Train Loss=1.0603, Val Loss=1.2305
# Epoch 914: Train Loss=1.0601, Val Loss=1.2434
# Epoch 915: Train Loss=1.0607, Val Loss=1.2329
# Epoch 916: Train Loss=1.0615, Val Loss=1.2317
# Epoch 917: Train Loss=1.0599, Val Loss=1.2440
# Epoch 918: Train Loss=1.0640, Val Loss=1.2337
# Epoch 919: Train Loss=1.0643, Val Loss=1.2384
# Epoch 920: Train Loss=1.0624, Val Loss=1.2329
# Epoch 921: Train Loss=1.0613, Val Loss=1.2420
# Epoch 922: Train Loss=1.0602, Val Loss=1.2426
# Epoch 923: Train Loss=1.0597, Val Loss=1.2435
# Epoch 924: Train Loss=1.0651, Val Loss=1.2257
# Epoch 925: Train Loss=1.0593, Val Loss=1.2372
# Epoch 926: Train Loss=1.0638, Val Loss=1.2294
# Epoch 927: Train Loss=1.0655, Val Loss=1.2372
# Epoch 928: Train Loss=1.0612, Val Loss=1.2321
# Epoch 929: Train Loss=1.0608, Val Loss=1.2508
# Epoch 930: Train Loss=1.0598, Val Loss=1.2508
# Epoch 931: Train Loss=1.0592, Val Loss=1.2391
# Epoch 932: Train Loss=1.0610, Val Loss=1.2421
# Epoch 933: Train Loss=1.0608, Val Loss=1.2350
# Epoch 934: Train Loss=1.0599, Val Loss=1.2437
# Epoch 935: Train Loss=1.0614, Val Loss=1.2442
# Epoch 936: Train Loss=1.0608, Val Loss=1.2468
# Epoch 937: Train Loss=1.0582, Val Loss=1.2464
# Epoch 938: Train Loss=1.0589, Val Loss=1.2494
# Epoch 939: Train Loss=1.0606, Val Loss=1.2585
# Epoch 940: Train Loss=1.0611, Val Loss=1.2440
# Epoch 941: Train Loss=1.0617, Val Loss=1.2423
# Epoch 942: Train Loss=1.0603, Val Loss=1.2406
# Epoch 943: Train Loss=1.0598, Val Loss=1.2545
# Epoch 944: Train Loss=1.0631, Val Loss=1.2331
# Epoch 945: Train Loss=1.0600, Val Loss=1.2434
# Epoch 946: Train Loss=1.0590, Val Loss=1.2524
# Epoch 947: Train Loss=1.0596, Val Loss=1.2417
# Epoch 948: Train Loss=1.0609, Val Loss=1.2215
# Epoch 949: Train Loss=1.0602, Val Loss=1.2398
# Epoch 950: Train Loss=1.0590, Val Loss=1.2511
# Epoch 951: Train Loss=1.0577, Val Loss=1.2543
# Epoch 952: Train Loss=1.0589, Val Loss=1.2486
# Epoch 953: Train Loss=1.0612, Val Loss=1.2344
# Epoch 954: Train Loss=1.0609, Val Loss=1.2542
# Epoch 955: Train Loss=1.0606, Val Loss=1.2424
# Epoch 956: Train Loss=1.0608, Val Loss=1.2405
# Epoch 957: Train Loss=1.0604, Val Loss=1.2464
# Epoch 958: Train Loss=1.0597, Val Loss=1.2409
# Epoch 959: Train Loss=1.0583, Val Loss=1.2498
# Epoch 960: Train Loss=1.0598, Val Loss=1.2367
# Epoch 961: Train Loss=1.0594, Val Loss=1.2459
# Epoch 962: Train Loss=1.0608, Val Loss=1.2496
# Epoch 963: Train Loss=1.0589, Val Loss=1.2539
# Epoch 964: Train Loss=1.0575, Val Loss=1.2441
# Epoch 965: Train Loss=1.0591, Val Loss=1.2576
# Epoch 966: Train Loss=1.0607, Val Loss=1.2243
# Epoch 967: Train Loss=1.0614, Val Loss=1.2195
# Epoch 968: Train Loss=1.0630, Val Loss=1.2218
# Epoch 969: Train Loss=1.0660, Val Loss=1.2401
# Epoch 970: Train Loss=1.0590, Val Loss=1.2541
# Epoch 971: Train Loss=1.0598, Val Loss=1.2395
# Epoch 972: Train Loss=1.0581, Val Loss=1.2562
# Epoch 973: Train Loss=1.0586, Val Loss=1.2358
# Epoch 974: Train Loss=1.0581, Val Loss=1.2397
# Epoch 975: Train Loss=1.0589, Val Loss=1.2492
# Epoch 976: Train Loss=1.0577, Val Loss=1.2489
# Epoch 977: Train Loss=1.0597, Val Loss=1.2386
# Epoch 978: Train Loss=1.0598, Val Loss=1.2321
# Epoch 979: Train Loss=1.0589, Val Loss=1.2401
# Epoch 980: Train Loss=1.0579, Val Loss=1.2467
# Epoch 981: Train Loss=1.0575, Val Loss=1.2587
# Epoch 982: Train Loss=1.0590, Val Loss=1.2523
# Epoch 983: Train Loss=1.0593, Val Loss=1.2519
# Epoch 984: Train Loss=1.0618, Val Loss=1.2557
# Epoch 985: Train Loss=1.0596, Val Loss=1.2347
# Epoch 986: Train Loss=1.0599, Val Loss=1.2503
# Epoch 987: Train Loss=1.0589, Val Loss=1.2440
# Epoch 988: Train Loss=1.0588, Val Loss=1.2602
# Epoch 989: Train Loss=1.0595, Val Loss=1.2476
# Epoch 990: Train Loss=1.0584, Val Loss=1.2509
# Epoch 991: Train Loss=1.0591, Val Loss=1.2513
# Epoch 992: Train Loss=1.0578, Val Loss=1.2548
# Epoch 993: Train Loss=1.0587, Val Loss=1.2384
# Epoch 994: Train Loss=1.0580, Val Loss=1.2484
# Epoch 995: Train Loss=1.0582, Val Loss=1.2517
# Epoch 996: Train Loss=1.0600, Val Loss=1.2397
# Epoch 997: Train Loss=1.0615, Val Loss=1.2514
# Epoch 998: Train Loss=1.0601, Val Loss=1.2645
# Epoch 999: Train Loss=1.0596, Val Loss=1.2477
# Epoch 1000: Train Loss=1.0587, Val Loss=1.2599
# Epoch 1001: Train Loss=1.0566, Val Loss=1.2557
# Epoch 1002: Train Loss=1.0578, Val Loss=1.2567
# Epoch 1003: Train Loss=1.0586, Val Loss=1.2510
# Epoch 1004: Train Loss=1.0577, Val Loss=1.2475
# Epoch 1005: Train Loss=1.0586, Val Loss=1.2582
# Epoch 1006: Train Loss=1.0585, Val Loss=1.2559
# Epoch 1007: Train Loss=1.0574, Val Loss=1.2502
# Epoch 1008: Train Loss=1.0579, Val Loss=1.2509
# Epoch 1009: Train Loss=1.0592, Val Loss=1.2516
# Epoch 1010: Train Loss=1.0620, Val Loss=1.2433
# Epoch 1011: Train Loss=1.0598, Val Loss=1.2526
# Epoch 1012: Train Loss=1.0577, Val Loss=1.2518
# Epoch 1013: Train Loss=1.0588, Val Loss=1.2521
# Epoch 1014: Train Loss=1.0573, Val Loss=1.2415
# Epoch 1015: Train Loss=1.0582, Val Loss=1.2631
# Epoch 1016: Train Loss=1.0563, Val Loss=1.2449
# Epoch 1017: Train Loss=1.0587, Val Loss=1.2371
# Epoch 1018: Train Loss=1.0616, Val Loss=1.2435
# Epoch 1019: Train Loss=1.0573, Val Loss=1.2557
# Epoch 1020: Train Loss=1.0566, Val Loss=1.2419
# Epoch 1021: Train Loss=1.0608, Val Loss=1.2543
# Epoch 1022: Train Loss=1.0599, Val Loss=1.2537
# Epoch 1023: Train Loss=1.0587, Val Loss=1.2487
# Epoch 1024: Train Loss=1.0574, Val Loss=1.2460
# Epoch 1025: Train Loss=1.0576, Val Loss=1.2391
# Epoch 1026: Train Loss=1.0555, Val Loss=1.2524
# Epoch 1027: Train Loss=1.0565, Val Loss=1.2633
# Epoch 1028: Train Loss=1.0571, Val Loss=1.2467
# Epoch 1029: Train Loss=1.0560, Val Loss=1.2706
# Epoch 1030: Train Loss=1.0569, Val Loss=1.2692
# Epoch 1031: Train Loss=1.0645, Val Loss=1.2670
# Epoch 1032: Train Loss=1.0596, Val Loss=1.2461
# Epoch 1033: Train Loss=1.0584, Val Loss=1.2375
# Epoch 1034: Train Loss=1.0576, Val Loss=1.2358
# Epoch 1035: Train Loss=1.0581, Val Loss=1.2510
# Epoch 1036: Train Loss=1.0566, Val Loss=1.2726
# Epoch 1037: Train Loss=1.0568, Val Loss=1.2618
# Epoch 1038: Train Loss=1.0567, Val Loss=1.2609
# Epoch 1039: Train Loss=1.0577, Val Loss=1.2644
# Epoch 1040: Train Loss=1.0579, Val Loss=1.2542
# Epoch 1041: Train Loss=1.0568, Val Loss=1.2342
# Epoch 1042: Train Loss=1.0566, Val Loss=1.2644
# Epoch 1043: Train Loss=1.0575, Val Loss=1.2260
# ...
# Epoch 1660: Train Loss=1.0437, Val Loss=1.3200
# Epoch 1661: Train Loss=1.0446, Val Loss=1.2831
# Epoch 1662: Train Loss=1.0442, Val Loss=1.2972
# Epoch 1663: Train Loss=1.0455, Val Loss=1.3057
# Epoch 1664: Train Loss=1.0474, Val Loss=1.3029
# Epoch 1665: Train Loss=1.0449, Val Loss=1.2973
# Epoch 1666: Train Loss=1.0459, Val Loss=1.3083
# Epoch 1667: Train Loss=1.0440, Val Loss=1.2965
# Epoch 1668: Train Loss=1.0438, Val Loss=1.3319
# Epoch 1669: Train Loss=1.0453, Val Loss=1.2908
# Epoch 1670: Train Loss=1.0451, Val Loss=1.3131
# Epoch 1671: Train Loss=1.0514, Val Loss=1.2833
# Epoch 1672: Train Loss=1.0454, Val Loss=1.3035
# Epoch 1673: Train Loss=1.0453, Val Loss=1.2945
# Epoch 1674: Train Loss=1.0442, Val Loss=1.3161
# Epoch 1675: Train Loss=1.0445, Val Loss=1.2892
# Epoch 1676: Train Loss=1.0435, Val Loss=1.3004
# Epoch 1677: Train Loss=1.0445, Val Loss=1.2990
# Epoch 1678: Train Loss=1.0424, Val Loss=1.3026
# Epoch 1679: Train Loss=1.0436, Val Loss=1.2919
# Epoch 1680: Train Loss=1.0441, Val Loss=1.3105
# Epoch 1681: Train Loss=1.0444, Val Loss=1.3228
# Epoch 1682: Train Loss=1.0449, Val Loss=1.3139
# Epoch 1683: Train Loss=1.0467, Val Loss=1.3097
# Epoch 1684: Train Loss=1.0443, Val Loss=1.3085
# Epoch 1685: Train Loss=1.0444, Val Loss=1.3201
# Epoch 1686: Train Loss=1.0439, Val Loss=1.3084
# Epoch 1687: Train Loss=1.0456, Val Loss=1.2983
# Epoch 1688: Train Loss=1.0437, Val Loss=1.3137
# Epoch 1689: Train Loss=1.0422, Val Loss=1.3052
# Epoch 1690: Train Loss=1.0482, Val Loss=1.3128
# Epoch 1691: Train Loss=1.0442, Val Loss=1.3288
# Epoch 1692: Train Loss=1.0435, Val Loss=1.3185
# Epoch 1693: Train Loss=1.0434, Val Loss=1.3214
# Epoch 1694: Train Loss=1.0442, Val Loss=1.3020
# Epoch 1695: Train Loss=1.0438, Val Loss=1.3306
# Epoch 1696: Train Loss=1.0442, Val Loss=1.3328
# Epoch 1697: Train Loss=1.0457, Val Loss=1.3281
# Epoch 1698: Train Loss=1.0444, Val Loss=1.3035
# Epoch 1699: Train Loss=1.0449, Val Loss=1.3363
# Epoch 1700: Train Loss=1.0447, Val Loss=1.3021
# Epoch 1701: Train Loss=1.0437, Val Loss=1.3276
# Epoch 1702: Train Loss=1.0439, Val Loss=1.3131
# Epoch 1703: Train Loss=1.0432, Val Loss=1.2966
# Epoch 1704: Train Loss=1.0435, Val Loss=1.3052
# Epoch 1705: Train Loss=1.0452, Val Loss=1.2970
# Epoch 1706: Train Loss=1.0451, Val Loss=1.3213
# Epoch 1707: Train Loss=1.0449, Val Loss=1.3109
# Epoch 1708: Train Loss=1.0447, Val Loss=1.3195
# Epoch 1709: Train Loss=1.0428, Val Loss=1.3163
# Epoch 1710: Train Loss=1.0437, Val Loss=1.3120
# Epoch 1711: Train Loss=1.0442, Val Loss=1.3255
# Epoch 1712: Train Loss=1.0432, Val Loss=1.3180
# Epoch 1713: Train Loss=1.0432, Val Loss=1.2962
# Epoch 1714: Train Loss=1.0437, Val Loss=1.3139
# Epoch 1715: Train Loss=1.0445, Val Loss=1.2955
# Epoch 1716: Train Loss=1.0448, Val Loss=1.3311
# Epoch 1717: Train Loss=1.0444, Val Loss=1.3163
# Epoch 1718: Train Loss=1.0437, Val Loss=1.3162
# Epoch 1719: Train Loss=1.0427, Val Loss=1.3348
# Epoch 1720: Train Loss=1.0445, Val Loss=1.3205
# Epoch 1721: Train Loss=1.0453, Val Loss=1.3178
# Epoch 1722: Train Loss=1.0458, Val Loss=1.3000
# Epoch 1723: Train Loss=1.0443, Val Loss=1.3214
# Epoch 1724: Train Loss=1.0462, Val Loss=1.3111
# Epoch 1725: Train Loss=1.0449, Val Loss=1.3115
# Epoch 1726: Train Loss=1.0438, Val Loss=1.3158
# Epoch 1727: Train Loss=1.0435, Val Loss=1.3125
# Epoch 1728: Train Loss=1.0429, Val Loss=1.3212
# Epoch 1729: Train Loss=1.0430, Val Loss=1.3245
# Epoch 1730: Train Loss=1.0435, Val Loss=1.3117
# Epoch 1731: Train Loss=1.0436, Val Loss=1.2955
# Epoch 1732: Train Loss=1.0455, Val Loss=1.3030
# Epoch 1733: Train Loss=1.0435, Val Loss=1.3181
# Epoch 1734: Train Loss=1.0470, Val Loss=1.3241
# Epoch 1735: Train Loss=1.0438, Val Loss=1.3141
# Epoch 1736: Train Loss=1.0450, Val Loss=1.2992
# Epoch 1737: Train Loss=1.0435, Val Loss=1.3238
# Epoch 1738: Train Loss=1.0433, Val Loss=1.2875
# Epoch 1739: Train Loss=1.0437, Val Loss=1.2911
# Epoch 1740: Train Loss=1.0444, Val Loss=1.3070
# Epoch 1741: Train Loss=1.0434, Val Loss=1.3234
# Epoch 1742: Train Loss=1.0435, Val Loss=1.3035
# Epoch 1743: Train Loss=1.0444, Val Loss=1.3273
# Epoch 1744: Train Loss=1.0437, Val Loss=1.3021
# Epoch 1745: Train Loss=1.0425, Val Loss=1.3209
# Epoch 1746: Train Loss=1.0442, Val Loss=1.3102
# Epoch 1747: Train Loss=1.0444, Val Loss=1.3158
# Epoch 1748: Train Loss=1.0448, Val Loss=1.3014
# Epoch 1749: Train Loss=1.0438, Val Loss=1.2990
# Epoch 1750: Train Loss=1.0425, Val Loss=1.3111
# Epoch 1751: Train Loss=1.0435, Val Loss=1.3089
# Epoch 1752: Train Loss=1.0429, Val Loss=1.2878
# Epoch 1753: Train Loss=1.0431, Val Loss=1.2899
# Epoch 1754: Train Loss=1.0441, Val Loss=1.3188
# Epoch 1755: Train Loss=1.0432, Val Loss=1.2892
# Epoch 1756: Train Loss=1.0418, Val Loss=1.3069
# Epoch 1757: Train Loss=1.0435, Val Loss=1.3258
# Epoch 1758: Train Loss=1.0463, Val Loss=1.2924
# Epoch 1759: Train Loss=1.0454, Val Loss=1.3291
# Epoch 1760: Train Loss=1.0437, Val Loss=1.3040
# Epoch 1761: Train Loss=1.0437, Val Loss=1.3219
# Epoch 1762: Train Loss=1.0438, Val Loss=1.3067
# Epoch 1763: Train Loss=1.0421, Val Loss=1.3137
# Epoch 1764: Train Loss=1.0429, Val Loss=1.3003
# Epoch 1765: Train Loss=1.0435, Val Loss=1.3259
# Epoch 1766: Train Loss=1.0438, Val Loss=1.3196
# Epoch 1767: Train Loss=1.0442, Val Loss=1.3026
# Epoch 1768: Train Loss=1.0446, Val Loss=1.3007
# Epoch 1769: Train Loss=1.0471, Val Loss=1.3003
# Epoch 1770: Train Loss=1.0445, Val Loss=1.3450
# Epoch 1771: Train Loss=1.0421, Val Loss=1.2989
# Epoch 1772: Train Loss=1.0447, Val Loss=1.3256
# Epoch 1773: Train Loss=1.0419, Val Loss=1.3142
# Epoch 1774: Train Loss=1.0426, Val Loss=1.3257
# Epoch 1775: Train Loss=1.0426, Val Loss=1.3105
# Epoch 1776: Train Loss=1.0436, Val Loss=1.3053
# Epoch 1777: Train Loss=1.0444, Val Loss=1.3133
# Epoch 1778: Train Loss=1.0422, Val Loss=1.3169
# Epoch 1779: Train Loss=1.0436, Val Loss=1.3148
# Epoch 1780: Train Loss=1.0433, Val Loss=1.2951
# Epoch 1781: Train Loss=1.0423, Val Loss=1.3244
# Epoch 1782: Train Loss=1.0458, Val Loss=1.3071
# Epoch 1783: Train Loss=1.0440, Val Loss=1.3088
# Epoch 1784: Train Loss=1.0429, Val Loss=1.3217
# Epoch 1785: Train Loss=1.0415, Val Loss=1.3186
# Epoch 1786: Train Loss=1.0425, Val Loss=1.3214
# Epoch 1787: Train Loss=1.0433, Val Loss=1.3194
# Epoch 1788: Train Loss=1.0433, Val Loss=1.3140
# Epoch 1789: Train Loss=1.0434, Val Loss=1.3127
# Epoch 1790: Train Loss=1.0444, Val Loss=1.3283
# Epoch 1791: Train Loss=1.0434, Val Loss=1.3194
# Epoch 1792: Train Loss=1.0427, Val Loss=1.3176
# Epoch 1793: Train Loss=1.0432, Val Loss=1.3142
# Epoch 1794: Train Loss=1.0433, Val Loss=1.3182
# Epoch 1795: Train Loss=1.0434, Val Loss=1.3359
# Epoch 1796: Train Loss=1.0486, Val Loss=1.3206
# Epoch 1797: Train Loss=1.0449, Val Loss=1.2894
# Epoch 1798: Train Loss=1.0444, Val Loss=1.3257
# Epoch 1799: Train Loss=1.0430, Val Loss=1.3003
# Epoch 1800: Train Loss=1.0423, Val Loss=1.3283
# Epoch 1801: Train Loss=1.0434, Val Loss=1.3196
# Epoch 1802: Train Loss=1.0425, Val Loss=1.3148
# Epoch 1803: Train Loss=1.0425, Val Loss=1.3218
# Epoch 1804: Train Loss=1.0425, Val Loss=1.3077
# Epoch 1805: Train Loss=1.0439, Val Loss=1.3199
# Epoch 1806: Train Loss=1.0431, Val Loss=1.3155
# Epoch 1807: Train Loss=1.0435, Val Loss=1.3058
# Epoch 1808: Train Loss=1.0420, Val Loss=1.3222
# Epoch 1809: Train Loss=1.0429, Val Loss=1.3265
# Epoch 1810: Train Loss=1.0427, Val Loss=1.3246
# Epoch 1811: Train Loss=1.0420, Val Loss=1.3188
# Epoch 1812: Train Loss=1.0413, Val Loss=1.3171
# Epoch 1813: Train Loss=1.0438, Val Loss=1.3300
# Epoch 1814: Train Loss=1.0440, Val Loss=1.3058
# Epoch 1815: Train Loss=1.0437, Val Loss=1.3210
# Epoch 1816: Train Loss=1.0433, Val Loss=1.3256
# Epoch 1817: Train Loss=1.0425, Val Loss=1.3235
# Epoch 1818: Train Loss=1.0427, Val Loss=1.3424
# Epoch 1819: Train Loss=1.0429, Val Loss=1.3187
# Epoch 1820: Train Loss=1.0437, Val Loss=1.3167
# Epoch 1821: Train Loss=1.0426, Val Loss=1.3136
# Epoch 1822: Train Loss=1.0420, Val Loss=1.3272
# Epoch 1823: Train Loss=1.0417, Val Loss=1.3148
# Epoch 1824: Train Loss=1.0429, Val Loss=1.3312
# Epoch 1825: Train Loss=1.0460, Val Loss=1.2947
# Epoch 1826: Train Loss=1.0433, Val Loss=1.3220
# Epoch 1827: Train Loss=1.0429, Val Loss=1.3159
# Epoch 1828: Train Loss=1.0428, Val Loss=1.3131
# Epoch 1829: Train Loss=1.0422, Val Loss=1.3229
# Epoch 1830: Train Loss=1.0427, Val Loss=1.3126
# Epoch 1831: Train Loss=1.0423, Val Loss=1.3277
# Epoch 1832: Train Loss=1.0433, Val Loss=1.3297
# Epoch 1833: Train Loss=1.0422, Val Loss=1.3172
# Epoch 1834: Train Loss=1.0428, Val Loss=1.3185
# Epoch 1835: Train Loss=1.0431, Val Loss=1.3012
# Epoch 1836: Train Loss=1.0481, Val Loss=1.3152
# Epoch 1837: Train Loss=1.0428, Val Loss=1.3208
# Epoch 1838: Train Loss=1.0420, Val Loss=1.3056
# Epoch 1839: Train Loss=1.0419, Val Loss=1.3228
# Epoch 1840: Train Loss=1.0409, Val Loss=1.3296
# Epoch 1841: Train Loss=1.0427, Val Loss=1.3133
# Epoch 1842: Train Loss=1.0429, Val Loss=1.3256
# Epoch 1843: Train Loss=1.0413, Val Loss=1.3294
# Epoch 1844: Train Loss=1.0423, Val Loss=1.3223
# Epoch 1845: Train Loss=1.0415, Val Loss=1.2943
# Epoch 1846: Train Loss=1.0413, Val Loss=1.3334
# Epoch 1847: Train Loss=1.0423, Val Loss=1.3299
# Epoch 1848: Train Loss=1.0436, Val Loss=1.3226
# Epoch 1849: Train Loss=1.0414, Val Loss=1.3016
# Epoch 1850: Train Loss=1.0416, Val Loss=1.3257
# Epoch 1851: Train Loss=1.0430, Val Loss=1.3308
# Epoch 1852: Train Loss=1.0461, Val Loss=1.2915
# Epoch 1853: Train Loss=1.0458, Val Loss=1.3082
# Epoch 1854: Train Loss=1.0446, Val Loss=1.3065
# Epoch 1855: Train Loss=1.0419, Val Loss=1.3264
# Epoch 1856: Train Loss=1.0423, Val Loss=1.3383
# Epoch 1857: Train Loss=1.0424, Val Loss=1.3337
# Epoch 1858: Train Loss=1.0427, Val Loss=1.2942
# Epoch 1859: Train Loss=1.0416, Val Loss=1.3282
# Epoch 1860: Train Loss=1.0416, Val Loss=1.3253
# Epoch 1861: Train Loss=1.0414, Val Loss=1.3138
# Epoch 1862: Train Loss=1.0418, Val Loss=1.3214
# Epoch 1863: Train Loss=1.0415, Val Loss=1.3235
# Epoch 1864: Train Loss=1.0437, Val Loss=1.3120
# Epoch 1865: Train Loss=1.0522, Val Loss=1.2706
# Epoch 1866: Train Loss=1.0449, Val Loss=1.3106
# Epoch 1867: Train Loss=1.0407, Val Loss=1.3246
# Epoch 1868: Train Loss=1.0429, Val Loss=1.3331
# Epoch 1869: Train Loss=1.0423, Val Loss=1.3313
# Epoch 1870: Train Loss=1.0425, Val Loss=1.3133
# Epoch 1871: Train Loss=1.0423, Val Loss=1.3238
# Epoch 1872: Train Loss=1.0421, Val Loss=1.3174
# Epoch 1873: Train Loss=1.0407, Val Loss=1.2978
# Epoch 1874: Train Loss=1.0412, Val Loss=1.3205
# Epoch 1875: Train Loss=1.0410, Val Loss=1.3133
# Epoch 1876: Train Loss=1.0422, Val Loss=1.3089
# Epoch 1877: Train Loss=1.0467, Val Loss=1.3196
# Epoch 1878: Train Loss=1.0430, Val Loss=1.3179
# Epoch 1879: Train Loss=1.0420, Val Loss=1.3290
# Epoch 1880: Train Loss=1.0423, Val Loss=1.3250
# Epoch 1881: Train Loss=1.0416, Val Loss=1.3436
# Epoch 1882: Train Loss=1.0419, Val Loss=1.3251
# Epoch 1883: Train Loss=1.0426, Val Loss=1.3083
# Epoch 1884: Train Loss=1.0425, Val Loss=1.3077
# Epoch 1885: Train Loss=1.0427, Val Loss=1.3146
# Epoch 1886: Train Loss=1.0410, Val Loss=1.3299
# Epoch 1887: Train Loss=1.0432, Val Loss=1.3143
# Epoch 1888: Train Loss=1.0410, Val Loss=1.3326
# Epoch 1889: Train Loss=1.0416, Val Loss=1.3193
# Epoch 1890: Train Loss=1.0418, Val Loss=1.3355
# Epoch 1891: Train Loss=1.0425, Val Loss=1.3383
# Epoch 1892: Train Loss=1.0404, Val Loss=1.3283
# Epoch 1893: Train Loss=1.0425, Val Loss=1.3143
# Epoch 1894: Train Loss=1.0430, Val Loss=1.3179
# Epoch 1895: Train Loss=1.0431, Val Loss=1.3247
# Epoch 1896: Train Loss=1.0427, Val Loss=1.3186
# Epoch 1897: Train Loss=1.0421, Val Loss=1.3286
# Epoch 1898: Train Loss=1.0420, Val Loss=1.3168
# Epoch 1899: Train Loss=1.0428, Val Loss=1.3376
# Epoch 1900: Train Loss=1.0418, Val Loss=1.3029
# Epoch 1901: Train Loss=1.0415, Val Loss=1.3190
# Epoch 1902: Train Loss=1.0415, Val Loss=1.3298
# Epoch 1903: Train Loss=1.0416, Val Loss=1.3315
# Epoch 1904: Train Loss=1.0407, Val Loss=1.3417
# Epoch 1905: Train Loss=1.0414, Val Loss=1.3352
# Epoch 1906: Train Loss=1.0402, Val Loss=1.3217
# Epoch 1907: Train Loss=1.0411, Val Loss=1.3370
# Epoch 1908: Train Loss=1.0443, Val Loss=1.3207
# Epoch 1909: Train Loss=1.0425, Val Loss=1.3200
# Epoch 1910: Train Loss=1.0423, Val Loss=1.3317
# Epoch 1911: Train Loss=1.0410, Val Loss=1.3112
# Epoch 1912: Train Loss=1.0424, Val Loss=1.3031
# Epoch 1913: Train Loss=1.0416, Val Loss=1.3255
# Epoch 1914: Train Loss=1.0416, Val Loss=1.3258
# Epoch 1915: Train Loss=1.0413, Val Loss=1.3338
# Epoch 1916: Train Loss=1.0409, Val Loss=1.3144
# Epoch 1917: Train Loss=1.0417, Val Loss=1.3102
# Epoch 1918: Train Loss=1.0407, Val Loss=1.3121
# Epoch 1919: Train Loss=1.0429, Val Loss=1.3212
# Epoch 1920: Train Loss=1.0442, Val Loss=1.3126
# Epoch 1921: Train Loss=1.0421, Val Loss=1.3023
# Epoch 1922: Train Loss=1.0416, Val Loss=1.3046
# Epoch 1923: Train Loss=1.0415, Val Loss=1.3263
# Epoch 1924: Train Loss=1.0410, Val Loss=1.3117
# Epoch 1925: Train Loss=1.0429, Val Loss=1.3236
# Epoch 1926: Train Loss=1.0414, Val Loss=1.3362
# Epoch 1927: Train Loss=1.0405, Val Loss=1.3505
# Epoch 1928: Train Loss=1.0416, Val Loss=1.3208
# Epoch 1929: Train Loss=1.0412, Val Loss=1.3288
# Epoch 1930: Train Loss=1.0438, Val Loss=1.3394
# Epoch 1931: Train Loss=1.0417, Val Loss=1.3468
# Epoch 1932: Train Loss=1.0419, Val Loss=1.3282
# Epoch 1933: Train Loss=1.0412, Val Loss=1.3297
# Epoch 1934: Train Loss=1.0414, Val Loss=1.3251
# Epoch 1935: Train Loss=1.0404, Val Loss=1.3385
# Epoch 1936: Train Loss=1.0416, Val Loss=1.3374
# Epoch 1937: Train Loss=1.0400, Val Loss=1.3261
# Epoch 1938: Train Loss=1.0420, Val Loss=1.2926
# Epoch 1939: Train Loss=1.0406, Val Loss=1.3202
# Epoch 1940: Train Loss=1.0407, Val Loss=1.3325
# Epoch 1941: Train Loss=1.0413, Val Loss=1.3037
# Epoch 1942: Train Loss=1.0422, Val Loss=1.3069
# Epoch 1943: Train Loss=1.0406, Val Loss=1.3375
# Epoch 1944: Train Loss=1.0427, Val Loss=1.3235
# Epoch 1945: Train Loss=1.0408, Val Loss=1.3054
# Epoch 1946: Train Loss=1.0409, Val Loss=1.3249
# Epoch 1947: Train Loss=1.0417, Val Loss=1.3275
# Epoch 1948: Train Loss=1.0418, Val Loss=1.3287
# Epoch 1949: Train Loss=1.0418, Val Loss=1.3251
# Epoch 1950: Train Loss=1.0403, Val Loss=1.3025
# Epoch 1951: Train Loss=1.0419, Val Loss=1.3172
# Epoch 1952: Train Loss=1.0417, Val Loss=1.3205
# Epoch 1953: Train Loss=1.0420, Val Loss=1.3146
# Epoch 1954: Train Loss=1.0412, Val Loss=1.3193
# Epoch 1955: Train Loss=1.0419, Val Loss=1.3269
# Epoch 1956: Train Loss=1.0414, Val Loss=1.3420
# Epoch 1957: Train Loss=1.0406, Val Loss=1.3133
# Epoch 1958: Train Loss=1.0404, Val Loss=1.3273
# Epoch 1959: Train Loss=1.0403, Val Loss=1.3492
# Epoch 1960: Train Loss=1.0416, Val Loss=1.3394
# Epoch 1961: Train Loss=1.0407, Val Loss=1.3291
# Epoch 1962: Train Loss=1.0409, Val Loss=1.3261
# Epoch 1963: Train Loss=1.0404, Val Loss=1.3376
# Epoch 1964: Train Loss=1.0434, Val Loss=1.3263
# Epoch 1965: Train Loss=1.0416, Val Loss=1.3016
# Epoch 1966: Train Loss=1.0417, Val Loss=1.3273
# Epoch 1967: Train Loss=1.0404, Val Loss=1.3530
# Epoch 1968: Train Loss=1.0435, Val Loss=1.3266
# Epoch 1969: Train Loss=1.0412, Val Loss=1.3075
# Epoch 1970: Train Loss=1.0399, Val Loss=1.3373
# Epoch 1971: Train Loss=1.0409, Val Loss=1.3249
# Epoch 1972: Train Loss=1.0402, Val Loss=1.3328
# Epoch 1973: Train Loss=1.0408, Val Loss=1.3301
# Epoch 1974: Train Loss=1.0414, Val Loss=1.2996
# Epoch 1975: Train Loss=1.0425, Val Loss=1.3089
# Epoch 1976: Train Loss=1.0419, Val Loss=1.3510
# Epoch 1977: Train Loss=1.0415, Val Loss=1.3345
# Epoch 1978: Train Loss=1.0432, Val Loss=1.3374
# Epoch 1979: Train Loss=1.0438, Val Loss=1.3376
# Epoch 1980: Train Loss=1.0410, Val Loss=1.3322
# Epoch 1981: Train Loss=1.0401, Val Loss=1.3210
# Epoch 1982: Train Loss=1.0404, Val Loss=1.3397
# Epoch 1983: Train Loss=1.0417, Val Loss=1.3199
# Epoch 1984: Train Loss=1.0414, Val Loss=1.3155
# Epoch 1985: Train Loss=1.0451, Val Loss=1.3391
# Epoch 1986: Train Loss=1.0397, Val Loss=1.3533
# Epoch 1987: Train Loss=1.0401, Val Loss=1.3350
# Epoch 1988: Train Loss=1.0398, Val Loss=1.3244
# Epoch 1989: Train Loss=1.0406, Val Loss=1.3195
# Epoch 1990: Train Loss=1.0394, Val Loss=1.3375
# Epoch 1991: Train Loss=1.0405, Val Loss=1.3582
# Epoch 1992: Train Loss=1.0409, Val Loss=1.3285
# Epoch 1993: Train Loss=1.0418, Val Loss=1.3195
# Epoch 1994: Train Loss=1.0410, Val Loss=1.3299
# Epoch 1995: Train Loss=1.0411, Val Loss=1.3419
# Epoch 1996: Train Loss=1.0402, Val Loss=1.3358
# Epoch 1997: Train Loss=1.0413, Val Loss=1.3145
# Epoch 1998: Train Loss=1.0413, Val Loss=1.3418
# Epoch 1999: Train Loss=1.0431, Val Loss=1.3661

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
#loader = DataLoader([train_loader.dataset[10]], batch_size=1)
# loader = DataLoader([test_data[2]], batch_size=1)
# batch = next(iter(loader)).to(device)
k=1

prec=[]
prec_dca=[]
for batch in test_loader:
    batch = batch.to(device)

    #accuracy for a single batch
    with torch.no_grad():
        _, pred_logits = model(batch)
        scores = torch.sigmoid(pred_logits.squeeze(-1))
        scores_dca = batch.edge_attr.squeeze(-1)  # DCA scores

    mask = batch.edge_mask & batch.pair_mask
    scores = scores[mask]
    scores_dca = scores_dca[mask]
    true_contacts = batch.y.squeeze(-1)[mask]

    L = batch.L
    topk = int(k * L)

    topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices
    topk_idx_dca = torch.topk(scores_dca, k=min(topk, scores_dca.numel())).indices

    topk_true = true_contacts[topk_idx]
    topk_true_dca = true_contacts[topk_idx_dca]

    num_correct = topk_true.sum()
    precision = (num_correct / len(topk_true)).item()
    prec.append(precision)

    num_correct_dca = topk_true_dca.sum()
    precision_dca = (num_correct_dca / len(topk_true_dca)).item()
    prec_dca.append(precision_dca)


print(f"Precision of the GNN: {np.mean(prec)}")
print(f"Precision of the DCA: {np.mean(prec_dca)}")
# Out:
# Precision of the GNN: 0.43758574448671045
# Precision of the DCA: 0.6426586673244253

# %%
from sklearn.metrics import roc_curve, auc

model.eval()

all_labels = []

all_scores = []
all_scores_dca = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)

        _, pred_logits = model(batch)
        scores = torch.sigmoid(pred_logits.squeeze(-1))
        dca_scores = batch.edge_attr.squeeze(-1)

        mask = batch.edge_mask & batch.pair_mask

        true_contacts = batch.y.squeeze(-1)[mask]
        y_score = scores[mask]

        all_labels.append(true_contacts.cpu())
        all_scores.append(y_score.cpu())
        all_scores_dca.append(dca_scores[mask].cpu())

# concatenate all batches
all_labels = torch.cat(all_labels).numpy()
all_scores = torch.cat(all_scores).numpy()
all_scores_dca = torch.cat(all_scores_dca).numpy()

# compute ROC
fpr, tpr, _ = roc_curve(all_labels, all_scores)
roc_auc = auc(fpr, tpr)

fpr_dca, tpr_dca, _ = roc_curve(all_labels, all_scores_dca)
roc_auc_dca = auc(fpr_dca, tpr_dca)

print("Validation ROC AUC GNN:", roc_auc)
print("Validation ROC AUC DCA:", roc_auc_dca)


plt.figure()

plt.plot(fpr, tpr, label=f"GNN (AUC={roc_auc:.3f})")
plt.plot(fpr_dca, tpr_dca, label=f"DCA (AUC={roc_auc_dca:.3f})")

plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()
# Out:
# Validation ROC AUC GNN: 0.7435948854895273
# Validation ROC AUC DCA: 0.6829355606489645

# %%
from sklearn.metrics import precision_recall_curve, auc

precision, recall, _ = precision_recall_curve(all_labels, all_scores)
pr_auc = auc(recall, precision)

precision_dca, recall_dca, _ = precision_recall_curve(all_labels, all_scores_dca)
pr_auc_dca = auc(recall_dca, precision_dca)


print("PR AUC GNN:", pr_auc)
print("PR AUC GNN:", pr_auc_dca)


plt.figure()
plt.plot(recall, precision, label=f"PR AUC GNN = {pr_auc:.3f}")
plt.plot(recall_dca, precision_dca, label=f"PR AUC DCA = {pr_auc_dca:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()

plt.show()
# Out:
# PR AUC GNN: 0.19420590207932037
# PR AUC GNN: 0.2677618729819932

# %%
#We want the precision for each graph to see the distribution
def precision_at_kL_per_graph(batch, pred_logits, k):
    scores = torch.sigmoid(pred_logits.squeeze(-1))
    y_true = batch.y.squeeze(-1)

    mask = batch.edge_mask & batch.pair_mask

    scores = scores[mask]
    y_true = y_true[mask]

    edge_batch = batch.batch[batch.edge_index[0]][mask]

    precisions = []


    for g in edge_batch.unique():
        g_mask = edge_batch == g

        g_scores = scores[g_mask]
        g_true = y_true[g_mask]

        L = batch.L[g].item() if isinstance(batch.L, torch.Tensor) else batch.L

        kL = int(k * L)
        kL = min(kL, g_scores.numel())

        if kL == 0:
            continue

        topk_idx = torch.topk(g_scores, kL).indices
        topk_true = g_true[topk_idx]

        precision = topk_true.float().mean().item()
        precisions.append(precision)
    
    return precisions

#the same but for dca
def precision_at_kL_dca_per_graph(batch, k):
    scores = batch.edge_attr.squeeze(-1)  # DCA scores
    y_true = batch.y.squeeze(-1)

    mask = batch.edge_mask & batch.pair_mask

    scores = scores[mask]
    y_true = y_true[mask]

    edge_batch = batch.batch[batch.edge_index[0]][mask]

    precisions = []

    for g in edge_batch.unique():
        g_mask = edge_batch == g

        g_scores = scores[g_mask]
        g_true = y_true[g_mask]

        L = batch.L[g].item() if isinstance(batch.L, torch.Tensor) else batch.L

        kL = int(k * L)
        kL = min(kL, g_scores.numel())

        if kL == 0:
            continue

        topk_idx = torch.topk(g_scores, kL).indices
        topk_true = g_true[topk_idx]

        precision = topk_true.float().mean().item()
        precisions.append(precision)

    return precisions

# %%
k_values = [1.0,2.0,3.0]

results = {k: [] for k in k_values}
results_dca = {k: [] for k in k_values}

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        _, pred_logits = model(batch)

        for k in k_values:
            vals= precision_at_kL_per_graph(batch, pred_logits, k)
            vals_dca= precision_at_kL_dca_per_graph(batch, k)
            results[k].extend(vals)
            results_dca[k].extend(vals_dca)

for k in k_values:
    plt.hist(results[k], bins=40, alpha=0.5, label=f"GNN k={k}")
    #plt.hist(results_dca[k], bins=40, alpha=0.5, label=f"DCA k={k}")

plt.legend()
plt.title("Precision@kL distributions")
plt.show()

# %%
k=1.0 
precision=[]
for batch in test_loader:
        batch = batch.to(device)
        _, pred_logits = model(batch)
        vals= precision_at_kL_per_graph(batch, pred_logits, k)
        precision.append(vals)
print(precision)
print(min(precision))
print(precision.index(min(precision)))
# Out:
# [[0.25], [0.5381166338920593], [0.26744186878204346], [0.5160256624221802], [0.3552631735801697], [0.36942675709724426], [0.761904776096344], [0.48349514603614807], [0.5542168617248535], [0.25], [0.565891444683075], [0.6569343209266663], [0.24873095750808716], [0.4716981053352356], [0.39170506596565247], [0.1927710771560669], [0.5696202516555786], [0.5039370059967041], [0.5204081535339355], [0.28125], [0.3670886158943176], [0.3544776141643524], [0.6000000238418579], [0.1975308656692505], [0.44565218687057495], [0.5736842155456543], [0.281879186630249], [0.2983870804309845], [0.5965664982795715], [0.5207253694534302], [0.22439023852348328], [0.3762376308441162], [0.26451611518859863], [0.30392158031463623], [0.4883720874786377], [0.4267241358757019], [0.7058823704719543], [0.4267100691795349], [0.4615384638309479], [0.37222224473953247], [0.2230769246816635], [0.6438356041908264], [0.6794871687889099], [0.7441860437393188], [0.6176470518112183], [0.470802903175354], [0.1666666716337204], [0.7878788113594055], [0.4647058844566345], [0.3710145056247711], [0.3499999940395355], [0.5250000357627869], [0.7910447716712952], [0.3285714387893677], [0.7599999904632568], [0.3380281627178192], [0.4583333432674408], [0.29729729890823364], [0.10218977928161621], [0.29439252614974976], [0.1990811675786972], [0.1621621698141098], [0.36301368474960327], [0.2222222238779068], [0.5462962985038757], [0.5666667222976685], [0.6818181872367859], [0.3863636255264282], [0.3715415298938751], [0.3987729847431183], [0.566964328289032], [0.3499999940395355], [0.6767676472663879], [0.3374485373497009], [0.1782945692539215], [0.5], [0.11917097866535187], [0.6441441774368286], [0.5734265446662903], [0.42105263471603394], [0.75], [0.6804123520851135], [0.2542372941970825], [0.3498098850250244], [0.23076923191547394], [0.2274247407913208], [0.3243243396282196], [0.3433476388454437], [0.5327868461608887], [0.2926829159259796], [0.5331491827964783], [0.23125000298023224], [0.6126760244369507], [0.3799392282962799], [0.597597599029541], [0.4363636374473572], [0.37959182262420654], [0.21487602591514587], [0.17391304671764374], [1.0], [0.6363636255264282], [0.5636363625526428], [0.625], [0.25], [0.2818181812763214], [0.7659574151039124], [0.3137255012989044], [0.19847328960895538], [0.7156863212585449], [0.5511810779571533], [0.4736842215061188], [0.45199060440063477], [0.7333333492279053], [0.5166667103767395], [0.47109824419021606], [0.8023256063461304], [0.35555556416511536], [0.25], [0.43515849113464355], [0.37078651785850525], [0.5126050710678101], [0.227848082780838], [0.6060606241226196], [0.3767705261707306], [0.6041666865348816], [0.28901731967926025], [0.4566473960876465], [0.3014705777168274], [0.5131964683532715], [0.1388888955116272], [0.4899135231971741], [0.4536585509777069], [0.3973509967327118], [0.40425530076026917], [0.3442622721195221], [0.6391752362251282], [0.48076924681663513], [0.593406617641449], [0.6904761791229248], [0.28289473056793213], [0.31896552443504333], [0.5454545021057129], [0.38461539149284363], [0.3378378450870514], [0.34939756989479065], [0.44029849767684937], [0.21804511547088623], [0.4712643623352051], [0.8536584973335266], [0.3186813294887543], [0.25190839171409607], [0.2520325183868408], [0.4524272084236145], [0.6341463327407837], [0.443502813577652], [0.4000000059604645], [0.36021506786346436], [0.6129032373428345], [0.4797297418117523], [0.12087912112474442], [0.3218390941619873], [0.5445544719696045], [0.7628865838050842], [0.2995169162750244], [0.46195653080940247], [0.4514106512069702], [0.6666666865348816], [0.5539215803146362], [0.3896103799343109], [0.3521444797515869], [0.37837836146354675], [0.09756097197532654], [0.1617647111415863], [0.39534881711006165], [0.4655172526836395], [0.4054054021835327], [0.5211267471313477], [0.5679442286491394], [0.2906976640224457], [0.19200000166893005], [0.6973684430122375], [0.7000000476837158], [0.7735849022865295], [0.4266054928302765], [0.18987342715263367], [0.26954177021980 ...
# [0.05714285746216774]
# 299

# %%
def graph_to_matrix(data, values, mask=None):
    num_nodes = data.x.shape[0]
    mat = torch.zeros((num_nodes, num_nodes))

    edge_index = data.edge_index

    if mask is not None:
        edge_index = edge_index[:, mask]
        values = values[mask]
    mat[edge_index[0], edge_index[1]] = values.squeeze()

    return mat

# %%
pos=5


i=0
with torch.no_grad():
    for batch in test_loader:
        if i==pos:
            batch = batch.to(device)
            _, pred_logits = model(batch)
        i+=1

batch=test_data[pos]
print(batch)

mask = batch.edge_mask #& batch.pair_mask

scores = torch.sigmoid(pred_logits.squeeze(-1))
pred_contact_map = graph_to_matrix(batch, scores.cpu(), mask.cpu())
true_contact_map = graph_to_matrix(batch, batch.y.cpu(),mask.cpu())
original_dca_map = graph_to_matrix(batch, batch.edge_attr.cpu())


fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns

# --- Predicted Distance Map ---
im0 = axes[0].imshow(pred_contact_map, cmap='coolwarm_r', origin='lower')
axes[0].set_title("Predicted Contact Map")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# --- True Distance Map ---


im1 = axes[1].imshow(true_contact_map, cmap='coolwarm_r', origin='lower')
axes[1].set_title("True Contact Map")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# --- Original DCA Map ---
im2 = axes[2].imshow(original_dca_map, cmap='coolwarm', origin='lower')
axes[2].set_title("Original DCA Map")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Data(x=[157, 16], edge_index=[2, 24492], edge_attr=[24492, 1], y=[24492, 1], edge_mask=[24492], pair_mask=[24492], L=157)
