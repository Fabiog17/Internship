# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
from torch_geometric.data import Data
print(os.getpid())
# Out:
# 1311275

# %%
import sequenceHandler  
import importlib
importlib.reload(sequenceHandler)

from sequenceHandler import distance_map_PDB
pdb_file = "PDB/PF00017.pdb"
chain_id = "A"
output_map_file = "None"  

distance_map, residue = distance_map_PDB(pdb_file, chain_id, output_map_file)

import matplotlib.pyplot as plt

plt.figure()
plt.imshow(distance_map,cmap='coolwarm_r', origin='lower')
plt.colorbar(label="Distance")
plt.title("Distance Matrix Heatmap")
plt.show()

# %%
def contact_from_distance(distance_map, threshold=8.0):
    contact_map = (distance_map < threshold).astype(int)
    return contact_map  

contact_map = contact_from_distance(distance_map, threshold=8.0)

plt.figure()
plt.imshow(contact_map,cmap='coolwarm_r', origin='lower')
plt.colorbar(label="Contact")
plt.title("Contact Matrix Heatmap")
plt.show()

# %%
def create_noisy_contact_map(contact_map, noise_level=0.1):
    noisy_contact_map = contact_map.copy()
    num_elements = contact_map.size
    num_noisy_elements = int(noise_level * num_elements)
    
    indices = np.random.choice(num_elements, num_noisy_elements, replace=False)
    noisy_contact_map.flat[indices] = 1 - noisy_contact_map.flat[indices]
    
    return noisy_contact_map

noisy_contact_map= create_noisy_contact_map(contact_map, noise_level=0.1)

plt.figure()
plt.imshow(noisy_contact_map,cmap='coolwarm_r', origin='lower')
plt.colorbar(label="Noisy Contact")
plt.title("Noisy Contact Matrix Heatmap")
plt.show()

# %%
def sinusoidal_positional_encoding(N, d_model):
    pe = torch.zeros(N, d_model)
    position = torch.arange(0, N, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # shape [N, d_model]

# %%
def build_graph_contact_topk(noisy_contact_map, true_contact_map=None, sep_min=5, k=64):
    noisy_contact_map = torch.as_tensor(noisy_contact_map, dtype=torch.float32)
    N = noisy_contact_map.size(0)

    edges_i = []
    edges_j = []
    edge_attr_list = []
    labels_list = []
    pair_mask_list = []
    edge_mask_list = []

    if true_contact_map is not None:
        true_contact_map = torch.as_tensor(true_contact_map, dtype=torch.float32)

    for i in range(N):
        # valid candidates
        candidates = torch.arange(N)
        mask = (candidates != i) & (torch.abs(candidates - i) >= sep_min)
        candidates = candidates[mask]

        scores = noisy_contact_map[i, candidates]

        # top-k selection
        if candidates.numel() > k:
            topk_idx = torch.topk(scores, k=k).indices
            candidates = candidates[topk_idx]
            scores = scores[topk_idx]

        edges_i.append(torch.full_like(candidates, i))
        edges_j.append(candidates)
        edge_attr_list.append(scores)
    
        # pair mask: keep only upper triangle
        pair_mask = i < candidates

        # long-range condition (already enforced, but keep for consistency)
        long_range_ok = torch.abs(candidates - i) >= sep_min

        if true_contact_map is not None:
            labels = (true_contact_map[i, candidates] == 1).float()
        else:
            labels = torch.zeros_like(scores)

        labels_list.append(labels)

        pair_mask_list.append(pair_mask)
        edge_mask_list.append(long_range_ok)

    i = torch.cat(edges_i)
    j = torch.cat(edges_j)

    edge_index = torch.stack([i, j], dim=0)
    edge_attr = torch.cat(edge_attr_list).unsqueeze(-1)
    y = torch.cat(labels_list).unsqueeze(-1)

      
    edge_mask = torch.cat(edge_mask_list)
    pair_mask = torch.cat(pair_mask_list)

    x = sinusoidal_positional_encoding(N, d_model=16)

    return Data(
        x=x,
        edge_index=edge_index,
        edge_attr=edge_attr,
        y=y,
        edge_mask=edge_mask,
        pair_mask=pair_mask,
        L=N
    )

# %%
import sequenceHandler  
import importlib
importlib.reload(sequenceHandler)
from sequenceHandler import distance_map_PDB

folder_path = "PDB"

all_data = []
for file in os.listdir(folder_path):
    pdb_path = os.path.join(folder_path, file)
    chain_id = "A"
    output_map_file = "None"  

    try:
        distance_map, __ = distance_map_PDB(pdb_path, chain_id, output_map_file)
        true_contact_map = contact_from_distance(distance_map, threshold=8.0)
        noisy_contact_map= create_noisy_contact_map(true_contact_map, noise_level=0.1)
        data = build_graph_contact_topk(noisy_contact_map, true_contact_map)
        all_data.append(data)
    except:
        print(f"Some error occurred in the sequence {file}")

torch.save(all_data, "all_data.pt")
# Out:
# Some error occurred in the sequence PF07714.pdb
# Some error occurred in the sequence PF00016.pdb
# Some error occurred in the sequence PF00031.pdb
# Some error occurred in the sequence PF00044.pdb
# Some error occurred in the sequence PF00046.pdb
# Some error occurred in the sequence PF00050.pdb
# Some error occurred in the sequence PF00058.pdb
# Some error occurred in the sequence PF00069.pdb
# Some error occurred in the sequence PF00073.pdb
# Some error occurred in the sequence PF00082.pdb
# Some error occurred in the sequence PF00095.pdb
# Some error occurred in the sequence PF00096.pdb
# Some error occurred in the sequence PF00098.pdb
# Some error occurred in the sequence PF00101.pdb
# Some error occurred in the sequence PF00111.pdb
# Some error occurred in the sequence PF00121.pdb
# Some error occurred in the sequence PF00124.pdb
# Some error occurred in the sequence PF00130.pdb
# Some error occurred in the sequence PF00157.pdb
# Some error occurred in the sequence PF00170.pdb
# Some error occurred in the sequence PF00173.pdb
# Some error occurred in the sequence PF00179.pdb
# Some error occurred in the sequence PF00189.pdb
# Some error occurred in the sequence PF00249.pdb
# Some error occurred in the sequence PF00252.pdb
# Some error occurred in the sequence PF00253.pdb
# Some error occurred in the sequence PF00276.pdb
# Some error occurred in the sequence PF00281.pdb
# Some error occurred in the sequence PF00292.pdb
# Some error occurred in the sequence PF00297.pdb
# Some error occurred in the sequence PF00310.pdb
# Some error occurred in the sequence PF00318.pdb
# Some error occurred in the sequence PF00338.pdb
# Some error occurred in the sequence PF00342.pdb
# Some error occurred in the sequence PF00349.pdb
# Some error occurred in the sequence PF00358.pdb
# Some error occurred in the sequence PF00365.pdb
# Some error occurred in the sequence PF00370.pdb
# Some error occurred in the sequence PF00377.pdb
# Some error occurred in the sequence PF00380.pdb
# Some error occurred in the sequence PF00411.pdb
# Some error occurred in the sequence PF00416.pdb
# Some error occurred in the sequence PF00466.pdb
# Some error occurred in the sequence PF00516.pdb
# Some error occurred in the sequence PF00545.pdb
# Some error occurred in the sequence PF00554.pdb
# Some error occurred in the sequence PF00560.pdb
# Some error occurred in the sequence PF00572.pdb
# Some error occurred in the sequence PF00595.pdb
# Some error occurred in the sequence PF00617.pdb
# Some error occurred in the sequence PF00618.pdb
# Some error occurred in the sequence PF00626.pdb
# Some error occurred in the sequence PF00644.pdb
# Some error occurred in the sequence PF00673.pdb
# Some error occurred in the sequence PF00710.pdb
# Some error occurred in the sequence PF00713.pdb
# Some error occurred in the sequence PF00715.pdb
# Some error occurred in the sequence PF00718.pdb
# Some error occurred in the sequence PF00720.pdb
# Some error occurred in the sequence PF00721.pdb
# Some error occurred in the sequence PF00740.pdb
# Some error occurred in the sequence PF00753.pdb
# Some error occurred in the sequence PF00820.pdb
# Some error occurred in the sequence PF00827.pdb
# Some error occurred in the sequence PF00828.pdb
# Some error occurred in the sequence PF00831.pdb
# Some error occurred in the sequence PF00832.pdb
# Some error occurred in the sequence PF00886.pdb
# Some error occurred in the sequence PF00897.pdb
# Some error occurred in the sequence PF00899.pdb
# Some error occurred in the sequence PF00935.pdb
# Some error occurred in the sequence PF00945.pdb
# Some error occurred in the sequence PF00975.pdb
# Some error occurred in the sequence PF00977.pdb
# Some error occurred in the sequence PF00988.pdb
# Some error occurred in the sequence PF01051.pdb
# Some error occurred in the sequence PF01058.pdb
# Some error occurred in the sequence PF01077.pdb
# Some error occurred in the sequence PF01084.pdb
# Some error occurred in the sequence PF01110.pdb
# Some error occurred in the sequence PF01157.pdb
# Some error occurred in the sequence PF01198.pdb
# Some error occurred in the sequence PF01221.pdb
# Some error occurred in the sequence PF01246.pdb
# Some error occurred in the sequence PF01280.pdb
# Some error occurred in the sequence PF01315.pdb
# Some error occurred in the sequence PF01347.pdb
# Some error occurred in the sequence PF01371.pdb
# Some error occurred in the sequence PF01382.pdb
# Some error occurred in the sequence PF01386.pdb
# Some error occurred in the sequence PF01388.pdb
# Some error occurred in the sequence PF01432.pdb
# Some error occurred in the sequence PF01447.pdb
# Some error occurred in the sequence PF01450.pdb
# Some error occurred in the sequence PF01497.pdb
# Some error occurred in the sequence PF01498.pdb
# Some error occurred in the sequence PF01649.pdb
# Some error occurred in the sequence PF01655.pdb
# Some error occurred in the sequence PF01780.pdb
# Some error occurred in the sequence PF01799.pdb
# Some error occurred in the sequence PF01818.pdb
# Some error occurred in the sequence PF01907.pdb
# Some error occurred in the sequence PF02017.pdb
# Some error occurred in the sequence PF02037.pdb
# Some error occurred in the sequence PF02226.pdb
# Some error occurred in the sequence PF02247.pdb
# Some error occurred in the sequence PF02248.pdb
# Some error occurred in the sequence PF02256.pdb
# Some error occurred in the sequence PF02257.pdb
# Some error occurred in the sequence PF02276.pdb
# Some error occurred in the sequence PF02304.pdb
# Some error occurred in the sequence PF02305.pdb
# Some error occurred in the sequence PF02306.pdb
# Some error occurred in the sequence PF02332.pdb
# Some error occurred in the sequence PF02368.pdb
# Some error occurred in the sequence PF02391.pdb
# Some error occurred in the sequence PF02429.pdb
# Some error occurred in the sequence PF02491.pdb

# %%
all_data = torch.load("all_data.pt",weights_only=False)
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(all_data, test_size=0.2, random_state=1)


train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
#train_loader = DataLoader([all_data[3]], batch_size=1)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# %%
print(test_loader.dataset[0])
# Out:
# Data(x=[342, 16], edge_index=[2, 21888], edge_attr=[21888, 1], y=[21888, 1], edge_mask=[21888], pair_mask=[21888], L=342)

# %%
import torch.nn as nn
from torch_geometric.nn import MessagePassing


# MessagePassing Module    
class EdgeMessagePassingLayer(MessagePassing):

    def __init__ (self, node_in_ch, edge_in_ch, node_out_ch, edge_out_ch, aggr='mean'):
        super(EdgeMessagePassingLayer, self).__init__(aggr=aggr, flow='source_to_target')  # <---- aggregation

        #print('Relu activation')

        # Edge MLP: [e_ij, x_i, x_j] -> e'_ij
        self.lin_phi_e = nn.Sequential(
            nn.Linear(edge_in_ch + 2 * node_in_ch, edge_out_ch),
            nn.LeakyReLU(negative_slope=0.2),
            #nn.ReLU(),
            nn.Linear(edge_out_ch, edge_out_ch)
        )

        # Node MLP: [x_i(old), agg([x_i, x_j, e'_ij] sugli edge incidenti a i)] -> x_i(new)
        self.lin_phi_x = nn.Sequential(
            nn.Linear(node_in_ch + (2 * node_in_ch + edge_out_ch),  node_out_ch),
            nn.LeakyReLU(negative_slope=0.2),
            #nn.ReLU(),
            nn.Linear(node_out_ch, node_out_ch)
        )
    
    def forward(self, x, edge_index, edge_attr):
        assert edge_attr is not None, 'Questa GNN runna solo con edge_attr!'
        
        # 1. Update edges
        edge_attr = self.edge_updater(edge_index, x=x, edge_attr=edge_attr)
        # 2. Update nodes
        x_out = self.propagate(edge_index, x=x, edge_attr=edge_attr)

        return x_out, edge_attr

    # -- EDGES --  <--- self.edge_updater
    def edge_update(self, x_i, x_j, edge_attr):
        edge_attr_out = self.lin_phi_e( torch.cat([edge_attr, x_i, x_j], dim=-1) )
        return edge_attr_out
        
    # -- NODES --   <--- self.propagate
    def message(self, x_i, x_j, edge_attr):
        message = torch.cat([x_i, x_j, edge_attr], dim=-1)
        return message

    # ... aggregate con mean o add nell'init ...

    def update(self, aggr_out, x):
        aggr = torch.cat([x, aggr_out], dim=-1)
        x_out = self.lin_phi_x(aggr)
        return x_out

# %%
from torch_geometric.nn import LayerNorm
import torch.nn.functional as F

class EdgeGNN(nn.Module):
    def __init__(self, node_in_ch = 8, edge_in_ch = 8, hidden_ch=128, mlp_hidden_ch=64,GNN_layers=4,node_norms =True, edge_norms=True, gating=True):
        super(EdgeGNN, self).__init__() 

        self.convs = nn.ModuleList()
        self.node_norms = nn.ModuleList() if node_norms else None
        self.edge_norms = nn.ModuleList() if edge_norms else None
        self.gating = nn.ModuleList() if gating else None

        # First layer
        if self.node_norms is not None:
            self.node_norms.append(LayerNorm(node_in_ch))
        if self.edge_norms is not None:
            self.edge_norms.append(LayerNorm(edge_in_ch))
        self.convs.append(EdgeMessagePassingLayer(
            node_in_ch = node_in_ch,
            edge_in_ch = edge_in_ch,
            node_out_ch = hidden_ch,
            edge_out_ch = hidden_ch
        ))
        if self.gating is not None:
            self.gating.append(nn.Sequential(
            nn.Linear(hidden_ch, hidden_ch),
            nn.Sigmoid()
            ))

        # Layer Intermedi
        for _ in range(GNN_layers - 1):
            if self.node_norms is not None:
                self.node_norms.append(LayerNorm(hidden_ch))
            if self.edge_norms is not None:
                self.edge_norms.append(LayerNorm(hidden_ch))

            self.convs.append(EdgeMessagePassingLayer(
                node_in_ch=hidden_ch,
                edge_in_ch=hidden_ch,
                node_out_ch=hidden_ch,
                edge_out_ch=hidden_ch
            ))
            
            if self.gating is not None:
                self.gating.append(nn.Sequential(
                nn.Linear(hidden_ch, hidden_ch),
                nn.Sigmoid()
                ))


         # MLP head for edge classification
        self.edge_head = nn.Sequential(
            nn.Linear(hidden_ch, mlp_hidden_ch),
            nn.ReLU(),
            nn.Linear(mlp_hidden_ch, 1)   # one logit
        )


    def forward(self, graph):
        x, edge_index, edge_attr, batch = graph.x, graph.edge_index, graph.edge_attr, graph.batch

        #edge_batch = batch[edge_index[0]]  # batch degli edge = batch del nodo sorgente
        batch = getattr(graph, "batch", None)
        for i, conv in enumerate(self.convs):
            x_in = x
            e_in = edge_attr

            x = self.node_norms[i](x, batch) if self.node_norms is not None else x
            edge_attr = self.edge_norms[i](edge_attr) if self.edge_norms is not None else edge_attr

            x, edge_attr = conv(x, edge_index, edge_attr)

            if x_in.shape == x.shape:
                x = x + x_in

            if e_in.shape == edge_attr.shape:
                gate = self.gating[i](edge_attr) if self.gating is not None else 1.0
                edge_attr = edge_attr * gate  # edge gating
                edge_attr = edge_attr + e_in

            x = F.leaky_relu(x, negative_slope=0.2)
            edge_attr = F.leaky_relu(edge_attr, negative_slope=0.2)

        # Final projection to output space
        edge_attr = self.edge_head(edge_attr)

        return x, edge_attr

# %%
def compute_pos_weight(loader, device):
    total_pos = 0
    total_neg = 0

    for batch in loader:
        batch = batch.to(device)

        y = batch.y.squeeze(-1)
        mask = batch.edge_mask #& batch.pair_mask  

        y = y[mask]

        total_pos += (y == 1).sum().item()
        total_neg += (y == 0).sum().item()

    pos_weight = total_neg / max(total_pos, 1)
    return torch.tensor(pos_weight, dtype=torch.float, device=device)

# %%
def average_loss(model, loader, loss_fn, device):
    model.eval()
    total_loss = 0.0
    total_edges = 0
    total_batches= 0

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)

            _, pred_logits = model(batch)
            pred_logits = pred_logits.squeeze(-1)
            true_contacts = batch.y.squeeze(-1)

            mask = batch.edge_mask #& batch.pair_mask

            loss = loss_fn(pred_logits[mask], true_contacts[mask])

            n_edges = mask.sum().item()
            total_loss += loss.item() * n_edges
            total_edges += n_edges
            total_batches += 1

    return total_loss / max(total_edges, 1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = EdgeGNN(node_in_ch=16, edge_in_ch=1, hidden_ch=25, mlp_hidden_ch=12, GNN_layers=3).to(device)

pos_weight = compute_pos_weight(train_loader, device)
print("pos_weight:", pos_weight.item())
loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight,reduction='mean')

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

train_losses = []
val_losses = []

for epoch in range(200):

    model.train()

    total_loss = 0.0
    total_edges = 0
    for batch in train_loader:

        batch = batch.to(device)
        optimizer.zero_grad()

        _, pred_logits = model(batch)

        pred_logits = pred_logits.squeeze(-1)
        true_contacts = batch.y.squeeze(-1)

        mask = batch.edge_mask #& batch.pair_mask

        loss = loss_fn(pred_logits[mask], true_contacts[mask])

        n_edges = mask.sum().item()
        total_loss += loss.item() * n_edges
        total_edges += n_edges

        loss.backward()
        optimizer.step()

    train_loss = total_loss / max(total_edges, 1)
    val_loss = average_loss(model, test_loader, loss_fn, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch {epoch}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")
# Out:
# pos_weight: 3.4775872230529785
# Epoch 0: Train Loss=0.8230, Val Loss=0.7516
# Epoch 1: Train Loss=0.7115, Val Loss=0.7398
# Epoch 2: Train Loss=0.6853, Val Loss=0.6913
# Epoch 3: Train Loss=0.6545, Val Loss=0.6530
# Epoch 4: Train Loss=0.6328, Val Loss=0.6398
# Epoch 5: Train Loss=0.6177, Val Loss=0.6418
# Epoch 6: Train Loss=0.6132, Val Loss=0.6249
# Epoch 7: Train Loss=0.6050, Val Loss=0.6215
# Epoch 8: Train Loss=0.5982, Val Loss=0.6143
# Epoch 9: Train Loss=0.5928, Val Loss=0.6145
# Epoch 10: Train Loss=0.5879, Val Loss=0.6086
# Epoch 11: Train Loss=0.5855, Val Loss=0.6063
# Epoch 12: Train Loss=0.5839, Val Loss=0.5911
# Epoch 13: Train Loss=0.5773, Val Loss=0.5950
# Epoch 14: Train Loss=0.5694, Val Loss=0.5846
# Epoch 15: Train Loss=0.5704, Val Loss=0.5885
# Epoch 16: Train Loss=0.5652, Val Loss=0.5825
# Epoch 17: Train Loss=0.5679, Val Loss=0.5773
# Epoch 18: Train Loss=0.5610, Val Loss=0.5747
# Epoch 19: Train Loss=0.5585, Val Loss=0.5830
# Epoch 20: Train Loss=0.5544, Val Loss=0.5777
# Epoch 21: Train Loss=0.5546, Val Loss=0.6004
# Epoch 22: Train Loss=0.5607, Val Loss=0.5882
# Epoch 23: Train Loss=0.5542, Val Loss=0.5652
# Epoch 24: Train Loss=0.5466, Val Loss=0.5746
# Epoch 25: Train Loss=0.5445, Val Loss=0.5705
# Epoch 26: Train Loss=0.5443, Val Loss=0.5652
# Epoch 27: Train Loss=0.5401, Val Loss=0.5585
# Epoch 28: Train Loss=0.5380, Val Loss=0.5667
# Epoch 29: Train Loss=0.5381, Val Loss=0.5609
# Epoch 30: Train Loss=0.5357, Val Loss=0.5502
# Epoch 31: Train Loss=0.5339, Val Loss=0.5522
# Epoch 32: Train Loss=0.5337, Val Loss=0.5506
# Epoch 33: Train Loss=0.5322, Val Loss=0.5527
# Epoch 34: Train Loss=0.5345, Val Loss=0.5481
# Epoch 35: Train Loss=0.5283, Val Loss=0.5551
# Epoch 36: Train Loss=0.5318, Val Loss=0.5618
# Epoch 37: Train Loss=0.5284, Val Loss=0.5515
# Epoch 38: Train Loss=0.5256, Val Loss=0.5400
# Epoch 39: Train Loss=0.5261, Val Loss=0.5451
# Epoch 40: Train Loss=0.5227, Val Loss=0.5380
# Epoch 41: Train Loss=0.5198, Val Loss=0.5620
# Epoch 42: Train Loss=0.5226, Val Loss=0.5367
# Epoch 43: Train Loss=0.5170, Val Loss=0.5375
# Epoch 44: Train Loss=0.5205, Val Loss=0.5355
# Epoch 45: Train Loss=0.5162, Val Loss=0.5432
# Epoch 46: Train Loss=0.5137, Val Loss=0.5388
# Epoch 47: Train Loss=0.5160, Val Loss=0.5410
# Epoch 48: Train Loss=0.5142, Val Loss=0.5433
# Epoch 49: Train Loss=0.5105, Val Loss=0.5421
# Epoch 50: Train Loss=0.5112, Val Loss=0.5295
# Epoch 51: Train Loss=0.5101, Val Loss=0.5314
# Epoch 52: Train Loss=0.5091, Val Loss=0.5344
# Epoch 53: Train Loss=0.5104, Val Loss=0.5333
# Epoch 54: Train Loss=0.5103, Val Loss=0.5262
# Epoch 55: Train Loss=0.5062, Val Loss=0.5442
# Epoch 56: Train Loss=0.5091, Val Loss=0.5260
# Epoch 57: Train Loss=0.5038, Val Loss=0.5256
# Epoch 58: Train Loss=0.5035, Val Loss=0.5309
# Epoch 59: Train Loss=0.5075, Val Loss=0.5325
# Epoch 60: Train Loss=0.5022, Val Loss=0.5320
# Epoch 61: Train Loss=0.5031, Val Loss=0.5234
# Epoch 62: Train Loss=0.5021, Val Loss=0.5268
# Epoch 63: Train Loss=0.5003, Val Loss=0.5181
# Epoch 64: Train Loss=0.4992, Val Loss=0.5294
# Epoch 65: Train Loss=0.4995, Val Loss=0.5233
# Epoch 66: Train Loss=0.5017, Val Loss=0.5176
# Epoch 67: Train Loss=0.4989, Val Loss=0.5363
# Epoch 68: Train Loss=0.5007, Val Loss=0.5222
# Epoch 69: Train Loss=0.4963, Val Loss=0.5187
# Epoch 70: Train Loss=0.4953, Val Loss=0.5183
# Epoch 71: Train Loss=0.4986, Val Loss=0.5228
# Epoch 72: Train Loss=0.4962, Val Loss=0.5196
# Epoch 73: Train Loss=0.4954, Val Loss=0.5146
# Epoch 74: Train Loss=0.4940, Val Loss=0.5237
# Epoch 75: Train Loss=0.4960, Val Loss=0.5155
# Epoch 76: Train Loss=0.4952, Val Loss=0.5426
# Epoch 77: Train Loss=0.5131, Val Loss=0.5354
# Epoch 78: Train Loss=0.4980, Val Loss=0.5250
# Epoch 79: Train Loss=0.4923, Val Loss=0.5123
# Epoch 80: Train Loss=0.4919, Val Loss=0.5262
# Epoch 81: Train Loss=0.4957, Val Loss=0.5259
# Epoch 82: Train Loss=0.4909, Val Loss=0.5215
# Epoch 83: Train Loss=0.4924, Val Loss=0.5253
# Epoch 84: Train Loss=0.4943, Val Loss=0.5156
# Epoch 85: Train Loss=0.4910, Val Loss=0.5083
# Epoch 86: Train Loss=0.4909, Val Loss=0.5129
# Epoch 87: Train Loss=0.4901, Val Loss=0.5200
# Epoch 88: Train Loss=0.4885, Val Loss=0.5248
# Epoch 89: Train Loss=0.4908, Val Loss=0.5164
# Epoch 90: Train Loss=0.4876, Val Loss=0.5070
# Epoch 91: Train Loss=0.4881, Val Loss=0.5351
# Epoch 92: Train Loss=0.4986, Val Loss=0.5222
# Epoch 93: Train Loss=0.4889, Val Loss=0.5226
# Epoch 94: Train Loss=0.4902, Val Loss=0.5153
# Epoch 95: Train Loss=0.4880, Val Loss=0.5069
# Epoch 96: Train Loss=0.4876, Val Loss=0.5054
# Epoch 97: Train Loss=0.4861, Val Loss=0.5135
# Epoch 98: Train Loss=0.4876, Val Loss=0.5163
# Epoch 99: Train Loss=0.4872, Val Loss=0.5029
# Epoch 100: Train Loss=0.4849, Val Loss=0.5073
# Epoch 101: Train Loss=0.4857, Val Loss=0.5122
# Epoch 102: Train Loss=0.4903, Val Loss=0.5475
# Epoch 103: Train Loss=0.4939, Val Loss=0.5025
# Epoch 104: Train Loss=0.4865, Val Loss=0.5150
# Epoch 105: Train Loss=0.4856, Val Loss=0.5066
# Epoch 106: Train Loss=0.4846, Val Loss=0.5097
# Epoch 107: Train Loss=0.4843, Val Loss=0.5033
# Epoch 108: Train Loss=0.4838, Val Loss=0.5020
# Epoch 109: Train Loss=0.4813, Val Loss=0.5465
# Epoch 110: Train Loss=0.4872, Val Loss=0.5083
# Epoch 111: Train Loss=0.4818, Val Loss=0.5044
# Epoch 112: Train Loss=0.4821, Val Loss=0.5168
# Epoch 113: Train Loss=0.4827, Val Loss=0.5434
# Epoch 114: Train Loss=0.5024, Val Loss=0.5101
# Epoch 115: Train Loss=0.4816, Val Loss=0.5101
# Epoch 116: Train Loss=0.4829, Val Loss=0.5016
# Epoch 117: Train Loss=0.4838, Val Loss=0.5011
# Epoch 118: Train Loss=0.4806, Val Loss=0.5041
# Epoch 119: Train Loss=0.4816, Val Loss=0.5094
# Epoch 120: Train Loss=0.4802, Val Loss=0.5163
# Epoch 121: Train Loss=0.4859, Val Loss=0.4994
# Epoch 122: Train Loss=0.4781, Val Loss=0.5001
# Epoch 123: Train Loss=0.4798, Val Loss=0.5012
# Epoch 124: Train Loss=0.4783, Val Loss=0.5069
# Epoch 125: Train Loss=0.4799, Val Loss=0.4984
# Epoch 126: Train Loss=0.4766, Val Loss=0.5064
# Epoch 127: Train Loss=0.4825, Val Loss=0.5025
# Epoch 128: Train Loss=0.4769, Val Loss=0.5004
# Epoch 129: Train Loss=0.4782, Val Loss=0.5054
# Epoch 130: Train Loss=0.4798, Val Loss=0.4996
# Epoch 131: Train Loss=0.4782, Val Loss=0.4969
# Epoch 132: Train Loss=0.4772, Val Loss=0.4962
# Epoch 133: Train Loss=0.4765, Val Loss=0.4935
# Epoch 134: Train Loss=0.4766, Val Loss=0.5018
# Epoch 135: Train Loss=0.4767, Val Loss=0.4956
# Epoch 136: Train Loss=0.4777, Val Loss=0.4990
# Epoch 137: Train Loss=0.4763, Val Loss=0.5016
# Epoch 138: Train Loss=0.4739, Val Loss=0.4938
# Epoch 139: Train Loss=0.4756, Val Loss=0.5000
# Epoch 140: Train Loss=0.4727, Val Loss=0.5006
# Epoch 141: Train Loss=0.4730, Val Loss=0.5019
# Epoch 142: Train Loss=0.4742, Val Loss=0.5028
# Epoch 143: Train Loss=0.4758, Val Loss=0.4928
# Epoch 144: Train Loss=0.4739, Val Loss=0.5070
# Epoch 145: Train Loss=0.4718, Val Loss=0.5001
# Epoch 146: Train Loss=0.4710, Val Loss=0.5031
# Epoch 147: Train Loss=0.4717, Val Loss=0.4916
# Epoch 148: Train Loss=0.4712, Val Loss=0.4963
# Epoch 149: Train Loss=0.4723, Val Loss=0.4970
# Epoch 150: Train Loss=0.4708, Val Loss=0.5004
# Epoch 151: Train Loss=0.4718, Val Loss=0.4926
# Epoch 152: Train Loss=0.4715, Val Loss=0.4903
# Epoch 153: Train Loss=0.4683, Val Loss=0.5195
# Epoch 154: Train Loss=0.4884, Val Loss=0.5034
# Epoch 155: Train Loss=0.4700, Val Loss=0.4908
# Epoch 156: Train Loss=0.4702, Val Loss=0.4912
# Epoch 157: Train Loss=0.4699, Val Loss=0.4963
# Epoch 158: Train Loss=0.4709, Val Loss=0.4874
# Epoch 159: Train Loss=0.4690, Val Loss=0.4964
# Epoch 160: Train Loss=0.4698, Val Loss=0.4947
# Epoch 161: Train Loss=0.4703, Val Loss=0.4970
# Epoch 162: Train Loss=0.4674, Val Loss=0.4905
# Epoch 163: Train Loss=0.4672, Val Loss=0.4874
# Epoch 164: Train Loss=0.4675, Val Loss=0.4930
# Epoch 165: Train Loss=0.4664, Val Loss=0.4993
# Epoch 166: Train Loss=0.4660, Val Loss=0.4861
# Epoch 167: Train Loss=0.4669, Val Loss=0.4923
# Epoch 168: Train Loss=0.4670, Val Loss=0.4910
# Epoch 169: Train Loss=0.4667, Val Loss=0.5039
# Epoch 170: Train Loss=0.4733, Val Loss=0.4861
# Epoch 171: Train Loss=0.4659, Val Loss=0.4896
# Epoch 172: Train Loss=0.4658, Val Loss=0.4875
# Epoch 173: Train Loss=0.4661, Val Loss=0.4901
# Epoch 174: Train Loss=0.4672, Val Loss=0.4876
# Epoch 175: Train Loss=0.4642, Val Loss=0.4932
# Epoch 176: Train Loss=0.4629, Val Loss=0.4910
# Epoch 177: Train Loss=0.4650, Val Loss=0.4929
# Epoch 178: Train Loss=0.4630, Val Loss=0.5113
# Epoch 179: Train Loss=0.4642, Val Loss=0.4887
# Epoch 180: Train Loss=0.4653, Val Loss=0.5131
# Epoch 181: Train Loss=0.4901, Val Loss=0.5059
# Epoch 182: Train Loss=0.4724, Val Loss=0.4959
# Epoch 183: Train Loss=0.4640, Val Loss=0.5027
# Epoch 184: Train Loss=0.4665, Val Loss=0.4885
# Epoch 185: Train Loss=0.4623, Val Loss=0.4891
# Epoch 186: Train Loss=0.4629, Val Loss=0.4960
# Epoch 187: Train Loss=0.4620, Val Loss=0.4821
# Epoch 188: Train Loss=0.4603, Val Loss=0.4846
# Epoch 189: Train Loss=0.4615, Val Loss=0.4884
# Epoch 190: Train Loss=0.4599, Val Loss=0.4826
# Epoch 191: Train Loss=0.4618, Val Loss=0.4837
# Epoch 192: Train Loss=0.4609, Val Loss=0.4862
# Epoch 193: Train Loss=0.4603, Val Loss=0.4802
# Epoch 194: Train Loss=0.4608, Val Loss=0.4861
# Epoch 195: Train Loss=0.4589, Val Loss=0.4861
# Epoch 196: Train Loss=0.4618, Val Loss=0.4842
# Epoch 197: Train Loss=0.4610, Val Loss=0.4865
# Epoch 198: Train Loss=0.4585, Val Loss=0.4749
# Epoch 199: Train Loss=0.4586, Val Loss=0.4802

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
from sklearn.metrics import auc, precision_score, recall_score, f1_score, average_precision_score, roc_curve

model.eval()

all_probs = []
all_true = []

for batch in test_loader:
    batch = batch.to(device)

    with torch.no_grad():
        _, pred_logits = model(batch)
        probs = torch.sigmoid(pred_logits.squeeze(-1))

    true_contacts = batch.y.squeeze(-1)
    mask = batch.edge_mask & batch.pair_mask
  


    all_probs.append(probs[mask].cpu())
    all_true.append(true_contacts[mask].cpu())

all_probs = torch.cat(all_probs)
all_true = torch.cat(all_true)


threshold=0.9

pred_contacts = (all_probs >= threshold).int().numpy()
true_contacts = all_true.int().numpy()

precision = precision_score(true_contacts, pred_contacts, zero_division=0)
recall = recall_score(true_contacts, pred_contacts, zero_division=0)
f1 = f1_score(true_contacts, pred_contacts, zero_division=0)
auprc = average_precision_score(true_contacts, all_probs.numpy())

print(f"Precision of the GNN: {np.mean(precision)}")
print(f"Recall of the GNN: {np.mean(recall)}")
print(f"F1 of the GNN: {np.mean(f1)}")
print(f"AUPRC of the GNN: {np.mean(auprc)}")



# compute ROC
fpr, tpr, _ = roc_curve(all_true, all_probs)
roc_auc = auc(fpr, tpr)

print("Validation ROC AUC GNN:", roc_auc)


plt.figure()

plt.plot(fpr, tpr, label=f"GNN (AUC={roc_auc:.3f})")

plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()

#compute PR
from sklearn.metrics import precision_recall_curve, auc

precision, recall, _ = precision_recall_curve(all_true, all_probs)
pr_auc = auc(recall, precision)


print("PR AUC GNN:", pr_auc)


plt.figure()
plt.plot(recall, precision, label=f"PR AUC GNN = {pr_auc:.3f}")
plt.plot([1, 0], [0, 1], linestyle='--')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()

plt.show()
# Out:
# Precision of the GNN: 0.8692278629314588
# Recall of the GNN: 0.4958957230883621
# F1 of the GNN: 0.63151261033254
# AUPRC of the GNN: 0.8252747838725708
# Validation ROC AUC GNN: 0.9410088817920091
# PR AUC GNN: 0.8252753636527673

# %%
def topk_L_precision(model, loader, device, ratio=1.0):
    model.eval()
    per_graph_precisions = []

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            _, logits = model(batch)

            probs = torch.sigmoid(logits.squeeze(-1))
            true_contacts = batch.y.squeeze(-1)

            valid_mask = batch.edge_mask & batch.pair_mask

            # graph id for each edge
            edge_graph_id = batch.batch[batch.edge_index[0]]

            num_graphs = batch.num_graphs

            for g in range(num_graphs):
                graph_mask = valid_mask & (edge_graph_id == g)

                probs_g = probs[graph_mask]
                true_g = true_contacts[graph_mask]

                if probs_g.numel() == 0:
                    continue

                # length of the protein
                L = int(batch.L[g]) if torch.is_tensor(batch.L) else int(batch.L)

                k = max(1, int(L * ratio))
                k = min(k, probs_g.numel())

                top_idx = torch.topk(probs_g, k=k).indices
                #knumber of true contacts in top-k​/k
                precision_g = (true_g[top_idx] > 0.5).float().mean().item()

                per_graph_precisions.append(precision_g)

    return float(np.mean(per_graph_precisions)), per_graph_precisions

print("Top-k*L precision:", topk_L_precision(model, test_loader, device, ratio=1)[0])
# Out:
# Top-k*L precision: 0.9704315742497803

# %%
k_values = [1,2,5]
results = {k: [] for k in k_values}
for k in k_values:
    vals= topk_L_precision(model, test_loader, device, ratio=k)[1]
    results[k].extend(vals)

for k in k_values:
    plt.hist(results[k], bins=40, alpha=0.5, label=f"GNN k={k}")


plt.legend()
plt.title("Precision@kL distributions")
plt.show()

# %%
k=1
precision= topk_L_precision(model, test_loader, device, ratio=k)[1]
print(precision)
print(min(precision))
print(precision.index(min(precision)))
# Out:
# [0.988304078578949, 0.9530791640281677, 0.9999999403953552, 1.0, 0.9685534238815308, 0.950276255607605, 0.9815497994422913, 0.9589040875434875, 0.98333340883255, 0.966292142868042, 0.9922178983688354, 0.9788135886192322, 0.9932432770729065, 0.9845678806304932, 0.9924242496490479, 0.993630588054657, 0.9881423115730286, 0.9809885621070862, 0.9870129823684692, 0.9825581312179565, 0.9340659379959106, 0.9386188983917236, 0.9948051571846008, 0.9965753555297852, 1.0, 0.9753086566925049, 0.9874213337898254, 1.0, 0.9830508232116699, 1.0, 0.9904762506484985, 0.9760765433311462, 0.9755101799964905, 0.8985507488250732, 0.9729729890823364, 0.9685534238815308, 0.9797979593276978, 0.9785714149475098, 0.9765258431434631, 0.9895104765892029, 0.9852941036224365, 0.9690476655960083, 0.9952381253242493, 0.6238532066345215, 0.9507042169570923, 0.9741935133934021, 0.9746376872062683, 0.9953270554542542, 0.9726027250289917, 0.9672130346298218, 1.0, 0.996874988079071, 0.9337016940116882, 0.9928057789802551, 0.9226933121681213, 0.9508196115493774, 0.9890109896659851, 0.9660194516181946, 0.9739413261413574, 0.9921875, 0.9836601614952087, 0.9748743772506714, 0.9812206625938416, 0.9927006959915161, 0.9924622774124146, 0.9723820686340332, 0.944444477558136, 1.0, 0.9853479862213135, 0.9803149700164795, 0.9665697813034058, 1.0, 1.0, 0.9854651093482971, 0.9882075786590576, 0.987500011920929, 0.9224806427955627, 0.9944133758544922, 0.9961089491844177, 1.0, 0.9345794320106506, 0.9863013625144958, 0.9776286482810974, 0.9475655555725098, 0.9831933379173279, 0.9930796027183533, 0.9925925731658936, 0.9874213337898254, 0.9859484434127808, 0.9786325097084045, 0.9945055246353149, 1.0, 0.9887640476226807, 0.9647887349128723, 0.9779411554336548, 1.0, 0.9615384340286255, 0.9927184581756592, 0.9784946441650391, 0.9862384796142578, 0.9874213337898254, 0.9824945330619812, 0.9907407760620117, 0.9873417615890503, 0.9568965435028076, 0.9632353186607361, 0.9823788404464722, 0.9579684734344482, 1.0, 0.9831932783126831, 0.9605263471603394, 0.9826989769935608, 1.0, 0.9691176414489746, 0.953125, 0.9883720874786377, 0.9861111044883728, 1.0, 0.9952830076217651, 0.9856321811676025, 0.9954544901847839, 0.9751772880554199, 0.9696969985961914, 0.9805194735527039, 0.9825707674026489, 0.9611801505088806, 0.9790209531784058, 0.9880952835083008, 1.0, 0.968000054359436, 0.9722921252250671, 0.9564428329467773, 0.985714316368103, 0.9855072498321533, 0.9300000071525574, 0.8842975497245789, 1.0, 0.9245947599411011, 0.785714328289032, 0.969072163105011, 0.977011501789093, 0.9602446556091309, 0.9952830076217651, 0.9495614171028137, 1.0, 0.406410276889801, 0.9596412777900696, 0.9936102032661438, 0.9873949885368347, 0.9714285731315613, 0.8971061110496521, 0.9882550239562988, 0.9580052495002747, 0.9651162624359131, 0.9837837815284729, 0.9884169697761536, 0.9722222685813904, 0.9797297716140747, 0.9831933379173279, 0.9619500637054443, 0.9787233471870422, 1.0, 0.9369369745254517, 0.9586206674575806, 0.9935897588729858, 0.9219512343406677, 0.9671052694320679, 1.0, 0.9354838132858276, 1.0, 0.9815950393676758, 0.9735449552536011, 1.0, 0.9741379022598267, 0.9836065173149109, 0.9543569087982178, 0.9999999403953552, 1.0, 0.9939758777618408, 0.9838709235191345, 0.9753086566925049, 0.9797101616859436, 0.9439252018928528, 0.9568764567375183, 0.949999988079071, 0.4949999749660492, 0.989847719669342, 0.9819819927215576, 1.0, 0.9860139489173889, 0.9639174938201904, 0.9795918464660645, 0.9628769755363464, 0.9718309640884399, 0.9731183052062988, 0.9730769395828247, 0.9678898453712463, 0.9740518927574158, 0.9864864945411682, 0.944444477558136, 0.9912663698196411, 0.9618320465087891, 0.9761905074119568, 0.9873188734054565, 0.9516128897666931, 1.0, 0.9436619281768799, 0.9795918464660645, 0.938144326210022, 0.9725036025047302, 1.0, 0.9876543283462524, 0.9708333611488342, 0.9649999737739563, 0.9883720874786377, 0.963302731513977, 0.9352014064788818, 0.9790940880775452, 0.9352941513061523, 0.9777777791023254, 0.96363633871 ...
# 0.406410276889801
# 145

# %%
def graph_to_matrix(data, values):
    num_nodes = data.x.shape[0]
    mat = torch.zeros((num_nodes, num_nodes))

    edge_index = data.edge_index
    mat[edge_index[0], edge_index[1]] = values.squeeze()

    return mat

# %%
pos=145
#worst case

i=0
with torch.no_grad():
    for batch in test_loader:
        if i==pos:
            batch = batch.to(device)
            _, pred_logits = model(batch)
        i+=1

batch=test_data[pos]
print(batch)

mask = batch.edge_mask & batch.pair_mask

scores = torch.sigmoid(pred_logits.squeeze(-1))
# threshold=0.8
# scores= (scores>= threshold).float()
pred_contact_map = graph_to_matrix(batch, scores.cpu())
true_contact_map = graph_to_matrix(batch, batch.y.cpu())
noisy_contact_map_map = graph_to_matrix(batch, batch.edge_attr.cpu())



fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns

# --- Predicted Distance Map ---
im0 = axes[0].imshow(pred_contact_map, cmap='coolwarm_r', origin='lower')
axes[0].set_title("Predicted Contact Map")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# --- True Distance Map ---
im1 = axes[1].imshow(true_contact_map, cmap='coolwarm_r', origin='lower')
axes[1].set_title("True Contact Map")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# --- Original Noisy Contact Map ---
im2 = axes[2].imshow(noisy_contact_map_map, cmap='coolwarm_r', origin='lower')
axes[2].set_title("Noisy Contact Map")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Data(x=[780, 16], edge_index=[2, 49920], edge_attr=[49920, 1], y=[49920, 1], edge_mask=[49920], pair_mask=[49920], L=780)
