# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
from torch_geometric.data import Data
print(os.getpid())
import sequenceHandler  
import importlib
importlib.reload(sequenceHandler)
from sequenceHandler import distance_map_PDB
import torch.nn as nn
from torch_geometric.nn import MessagePassing, LayerNorm
import torch.nn.functional as F
from sklearn.metrics import auc, precision_score, recall_score, f1_score, average_precision_score, roc_curve, precision_recall_curve
from torch_geometric.utils import softmax
# Out:
# 52222

# %%
folder_DCA="Data"
folder_PDB="PDB"
thres=8.0
learning_rate=0.001
minimum_separation=0

# %%
def sinusoidal_positional_encoding(N, d_model):
    pe = torch.zeros(N, d_model)
    position = torch.arange(0, N, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # shape [N, d_model]

# %%
def contact_from_distance(distance_map, threshold=thres):
    contact_map = (distance_map < threshold).astype(int)
    return contact_map  

#function to take the top k element of a matrix (excludin the ones masked) 
def top_k_mask(matrix, k, mask=None):
    n = matrix.shape[0]

    # Get upper triangle indices (excluding diagonal)
    triu_indices = np.triu_indices(n, k=1)

    # Extract corresponding values
    values = matrix[triu_indices]

    if mask is not None:
        mask_vals = mask[triu_indices]
        #make the masked point distant -inf
        values = np.where(mask_vals, values, -np.inf)

    # Get indices of top-k values
    top_k_idx = np.argpartition(values, -k)[-k:]

    # Create empty mask
    mask_out = np.zeros_like(matrix, dtype=int)

    # Map back to matrix indices
    rows = triu_indices[0][top_k_idx]
    cols = triu_indices[1][top_k_idx]

    # Set both (i,j) and (j,i) = 1 (since symmetric)
    mask_out[rows, cols] = 1
    mask_out[cols, rows] = 1

    return mask_out

# %%
#how to store the data

def build_graph_contact(noisy_contact_map, distance_map=None, sep_min=minimum_separation):
    
    N = len(noisy_contact_map)

    # contact map to tensor
    noisy_contact_map = torch.tensor(noisy_contact_map, dtype=torch.float)

    idx = torch.arange(N)
    i, j = torch.meshgrid(idx, idx, indexing='ij')  # shape [N, N]

    # masks
    not_self = i != j
    pair_mask = i < j
    long_range_ok = (torch.abs(i - j) >= sep_min)

    if distance_map is not None:
        known = np.isfinite(distance_map)
        known = torch.tensor(known, dtype=torch.bool)
        true_contact_map = contact_from_distance(distance_map, threshold=8.0)
        true_contact_map = torch.tensor(true_contact_map, dtype=torch.float)
        labels = (known & (true_contact_map == 1)).float()
    else:
        known = torch.ones((N, N), dtype=torch.bool)
        labels = torch.zeros((N, N), dtype=torch.float)

    edge_mask = known & long_range_ok
     # remove i == j
    valid = not_self

    src = i[valid]
    dst = j[valid]

    edge_index = torch.stack([src, dst], dim=0)
    edge_attr = noisy_contact_map[valid].unsqueeze(-1)
    y = labels[valid].unsqueeze(-1) 
        
    mask = edge_mask[valid]
    pair_mask = pair_mask[valid]

    x = sinusoidal_positional_encoding(N, d_model=16)

    return Data(
        x=x,
        edge_index=edge_index,
        edge_attr=edge_attr,
        y=y,                 # binary contact labels
        edge_mask=mask,      # valid + long-range
        pair_mask=pair_mask, # only one direction per pair
        L=N
    )

# %%
def compute_pos_weight(loader, device):
    total_pos = 0
    total_neg = 0

    for batch in loader:
        batch = batch.to(device)

        y = batch.y.squeeze(-1)
        mask = batch.edge_mask #& batch.pair_mask  

        y = y[mask]

        total_pos += (y == 1).sum().item()
        total_neg += (y == 0).sum().item()

    pos_weight = total_neg / max(total_pos, 1)
    return torch.tensor(pos_weight, dtype=torch.float, device=device)

# %%
def model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(
        p.numel() for p in model.parameters()
        if p.requires_grad
    )

    print(f"Total parameters:      {total_params:,}")
    print(f"Trainable parameters:  {trainable_params:,}")
    print(f"Non-trainable params:  {total_params - trainable_params:,}")

# %%
class AttentionMPLayer(MessagePassing):
    """Single attention-based message-passing layer (node + edge updates)."""

    def __init__(self, hidden_dim, heads=4, dropout=0.0):
        super().__init__(node_dim=0, aggr='add', flow='source_to_target')

        self.hidden_dim = hidden_dim
        self.heads = heads
        self.head_dim = hidden_dim // heads
        self.dropout = dropout

        assert hidden_dim % heads == 0, "hidden_dim must be divisible by heads"

        # Edge update MLP: [x_i, x_j, e_ij] -> e'_ij
        self.edge_mlp = nn.Sequential(
            nn.Linear(3 * hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, hidden_dim)
        )

        # Attention projections (Q, K spaces)
        self.att_lin_i = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_lin_j = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_lin_e = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.att_vec = nn.Parameter(torch.Tensor(1, heads, self.head_dim))

        # Message projections (V space)
        self.pay_lin_j = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)
        self.pay_lin_e = nn.Linear(hidden_dim, heads * self.head_dim, bias=False)

        # Node update MLP: [x_i, aggregated_messages] -> x'_i
        self.node_mlp = nn.Sequential(
            nn.Linear(2 * hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.att_lin_i.weight)
        nn.init.xavier_uniform_(self.att_lin_j.weight)
        nn.init.xavier_uniform_(self.att_lin_e.weight)
        nn.init.xavier_uniform_(self.pay_lin_j.weight)
        nn.init.xavier_uniform_(self.pay_lin_e.weight)
        nn.init.xavier_uniform_(self.att_vec)

    def forward(self, x, edge_index, edge_attr):
        edge_attr_new = self.edge_updater(edge_index, x=x, edge_attr=edge_attr)
        message = self.propagate(edge_index, x=x, edge_attr=edge_attr_new)
        x_new = self.node_mlp(torch.cat([x, message], dim=-1))
        return x_new, edge_attr_new

    def edge_update(self, x_i, x_j, edge_attr):
        return self.edge_mlp(torch.cat([x_i, x_j, edge_attr], dim=-1))

    def message(self, x_i, x_j, edge_attr, index, ptr, size_i):
        q_i = self.att_lin_i(x_i).view(-1, self.heads, self.head_dim)
        k_j = self.att_lin_j(x_j).view(-1, self.heads, self.head_dim)
        k_e = self.att_lin_e(edge_attr).view(-1, self.heads, self.head_dim)

        score = F.leaky_relu(q_i + k_j + k_e, 0.2)
        alpha = (score * self.att_vec).sum(dim=-1)
        alpha = softmax(alpha, index, ptr, size_i)
        alpha = F.dropout(alpha, p=self.dropout, training=self.training)

        v_j = self.pay_lin_j(x_j).view(-1, self.heads, self.head_dim)
        v_e = self.pay_lin_e(edge_attr).view(-1, self.heads, self.head_dim)
        return (v_j + v_e) * alpha.unsqueeze(-1)

    def update(self, inputs, x):
        return inputs.view(-1, self.heads * self.head_dim)


class MP_GNN(nn.Module):
    """
    Attention MPNN for edge classification + SAGE contrastive learning.

    Returns (x_sage, out_reg, out_cls):
      x_sage   — L2-normalized node embeddings at layer num_layers_sage (for SAGE loss)
      out_reg  — per-edge regression logits [E]
      out_cls  — per-edge classification logits [E]
    """

    def __init__(self, num_layers=6, num_heads=2,
                 node_in_dim=16, edge_in_dim=16, latent_dim=32):
        super().__init__()

        assert latent_dim % num_heads == 0, "latent_dim must be divisible by num_heads"

        
        self.node_in_dim = node_in_dim
        self.edge_in_dim = edge_in_dim

        self.in_x_proj = nn.Linear(node_in_dim, latent_dim)
        self.in_e_proj = nn.Linear(edge_in_dim, latent_dim)

        self.convs = nn.ModuleList()
        self.node_norms = nn.ModuleList()
        self.edge_norms = nn.ModuleList()
        for _ in range(num_layers):
            self.node_norms.append(LayerNorm(latent_dim))
            self.edge_norms.append(LayerNorm(latent_dim))
            self.convs.append(AttentionMPLayer(hidden_dim=latent_dim, heads=num_heads, dropout=0.1))

        self.out_cls = nn.Sequential(
            nn.Linear(latent_dim, latent_dim),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Linear(latent_dim, 1)
        )

    def forward(self, graph):
        x, edge_index, edge_attr = graph.x, graph.edge_index, graph.edge_attr

        x = self.in_x_proj(x)
        edge_attr = self.in_e_proj(edge_attr)

        for i, (conv, node_norm, edge_norm) in enumerate(zip(self.convs, self.node_norms, self.edge_norms)):
            x = node_norm(x)
            edge_attr = edge_norm(edge_attr)
            x_new, edge_attr_new = conv(x, edge_index, edge_attr)
            x = x + x_new
            edge_attr = edge_attr + edge_attr_new

        out_cls = self.out_cls(edge_attr).squeeze(-1)
        return out_cls

# %%
#how to evaluate the precision of the top kL contact for each graph
def topk_L_precision(model, loader, device, ratio=1.0):
    model.eval()
    per_graph_precisions = []

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            logits = model(batch)

            probs = torch.sigmoid(logits.squeeze(-1))
            true_contacts = batch.y.squeeze(-1)

            valid_mask = batch.edge_mask & batch.pair_mask

            # graph id for each edge
            edge_graph_id = batch.batch[batch.edge_index[0]]

            num_graphs = batch.num_graphs

            for g in range(num_graphs):
                graph_mask = valid_mask & (edge_graph_id == g)

                probs_g = probs[graph_mask]
                true_g = true_contacts[graph_mask]

                if probs_g.numel() == 0:
                    continue

                # length of the protein
                L = int(batch.L[g]) if torch.is_tensor(batch.L) else int(batch.L)

                k = max(1, int(L * ratio))
                k = min(k, probs_g.numel())

                top_idx = torch.topk(probs_g, k=k).indices
                #knumber of true contacts in top-k​/k
                precision_g = (true_g[top_idx] > 0.5).float().mean().item()

                per_graph_precisions.append(precision_g)

    return float(np.mean(per_graph_precisions)), per_graph_precisions

# %%
def graph_to_matrix(data, values):
    num_nodes = data.x.shape[0]
    mat = torch.zeros((num_nodes, num_nodes))

    edge_index = data.edge_index
    mat[edge_index[0], edge_index[1]] = values.squeeze()

    return mat

# %%
class AsymmetricLoss(nn.Module):
    def __init__(
        self,
        gamma_neg=6,
        gamma_pos=1,
        clip=0.05,
        eps=1e-8
    ):
        super().__init__()

        self.gamma_neg = gamma_neg
        self.gamma_pos = gamma_pos
        self.clip = clip
        self.eps = eps

    def forward(self, logits, targets):

        probs = torch.sigmoid(logits)

        # optional clipping
        if self.clip is not None and self.clip > 0:
            probs_neg = (1 - probs + self.clip).clamp(max=1)
        else:
            probs_neg = 1 - probs

        pos_loss = targets * torch.log(probs.clamp(min=self.eps))
        neg_loss = (1 - targets) * torch.log(
            probs_neg.clamp(min=self.eps)
        )

        pos_weight = (1 - probs) ** self.gamma_pos
        neg_weight = probs ** self.gamma_neg

        loss = -(
            pos_weight * pos_loss
            + neg_weight * neg_loss
        )

        return loss.mean()

# %% [markdown]
# <- functions and class

# %%
#data import
from noise import build_noisy_map
TC = 2.0 / np.log(1.0 + np.sqrt(2.0))

folder_path = folder_PDB


all_data = []
index=0
for file in os.listdir(folder_path):
    index +=1
    pdb_path = os.path.join(folder_path, file)
    chain_id = "A"
    output_map_file = "None"  

    try:
        distance_map, __ = distance_map_PDB(pdb_path, chain_id, output_map_file)

    
        true_contact_map = contact_from_distance(distance_map, threshold=8.0) 
        
        fake_noisy = build_noisy_map(true_contact_map, use_metropolis=True, J=1.0, T=0.9*TC, alpha=0.5, n_sweeps=30, zero_field=True, seed=index)

        data = build_graph_contact(fake_noisy, distance_map)
        all_data.append(data)
    except:
        print(f"Some error occurred in the sequence {file}")


torch.save(all_data, "all_data_likeDCA_sep0_Federico.pt")
# Out:
# Some error occurred in the sequence PF07714.pdb
# Some error occurred in the sequence PF00016.pdb
# Some error occurred in the sequence PF00031.pdb
# Some error occurred in the sequence PF00044.pdb
# Some error occurred in the sequence PF00046.pdb
# Some error occurred in the sequence PF00050.pdb
# Some error occurred in the sequence PF00058.pdb
# Some error occurred in the sequence PF00069.pdb
# Some error occurred in the sequence PF00073.pdb
# Some error occurred in the sequence PF00082.pdb
# Some error occurred in the sequence PF00095.pdb
# Some error occurred in the sequence PF00096.pdb
# Some error occurred in the sequence PF00098.pdb
# Some error occurred in the sequence PF00101.pdb
# Some error occurred in the sequence PF00111.pdb
# Some error occurred in the sequence PF00121.pdb
# Some error occurred in the sequence PF00124.pdb
# Some error occurred in the sequence PF00130.pdb
# Some error occurred in the sequence PF00157.pdb
# Some error occurred in the sequence PF00170.pdb
# Some error occurred in the sequence PF00173.pdb
# Some error occurred in the sequence PF00179.pdb
# Some error occurred in the sequence PF00189.pdb
# Some error occurred in the sequence PF00249.pdb
# Some error occurred in the sequence PF00252.pdb
# Some error occurred in the sequence PF00253.pdb
# Some error occurred in the sequence PF00276.pdb
# Some error occurred in the sequence PF00281.pdb
# Some error occurred in the sequence PF00292.pdb
# Some error occurred in the sequence PF00297.pdb
# Some error occurred in the sequence PF00310.pdb
# Some error occurred in the sequence PF00318.pdb
# Some error occurred in the sequence PF00338.pdb
# Some error occurred in the sequence PF00342.pdb
# Some error occurred in the sequence PF00349.pdb
# Some error occurred in the sequence PF00358.pdb
# Some error occurred in the sequence PF00365.pdb
# Some error occurred in the sequence PF00370.pdb
# Some error occurred in the sequence PF00377.pdb
# Some error occurred in the sequence PF00380.pdb
# Some error occurred in the sequence PF00411.pdb
# Some error occurred in the sequence PF00416.pdb
# Some error occurred in the sequence PF00466.pdb
# Some error occurred in the sequence PF00516.pdb
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

train_val_data, test_data = train_test_split(
    filtered_data,
    test_size=0.2,
    random_state=1
)

train_data, val_data = train_test_split(
    train_val_data,
    test_size=0.25,  
    random_state=1
)

train_loader = DataLoader(train_data, batch_size=1, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)
val_loader = DataLoader(val_data, batch_size=1,shuffle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = MP_GNN(
    num_layers=4,
    num_heads=4,
    node_in_dim=16,
    edge_in_dim=1,
    latent_dim=64
).to(device)

model_size(model)

save_path = "best_model_cc_likeDCA_sep0_attention_Federico.pt"
#to load an old model
# state_dict = torch.load(save_path)
# model.load_state_dict(state_dict)

# pos_weight = torch.minimum(
#     compute_pos_weight(train_loader, device),
#     torch.tensor(8.0, device=device)
# )



# print("pos_weight:", pos_weight.item())
# loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight,reduction='mean')

loss_fn = AsymmetricLoss(
    gamma_neg=8,
    gamma_pos=1
)



optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)   
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,mode='min',factor=0.5, patience=10,min_lr=1e-6)
# Out:
# Total parameters:      205,377
# Trainable parameters:  205,377
# Non-trainable params:  0

# %%
train_losses = []
val_losses = []


best_val_loss = float('inf')
patience = 70
epochs_no_improve = 0

for epoch in range(3000):

    model.train()

    total_loss = 0.0
    total_edges = 0
    for batch in train_loader:

        batch = batch.to(device)
        optimizer.zero_grad()

        pred_logits = model(batch)

        pred_logits = pred_logits.squeeze(-1)
        true_contacts = batch.y.squeeze(-1)

        mask = batch.edge_mask #& batch.pair_mask

        loss = loss_fn(pred_logits[mask], true_contacts[mask])

        n_edges = mask.sum().item()
        total_loss += loss.item() * n_edges
        total_edges += n_edges

        loss.backward()
        optimizer.step()

    train_loss = total_loss / max(total_edges, 1)

    model.eval()
    total_loss_val = 0.0
    total_edges_val = 0

    with torch.no_grad():

        loss_contact_tot=[]
        loss_regression_tot=[]
        for batch in val_loader:
            batch = batch.to(device)
            pred_logits = model(batch)
            pred_logits = pred_logits.squeeze(-1)
            true_contacts = batch.y.squeeze(-1)

            mask = batch.edge_mask #& batch.pair_mask

            loss = loss_fn(pred_logits[mask], true_contacts[mask])

            n_edges = mask.sum().item()
            total_loss_val += loss.item() * n_edges
            total_edges_val += n_edges

    val_loss= total_loss_val / max(total_edges_val, 1)
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0

        torch.save(model.state_dict(), save_path)

    else:
        epochs_no_improve += 1

    if epochs_no_improve >= patience:
        print(f"Early stopping triggered after {epoch+1} epochs")
        break
# Out:
# Epoch 0: Train Loss=0.0082, Val Loss=0.0072
# Epoch 1: Train Loss=0.0073, Val Loss=0.0072
# Epoch 2: Train Loss=0.0075, Val Loss=0.0068
# Epoch 3: Train Loss=0.0071, Val Loss=0.0071
# Epoch 4: Train Loss=0.0069, Val Loss=0.0068
# Epoch 5: Train Loss=0.0067, Val Loss=0.0063
# Epoch 6: Train Loss=0.0065, Val Loss=0.0062
# Epoch 7: Train Loss=0.0064, Val Loss=0.0065
# Epoch 8: Train Loss=0.0064, Val Loss=0.0061
# Epoch 9: Train Loss=0.0062, Val Loss=0.0061
# Epoch 10: Train Loss=0.0062, Val Loss=0.0059
# Epoch 11: Train Loss=0.0061, Val Loss=0.0058
# Epoch 12: Train Loss=0.0061, Val Loss=0.0060
# Epoch 13: Train Loss=0.0060, Val Loss=0.0060
# Epoch 14: Train Loss=0.0060, Val Loss=0.0060
# Epoch 15: Train Loss=0.0060, Val Loss=0.0058
# Epoch 16: Train Loss=0.0059, Val Loss=0.0057
# Epoch 17: Train Loss=0.0060, Val Loss=0.0057
# Epoch 18: Train Loss=0.0059, Val Loss=0.0058
# Epoch 19: Train Loss=0.0059, Val Loss=0.0057
# Epoch 20: Train Loss=0.0058, Val Loss=0.0057
# Epoch 21: Train Loss=0.0058, Val Loss=0.0057
# Epoch 22: Train Loss=0.0058, Val Loss=0.0056
# Epoch 23: Train Loss=0.0058, Val Loss=0.0057
# Epoch 24: Train Loss=0.0057, Val Loss=0.0056
# Epoch 25: Train Loss=0.0058, Val Loss=0.0057
# Epoch 26: Train Loss=0.0057, Val Loss=0.0056
# Epoch 27: Train Loss=0.0057, Val Loss=0.0060
# Epoch 28: Train Loss=0.0057, Val Loss=0.0054
# Epoch 29: Train Loss=0.0057, Val Loss=0.0055
# Epoch 30: Train Loss=0.0056, Val Loss=0.0055
# Epoch 31: Train Loss=0.0056, Val Loss=0.0057
# Epoch 32: Train Loss=0.0056, Val Loss=0.0055
# Epoch 33: Train Loss=0.0056, Val Loss=0.0054
# Epoch 34: Train Loss=0.0056, Val Loss=0.0054
# Epoch 35: Train Loss=0.0056, Val Loss=0.0054
# Epoch 36: Train Loss=0.0055, Val Loss=0.0054
# Epoch 37: Train Loss=0.0055, Val Loss=0.0053
# Epoch 38: Train Loss=0.0055, Val Loss=0.0054
# Epoch 39: Train Loss=0.0055, Val Loss=0.0056
# Epoch 40: Train Loss=0.0055, Val Loss=0.0056
# Epoch 41: Train Loss=0.0055, Val Loss=0.0054
# Epoch 42: Train Loss=0.0055, Val Loss=0.0055
# Epoch 43: Train Loss=0.0054, Val Loss=0.0053
# Epoch 44: Train Loss=0.0054, Val Loss=0.0054
# Epoch 45: Train Loss=0.0054, Val Loss=0.0052
# Epoch 46: Train Loss=0.0054, Val Loss=0.0053
# Epoch 47: Train Loss=0.0054, Val Loss=0.0054
# Epoch 48: Train Loss=0.0054, Val Loss=0.0052
# Epoch 49: Train Loss=0.0053, Val Loss=0.0052
# Epoch 50: Train Loss=0.0053, Val Loss=0.0052
# Epoch 51: Train Loss=0.0053, Val Loss=0.0052
# Epoch 52: Train Loss=0.0053, Val Loss=0.0051
# Epoch 53: Train Loss=0.0053, Val Loss=0.0053
# Epoch 54: Train Loss=0.0053, Val Loss=0.0052
# Epoch 55: Train Loss=0.0053, Val Loss=0.0052
# Epoch 56: Train Loss=0.0053, Val Loss=0.0052
# Epoch 57: Train Loss=0.0053, Val Loss=0.0052
# Epoch 58: Train Loss=0.0052, Val Loss=0.0051
# Epoch 59: Train Loss=0.0052, Val Loss=0.0052
# Epoch 60: Train Loss=0.0052, Val Loss=0.0050
# Epoch 61: Train Loss=0.0052, Val Loss=0.0051
# Epoch 62: Train Loss=0.0052, Val Loss=0.0051
# Epoch 63: Train Loss=0.0052, Val Loss=0.0051
# Epoch 64: Train Loss=0.0052, Val Loss=0.0050
# Epoch 65: Train Loss=0.0052, Val Loss=0.0051
# Epoch 66: Train Loss=0.0051, Val Loss=0.0052
# Epoch 67: Train Loss=0.0051, Val Loss=0.0050
# Epoch 68: Train Loss=0.0051, Val Loss=0.0051
# Epoch 69: Train Loss=0.0051, Val Loss=0.0050
# Epoch 70: Train Loss=0.0051, Val Loss=0.0049
# Epoch 71: Train Loss=0.0051, Val Loss=0.0051
# Epoch 72: Train Loss=0.0051, Val Loss=0.0049
# Epoch 73: Train Loss=0.0051, Val Loss=0.0050
# Epoch 74: Train Loss=0.0051, Val Loss=0.0050
# Epoch 75: Train Loss=0.0051, Val Loss=0.0050
# Epoch 76: Train Loss=0.0050, Val Loss=0.0051
# Epoch 77: Train Loss=0.0050, Val Loss=0.0049
# Epoch 78: Train Loss=0.0050, Val Loss=0.0049
# Epoch 79: Train Loss=0.0050, Val Loss=0.0051
# Epoch 80: Train Loss=0.0050, Val Loss=0.0048
# Epoch 81: Train Loss=0.0050, Val Loss=0.0050
# Epoch 82: Train Loss=0.0050, Val Loss=0.0049
# Epoch 83: Train Loss=0.0050, Val Loss=0.0048
# Epoch 84: Train Loss=0.0050, Val Loss=0.0050
# Epoch 85: Train Loss=0.0050, Val Loss=0.0048
# Epoch 86: Train Loss=0.0050, Val Loss=0.0048
# Epoch 87: Train Loss=0.0049, Val Loss=0.0050
# Epoch 88: Train Loss=0.0050, Val Loss=0.0048
# Epoch 89: Train Loss=0.0049, Val Loss=0.0048
# Epoch 90: Train Loss=0.0049, Val Loss=0.0050
# Epoch 91: Train Loss=0.0049, Val Loss=0.0051
# Epoch 92: Train Loss=0.0049, Val Loss=0.0049
# Epoch 93: Train Loss=0.0049, Val Loss=0.0048
# Epoch 94: Train Loss=0.0049, Val Loss=0.0048
# Epoch 95: Train Loss=0.0049, Val Loss=0.0049
# Epoch 96: Train Loss=0.0049, Val Loss=0.0049
# Epoch 97: Train Loss=0.0049, Val Loss=0.0048
# Epoch 98: Train Loss=0.0048, Val Loss=0.0048
# Epoch 99: Train Loss=0.0048, Val Loss=0.0048
# Epoch 100: Train Loss=0.0048, Val Loss=0.0047
# Epoch 101: Train Loss=0.0048, Val Loss=0.0047
# Epoch 102: Train Loss=0.0048, Val Loss=0.0047
# Epoch 103: Train Loss=0.0048, Val Loss=0.0047
# Epoch 104: Train Loss=0.0048, Val Loss=0.0048
# Epoch 105: Train Loss=0.0048, Val Loss=0.0047
# Epoch 106: Train Loss=0.0048, Val Loss=0.0047
# Epoch 107: Train Loss=0.0048, Val Loss=0.0049
# Epoch 108: Train Loss=0.0048, Val Loss=0.0047
# Epoch 109: Train Loss=0.0048, Val Loss=0.0047
# Epoch 110: Train Loss=0.0047, Val Loss=0.0047
# Epoch 111: Train Loss=0.0047, Val Loss=0.0047
# Epoch 112: Train Loss=0.0047, Val Loss=0.0046
# Epoch 113: Train Loss=0.0047, Val Loss=0.0046
# Epoch 114: Train Loss=0.0047, Val Loss=0.0047
# Epoch 115: Train Loss=0.0047, Val Loss=0.0047
# Epoch 116: Train Loss=0.0048, Val Loss=0.0047
# Epoch 117: Train Loss=0.0048, Val Loss=0.0046
# Epoch 118: Train Loss=0.0047, Val Loss=0.0046
# Epoch 119: Train Loss=0.0047, Val Loss=0.0047
# Epoch 120: Train Loss=0.0047, Val Loss=0.0047
# Epoch 121: Train Loss=0.0047, Val Loss=0.0046
# Epoch 122: Train Loss=0.0047, Val Loss=0.0048
# Epoch 123: Train Loss=0.0047, Val Loss=0.0047
# Epoch 124: Train Loss=0.0047, Val Loss=0.0047
# Epoch 125: Train Loss=0.0047, Val Loss=0.0046
# Epoch 126: Train Loss=0.0047, Val Loss=0.0046
# Epoch 127: Train Loss=0.0047, Val Loss=0.0047
# Epoch 128: Train Loss=0.0047, Val Loss=0.0046
# Epoch 129: Train Loss=0.0046, Val Loss=0.0046
# Epoch 130: Train Loss=0.0047, Val Loss=0.0046
# Epoch 131: Train Loss=0.0047, Val Loss=0.0046
# Epoch 132: Train Loss=0.0047, Val Loss=0.0047
# Epoch 133: Train Loss=0.0047, Val Loss=0.0048
# Epoch 134: Train Loss=0.0046, Val Loss=0.0048
# Epoch 135: Train Loss=0.0047, Val Loss=0.0048
# Epoch 136: Train Loss=0.0047, Val Loss=0.0049
# Epoch 137: Train Loss=0.0046, Val Loss=0.0047
# Epoch 138: Train Loss=0.0046, Val Loss=0.0046
# Epoch 139: Train Loss=0.0046, Val Loss=0.0046
# Epoch 140: Train Loss=0.0046, Val Loss=0.0046
# Epoch 141: Train Loss=0.0046, Val Loss=0.0046
# Epoch 142: Train Loss=0.0046, Val Loss=0.0047
# Epoch 143: Train Loss=0.0046, Val Loss=0.0046
# Epoch 144: Train Loss=0.0046, Val Loss=0.0046
# Epoch 145: Train Loss=0.0046, Val Loss=0.0046
# Epoch 146: Train Loss=0.0046, Val Loss=0.0045
# Epoch 147: Train Loss=0.0046, Val Loss=0.0045
# Epoch 148: Train Loss=0.0046, Val Loss=0.0045
# Epoch 149: Train Loss=0.0046, Val Loss=0.0045
# Epoch 150: Train Loss=0.0046, Val Loss=0.0046
# Epoch 151: Train Loss=0.0046, Val Loss=0.0046
# Epoch 152: Train Loss=0.0046, Val Loss=0.0047
# Epoch 153: Train Loss=0.0046, Val Loss=0.0045
# Epoch 154: Train Loss=0.0045, Val Loss=0.0045
# Epoch 155: Train Loss=0.0046, Val Loss=0.0045
# Epoch 156: Train Loss=0.0045, Val Loss=0.0045
# Epoch 157: Train Loss=0.0045, Val Loss=0.0048
# Epoch 158: Train Loss=0.0045, Val Loss=0.0045
# Epoch 159: Train Loss=0.0045, Val Loss=0.0045
# Epoch 160: Train Loss=0.0045, Val Loss=0.0045
# Epoch 161: Train Loss=0.0045, Val Loss=0.0045
# Epoch 162: Train Loss=0.0045, Val Loss=0.0046
# Epoch 163: Train Loss=0.0045, Val Loss=0.0045
# Epoch 164: Train Loss=0.0045, Val Loss=0.0044
# Epoch 165: Train Loss=0.0045, Val Loss=0.0045
# Epoch 166: Train Loss=0.0045, Val Loss=0.0044
# Epoch 167: Train Loss=0.0045, Val Loss=0.0046
# Epoch 168: Train Loss=0.0045, Val Loss=0.0045
# Epoch 169: Train Loss=0.0045, Val Loss=0.0045
# Epoch 170: Train Loss=0.0045, Val Loss=0.0046
# Epoch 171: Train Loss=0.0045, Val Loss=0.0044
# Epoch 172: Train Loss=0.0044, Val Loss=0.0045
# Epoch 173: Train Loss=0.0045, Val Loss=0.0045
# Epoch 174: Train Loss=0.0045, Val Loss=0.0045
# Epoch 175: Train Loss=0.0044, Val Loss=0.0045
# Epoch 176: Train Loss=0.0045, Val Loss=0.0045
# Epoch 177: Train Loss=0.0045, Val Loss=0.0045
# Epoch 178: Train Loss=0.0044, Val Loss=0.0044
# Epoch 179: Train Loss=0.0043, Val Loss=0.0044
# Epoch 180: Train Loss=0.0043, Val Loss=0.0044
# Epoch 181: Train Loss=0.0043, Val Loss=0.0044
# Epoch 182: Train Loss=0.0043, Val Loss=0.0044
# Epoch 183: Train Loss=0.0043, Val Loss=0.0044
# Epoch 184: Train Loss=0.0043, Val Loss=0.0043
# Epoch 185: Train Loss=0.0043, Val Loss=0.0043
# Epoch 186: Train Loss=0.0043, Val Loss=0.0044
# Epoch 187: Train Loss=0.0043, Val Loss=0.0043
# Epoch 188: Train Loss=0.0043, Val Loss=0.0043
# Epoch 189: Train Loss=0.0043, Val Loss=0.0043
# Epoch 190: Train Loss=0.0043, Val Loss=0.0043
# Epoch 191: Train Loss=0.0043, Val Loss=0.0043
# Epoch 192: Train Loss=0.0043, Val Loss=0.0043
# Epoch 193: Train Loss=0.0043, Val Loss=0.0044
# Epoch 194: Train Loss=0.0043, Val Loss=0.0043
# Epoch 195: Train Loss=0.0043, Val Loss=0.0044
# Epoch 196: Train Loss=0.0043, Val Loss=0.0043
# Epoch 197: Train Loss=0.0043, Val Loss=0.0043
# Epoch 198: Train Loss=0.0043, Val Loss=0.0043
# Epoch 199: Train Loss=0.0043, Val Loss=0.0043
# Epoch 200: Train Loss=0.0043, Val Loss=0.0043
# Epoch 201: Train Loss=0.0043, Val Loss=0.0043
# Epoch 202: Train Loss=0.0043, Val Loss=0.0043
# Epoch 203: Train Loss=0.0043, Val Loss=0.0043
# Epoch 204: Train Loss=0.0043, Val Loss=0.0043
# Epoch 205: Train Loss=0.0043, Val Loss=0.0043
# Epoch 206: Train Loss=0.0043, Val Loss=0.0043
# Epoch 207: Train Loss=0.0043, Val Loss=0.0044
# Epoch 208: Train Loss=0.0043, Val Loss=0.0043
# Epoch 209: Train Loss=0.0043, Val Loss=0.0043
# Epoch 210: Train Loss=0.0043, Val Loss=0.0043
# Epoch 211: Train Loss=0.0043, Val Loss=0.0044
# Epoch 212: Train Loss=0.0043, Val Loss=0.0043
# Epoch 213: Train Loss=0.0043, Val Loss=0.0043
# Epoch 214: Train Loss=0.0042, Val Loss=0.0043
# Epoch 215: Train Loss=0.0043, Val Loss=0.0043
# Epoch 216: Train Loss=0.0042, Val Loss=0.0043
# Epoch 217: Train Loss=0.0043, Val Loss=0.0044
# Epoch 218: Train Loss=0.0042, Val Loss=0.0043
# Epoch 219: Train Loss=0.0042, Val Loss=0.0043
# Epoch 220: Train Loss=0.0042, Val Loss=0.0043
# Epoch 221: Train Loss=0.0042, Val Loss=0.0043
# Epoch 222: Train Loss=0.0042, Val Loss=0.0043
# Epoch 223: Train Loss=0.0042, Val Loss=0.0043
# Epoch 224: Train Loss=0.0042, Val Loss=0.0043
# Epoch 225: Train Loss=0.0042, Val Loss=0.0043
# Epoch 226: Train Loss=0.0042, Val Loss=0.0043
# Epoch 227: Train Loss=0.0042, Val Loss=0.0043
# Epoch 228: Train Loss=0.0042, Val Loss=0.0043
# Epoch 229: Train Loss=0.0042, Val Loss=0.0043
# Epoch 230: Train Loss=0.0042, Val Loss=0.0043
# Epoch 231: Train Loss=0.0042, Val Loss=0.0043
# Epoch 232: Train Loss=0.0042, Val Loss=0.0043
# Epoch 233: Train Loss=0.0042, Val Loss=0.0043
# Epoch 234: Train Loss=0.0042, Val Loss=0.0043
# Epoch 235: Train Loss=0.0042, Val Loss=0.0043
# Epoch 236: Train Loss=0.0042, Val Loss=0.0043
# Epoch 237: Train Loss=0.0042, Val Loss=0.0043
# Epoch 238: Train Loss=0.0042, Val Loss=0.0043
# Epoch 239: Train Loss=0.0042, Val Loss=0.0043
# Epoch 240: Train Loss=0.0042, Val Loss=0.0043
# Epoch 241: Train Loss=0.0042, Val Loss=0.0043
# Epoch 242: Train Loss=0.0042, Val Loss=0.0043
# Epoch 243: Train Loss=0.0042, Val Loss=0.0042
# Epoch 244: Train Loss=0.0042, Val Loss=0.0043
# Epoch 245: Train Loss=0.0042, Val Loss=0.0043
# Epoch 246: Train Loss=0.0042, Val Loss=0.0043
# Epoch 247: Train Loss=0.0042, Val Loss=0.0043
# Epoch 248: Train Loss=0.0042, Val Loss=0.0043
# Epoch 249: Train Loss=0.0042, Val Loss=0.0043
# Epoch 250: Train Loss=0.0042, Val Loss=0.0043
# Epoch 251: Train Loss=0.0042, Val Loss=0.0043
# Epoch 252: Train Loss=0.0042, Val Loss=0.0043
# Epoch 253: Train Loss=0.0041, Val Loss=0.0043
# Epoch 254: Train Loss=0.0042, Val Loss=0.0043
# Epoch 255: Train Loss=0.0041, Val Loss=0.0042
# Epoch 256: Train Loss=0.0041, Val Loss=0.0043
# Epoch 257: Train Loss=0.0041, Val Loss=0.0043
# Epoch 258: Train Loss=0.0041, Val Loss=0.0042
# Epoch 259: Train Loss=0.0041, Val Loss=0.0042
# Epoch 260: Train Loss=0.0041, Val Loss=0.0042
# Epoch 261: Train Loss=0.0041, Val Loss=0.0042
# Epoch 262: Train Loss=0.0041, Val Loss=0.0042
# Epoch 263: Train Loss=0.0041, Val Loss=0.0042
# Epoch 264: Train Loss=0.0041, Val Loss=0.0043
# Epoch 265: Train Loss=0.0041, Val Loss=0.0042
# Epoch 266: Train Loss=0.0041, Val Loss=0.0043
# Epoch 267: Train Loss=0.0041, Val Loss=0.0043
# Epoch 268: Train Loss=0.0041, Val Loss=0.0042
# Epoch 269: Train Loss=0.0041, Val Loss=0.0043
# Epoch 270: Train Loss=0.0041, Val Loss=0.0042
# Epoch 271: Train Loss=0.0041, Val Loss=0.0043
# Epoch 272: Train Loss=0.0041, Val Loss=0.0042
# Epoch 273: Train Loss=0.0041, Val Loss=0.0042
# Epoch 274: Train Loss=0.0041, Val Loss=0.0042
# Epoch 275: Train Loss=0.0041, Val Loss=0.0042
# Epoch 276: Train Loss=0.0041, Val Loss=0.0042
# Epoch 277: Train Loss=0.0041, Val Loss=0.0042
# Epoch 278: Train Loss=0.0041, Val Loss=0.0043
# Epoch 279: Train Loss=0.0041, Val Loss=0.0042
# Epoch 280: Train Loss=0.0041, Val Loss=0.0042
# Epoch 281: Train Loss=0.0041, Val Loss=0.0042
# Epoch 282: Train Loss=0.0041, Val Loss=0.0042
# Epoch 283: Train Loss=0.0041, Val Loss=0.0042
# Epoch 284: Train Loss=0.0041, Val Loss=0.0042
# Epoch 285: Train Loss=0.0041, Val Loss=0.0042
# Epoch 286: Train Loss=0.0041, Val Loss=0.0042
# Epoch 287: Train Loss=0.0041, Val Loss=0.0042
# Epoch 288: Train Loss=0.0041, Val Loss=0.0042
# Epoch 289: Train Loss=0.0041, Val Loss=0.0042
# Epoch 290: Train Loss=0.0041, Val Loss=0.0042
# Epoch 291: Train Loss=0.0041, Val Loss=0.0042
# Epoch 292: Train Loss=0.0041, Val Loss=0.0042
# Epoch 293: Train Loss=0.0041, Val Loss=0.0042
# Epoch 294: Train Loss=0.0041, Val Loss=0.0042
# Epoch 295: Train Loss=0.0041, Val Loss=0.0042
# Epoch 296: Train Loss=0.0041, Val Loss=0.0042
# Epoch 297: Train Loss=0.0041, Val Loss=0.0042
# Epoch 298: Train Loss=0.0041, Val Loss=0.0042
# Epoch 299: Train Loss=0.0041, Val Loss=0.0042
# Epoch 300: Train Loss=0.0041, Val Loss=0.0042
# Epoch 301: Train Loss=0.0041, Val Loss=0.0042
# Epoch 302: Train Loss=0.0041, Val Loss=0.0042
# Epoch 303: Train Loss=0.0041, Val Loss=0.0042
# Epoch 304: Train Loss=0.0041, Val Loss=0.0042
# Epoch 305: Train Loss=0.0041, Val Loss=0.0042
# Epoch 306: Train Loss=0.0041, Val Loss=0.0042
# Epoch 307: Train Loss=0.0041, Val Loss=0.0042
# Epoch 308: Train Loss=0.0041, Val Loss=0.0042
# Epoch 309: Train Loss=0.0041, Val Loss=0.0042
# Epoch 310: Train Loss=0.0041, Val Loss=0.0042
# Epoch 311: Train Loss=0.0041, Val Loss=0.0042
# Epoch 312: Train Loss=0.0041, Val Loss=0.0042
# Epoch 313: Train Loss=0.0041, Val Loss=0.0042
# Epoch 314: Train Loss=0.0041, Val Loss=0.0042
# Epoch 315: Train Loss=0.0041, Val Loss=0.0042
# Epoch 316: Train Loss=0.0041, Val Loss=0.0042
# Epoch 317: Train Loss=0.0041, Val Loss=0.0042
# Epoch 318: Train Loss=0.0041, Val Loss=0.0042
# Epoch 319: Train Loss=0.0041, Val Loss=0.0042
# Epoch 320: Train Loss=0.0041, Val Loss=0.0042
# Epoch 321: Train Loss=0.0041, Val Loss=0.0042
# Epoch 322: Train Loss=0.0041, Val Loss=0.0042
# Epoch 323: Train Loss=0.0041, Val Loss=0.0042
# Epoch 324: Train Loss=0.0041, Val Loss=0.0042
# Epoch 325: Train Loss=0.0041, Val Loss=0.0042
# Epoch 326: Train Loss=0.0041, Val Loss=0.0042
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 27
#      23 true_contacts = batch.y.squeeze(-1)
#      25 mask = batch.edge_mask #& batch.pair_mask
# ---> 27 loss = loss_fn(pred_logits[mask], true_contacts[mask])
#      29 n_edges = mask.sum().item()
#      30 total_loss += loss.item() * n_edges
#
# File ~/miniconda3/envs/Internship/lib/python3.14/site-packages/torch/nn/modules/module.py:1772, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1769             tracing_state.pop_scope()
#    1770     return result
# -> 1772 def _wrapped_call_impl(self, *args, **kwargs):
#    1773     if self._compiled_call_impl is not None:
#    1774         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
print(optimizer.param_groups[0]['lr'])
# Out:
# 1.5625e-05

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


model = MP_GNN(
    num_layers=4,
    num_heads=4,
    node_in_dim=16,
    edge_in_dim=1,
    latent_dim=64
).to(device)


save_path = "best_model_cc_likeDCA_sep0_attention_Federico.pt"

state_dict = torch.load(save_path)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
#ROC and Precision-Recall curve

model.eval()

all_probs = []
all_true = []

for batch in test_loader:
    batch = batch.to(device)

    with torch.no_grad():
        pred_logits = model(batch)
        probs = torch.sigmoid(pred_logits.squeeze(-1))

    true_contacts = batch.y.squeeze(-1)
    mask = batch.edge_mask & batch.pair_mask

    all_probs.append(probs[mask].cpu())
    all_true.append(true_contacts[mask].cpu())

all_probs = torch.cat(all_probs)
all_true = torch.cat(all_true)


# compute ROC
fpr, tpr, _ = roc_curve(all_true, all_probs)
roc_auc = auc(fpr, tpr)

print("Validation ROC AUC GNN:", roc_auc)


plt.figure()
plt.plot(fpr, tpr, label=f"GNN (AUC={roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()

#compute PR

precision, recall, _ = precision_recall_curve(all_true, all_probs)
pr_auc = auc(recall, precision)


print("PR AUC GNN:", pr_auc)


plt.figure()
plt.plot(recall, precision, label=f"PR AUC GNN = {pr_auc:.3f}")
plt.plot([1, 0], [0, 1], linestyle='--')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()

plt.show()
# Out:
# Validation ROC AUC GNN: 0.997750713614472
# PR AUC GNN: 0.9634435947132249
# /home/fabio/miniconda3/envs/Internship/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("Top-k*L precision:", topk_L_precision(model, test_loader, device, ratio=5)[0])
# Out:
# Top-k*L precision: 0.9872918451743269

# %%
#precision in function of the number of contact to predict

total_k=np.linspace(0.1,10,10)
p_GNN=[]

for k in total_k:
    prec=[]

    for batch in test_loader:
        batch = batch.to(device)

        #accuracy for a single batch
        with torch.no_grad():
            pred_logits = model(batch)
            scores = torch.sigmoid(pred_logits.squeeze(-1))
            

        mask = batch.edge_mask & batch.pair_mask
        scores = scores[mask]

        true_contacts = batch.y.squeeze(-1)[mask]

        L = batch.L
        topk = int(k * L)

        topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices


        topk_true = true_contacts[topk_idx]


        num_correct = topk_true.sum()
        precision = (num_correct / len(topk_true)).item()
        prec.append(precision)


    p_GNN.append(np.mean(prec))

plt.figure()

plt.plot(total_k, p_GNN, label=f"Precision GNN")


plt.xlabel("k")
plt.ylabel("Precision")
plt.title("Precision of the top k*L contacts")
plt.legend()

plt.show()

# %%
k_values = [1,2,5]
results = {k: [] for k in k_values}
for k in k_values:
    vals= topk_L_precision(model, test_loader, device, ratio=k)[1]
    results[k].extend(vals)

for k in k_values:
    plt.hist(results[k], bins=40, histtype='step',linewidth=2, label=f"GNN k={k}")


plt.legend()
plt.title("Precision@kL distributions")
plt.show()

# %%
164573669, 0.9971631169319153, 0.98740154504776, 0.9922581315040588, 0.9927083849906921, 0.9946612119674683, 0.9657142758369446, 0.997183084487915, 0.9870967268943787, 0.9889285564422607, 0.9949367046356201, 0.9930894374847412, 0.9820224642753601, 0.9920374751091003, 0.9853846430778503, 0.9859259128570557, 0.9963218569755554, 0.9830188751220703, 0.9988165497779846, 0.9860278964042664, 0.9916216731071472, 0.9964044690132141, 0.9925925731658936, 0.9910000562667847, 0.9828685522079468, 0.9723076820373535, 0.9893719553947449, 1.0, 0.9970588684082031, 0.9944444894790649, 0.995918333530426, 0.982677161693573, 0.9982456564903259, 0.9868354201316833, 1.0, 0.9738515615463257, 0.995555579662323, 0.9832935929298401, 0.9949790835380554, 0.9981220960617065, 0.9978947043418884, 0.9854604601860046, 0.9949367046356201, 0.9871313571929932, 0.9827309250831604, 0.9988826513290405, 0.9854369163513184, 0.9957142472267151, 0.9978947043418884, 0.9947858452796936, 0.9956521391868591, 0.9933109879493713, 0.995505630970001 ...
# 1.0
# 6

# %%
pos=6
#best case

i=0
with torch.no_grad():
    for batch in test_loader:
        if i==pos:
            batch = batch.to(device)
            pred_logits = model(batch)
        i+=1

batch=test_data[pos]
print(batch)



scores = torch.sigmoid(pred_logits.squeeze(-1))
# threshold=0.8
# scores= (scores>= threshold).float()
pred_contact_map = graph_to_matrix(batch, scores.cpu())
true_contact_map = graph_to_matrix(batch, batch.y.cpu())
noisy_contact_map = graph_to_matrix(batch, batch.edge_attr.cpu())



fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns

# --- Predicted Distance Map ---
im0 = axes[0].imshow(pred_contact_map, cmap='coolwarm_r', origin='lower')
axes[0].set_title("Predicted Contact Map")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# --- True Distance Map ---
im1 = axes[1].imshow(true_contact_map, cmap='coolwarm_r', origin='lower')
axes[1].set_title("True Contact Map")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# --- Original Noisy Contact Map ---
im2 = axes[2].imshow(noisy_contact_map, cmap='coolwarm_r', origin='lower')
axes[2].set_title("Noisy Contact Map")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Data(x=[74, 16], edge_index=[2, 5402], edge_attr=[5402, 1], y=[5402, 1], edge_mask=[5402], pair_mask=[5402], L=74)

# %% [markdown]
# Now we can test this on real DCA data

# %%
#test on DCA data

folder_path = folder_DCA

dca_data = []
for file in os.listdir(folder_path):
    if file.endswith(".pkl"):
        full_path = os.path.join(folder_path, file)
        
        with open(full_path, "rb") as f:
            loaded = pickle.load(f)

        sequence=loaded['sequence']
        distance_map=loaded['distance_map']
        contact_map_DCA=loaded['dca']

        #each DCA score is transformed into a contact map with 5L contacts
        k = 5*len(sequence)  
        binary_map = top_k_mask(contact_map_DCA, k)
        
        data = build_graph_contact(binary_map, distance_map)
        
        dca_data.append(data)

test_dca_loader = DataLoader(dca_data, batch_size=1, shuffle=False)

# %%
#DCA scores
all_scores = []
all_labels = []

min_sep=minimum_separation

folder_path = folder_DCA
for file in os.listdir(folder_path):
    if file.endswith(".pkl"):
        with open(os.path.join(folder_path, file), "rb") as f:
            loaded = pickle.load(f)

        sequence = loaded['sequence']
        distance_map = loaded['distance_map']
        contact_map_DCA = loaded['dca']

        true_contact_map = contact_from_distance(distance_map, threshold=8.0)
        
        L = len(sequence)
        i, j = np.indices((L, L))

        mask = (np.isfinite(distance_map) & (np.abs(i - j) >= min_sep) & (i < j)) 
        # Flatten
        scores = contact_map_DCA[mask].flatten()
        labels = true_contact_map[mask].flatten()

        all_scores.append(scores)
        all_labels.append(labels)

all_scores = np.concatenate(all_scores)
all_labels = np.concatenate(all_labels)


#Model scores
model.eval()

all_probs = []
all_true = []

for batch in test_dca_loader:
    batch = batch.to(device)

    with torch.no_grad():
        pred_logits = model(batch)
        probs = torch.sigmoid(pred_logits.squeeze(-1))

    true_contacts = batch.y.squeeze(-1)
    mask = batch.edge_mask & batch.pair_mask
  


    all_probs.append(probs[mask].cpu())
    all_true.append(true_contacts[mask].cpu())

all_probs = torch.cat(all_probs)
all_true = torch.cat(all_true)



# compute ROC
fpr, tpr, _ = roc_curve(all_true, all_probs)
roc_auc = auc(fpr, tpr)


print("Validation ROC AUC GNN:", roc_auc)


fpr_dca, tpr_dca, _ = roc_curve(all_labels, all_scores)
roc_auc_dca = auc(fpr_dca, tpr_dca)


print("Validation ROC AUC DCA:", roc_auc_dca)


plt.figure()

plt.plot(fpr, tpr, label=f"GNN (AUC={roc_auc:.3f})")
plt.plot(fpr_dca, tpr_dca, label=f"DCA (AUC={roc_auc_dca:.3f})")


plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()

plt.show()

#compute PR

precision, recall, _ = precision_recall_curve(all_true, all_probs)
pr_auc = auc(recall, precision)


print("PR AUC GNN:", pr_auc)



precision_dca, recall_dca, _ = precision_recall_curve(all_labels, all_scores)
pr_auc_dca = auc(recall_dca, precision_dca)


print("PR AUC DCA:", pr_auc_dca)

plt.figure()
plt.plot(recall, precision, label=f"PR AUC GNN = {pr_auc:.3f}")
plt.plot(recall_dca, precision_dca, label=f"PR AUC DCA = {pr_auc_dca:.3f}")
plt.plot([1, 0], [0, 1], linestyle='--')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()

plt.show()
# Out:
# Validation ROC AUC GNN: 0.5060706469145168
# Validation ROC AUC DCA: 0.7278826305419349
# /home/fabio/miniconda3/envs/Internship/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# PR AUC GNN: 0.2977859755783137
# PR AUC DCA: 0.40158430373699566
# /home/fabio/miniconda3/envs/Internship/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#precision for the GNN and DCA

#GNN precision
k=2

prec=[]

for batch in test_dca_loader:
    batch = batch.to(device)

    #accuracy for a single batch
    with torch.no_grad():
        pred_logits = model(batch)
        scores = torch.sigmoid(pred_logits.squeeze(-1))
    

    mask = batch.edge_mask & batch.pair_mask
    scores = scores[mask]
    true_contacts = batch.y.squeeze(-1)[mask]

    L = batch.L
    topk = int(k * L)

    topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

    topk_true = true_contacts[topk_idx]

    num_correct = topk_true.sum()
    precision = (num_correct / len(topk_true)).item()
    prec.append(precision)
print(np.mean(prec))


#DCA precision
prec_dca=[]
min_sep = minimum_separation
folder_path=folder_DCA
for file in os.listdir(folder_path):
    if file.endswith(".pkl"):
        with open(os.path.join(folder_path, file), "rb") as f:
            loaded = pickle.load(f)

        sequence = loaded['sequence']
        distance_map = loaded['distance_map']
        contact_map_DCA = loaded['dca']

        true_contact_map = contact_from_distance(distance_map, threshold=8.0)
        
        L = len(sequence)
        i, j = np.indices((L, L))

        mask = (np.isfinite(distance_map) & (np.abs(i - j) >= min_sep) & (i < j)) 
        # Flatten and go to torch
        scores = torch.tensor(contact_map_DCA[mask].flatten(), dtype=torch.float)
        labels = torch.tensor(true_contact_map[mask].flatten(), dtype=torch.float)

        topk = int(k * L)

        topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

        topk_true = labels[topk_idx]

        num_correct = topk_true.sum()
        precision = (num_correct / len(topk_true)).item()
        prec_dca.append(precision)
print(np.mean(prec_dca))
# Out:
# 0.7960430865893755
# 0.7527846958796082

# %%
#for the GNN it's possible to obtain the same with the function topk_L_precision
k=2

print("Top-k*L precision GNN:", topk_L_precision(model, test_dca_loader, device, ratio=k)[0])
# Out:
# Top-k*L precision GNN: 0.7960430865893755

# %%
#precision in function of the number of contact to predict
total_k=np.linspace(0.1,10,10)
p_GNN=[]
p_DCA=[]
for k in total_k:

    #GNN    
    prec=[]

    for batch in test_dca_loader:
        batch = batch.to(device)

        #accuracy for a single batch
        with torch.no_grad():
            pred_logits = model(batch)
            scores = torch.sigmoid(pred_logits.squeeze(-1))
        

        mask = batch.edge_mask & batch.pair_mask
        scores = scores[mask]
        true_contacts = batch.y.squeeze(-1)[mask]

        L = batch.L
        topk = int(k * L)

        topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

        topk_true = true_contacts[topk_idx]

        num_correct = topk_true.sum()
        precision = (num_correct / len(topk_true)).item()
        prec.append(precision)
    
    p_GNN.append(np.mean(prec))

    #DCA

    prec_dca=[]


    min_sep=minimum_separation

    folder_path=folder_DCA
    for file in os.listdir(folder_path):
        if file.endswith(".pkl"):
            with open(os.path.join(folder_path, file), "rb") as f:
                loaded = pickle.load(f)

            sequence = loaded['sequence']
            distance_map = loaded['distance_map']
            contact_map_DCA = loaded['dca']

            true_contact_map = contact_from_distance(distance_map, threshold=8.0)
            
            L = len(sequence)
            i, j = np.indices((L, L))

            mask = (np.isfinite(distance_map) & (np.abs(i - j) >= min_sep) & (i < j)) 
            # Flatten and go to torch
            scores = torch.tensor(contact_map_DCA[mask].flatten(), dtype=torch.float)
            labels = torch.tensor(true_contact_map[mask].flatten(), dtype=torch.float)

            topk = int(k * L)

            topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

            topk_true = labels[topk_idx]

            num_correct = topk_true.sum()
            precision = (num_correct / len(topk_true)).item()
            prec_dca.append(precision)

    p_DCA.append(np.mean(prec_dca))
    

plt.figure()

plt.plot(total_k, p_GNN, label=f"Precision GNN")
plt.plot(total_k, p_DCA, label=f"Precision DCA")


plt.xlabel("k")
plt.ylabel("Precision")
plt.title("Precision of the top k*L contacts")
plt.legend()

plt.show()

# %%
k_values = [1,2,5]
results = {k: [] for k in k_values}
for k in k_values:
    vals= topk_L_precision(model, test_dca_loader, device, ratio=k)[1]
    results[k].extend(vals)

for k in k_values:
    plt.hist(results[k], bins=40, histtype='step',linewidth=2, label=f"GNN k={k}")


plt.legend()
plt.title("Precision@kL distributions")
plt.show()

# %%
k=1
precision= topk_L_precision(model, test_dca_loader, device, ratio=k)[1]
print(precision)
print(min(precision))
print(precision.index(min(precision)))
print(max(precision))
print(precision.index(max(precision)))
# Out:
# [1.0, 0.9811320900917053, 1.0, 1.0, 0.8333333730697632, 0.925000011920929, 1.0, 1.0, 1.0, 1.0, 0.9819819927215576, 1.0, 1.0, 0.6761904954910278, 1.0, 0.9415692687034607, 1.0, 0.9736841917037964, 1.0, 0.9968253970146179, 0.9999999403953552, 1.0, 1.0, 1.0, 1.0, 0.9923664331436157, 0.9999999403953552, 0.9793103337287903, 0.29336732625961304, 0.8727272748947144, 0.8271604776382446, 0.9999999403953552, 0.9999999403953552, 1.0, 1.0, 0.9924812316894531, 0.875, 0.9767441749572754, 0.994736909866333, 0.8325581550598145, 0.9812206625938416, 1.0, 0.9954128265380859, 0.9591001868247986, 0.9912790656089783, 1.0, 0.9710144996643066, 0.9980582594871521, 0.9880000352859497, 0.9999999403953552, 0.7453874349594116, 1.0, 0.9817629456520081, 1.0, 0.9774435758590698, 0.9935064911842346, 0.805343508720398, 0.9683544635772705, 0.7777777910232544, 0.9796954393386841, 0.9947230219841003, 0.800000011920929, 0.9285714626312256, 0.8817204236984253, 0.9919354319572449, 0.9940828680992126, 1.0, 1.0, 1.0,
# 0.07942238450050354
# 1141
# 1.0
# 0

# %%
pos=0


i=0
with torch.no_grad():
    for batch in test_dca_loader:
        if i==pos:
            batch = batch.to(device)
            pred_logits = model(batch)
        i+=1

batch=dca_data[pos]
print(batch)

mask = batch.edge_mask #& batch.pair_mask

scores = torch.sigmoid(pred_logits.squeeze(-1))
# threshold=0.9
# scores= (scores>= threshold).float()
pred_contact_map = graph_to_matrix(batch, scores.cpu())
true_contact_map = graph_to_matrix(batch, batch.y.cpu())
noisy_contact_map_map = graph_to_matrix(batch, batch.edge_attr.cpu())



fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 1 row, 3 columns

# --- Predicted Distance Map ---
im0 = axes[0].imshow(pred_contact_map, cmap='coolwarm_r', origin='lower')
axes[0].set_title("Predicted Contact Map")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# --- True Distance Map ---
im1 = axes[1].imshow(true_contact_map, cmap='coolwarm_r', origin='lower')
axes[1].set_title("True Contact Map")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# --- Original Noisy Contact Map ---
im2 = axes[2].imshow(noisy_contact_map_map, cmap='coolwarm_r', origin='lower')
axes[2].set_title("Noisy Contact Map")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Data(x=[65, 16], edge_index=[2, 4160], edge_attr=[4160, 1], y=[4160, 1], edge_mask=[4160], pair_mask=[4160], L=65)

# %%
#we want to see if the prediction for not near-diagonal terms have been improved or not
min_sep = 5

total_k=np.linspace(0.5,10,10)
p_GNN=[]
p_DCA=[]

for k in total_k:


    prec = []

    for batch in test_dca_loader:
        batch = batch.to(device)

        with torch.no_grad():
            pred_logits = model(batch)
            scores = torch.sigmoid(pred_logits.squeeze(-1))
            
        # keep only valid pairs and exclude diagonal / near-diagonal pairs
        sep_mask = (batch.edge_index[0] - batch.edge_index[1]).abs() >= min_sep
        upper_mask = batch.edge_index[0] < batch.edge_index[1]
        mask = batch.edge_mask & batch.pair_mask & sep_mask & upper_mask

        scores = scores[mask]
        true_contacts = batch.y.squeeze(-1)[mask]

        L = batch.L
        topk = int(k * L)

        if scores.numel() == 0:
            continue

        topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

        topk_true = true_contacts[topk_idx]


        precision = topk_true.float().mean().item() if len(topk_true) > 0 else 0.0


        prec.append(precision)


    p_GNN.append(np.mean(prec))


    prec=[]
    folder_path=folder_DCA
    for file in os.listdir(folder_path):
        if file.endswith(".pkl"):
            with open(os.path.join(folder_path, file), "rb") as f:
                loaded = pickle.load(f)

            sequence = loaded['sequence']
            distance_map = loaded['distance_map']
            contact_map_DCA = loaded['dca']

            true_contact_map = contact_from_distance(distance_map, threshold=8.0)
            
            L = len(sequence)
            i, j = np.indices((L, L))

            mask = (np.isfinite(distance_map) & (np.abs(i - j) >= min_sep) & (i < j)) 
            # Flatten
            scores = torch.tensor(contact_map_DCA[mask].flatten())
            labels = torch.tensor(true_contact_map[mask].flatten())

            topk = int(k * L)

            topk_idx = torch.topk(scores, k=min(topk, scores.numel())).indices

            topk_true = labels[topk_idx]

            precision = topk_true.float().mean().item() if len(topk_true) > 0 else 0.0

            prec.append(precision)


    p_DCA.append(np.mean(prec))
    

plt.figure()

plt.plot(total_k, p_GNN, label=f"Precision GNN")
plt.plot(total_k, p_DCA, label=f"Precision DCA")


plt.xlabel("k")
plt.ylabel("Precision")
plt.title("Precision of the top non trivial k*L contacts")
plt.legend()

plt.show()
